# %%
# Library
import numpy as np
import pandas as pd
import threading
from sklearn.feature_selection import (chi2, f_classif, mutual_info_classif, VarianceThreshold, RFE, SequentialFeatureSelector, SelectFromModel)
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from deap import base, creator, tools, algorithms  # For genetic algorithm in feature selection
from boruta import BorutaPy  # For Boruta algorithm
from sklearn.svm import SVR  # Example estimator for RFE and SFS
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
# Input Dataset 

DM1 = pd.read_parquet("C:\\Data Raihan\\Penelitian Threshold\\Dataset\\CCCS-CIC-AndMal-2020\\cicandmal2020-dynamic.parquet") #DM--> Dataset Malware 1
DM2 = pd.read_parquet("C:\\Data Raihan\\Penelitian Threshold\\Dataset\\CCCS-CIC-AndMal-2020\\cicandmal2020-static.parquet") #DM--> Dataset Malware 2

# %%
DM1.info('display.max_columns', None)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53439 entries, 0 to 53438
# Data columns (total 145 columns):
#  #    Column                                                                              Dtype
# ---   ------                                                                              -----
#  0    Memory_PssTotal                                                                     int32
#  1    Memory_PssClean                                                                     int32
#  2    Memory_SharedDirty                                                                  int32
#  3    Memory_PrivateDirty                                                                 int32
#  4    Memory_SharedClean                                                                  int32
#  5    Memory_PrivateClean                                                                 int32
#  6    Memory_SwapPssDirty                                                                 int8
#  7    Memory_HeapSize                                                                     int32
#  8    Memory_HeapAlloc                                                                    int32
#  9    Memory_HeapFree                                                                     int32
#  10   Memory_Views                                                                        int16
#  11   Memory_ViewRootImpl                                                                 int16
#  12   Memory_AppContexts                                                                  int16
#  13   Memory_Activities                                                                   int16
#  14   Memory_Assets                                                                       int8
#  15   Memory_AssetManagers                                                                int8
#  16   Memory_LocalBinders                                                                 int16
#  17   Memory_ProxyBinders                                                                 int16
#  18   Memory_ParcelMemory                                                                 int16
#  19   Memory_ParcelCount                                                                  int16
#  20   Memory_DeathRecipients                                                              int8
#  21   Memory_OpenSSLSockets                                                               int8
#  22   Memory_WebViews                                                                     int8
#  23   API_Process_android.os.Process_start                                                int8
#  24   API_Process_android.app.ActivityManager_killBackgroundProcesses                     int16
#  25   API_Process_android.os.Process_killProcess                                          int16
#  26   API_Command_java.lang.Runtime_exec                                                  int16
#  27   API_Command_java.lang.ProcessBuilder_start                                          int16
#  28   API_JavaNativeInterface_java.lang.Runtime_loadLibrary                               int8
#  29   API_JavaNativeInterface_java.lang.Runtime_load                                      int8
#  30   API_WebView_android.webkit.WebView_loadUrl                                          int16
#  31   API_WebView_android.webkit.WebView_loadData                                         int8
#  32   API_WebView_android.webkit.WebView_loadDataWithBaseURL                              int16
#  33   API_WebView_android.webkit.WebView_addJavascriptInterface                           int16
#  34   API_WebView_android.webkit.WebView_evaluateJavascript                               int16
#  35   API_WebView_android.webkit.WebView_postUrl                                          int8
#  36   API_WebView_android.webkit.WebView_postWebMessage                                   int8
#  37   API_WebView_android.webkit.WebView_savePassword                                     int8
#  38   API_WebView_android.webkit.WebView_setHttpAuthUsernamePassword                      int8
#  39   API_WebView_android.webkit.WebView_getHttpAuthUsernamePassword                      int8
#  40   API_WebView_android.webkit.WebView_setWebContentsDebuggingEnabled                   int16
#  41   API_FileIO_libcore.io.IoBridge_open                                                 int16
#  42   API_FileIO_android.content.ContextWrapper_openFileInput                             int16
#  43   API_FileIO_android.content.ContextWrapper_openFileOutput                            int16
#  44   API_FileIO_android.content.ContextWrapper_deleteFile                                int8
#  45   API_Database_android.content.ContextWrapper_openOrCreateDatabase                    int16
#  46   API_Database_android.content.ContextWrapper_databaseList                            int8
#  47   API_Database_android.content.ContextWrapper_deleteDatabase                          int8
#  48   API_Database_android.database.sqlite.SQLiteDatabase_execSQL                         int16
#  49   API_Database_android.database.sqlite.SQLiteDatabase_deleteDatabase                  int8
#  50   API_Database_android.database.sqlite.SQLiteDatabase_getPath                         int16
#  51   API_Database_android.database.sqlite.SQLiteDatabase_insert                          int16
#  52   API_Database_android.database.sqlite.SQLiteDatabase_insertOrThrow                   int16
#  53   API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict            int16
#  54   API_Database_android.database.sqlite.SQLiteDatabase_openDatabase                    int16
#  55   API_Database_android.database.sqlite.SQLiteDatabase_openOrCreateDatabase            int16
#  56   API_Database_android.database.sqlite.SQLiteDatabase_query                           int16
#  57   API_Database_android.database.sqlite.SQLiteDatabase_queryWithFactory                int16
#  58   API_Database_android.database.sqlite.SQLiteDatabase_rawQuery                        int16
#  59   API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory             int16
#  60   API_Database_android.database.sqlite.SQLiteDatabase_update                          int16
#  61   API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict            int16
#  62   API_Database_android.database.sqlite.SQLiteDatabase_compileStatement                int16
#  63   API_Database_android.database.sqlite.SQLiteDatabase_create                          int8
#  64   API_IPC_android.content.ContextWrapper_sendBroadcast                                int16
#  65   API_IPC_android.content.ContextWrapper_sendStickyBroadcast                          int8
#  66   API_IPC_android.content.ContextWrapper_startActivity                                int16
#  67   API_IPC_android.content.ContextWrapper_startService                                 int16
#  68   API_IPC_android.content.ContextWrapper_stopService                                  int8
#  69   API_IPC_android.content.ContextWrapper_registerReceiver                             int16
#  70   API_Binder_android.app.ContextImpl_registerReceiver                                 int16
#  71   API_Binder_android.app.ActivityThread_handleReceiver                                int16
#  72   API_Binder_android.app.Activity_startActivity                                       int16
#  73   API_Crypto_javax.crypto.spec.SecretKeySpec_$init                                    int32
#  74   API_Crypto_javax.crypto.Cipher_doFinal                                              int16
#  75   API_Crypto-Hash_java.security.MessageDigest_digest                                  int16
#  76   API_Crypto-Hash_java.security.MessageDigest_update                                  int32
#  77   API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId                       int16
#  78   API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId                   int16
#  79   API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number                    int16
#  80   API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperator                int16
#  81   API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperatorName            int16
#  82   API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName                int16
#  83   API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress                              int16
#  84   API_DeviceInfo_android.net.wifi.WifiInfo_getBSSID                                   int16
#  85   API_DeviceInfo_android.net.wifi.WifiInfo_getIpAddress                               int16
#  86   API_DeviceInfo_android.net.wifi.WifiInfo_getNetworkId                               int16
#  87   API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso                  int16
#  88   API_DeviceInfo_android.telephony.TelephonyManager_getSimSerialNumber                int16
#  89   API_DeviceInfo_android.telephony.TelephonyManager_getNetworkCountryIso              int16
#  90   API_DeviceInfo_android.telephony.TelephonyManager_getDeviceSoftwareVersion          int8
#  91   API_DeviceInfo_android.os.Debug_isDebuggerConnected                                 int16
#  92   API_DeviceInfo_android.content.pm.PackageManager_getInstallerPackageName            int8
#  93   API_DeviceInfo_android.content.pm.PackageManager_getInstalledApplications           int8
#  94   API_DeviceInfo_android.content.pm.PackageManager_getInstalledModules                int8
#  95   API_DeviceInfo_android.content.pm.PackageManager_getInstalledPackages               int8
#  96   API_Network_java.net.URL_openConnection                                             int16
#  97   API_Network_org.apache.http.impl.client.AbstractHttpClient_execute                  int8
#  98   API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream    int16
#  99   API_Network_com.android.okhttp.internal.http.HttpURLConnectionImpl_getInputStream   int8
#  100  API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResource                    int16
#  101  API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResources                   int8
#  102  API_DexClassLoader_dalvik.system.BaseDexClassLoader_findLibrary                     int16
#  103  API_DexClassLoader_dalvik.system.DexFile_loadDex                                    int8
#  104  API_DexClassLoader_dalvik.system.DexFile_loadClass                                  int16
#  105  API_DexClassLoader_dalvik.system.DexClassLoader_$init                               int16
#  106  API_Base64_android.util.Base64_decode                                               int16
#  107  API_Base64_android.util.Base64_encode                                               int16
#  108  API_Base64_android.util.Base64_encodeToString                                       int16
#  109  API_SystemManager_android.app.ApplicationPackageManager_setComponentEnabledSetting  int16
#  110  API_SystemManager_android.app.NotificationManager_notify                            int16
#  111  API_SystemManager_android.telephony.TelephonyManager_listen                         int8
#  112  API_SystemManager_android.content.BroadcastReceiver_abortBroadcast                  int8
#  113  API_SMS_android.telephony.SmsManager_sendTextMessage                                int16
#  114  API_SMS_android.telephony.SmsManager_sendMultipartTextMessage                       int8
#  115  API_DeviceData_android.content.ContentResolver_query                                int16
#  116  API_DeviceData_android.content.ContentResolver_registerContentObserver              int16
#  117  API_DeviceData_android.content.ContentResolver_insert                               int16
#  118  API_DeviceData_android.content.ContentResolver_delete                               int16
#  119  API_DeviceData_android.accounts.AccountManager_getAccountsByType                    int8
#  120  API_DeviceData_android.accounts.AccountManager_getAccounts                          int16
#  121  API_DeviceData_android.location.Location_getLatitude                                int16
#  122  API_DeviceData_android.location.Location_getLongitude                               int16
#  123  API_DeviceData_android.media.AudioRecord_startRecording                             int16
#  124  API_DeviceData_android.media.MediaRecorder_start                                    int8
#  125  API_DeviceData_android.os.SystemProperties_get                                      int16
#  126  API_DeviceData_android.app.ApplicationPackageManager_getInstalledPackages           int16
#  127  API__sessions                                                                       int8
#  128  Network_TotalReceivedBytes                                                          int32
#  129  Network_TotalReceivedPackets                                                        int32
#  130  Network_TotalTransmittedBytes                                                       int32
#  131  Network_TotalTransmittedPackets                                                     int32
#  132  Battery_wakelock                                                                    int8
#  133  Battery_service                                                                     int8
#  134  Logcat_debug                                                                        int32
#  135  Logcat_warning                                                                      int32
#  136  Logcat_info                                                                         int32
#  137  Logcat_verbose                                                                      int32
#  138  Logcat_error                                                                        int32
#  139  Logcat_total                                                                        int32
#  140  Process_total                                                                       int16
#  141  Hash                                                                                object
#  142  Category                                                                            object
#  143  Family                                                                              object
#  144  Label                                                                               object
# dtypes: int16(81), int32(21), int8(39), object(4)
# memory usage: 16.2+ MB

# %%
#Feature Selection
X = DM1.drop(['Hash', 'Family', 'Category','Label'],axis=1).values    #Droping this because classification model will not accept object type elements (float and int only)
# Target variable
y = DM1['Label'].values

# %%
#Remove Nan
X = pd.DataFrame(X).dropna()
y = y[X.index]

# %%
# Store selected features
features = {}

# %%
# Function to print and append selected features
def print_selected_features(method_name, selected_indices, importance=None):
    selected_features = []
    print(f"\n{method_name} Selected Features:")
    for i, idx in enumerate(selected_indices):
        feature_name = DM1.columns[idx]
        if importance is not None:
            print(f"{i + 1}. Feature {feature_name} (Importance: {importance[idx]:.6f})")
        else:
            print(f"{i + 1}. Feature {feature_name}")
        selected_features.append(feature_name)
    features[method_name] = selected_features

# %%
# Apply Min-Max scaling to make X non-negative
scaler = MinMaxScaler()
X_chi2 = scaler.fit_transform(X)

# 1. Chi-Square Test (Filter)
chi2_selector = chi2(X_chi2, y)
chi2_scores = chi2_selector[0]
chi2_top_features = np.argsort(chi2_scores)[::-1][:5]
print_selected_features("Chi-Square", chi2_top_features, chi2_scores)
# Out:
# Chi-Square Selected Features:
# 1. Feature API_DeviceInfo_android.content.pm.PackageManager_getInstallerPackageName (Importance: nan)
# 2. Feature API_Process_android.os.Process_start (Importance: nan)
# 3. Feature API_Database_android.database.sqlite.SQLiteDatabase_create (Importance: nan)
# 4. Feature API_Network_org.apache.http.impl.client.AbstractHttpClient_execute (Importance: nan)
# 5. Feature API_DeviceInfo_android.content.pm.PackageManager_getInstalledPackages (Importance: nan)

# %%
# 2. ANOVA F-test (Filter)

#Identify constant features (ada Constant Features)
constant_features = [col for col in X.columns if X[col].nunique() <= 1]
X_filtered = X.drop(columns=constant_features)

anova_selector = f_classif(X_filtered, y)
anova_scores = anova_selector[0]
anova_top_features = np.argsort(anova_scores)[::-1][:5]
print_selected_features("ANOVA", anova_top_features, anova_scores)
# Out:
# ANOVA Selected Features:
# 1. Feature API_DeviceData_android.os.SystemProperties_get (Importance: 1497.637817)
# 2. Feature API_DeviceData_android.content.ContentResolver_insert (Importance: 681.850159)
# 3. Feature API_Network_org.apache.http.impl.client.AbstractHttpClient_execute (Importance: 441.402008)
# 4. Feature API_IPC_android.content.ContextWrapper_registerReceiver (Importance: 441.354523)
# 5. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso (Importance: 404.332428)

# %%
# 3. Mutual Information (Filter)
mutual_info_scores = mutual_info_classif(X, y)
mutual_info_top_features = np.argsort(mutual_info_scores)[::-1][:5]
print_selected_features("Mutual Information", mutual_info_top_features, mutual_info_scores)
# Out:
# Mutual Information Selected Features:
# 1. Feature Memory_HeapSize (Importance: 0.501720)
# 2. Feature Network_TotalReceivedBytes (Importance: 0.460811)
# 3. Feature Network_TotalTransmittedBytes (Importance: 0.361782)
# 4. Feature Memory_Views (Importance: 0.347938)
# 5. Feature API_Crypto-Hash_java.security.MessageDigest_update (Importance: 0.328526)

# %%
# 4. Variance Threshold (Filter)
vt_selector = VarianceThreshold(threshold=0.1)  # You can adjust the threshold
X_vt = vt_selector.fit_transform(X)
vt_top_features = np.where(vt_selector.get_support())[0]
print_selected_features("Variance Threshold", vt_top_features)
# Out:
# Variance Threshold Selected Features:
# 1. Feature Memory_PssTotal
# 2. Feature Memory_PssClean
# 3. Feature Memory_SharedDirty
# 4. Feature Memory_PrivateDirty
# 5. Feature Memory_SharedClean
# 6. Feature Memory_PrivateClean
# 7. Feature Memory_HeapSize
# 8. Feature Memory_HeapAlloc
# 9. Feature Memory_HeapFree
# 10. Feature Memory_Views
# 11. Feature Memory_ViewRootImpl
# 12. Feature Memory_AppContexts
# 13. Feature Memory_Activities
# 14. Feature Memory_Assets
# 15. Feature Memory_LocalBinders
# 16. Feature Memory_ProxyBinders
# 17. Feature Memory_ParcelMemory
# 18. Feature Memory_ParcelCount
# 19. Feature Memory_DeathRecipients
# 20. Feature Memory_OpenSSLSockets
# 21. Feature Memory_WebViews
# 22. Feature API_Process_android.app.ActivityManager_killBackgroundProcesses
# 23. Feature API_Process_android.os.Process_killProcess
# 24. Feature API_Command_java.lang.Runtime_exec
# 25. Feature API_Command_java.lang.ProcessBuilder_start
# 26. Feature API_WebView_android.webkit.WebView_loadUrl
# 27. Feature API_WebView_android.webkit.WebView_loadData
# 28. Feature API_WebView_android.webkit.WebView_loadDataWithBaseURL
# 29. Feature API_WebView_android.webkit.WebView_addJavascriptInterface
# 30. Feature API_WebView_android.webkit.WebView_evaluateJavascript
# 31. Feature API_WebView_android.webkit.WebView_setWebContentsDebuggingEnabled
# 32. Feature API_FileIO_libcore.io.IoBridge_open
# 33. Feature API_FileIO_android.content.ContextWrapper_openFileInput
# 34. Feature API_FileIO_android.content.ContextWrapper_openFileOutput
# 35. Feature API_FileIO_android.content.ContextWrapper_deleteFile
# 36. Feature API_Database_android.content.ContextWrapper_openOrCreateDatabase
# 37. Feature API_Database_android.database.sqlite.SQLiteDatabase_execSQL
# 38. Feature API_Database_android.database.sqlite.SQLiteDatabase_getPath
# 39. Feature API_Database_android.database.sqlite.SQLiteDatabase_insert
# 40. Feature API_Database_android.database.sqlite.SQLiteDatabase_insertOrThrow
# 41. Feature API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict
# 42. Feature API_Database_android.database.sqlite.SQLiteDatabase_openDatabase
# 43. Feature API_Database_android.database.sqlite.SQLiteDatabase_openOrCreateDatabase
# 44. Feature API_Database_android.database.sqlite.SQLiteDatabase_query
# 45. Feature API_Database_android.database.sqlite.SQLiteDatabase_queryWithFactory
# 46. Feature API_Database_android.database.sqlite.SQLiteDatabase_rawQuery
# 47. Feature API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory
# 48. Feature API_Database_android.database.sqlite.SQLiteDatabase_update
# 49. Feature API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict
# 50. Feature API_Database_android.database.sqlite.SQLiteDatabase_compileStatement
# 51. Feature API_IPC_android.content.ContextWrapper_sendBroadcast
# 52. Feature API_IPC_android.content.ContextWrapper_startActivity
# 53. Feature API_IPC_android.content.ContextWrapper_startService
# 54. Feature API_IPC_android.content.ContextWrapper_stopService
# 55. Feature API_IPC_android.content.ContextWrapper_registerReceiver
# 56. Feature API_Binder_android.app.ContextImpl_registerReceiver
# 57. Feature API_Binder_android.app.ActivityThread_handleReceiver
# 58. Feature API_Binder_android.app.Activity_startActivity
# 59. Feature API_Crypto_javax.crypto.spec.SecretKeySpec_$init
# 60. Feature API_Crypto_javax.crypto.Cipher_doFinal
# 61. Feature API_Crypto-Hash_java.security.MessageDigest_digest
# 62. Feature API_Crypto-Hash_java.security.MessageDigest_update
# 63. Feature API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId
# 64. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId
# 65. Feature API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number
# 66. Feature API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperator
# 67. Feature API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperatorName
# 68. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName
# 69. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress
# 70. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getBSSID
# 71. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getIpAddress
# 72. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getNetworkId
# 73. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso
# 74. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimSerialNumber
# 75. Feature API_DeviceInfo_android.telephony.TelephonyManager_getNetworkCountryIso
# 76. Feature API_DeviceInfo_android.telephony.TelephonyManager_getDeviceSoftwareVersion
# 77. Feature API_DeviceInfo_android.os.Debug_isDebuggerConnected
# 78. Feature API_Network_java.net.URL_openConnection
# 79. Feature API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream
# 80. Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResource
# 81. Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResources
# 82. Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findLibrary
# 83. Feature API_DexClassLoader_dalvik.system.DexFile_loadDex
# 84. Feature API_DexClassLoader_dalvik.system.DexFile_loadClass
# 85. Feature API_DexClassLoader_dalvik.system.DexClassLoader_$init
# 86. Feature API_Base64_android.util.Base64_decode
# 87. Feature API_Base64_android.util.Base64_encode
# 88. Feature API_Base64_android.util.Base64_encodeToString
# 89. Feature API_SystemManager_android.app.ApplicationPackageManager_setComponentEnabledSetting
# 90. Feature API_SystemManager_android.app.NotificationManager_notify
# 91. Feature API_SystemManager_android.telephony.TelephonyManager_listen
# 92. Feature API_SMS_android.telephony.SmsManager_sendTextMessage
# 93. Feature API_SMS_android.telephony.SmsManager_sendMultipartTextMessage
# 94. Feature API_DeviceData_android.content.ContentResolver_query
# 95. Feature API_DeviceData_android.content.ContentResolver_registerContentObserver
# 96. Feature API_DeviceData_android.content.ContentResolver_insert
# 97. Feature API_DeviceData_android.content.ContentResolver_delete
# 98. Feature API_DeviceData_android.accounts.AccountManager_getAccountsByType
# 99. Feature API_DeviceData_android.accounts.AccountManager_getAccounts
# 100. Feature API_DeviceData_android.location.Location_getLatitude
# 101. Feature API_DeviceData_android.location.Location_getLongitude
# 102. Feature API_DeviceData_android.media.AudioRecord_startRecording
# 103. Feature API_DeviceData_android.os.SystemProperties_get
# 104. Feature API_DeviceData_android.app.ApplicationPackageManager_getInstalledPackages
# 105. Feature API__sessions
# 106. Feature Network_TotalReceivedBytes
# 107. Feature Network_TotalReceivedPackets
# 108. Feature Network_TotalTransmittedBytes
# 109. Feature Network_TotalTransmittedPackets
# 110. Feature Battery_wakelock
# 111. Feature Battery_service
# 112. Feature Logcat_debug
# 113. Feature Logcat_warning
# 114. Feature Logcat_info
# 115. Feature Logcat_verbose
# 116. Feature Logcat_error
# 117. Feature Logcat_total
# 118. Feature Process_total

# %%
# 5. Recursive Feature Elimination (RFE) - Wrapper
rfe_selector = RFE(estimator=RandomForestClassifier(), n_features_to_select=5)
X_rfe = rfe_selector.fit_transform(X, y)
rfe_top_features = np.where(rfe_selector.support_)[0]
print_selected_features("RFE", rfe_top_features)
# Out:
# RFE Selected Features:
# 1. Feature Memory_PssClean
# 2. Feature Memory_SharedDirty
# 3. Feature Memory_PrivateDirty
# 4. Feature Memory_SharedClean
# 5. Feature Memory_HeapAlloc

# %%
# 6. Sequential Feature Selector (SFS) - Wrapper (Running too Long)

# Encode the target variable (Y Still contain String)
#label_encoder = LabelEncoder()
#y_encoded = label_encoder.fit_transform(y)

# Sequential Feature Selector
#sfs_selector = SequentialFeatureSelector(estimator=SVR(kernel="linear"), n_features_to_select=5)
#X_sfs = sfs_selector.fit_transform(X, y_encoded)
#sfs_top_features = np.where(sfs_selector.get_support())[0]
#print_selected_features("SFS", sfs_top_features)

# %%
# 6. Sequential Feature Selector (SFS) - Wrapper

# Function to run SFS
def run_sfs(X, y_encoded):
    global sfs_selector, X_sfs
    sfs_selector = SequentialFeatureSelector(estimator=SVR(kernel="linear"),n_features_to_select=5, direction='forward', n_jobs=-1)
    X_sfs = sfs_selector.fit_transform(X, y_encoded)

# Encode the target variable (Y Still contain String)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Set a timeout duration (in seconds)
timeout_duration = 600  # 600 seconds = 10 minutes

# Create a thread for running SFS
sfs_thread = threading.Thread(target=run_sfs, args=(X, y_encoded))

# Start the thread
sfs_thread.start()

# Wait for the thread to complete or timeout
sfs_thread.join(timeout=timeout_duration)

# Check if the thread is still active
if sfs_thread.is_alive():
    print("SFS did not complete within the time limit. Terminating...")
    # Optionally, raise an error or take other actions
else:
    # If the thread finished in time, print selected features
    sfs_top_features = np.where(sfs_selector.get_support())[0]
    print_selected_features("SFS", sfs_top_features)
# Out:
# SFS did not complete within the time limit. Terminating...

# %%
# 7. Genetic Algorithm (DEAP) - Wrapper (Running to Long)
#def evaluate(individual):
#    """ Evaluation function for genetic algorithm """
#    selected_features = [i for i, value in enumerate(individual) if value > 0]
#    if len(selected_features) == 0:
#        return 1000,  # Penalty for selecting no features
#    estimator = RandomForestClassifier()
#    X_selected = X.iloc[:, selected_features]
#    estimator.fit(X_selected, y)
#    return 1 - estimator.score(X_selected, y),

# Genetic Algorithm setup
#creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
#creator.create("Individual", list, fitness=creator.FitnessMin)
#toolbox = base.Toolbox()
#toolbox.register("attr_bool", np.random.randint, 0, 2)
#toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, n=len(X.columns))
#toolbox.register("population", tools.initRepeat, list, toolbox.individual)
#toolbox.register("evaluate", evaluate)
#toolbox.register("mate", tools.cxTwoPoint)
#toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
#toolbox.register("select", tools.selTournament, tournsize=3)

#population = toolbox.population(n=50)
#algorithms.eaSimple(population, toolbox, cxpb=0.5, mutpb=0.2, ngen=20, verbose=False)
#best_individual = tools.selBest(population, k=1)[0]
#genetic_selected_features = [i for i, value in enumerate(best_individual) if value > 0]
#print_selected_features("Genetic Algorithm", genetic_selected_features)

# %%
# 7. Genetic Algorithm (DEAP) - Wrapper
def evaluate(individual):
    """Evaluation function for genetic algorithm"""
    selected_features = [i for i, value in enumerate(individual) if value > 0]
    if len(selected_features) == 0:
        return 1000,  # Penalty for selecting no features
    estimator = RandomForestClassifier()
    X_selected = X.iloc[:, selected_features]
    estimator.fit(X_selected, y)
    return 1 - estimator.score(X_selected, y),

# Genetic Algorithm setup
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)
toolbox = base.Toolbox()
toolbox.register("attr_bool", np.random.randint, 0, 2)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, n=len(X.columns))
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", evaluate)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)

# Function to run Genetic Algorithm (GA)
def run_ga():
    global population
    population = toolbox.population(n=50)
    algorithms.eaSimple(population, toolbox, cxpb=0.5, mutpb=0.2, ngen=20, verbose=False)

# Set a timeout duration (in seconds)
timeout_duration = 600  # 600 seconds = 10 minutes

# Create a thread for running the GA
ga_thread = threading.Thread(target=run_ga)

# Start the thread
ga_thread.start()

# Wait for the thread to complete or timeout
ga_thread.join(timeout=timeout_duration)

# Check if the thread is still active
if ga_thread.is_alive():
    print("Genetic Algorithm did not complete within the time limit of 10 minutes. Terminating...")
    # Optionally, raise an error or take other actions
else:
    # If the thread finished in time, print the selected features
    best_individual = tools.selBest(population, k=1)[0]
    genetic_selected_features = [i for i, value in enumerate(best_individual) if value > 0]
    print_selected_features("Genetic Algorithm", genetic_selected_features)
# Out:
# Exception in thread Thread-6 (run_ga):
# Traceback (most recent call last):
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Muhammad Raihan\AppData\Local\Temp\ipykernel_27328\3259204369.py", line 28, in run_ga
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\deap\algorithms.py", line 151, in eaSimple
#     for ind, fit in zip(invalid_ind, fitnesses):
#   File "C:\Users\Muhammad Raihan\AppData\Local\Temp\ipykernel_27328\3259204369.py", line 10, in evaluate
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 706, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py", line 823, in predict
#     proba = self.predict_proba(X)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py", line 876, in predict_proba
#     Parallel(n_jobs=n_jobs, verbose=self.verbose, require="sharedmem")(
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py", line 647, in _accumulate_prediction
#     prediction = predict(X, check_input=False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_classes.py", line 993, in predict_proba
#     proba = self.tree_.predict(X)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "sklearn\tree\_tree.pyx", line 833, in sklearn.tree._tree.Tree.predict
#   File "sklearn\tree\_tree.pyx", line 835, in sklearn.tree._tree.Tree.predict
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 11.4 MiB for an array with shape (53439, 1, 28) and data type float64
# Genetic Algorithm Selected Features:
# 1. Feature Memory_PssClean
# 2. Feature Memory_SharedClean
# 3. Feature Memory_SwapPssDirty
# 4. Feature Memory_HeapAlloc
# 5. Feature Memory_HeapFree
# 6. Feature Memory_Views
# 7. Feature Memory_ViewRootImpl
# 8. Feature Memory_Assets
# 9. Feature Memory_AssetManagers
# 10. Feature Memory_LocalBinders
# 11. Feature Memory_ProxyBinders
# 12. Feature Memory_DeathRecipients
# 13. Feature Memory_OpenSSLSockets
# 14. Feature Memory_WebViews
# 15. Feature API_Process_android.app.ActivityManager_killBackgroundProcesses
# 16. Feature API_Process_android.os.Process_killProcess
# 17. Feature API_Command_java.lang.Runtime_exec
# 18. Feature API_Command_java.lang.ProcessBuilder_start
# 19. Feature API_JavaNativeInterface_java.lang.Runtime_loadLibrary
# 20. Feature API_JavaNativeInterface_java.lang.Runtime_load
# 21. Feature API_WebView_android.webkit.WebView_loadUrl
# 22. Feature API_WebView_android.webkit.WebView_loadDataWithBaseURL
# 23. Feature API_WebView_android.webkit.WebView_addJavascriptInterface
# 24. Feature API_WebView_android.webkit.WebView_postUrl
# 25. Feature API_WebView_android.webkit.WebView_postWebMessage
# 26. Feature API_WebView_android.webkit.WebView_setHttpAuthUsernamePassword
# 27. Feature API_FileIO_libcore.io.IoBridge_open
# 28. Feature API_FileIO_android.content.ContextWrapper_openFileOutput
# 29. Feature API_FileIO_android.content.ContextWrapper_deleteFile
# 30. Feature API_Database_android.content.ContextWrapper_openOrCreateDatabase
# 31. Feature API_Database_android.content.ContextWrapper_databaseList
# 32. Feature API_Database_android.content.ContextWrapper_deleteDatabase
# 33. Feature API_Database_android.database.sqlite.SQLiteDatabase_deleteDatabase
# 34. Feature API_Database_android.database.sqlite.SQLiteDatabase_getPath
# 35. Feature API_Database_android.database.sqlite.SQLiteDatabase_insert
# 36. Feature API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict
# 37. Feature API_Database_android.database.sqlite.SQLiteDatabase_openDatabase
# 38. Feature API_Database_android.database.sqlite.SQLiteDatabase_query
# 39. Feature API_Database_android.database.sqlite.SQLiteDatabase_queryWithFactory
# 40. Feature API_Database_android.database.sqlite.SQLiteDatabase_rawQuery
# 41. Feature API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory
# 42. Feature API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict
# 43. Feature API_Database_android.database.sqlite.SQLiteDatabase_create
# 44. Feature API_IPC_android.content.ContextWrapper_sendStickyBroadcast
# 45. Feature API_IPC_android.content.ContextWrapper_startActivity
# 46. Feature API_IPC_android.content.ContextWrapper_startService
# 47. Feature API_IPC_android.content.ContextWrapper_stopService
# 48. Feature API_IPC_android.content.ContextWrapper_registerReceiver
# 49. Feature API_Binder_android.app.ActivityThread_handleReceiver
# 50. Feature API_Binder_android.app.Activity_startActivity
# 51. Feature API_Crypto_javax.crypto.spec.SecretKeySpec_$init
# 52. Feature API_Crypto_javax.crypto.Cipher_doFinal
# 53. Feature API_Crypto-Hash_java.security.MessageDigest_digest
# 54. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName
# 55. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getBSSID
# 56. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getIpAddress
# 57. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getNetworkId
# 58. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso
# 59. Feature API_DeviceInfo_android.os.Debug_isDebuggerConnected
# 60. Feature API_DeviceInfo_android.content.pm.PackageManager_getInstallerPackageName
# 61. Feature API_DeviceInfo_android.content.pm.PackageManager_getInstalledApplications
# 62. Feature API_DeviceInfo_android.content.pm.PackageManager_getInstalledPackages
# 63. Feature API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream
# 64. Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findLibrary
# 65. Feature API_DexClassLoader_dalvik.system.DexFile_loadDex
# 66. Feature API_DexClassLoader_dalvik.system.DexFile_loadClass
# 67. Feature API_DexClassLoader_dalvik.system.DexClassLoader_$init
# 68. Feature API_Base64_android.util.Base64_decode
# 69. Feature API_Base64_android.util.Base64_encodeToString
# 70. Feature API_SystemManager_android.app.ApplicationPackageManager_setComponentEnabledSetting
# 71. Feature API_SystemManager_android.content.BroadcastReceiver_abortBroadcast
# 72. Feature API_SMS_android.telephony.SmsManager_sendTextMessage
# 73. Feature API_SMS_android.telephony.SmsManager_sendMultipartTextMessage
# 74. Feature API_DeviceData_android.content.ContentResolver_registerContentObserver
# 75. Feature API_DeviceData_android.content.ContentResolver_insert
# 76. Feature API_DeviceData_android.content.ContentResolver_delete
# 77. Feature API_DeviceData_android.accounts.AccountManager_getAccountsByType
# 78. Feature API_DeviceData_android.media.AudioRecord_startRecording
# 79. Feature API_DeviceData_android.media.MediaRecorder_start
# 80. Feature API_DeviceData_android.os.SystemProperties_get
# 81. Feature API_DeviceData_android.app.ApplicationPackageManager_getInstalledPackages
# 82. Feature Network_TotalReceivedBytes
# 83. Feature Network_TotalTransmittedBytes
# 84. Feature Battery_service
# 85. Feature Logcat_warning
# 86. Feature Logcat_info
# 87. Feature Process_total

# %%
# 8. Boruta Algorithm (Wrapper)
rf = RandomForestClassifier(n_estimators=1000, n_jobs=-1, class_weight='balanced')
boruta_selector = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=42)
boruta_selector.fit(X, y)
boruta_selected_features = np.where(boruta_selector.support_)[0]
print_selected_features("Boruta", boruta_selected_features)
# Out:
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\_parallel_backends.py", line 273, in _wrap_func_call
#     return func()
#            ^^^^^^
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py", line 589, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py", line 589, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py", line 188, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_classes.py", line 959, in fit
#     super()._fit(
#   File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_classes.py", line 443, in _fit
#     builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#   File "sklearn\tree\_tree.pyx", line 164, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn\tree\_tree.pyx", line 265, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn\tree\_tree.pyx", line 803, in sklearn.tree._tree.Tree._add_node
#   File "sklearn\tree\_tree.pyx", line 772, in sklearn.tree._tree.Tree._resize_c
#   File "sklearn\tree\_utils.pyx", line 37, in sklearn.tree._utils.safe_realloc
# MemoryError: could not allocate 7340032 bytes
# """
#
# The above exception was the direct cause of the following exception:
#
# MemoryError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\boruta\boruta_py.py:475, in BorutaPy._get_imp(self, X, y)
#     474 try:
# --> 475     self.estimator.fit(X, y)
#     476 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:456, in BaseForest.fit(self, X, y, sample_weight)
#     450 # Parallel loop: we prefer the threading backend as the Cython code
#     451 # for fitting the trees is internally releasing the Python GIL
#     452 # making threading more efficient than multiprocessing in
#     453 # that case. However, for joblib 0.12+ we respect any
#     454 # parallel_backend contexts set at a higher level,
#     455 # since correctness does not rely on using threads.
# --> 456 trees = Parallel(
#     457     n_jobs=self.n_jobs,
#     458     verbose=self.verbose,
#     459     prefer="threads",
#     460 )(
#     461     delayed(_parallel_build_trees)(
#     462         t,
#     463         self.bootstrap,
#     464         X,
#     465         y,
#     466         sample_weight,
#     467         i,
#     468         len(trees),
#     469         verbose=self.verbose,
#     470         class_weight=self.class_weight,
#     471         n_samples_bootstrap=n_samples_bootstrap,
#     472     )
#     473     for i, t in enumerate(trees)
#     474 )
#     476 # Collect newly grown trees
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1952, in Parallel.__call__(self, iterable)
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1699, in Parallel._retrieve(self)
#    1698 if self._aborting:
# -> 1699     self._raise_error_fast()
#    1700     break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1734, in Parallel._raise_error_fast(self)
#    1733 if error_job is not None:
# -> 1734     error_job.get_result(self.timeout)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:736, in BatchCompletionCallBack.get_result(self, timeout)
#     732 if backend.supports_retrieve_callback:
#     733     # We assume that the result has already been retrieved by the
#     734     # callback thread, and is stored internally. It's just waiting to
#     735     # be returned.
# --> 736     return self._return_or_raise()
#     738 # For other backends, the main thread needs to run the retrieval step.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:754, in BatchCompletionCallBack._return_or_raise(self)
#     753 if self.status == TASK_ERROR:
# --> 754     raise self._result
#     755 return self._result
#
# MemoryError: could not allocate 7340032 bytes
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       2 rf = RandomForestClassifier(n_estimators=1000, n_jobs=-1, class_weight='balanced')
#       3 boruta_selector = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=42)
# ----> 4 boruta_selector.fit(X, y)
#       5 boruta_selected_features = np.where(boruta_selector.support_)[0]
#       6 print_selected_features("Boruta", boruta_selected_features)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\boruta\boruta_py.py:222, in BorutaPy.fit(self, X, y)
#     209 def fit(self, X, y):
#     210     """
#     211     Fits the Boruta feature selection with the provided estimator.
#     212
#    (...)
#     219         The target values.
#     220     """
# --> 222     return self._fit(X, y)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\boruta\boruta_py.py:347, in BorutaPy._fit(self, X, y)
#     344     self.estimator.set_params(random_state=self.random_state)
#     346 # add shadow attributes, shuffle them and train estimator, get imps
# --> 347 cur_imp = self._add_shadows_get_imps(X, y, dec_reg)
#     349 # get the threshold of shadow importances we will use for rejection
#     350 imp_sha_max = np.percentile(cur_imp[1], self.perc)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\boruta\boruta_py.py:503, in BorutaPy._add_shadows_get_imps(self, X, y, dec_reg)
#     501 x_sha = np.apply_along_axis(self._get_shuffle, 0, x_sha)
#     502 # get importance of the merged matrix
# --> 503 imp = self._get_imp(np.hstack((x_cur, x_sha)), y)
#     504 # separate importances of real and shadow features
#     505 imp_sha = imp[x_cur_w:]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\boruta\boruta_py.py:477, in BorutaPy._get_imp(self, X, y)
#     475     self.estimator.fit(X, y)
#     476 except Exception as e:
# --> 477     raise ValueError('Please check your X and y variable. The provided '
#     478                      'estimator cannot be fitted to your data.\n' + str(e))
#     479 try:
#     480     imp = self.estimator.feature_importances_
#
# ValueError: Please check your X and y variable. The provided estimator cannot be fitted to your data.
# could not allocate 7340032 bytes

# %%
# could not convert string to float for Lasso, Ridge, and Elastic Net so need to change the y variable
# Assuming y is your target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# 9. Lasso (L1 Regularization) - Embedded
lasso = Lasso(alpha=0.01)
lasso.fit(X, y_encoded)
lasso_support = np.where(lasso.coef_ != 0)[0]
print_selected_features("Lasso", lasso_support)
# Out:
# Lasso Selected Features:
# 1. Feature Memory_PssTotal
# 2. Feature Memory_PssClean
# 3. Feature Memory_SharedDirty
# 4. Feature Memory_PrivateDirty
# 5. Feature Memory_SharedClean
# 6. Feature Memory_PrivateClean
# 7. Feature Memory_HeapSize
# 8. Feature Memory_HeapAlloc
# 9. Feature Memory_HeapFree
# 10. Feature Memory_Views
# 11. Feature Memory_ViewRootImpl
# 12. Feature Memory_AppContexts
# 13. Feature Memory_Activities
# 14. Feature Memory_Assets
# 15. Feature Memory_LocalBinders
# 16. Feature Memory_ProxyBinders
# 17. Feature Memory_ParcelMemory
# 18. Feature Memory_ParcelCount
# 19. Feature Memory_DeathRecipients
# 20. Feature Memory_OpenSSLSockets
# 21. Feature Memory_WebViews
# 22. Feature API_Process_android.app.ActivityManager_killBackgroundProcesses
# 23. Feature API_Process_android.os.Process_killProcess
# 24. Feature API_Command_java.lang.Runtime_exec
# 25. Feature API_Command_java.lang.ProcessBuilder_start
# 26. Feature API_WebView_android.webkit.WebView_loadUrl
# 27. Feature API_WebView_android.webkit.WebView_loadDataWithBaseURL
# 28. Feature API_WebView_android.webkit.WebView_addJavascriptInterface
# 29. Feature API_WebView_android.webkit.WebView_evaluateJavascript
# 30. Feature API_WebView_android.webkit.WebView_setWebContentsDebuggingEnabled
# 31. Feature API_FileIO_libcore.io.IoBridge_open
# 32. Feature API_FileIO_android.content.ContextWrapper_openFileInput
# 33. Feature API_FileIO_android.content.ContextWrapper_openFileOutput
# 34. Feature API_FileIO_android.content.ContextWrapper_deleteFile
# 35. Feature API_Database_android.content.ContextWrapper_openOrCreateDatabase
# 36. Feature API_Database_android.content.ContextWrapper_databaseList
# 37. Feature API_Database_android.database.sqlite.SQLiteDatabase_execSQL
# 38. Feature API_Database_android.database.sqlite.SQLiteDatabase_getPath
# 39. Feature API_Database_android.database.sqlite.SQLiteDatabase_insert
# 40. Feature API_Database_android.database.sqlite.SQLiteDatabase_insertOrThrow
# 41. Feature API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict
# 42. Feature API_Database_android.database.sqlite.SQLiteDatabase_openDatabase
# 43. Feature API_Database_android.database.sqlite.SQLiteDatabase_openOrCreateDatabase
# 44. Feature API_Database_android.database.sqlite.SQLiteDatabase_query
# 45. Feature API_Database_android.database.sqlite.SQLiteDatabase_queryWithFactory
# 46. Feature API_Database_android.database.sqlite.SQLiteDatabase_rawQuery
# 47. Feature API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory
# 48. Feature API_Database_android.database.sqlite.SQLiteDatabase_update
# 49. Feature API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict
# 50. Feature API_Database_android.database.sqlite.SQLiteDatabase_compileStatement
# 51. Feature API_IPC_android.content.ContextWrapper_sendBroadcast
# 52. Feature API_IPC_android.content.ContextWrapper_startActivity
# 53. Feature API_IPC_android.content.ContextWrapper_startService
# 54. Feature API_IPC_android.content.ContextWrapper_stopService
# 55. Feature API_IPC_android.content.ContextWrapper_registerReceiver
# 56. Feature API_Binder_android.app.ContextImpl_registerReceiver
# 57. Feature API_Binder_android.app.ActivityThread_handleReceiver
# 58. Feature API_Binder_android.app.Activity_startActivity
# 59. Feature API_Crypto_javax.crypto.spec.SecretKeySpec_$init
# 60. Feature API_Crypto_javax.crypto.Cipher_doFinal
# 61. Feature API_Crypto-Hash_java.security.MessageDigest_digest
# 62. Feature API_Crypto-Hash_java.security.MessageDigest_update
# 63. Feature API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId
# 64. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId
# 65. Feature API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number
# 66. Feature API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperator
# 67. Feature API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperatorName
# 68. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName
# 69. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress
# 70. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getNetworkId
# 71. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso
# 72. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimSerialNumber
# 73. Feature API_DeviceInfo_android.telephony.TelephonyManager_getNetworkCountryIso
# 74. Feature API_DeviceInfo_android.telephony.TelephonyManager_getDeviceSoftwareVersion
# 75. Feature API_DeviceInfo_android.os.Debug_isDebuggerConnected
# 76. Feature API_Network_java.net.URL_openConnection
# 77. Feature API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream
# 78. Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResource
# 79. Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResources
# 80. Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findLibrary
# 81. Feature API_DexClassLoader_dalvik.system.DexFile_loadDex
# 82. Feature API_DexClassLoader_dalvik.system.DexFile_loadClass
# 83. Feature API_DexClassLoader_dalvik.system.DexClassLoader_$init
# 84. Feature API_Base64_android.util.Base64_decode
# 85. Feature API_Base64_android.util.Base64_encode
# 86. Feature API_Base64_android.util.Base64_encodeToString
# 87. Feature API_SystemManager_android.app.ApplicationPackageManager_setComponentEnabledSetting
# 88. Feature API_SystemManager_android.app.NotificationManager_notify
# 89. Feature API_SystemManager_android.telephony.TelephonyManager_listen
# 90. Feature API_SMS_android.telephony.SmsManager_sendTextMessage
# 91. Feature API_SMS_android.telephony.SmsManager_sendMultipartTextMessage
# 92. Feature API_DeviceData_android.content.ContentResolver_query
# 93. Feature API_DeviceData_android.content.ContentResolver_registerContentObserver
# 94. Feature API_DeviceData_android.content.ContentResolver_insert
# 95. Feature API_DeviceData_android.content.ContentResolver_delete
# 96. Feature API_DeviceData_android.accounts.AccountManager_getAccountsByType
# 97. Feature API_DeviceData_android.accounts.AccountManager_getAccounts
# 98. Feature API_DeviceData_android.location.Location_getLatitude
# 99. Feature API_DeviceData_android.location.Location_getLongitude
# 100. Feature API_DeviceData_android.media.AudioRecord_startRecording
# 101. Feature API_DeviceData_android.os.SystemProperties_get
# 102. Feature API_DeviceData_android.app.ApplicationPackageManager_getInstalledPackages
# 103. Feature API__sessions
# 104. Feature Network_TotalReceivedBytes
# 105. Feature Network_TotalReceivedPackets
# 106. Feature Network_TotalTransmittedBytes
# 107. Feature Network_TotalTransmittedPackets
# 108. Feature Battery_wakelock
# 109. Feature Battery_service
# 110. Feature Logcat_debug
# 111. Feature Logcat_warning
# 112. Feature Logcat_info
# 113. Feature Logcat_verbose
# 114. Feature Logcat_error
# 115. Feature Logcat_total
# 116. Feature Process_total
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.671e+06, tolerance: 4.345e+02
#   model = cd_fast.enet_coordinate_descent(

# %%
# 10. Ridge (L2 Regularization) - Embedded
ridge = Ridge(alpha=1.0)
ridge.fit(X, y_encoded)
ridge_support = np.where(ridge.coef_ != 0)[0]
print_selected_features("Ridge", ridge_support)
# Out:
# Ridge Selected Features:
# 1. Feature Memory_PssTotal
# 2. Feature Memory_PssClean
# 3. Feature Memory_SharedDirty
# 4. Feature Memory_PrivateDirty
# 5. Feature Memory_SharedClean
# 6. Feature Memory_PrivateClean
# 7. Feature Memory_HeapSize
# 8. Feature Memory_HeapAlloc
# 9. Feature Memory_HeapFree
# 10. Feature Memory_Views
# 11. Feature Memory_ViewRootImpl
# 12. Feature Memory_AppContexts
# 13. Feature Memory_Activities
# 14. Feature Memory_Assets
# 15. Feature Memory_LocalBinders
# 16. Feature Memory_ProxyBinders
# 17. Feature Memory_ParcelMemory
# 18. Feature Memory_ParcelCount
# 19. Feature Memory_DeathRecipients
# 20. Feature Memory_OpenSSLSockets
# 21. Feature Memory_WebViews
# 22. Feature API_Process_android.app.ActivityManager_killBackgroundProcesses
# 23. Feature API_Process_android.os.Process_killProcess
# 24. Feature API_Command_java.lang.Runtime_exec
# 25. Feature API_Command_java.lang.ProcessBuilder_start
# 26. Feature API_JavaNativeInterface_java.lang.Runtime_load
# 27. Feature API_WebView_android.webkit.WebView_loadUrl
# 28. Feature API_WebView_android.webkit.WebView_loadData
# 29. Feature API_WebView_android.webkit.WebView_loadDataWithBaseURL
# 30. Feature API_WebView_android.webkit.WebView_addJavascriptInterface
# 31. Feature API_WebView_android.webkit.WebView_evaluateJavascript
# 32. Feature API_WebView_android.webkit.WebView_postUrl
# 33. Feature API_WebView_android.webkit.WebView_setWebContentsDebuggingEnabled
# 34. Feature API_FileIO_libcore.io.IoBridge_open
# 35. Feature API_FileIO_android.content.ContextWrapper_openFileInput
# 36. Feature API_FileIO_android.content.ContextWrapper_openFileOutput
# 37. Feature API_FileIO_android.content.ContextWrapper_deleteFile
# 38. Feature API_Database_android.content.ContextWrapper_openOrCreateDatabase
# 39. Feature API_Database_android.content.ContextWrapper_databaseList
# 40. Feature API_Database_android.content.ContextWrapper_deleteDatabase
# 41. Feature API_Database_android.database.sqlite.SQLiteDatabase_execSQL
# 42. Feature API_Database_android.database.sqlite.SQLiteDatabase_deleteDatabase
# 43. Feature API_Database_android.database.sqlite.SQLiteDatabase_getPath
# 44. Feature API_Database_android.database.sqlite.SQLiteDatabase_insert
# 45. Feature API_Database_android.database.sqlite.SQLiteDatabase_insertOrThrow
# 46. Feature API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict
# 47. Feature API_Database_android.database.sqlite.SQLiteDatabase_openDatabase
# 48. Feature API_Database_android.database.sqlite.SQLiteDatabase_openOrCreateDatabase
# 49. Feature API_Database_android.database.sqlite.SQLiteDatabase_query
# 50. Feature API_Database_android.database.sqlite.SQLiteDatabase_queryWithFactory
# 51. Feature API_Database_android.database.sqlite.SQLiteDatabase_rawQuery
# 52. Feature API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory
# 53. Feature API_Database_android.database.sqlite.SQLiteDatabase_update
# 54. Feature API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict
# 55. Feature API_Database_android.database.sqlite.SQLiteDatabase_compileStatement
# 56. Feature API_IPC_android.content.ContextWrapper_sendBroadcast
# 57. Feature API_IPC_android.content.ContextWrapper_sendStickyBroadcast
# 58. Feature API_IPC_android.content.ContextWrapper_startActivity
# 59. Feature API_IPC_android.content.ContextWrapper_startService
# 60. Feature API_IPC_android.content.ContextWrapper_stopService
# 61. Feature API_IPC_android.content.ContextWrapper_registerReceiver
# 62. Feature API_Binder_android.app.ContextImpl_registerReceiver
# 63. Feature API_Binder_android.app.ActivityThread_handleReceiver
# 64. Feature API_Binder_android.app.Activity_startActivity
# 65. Feature API_Crypto_javax.crypto.spec.SecretKeySpec_$init
# 66. Feature API_Crypto_javax.crypto.Cipher_doFinal
# 67. Feature API_Crypto-Hash_java.security.MessageDigest_digest
# 68. Feature API_Crypto-Hash_java.security.MessageDigest_update
# 69. Feature API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId
# 70. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId
# 71. Feature API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number
# 72. Feature API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperator
# 73. Feature API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperatorName
# 74. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName
# 75. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress
# 76. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getBSSID
# 77. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getIpAddress
# 78. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getNetworkId
# 79. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso
# 80. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimSerialNumber
# 81. Feature API_DeviceInfo_android.telephony.TelephonyManager_getNetworkCountryIso
# 82. Feature API_DeviceInfo_android.telephony.TelephonyManager_getDeviceSoftwareVersion
# 83. Feature API_DeviceInfo_android.os.Debug_isDebuggerConnected
# 84. Feature API_Network_java.net.URL_openConnection
# 85. Feature API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream
# 86. Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResource
# 87. Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResources
# 88. Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findLibrary
# 89. Feature API_DexClassLoader_dalvik.system.DexFile_loadDex
# 90. Feature API_DexClassLoader_dalvik.system.DexFile_loadClass
# 91. Feature API_DexClassLoader_dalvik.system.DexClassLoader_$init
# 92. Feature API_Base64_android.util.Base64_decode
# 93. Feature API_Base64_android.util.Base64_encode
# 94. Feature API_Base64_android.util.Base64_encodeToString
# 95. Feature API_SystemManager_android.app.ApplicationPackageManager_setComponentEnabledSetting
# 96. Feature API_SystemManager_android.app.NotificationManager_notify
# 97. Feature API_SystemManager_android.telephony.TelephonyManager_listen
# 98. Feature API_SystemManager_android.content.BroadcastReceiver_abortBroadcast
# 99. Feature API_SMS_android.telephony.SmsManager_sendTextMessage
# 100. Feature API_SMS_android.telephony.SmsManager_sendMultipartTextMessage
# 101. Feature API_DeviceData_android.content.ContentResolver_query
# 102. Feature API_DeviceData_android.content.ContentResolver_registerContentObserver
# 103. Feature API_DeviceData_android.content.ContentResolver_insert
# 104. Feature API_DeviceData_android.content.ContentResolver_delete
# 105. Feature API_DeviceData_android.accounts.AccountManager_getAccountsByType
# 106. Feature API_DeviceData_android.accounts.AccountManager_getAccounts
# 107. Feature API_DeviceData_android.location.Location_getLatitude
# 108. Feature API_DeviceData_android.location.Location_getLongitude
# 109. Feature API_DeviceData_android.media.AudioRecord_startRecording
# 110. Feature API_DeviceData_android.media.MediaRecorder_start
# 111. Feature API_DeviceData_android.os.SystemProperties_get
# 112. Feature API_DeviceData_android.app.ApplicationPackageManager_getInstalledPackages
# 113. Feature API__sessions
# 114. Feature Network_TotalReceivedBytes
# 115. Feature Network_TotalReceivedPackets
# 116. Feature Network_TotalTransmittedBytes
# 117. Feature Network_TotalTransmittedPackets
# 118. Feature Battery_wakelock
# 119. Feature Battery_service
# 120. Feature Logcat_debug
# 121. Feature Logcat_warning
# 122. Feature Logcat_info
# 123. Feature Logcat_verbose
# 124. Feature Logcat_error
# 125. Feature Logcat_total
# 126. Feature Process_total
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_ridge.py:200: LinAlgWarning: Ill-conditioned matrix (rcond=1.61896e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
# 11. Elastic Net - Embedded
elastic_net = ElasticNet(alpha=1.0, l1_ratio=0.5)
elastic_net.fit(X, y_encoded)
elastic_net_support = np.where(elastic_net.coef_ != 0)[0]
print_selected_features("Elastic Net", elastic_net_support)
# Out:
# Elastic Net Selected Features:
# 1. Feature Memory_PssTotal
# 2. Feature Memory_PssClean
# 3. Feature Memory_SharedDirty
# 4. Feature Memory_PrivateDirty
# 5. Feature Memory_SharedClean
# 6. Feature Memory_PrivateClean
# 7. Feature Memory_HeapSize
# 8. Feature Memory_HeapAlloc
# 9. Feature Memory_HeapFree
# 10. Feature Memory_Views
# 11. Feature Memory_ViewRootImpl
# 12. Feature Memory_LocalBinders
# 13. Feature Memory_ProxyBinders
# 14. Feature Memory_ParcelMemory
# 15. Feature Memory_ParcelCount
# 16. Feature Memory_OpenSSLSockets
# 17. Feature API_Process_android.app.ActivityManager_killBackgroundProcesses
# 18. Feature API_Command_java.lang.Runtime_exec
# 19. Feature API_WebView_android.webkit.WebView_addJavascriptInterface
# 20. Feature API_WebView_android.webkit.WebView_evaluateJavascript
# 21. Feature API_FileIO_libcore.io.IoBridge_open
# 22. Feature API_FileIO_android.content.ContextWrapper_openFileInput
# 23. Feature API_FileIO_android.content.ContextWrapper_openFileOutput
# 24. Feature API_FileIO_android.content.ContextWrapper_deleteFile
# 25. Feature API_Database_android.database.sqlite.SQLiteDatabase_execSQL
# 26. Feature API_Database_android.database.sqlite.SQLiteDatabase_getPath
# 27. Feature API_Database_android.database.sqlite.SQLiteDatabase_insert
# 28. Feature API_Database_android.database.sqlite.SQLiteDatabase_insertOrThrow
# 29. Feature API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict
# 30. Feature API_Database_android.database.sqlite.SQLiteDatabase_query
# 31. Feature API_Database_android.database.sqlite.SQLiteDatabase_rawQuery
# 32. Feature API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory
# 33. Feature API_Database_android.database.sqlite.SQLiteDatabase_update
# 34. Feature API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict
# 35. Feature API_IPC_android.content.ContextWrapper_sendBroadcast
# 36. Feature API_IPC_android.content.ContextWrapper_startActivity
# 37. Feature API_IPC_android.content.ContextWrapper_startService
# 38. Feature API_IPC_android.content.ContextWrapper_stopService
# 39. Feature API_IPC_android.content.ContextWrapper_registerReceiver
# 40. Feature API_Binder_android.app.ContextImpl_registerReceiver
# 41. Feature API_Binder_android.app.ActivityThread_handleReceiver
# 42. Feature API_Binder_android.app.Activity_startActivity
# 43. Feature API_Crypto_javax.crypto.spec.SecretKeySpec_$init
# 44. Feature API_Crypto_javax.crypto.Cipher_doFinal
# 45. Feature API_Crypto-Hash_java.security.MessageDigest_digest
# 46. Feature API_Crypto-Hash_java.security.MessageDigest_update
# 47. Feature API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId
# 48. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId
# 49. Feature API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number
# 50. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName
# 51. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress
# 52. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getBSSID
# 53. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimSerialNumber
# 54. Feature API_DeviceInfo_android.telephony.TelephonyManager_getNetworkCountryIso
# 55. Feature API_DeviceInfo_android.os.Debug_isDebuggerConnected
# 56. Feature API_Network_java.net.URL_openConnection
# 57. Feature API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream
# 58. Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResource
# 59. Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findLibrary
# 60. Feature API_DexClassLoader_dalvik.system.DexFile_loadDex
# 61. Feature API_DexClassLoader_dalvik.system.DexFile_loadClass
# 62. Feature API_DexClassLoader_dalvik.system.DexClassLoader_$init
# 63. Feature API_Base64_android.util.Base64_decode
# 64. Feature API_Base64_android.util.Base64_encodeToString
# 65. Feature API_SystemManager_android.app.ApplicationPackageManager_setComponentEnabledSetting
# 66. Feature API_SystemManager_android.app.NotificationManager_notify
# 67. Feature API_SMS_android.telephony.SmsManager_sendTextMessage
# 68. Feature API_DeviceData_android.content.ContentResolver_query
# 69. Feature API_DeviceData_android.content.ContentResolver_registerContentObserver
# 70. Feature API_DeviceData_android.accounts.AccountManager_getAccountsByType
# 71. Feature API_DeviceData_android.accounts.AccountManager_getAccounts
# 72. Feature API_DeviceData_android.os.SystemProperties_get
# 73. Feature API_DeviceData_android.app.ApplicationPackageManager_getInstalledPackages
# 74. Feature API__sessions
# 75. Feature Network_TotalReceivedBytes
# 76. Feature Network_TotalReceivedPackets
# 77. Feature Network_TotalTransmittedBytes
# 78. Feature Network_TotalTransmittedPackets
# 79. Feature Battery_wakelock
# 80. Feature Battery_service
# 81. Feature Logcat_debug
# 82. Feature Logcat_warning
# 83. Feature Logcat_info
# 84. Feature Logcat_verbose
# 85. Feature Logcat_error
# 86. Feature Logcat_total
# 87. Feature Process_total
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.816e+06, tolerance: 4.345e+02
#   model = cd_fast.enet_coordinate_descent(

# %%
# 12. Random Forest Feature Importance - Embedded
rf_model = RandomForestClassifier().fit(X, y)
rf_importances = rf_model.feature_importances_
rf_top_features = np.argsort(rf_importances)[::-1][:5]
print_selected_features("Random Forest", rf_top_features, rf_importances)
# Out:
# Random Forest Selected Features:
# 1. Feature Process_total (Importance: 0.042191)
# 2. Feature Battery_wakelock (Importance: 0.039227)
# 3. Feature Logcat_total (Importance: 0.024331)
# 4. Feature Memory_SharedClean (Importance: 0.023574)
# 5. Feature Memory_HeapAlloc (Importance: 0.020164)

# %%
# 13. ExtraTreesClassifier - Embedded (Already used in your code)
extratrees = ExtraTreesClassifier().fit(X, y)
model = SelectFromModel(extratrees, prefit=True)
X_new = model.transform(X)
nbfeatures = X_new.shape[1]
index = np.argsort(extratrees.feature_importances_)[::-1][:nbfeatures]
print_selected_features("ExtraTreesClassifier", index, extratrees.feature_importances_)
# Out:
# ExtraTreesClassifier Selected Features:
# 1. Feature Battery_wakelock (Importance: 0.056942)
# 2. Feature Process_total (Importance: 0.039842)
# 3. Feature Memory_SharedClean (Importance: 0.025768)
# 4. Feature Memory_PrivateClean (Importance: 0.019926)
# 5. Feature Memory_PssClean (Importance: 0.019705)
# 6. Feature Logcat_total (Importance: 0.019321)
# 7. Feature Memory_HeapAlloc (Importance: 0.017398)
# 8. Feature Memory_SharedDirty (Importance: 0.017084)
# 9. Feature Memory_HeapSize (Importance: 0.016924)
# 10. Feature API_DeviceData_android.os.SystemProperties_get (Importance: 0.016046)
# 11. Feature Memory_PssTotal (Importance: 0.016033)
# 12. Feature API__sessions (Importance: 0.015882)
# 13. Feature API_Binder_android.app.ActivityThread_handleReceiver (Importance: 0.015794)
# 14. Feature Memory_PrivateDirty (Importance: 0.015624)
# 15. Feature API_Binder_android.app.Activity_startActivity (Importance: 0.015054)
# 16. Feature Battery_service (Importance: 0.014536)
# 17. Feature API_DeviceData_android.content.ContentResolver_registerContentObserver (Importance: 0.014471)
# 18. Feature Memory_HeapFree (Importance: 0.014218)
# 19. Feature Memory_ParcelCount (Importance: 0.014188)
# 20. Feature API_Database_android.database.sqlite.SQLiteDatabase_execSQL (Importance: 0.013509)
# 21. Feature API_IPC_android.content.ContextWrapper_registerReceiver (Importance: 0.013302)
# 22. Feature Memory_AppContexts (Importance: 0.013040)
# 23. Feature Memory_ParcelMemory (Importance: 0.013028)
# 24. Feature Memory_ProxyBinders (Importance: 0.012811)
# 25. Feature Memory_LocalBinders (Importance: 0.012397)
# 26. Feature API_Binder_android.app.ContextImpl_registerReceiver (Importance: 0.012323)
# 27. Feature Logcat_warning (Importance: 0.012278)
# 28. Feature Logcat_error (Importance: 0.012214)
# 29. Feature Logcat_verbose (Importance: 0.012197)
# 30. Feature API_IPC_android.content.ContextWrapper_startService (Importance: 0.012038)
# 31. Feature Logcat_debug (Importance: 0.012029)
# 32. Feature Logcat_info (Importance: 0.012000)
# 33. Feature Memory_Views (Importance: 0.011998)
# 34. Feature API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId (Importance: 0.011646)
# 35. Feature API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId (Importance: 0.011437)
# 36. Feature API_Crypto-Hash_java.security.MessageDigest_digest (Importance: 0.010341)
# 37. Feature API_Base64_android.util.Base64_decode (Importance: 0.010227)
# 38. Feature Memory_ViewRootImpl (Importance: 0.010203)
# 39. Feature API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress (Importance: 0.009983)
# 40. Feature Network_TotalTransmittedBytes (Importance: 0.009948)
# 41. Feature API_Network_java.net.URL_openConnection (Importance: 0.009866)
# 42. Feature Network_TotalTransmittedPackets (Importance: 0.009781)
# 43. Feature API_FileIO_android.content.ContextWrapper_deleteFile (Importance: 0.009751)
# 44. Feature Network_TotalReceivedBytes (Importance: 0.009731)
# 45. Feature API_Crypto-Hash_java.security.MessageDigest_update (Importance: 0.009683)
# 46. Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findLibrary (Importance: 0.009367)
# 47. Feature Memory_Activities (Importance: 0.009206)
# 48. Feature API_Command_java.lang.Runtime_exec (Importance: 0.008954)
# 49. Feature API_Command_java.lang.ProcessBuilder_start (Importance: 0.008825)
# 50. Feature Network_TotalReceivedPackets (Importance: 0.008713)
# 51. Feature API_FileIO_android.content.ContextWrapper_openFileInput (Importance: 0.008628)
# 52. Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResource (Importance: 0.008477)
# 53. Feature API_DeviceData_android.app.ApplicationPackageManager_getInstalledPackages (Importance: 0.008369)
# 54. Feature API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream (Importance: 0.008047)
# 55. Feature API_Database_android.database.sqlite.SQLiteDatabase_rawQuery (Importance: 0.007892)
# 56. Feature API_Crypto_javax.crypto.Cipher_doFinal (Importance: 0.007836)
# 57. Feature API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperatorName (Importance: 0.007349)
# 58. Feature API_DexClassLoader_dalvik.system.DexClassLoader_$init (Importance: 0.007329)
# 59. Feature API_Database_android.database.sqlite.SQLiteDatabase_openDatabase (Importance: 0.007301)
# 60. Feature API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number (Importance: 0.007174)

# %%
# Compare all selected features
print("\nSummary of Selected Features for Each Method:")
for method, selected in features.items():
    print(f"{method}: {selected}")
# Out:
# Summary of Selected Features for Each Method:
# Chi-Square: ['API_DeviceInfo_android.content.pm.PackageManager_getInstallerPackageName', 'API_Process_android.os.Process_start', 'API_Database_android.database.sqlite.SQLiteDatabase_create', 'API_Network_org.apache.http.impl.client.AbstractHttpClient_execute', 'API_DeviceInfo_android.content.pm.PackageManager_getInstalledPackages']
# ANOVA: ['API_DeviceData_android.os.SystemProperties_get', 'API_DeviceData_android.content.ContentResolver_insert', 'API_Network_org.apache.http.impl.client.AbstractHttpClient_execute', 'API_IPC_android.content.ContextWrapper_registerReceiver', 'API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso']
# Mutual Information: ['Memory_HeapSize', 'Network_TotalReceivedBytes', 'Network_TotalTransmittedBytes', 'Memory_Views', 'API_Crypto-Hash_java.security.MessageDigest_update']
# Variance Threshold: ['Memory_PssTotal', 'Memory_PssClean', 'Memory_SharedDirty', 'Memory_PrivateDirty', 'Memory_SharedClean', 'Memory_PrivateClean', 'Memory_HeapSize', 'Memory_HeapAlloc', 'Memory_HeapFree', 'Memory_Views', 'Memory_ViewRootImpl', 'Memory_AppContexts', 'Memory_Activities', 'Memory_Assets', 'Memory_LocalBinders', 'Memory_ProxyBinders', 'Memory_ParcelMemory', 'Memory_ParcelCount', 'Memory_DeathRecipients', 'Memory_OpenSSLSockets', 'Memory_WebViews', 'API_Process_android.app.ActivityManager_killBackgroundProcesses', 'API_Process_android.os.Process_killProcess', 'API_Command_java.lang.Runtime_exec', 'API_Command_java.lang.ProcessBuilder_start', 'API_WebView_android.webkit.WebView_loadUrl', 'API_WebView_android.webkit.WebView_loadData', 'API_WebView_android.webkit.WebView_loadDataWithBaseURL', 'API_WebView_android.webkit.WebView_addJavascriptInterface', 'API_WebView_android.webkit.WebView_evaluateJavascript', 'API_WebView_android.webkit.WebView_setWebContentsDebuggingEnabled', 'API_FileIO_libcore.io.IoBridge_open', 'API_FileIO_android.content.ContextWrapper_openFileInput', 'API_FileIO_android.content.ContextWrapper_openFileOutput', 'API_FileIO_android.content.ContextWrapper_deleteFile', 'API_Database_android.content.ContextWrapper_openOrCreateDatabase', 'API_Database_android.database.sqlite.SQLiteDatabase_execSQL', 'API_Database_android.database.sqlite.SQLiteDatabase_getPath', 'API_Database_android.database.sqlite.SQLiteDatabase_insert', 'API_Database_android.database.sqlite.SQLiteDatabase_insertOrThrow', 'API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict', 'API_Database_android.database.sqlite.SQLiteDatabase_openDatabase', 'API_Database_android.database.sqlite.SQLiteDatabase_openOrCreateDatabase', 'API_Database_android.database.sqlite.SQLiteDatabase_query', 'API_Database_android.database.sqlite.SQLiteDatabase_queryWithFactory', 'API_Database_android.database.sqlite.SQLiteDatabase_rawQuery', 'API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory', 'API_Database_android.database.sqlite.SQLiteDatabase_update', 'API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict', 'API_Database_android.database.sqlite.SQLiteDatabase_compileStatement', 'API_IPC_android.content.ContextWrapper_sendBroadcast', 'API_IPC_android.content.ContextWrapper_startActivity', 'API_IPC_android.content.ContextWrapper_startService', 'API_IPC_android.content.ContextWrapper_stopService', 'API_IPC_android.content.ContextWrapper_registerReceiver', 'API_Binder_android.app.ContextImpl_registerReceiver', 'API_Binder_android.app.ActivityThread_handleReceiver', 'API_Binder_android.app.Activity_startActivity', 'API_Crypto_javax.crypto.spec.SecretKeySpec_$init', 'API_Crypto_javax.crypto.Cipher_doFinal', 'API_Crypto-Hash_java.security.MessageDigest_digest', 'API_Crypto-Hash_java.security.MessageDigest_update', 'API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId', 'API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId', 'API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number', 'API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperator', 'API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperatorName', 'API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName', 'API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress', 'API_DeviceInfo_android.net.wifi.WifiInfo_getBSSID', 'API_DeviceInfo_android.net.wifi.WifiInfo_getIpAddress', 'API_DeviceInfo_android.net.wifi.WifiInfo_getNetworkId', 'API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso', 'API_DeviceInfo_android.telephony.TelephonyManager_getSimSerialNumber', 'API_DeviceInfo_android.telephony.TelephonyManager_getNetworkCountryIso', 'API_DeviceInfo_android.telephony.TelephonyManager_getDeviceSoftwareVersion', 'API_DeviceInfo_android.os.Debug_isDebuggerConnected', 'API_Network_java.net.URL_openConnection', 'API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputS ...
# RFE: ['Memory_PssClean', 'Memory_SharedDirty', 'Memory_PrivateDirty', 'Memory_SharedClean', 'Memory_HeapAlloc']
# Genetic Algorithm: ['Memory_PssClean', 'Memory_SharedClean', 'Memory_SwapPssDirty', 'Memory_HeapAlloc', 'Memory_HeapFree', 'Memory_Views', 'Memory_ViewRootImpl', 'Memory_Assets', 'Memory_AssetManagers', 'Memory_LocalBinders', 'Memory_ProxyBinders', 'Memory_DeathRecipients', 'Memory_OpenSSLSockets', 'Memory_WebViews', 'API_Process_android.app.ActivityManager_killBackgroundProcesses', 'API_Process_android.os.Process_killProcess', 'API_Command_java.lang.Runtime_exec', 'API_Command_java.lang.ProcessBuilder_start', 'API_JavaNativeInterface_java.lang.Runtime_loadLibrary', 'API_JavaNativeInterface_java.lang.Runtime_load', 'API_WebView_android.webkit.WebView_loadUrl', 'API_WebView_android.webkit.WebView_loadDataWithBaseURL', 'API_WebView_android.webkit.WebView_addJavascriptInterface', 'API_WebView_android.webkit.WebView_postUrl', 'API_WebView_android.webkit.WebView_postWebMessage', 'API_WebView_android.webkit.WebView_setHttpAuthUsernamePassword', 'API_FileIO_libcore.io.IoBridge_open', 'API_FileIO_android.content.ContextWrapper_openFileOutput', 'API_FileIO_android.content.ContextWrapper_deleteFile', 'API_Database_android.content.ContextWrapper_openOrCreateDatabase', 'API_Database_android.content.ContextWrapper_databaseList', 'API_Database_android.content.ContextWrapper_deleteDatabase', 'API_Database_android.database.sqlite.SQLiteDatabase_deleteDatabase', 'API_Database_android.database.sqlite.SQLiteDatabase_getPath', 'API_Database_android.database.sqlite.SQLiteDatabase_insert', 'API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict', 'API_Database_android.database.sqlite.SQLiteDatabase_openDatabase', 'API_Database_android.database.sqlite.SQLiteDatabase_query', 'API_Database_android.database.sqlite.SQLiteDatabase_queryWithFactory', 'API_Database_android.database.sqlite.SQLiteDatabase_rawQuery', 'API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory', 'API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict', 'API_Database_android.database.sqlite.SQLiteDatabase_create', 'API_IPC_android.content.ContextWrapper_sendStickyBroadcast', 'API_IPC_android.content.ContextWrapper_startActivity', 'API_IPC_android.content.ContextWrapper_startService', 'API_IPC_android.content.ContextWrapper_stopService', 'API_IPC_android.content.ContextWrapper_registerReceiver', 'API_Binder_android.app.ActivityThread_handleReceiver', 'API_Binder_android.app.Activity_startActivity', 'API_Crypto_javax.crypto.spec.SecretKeySpec_$init', 'API_Crypto_javax.crypto.Cipher_doFinal', 'API_Crypto-Hash_java.security.MessageDigest_digest', 'API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName', 'API_DeviceInfo_android.net.wifi.WifiInfo_getBSSID', 'API_DeviceInfo_android.net.wifi.WifiInfo_getIpAddress', 'API_DeviceInfo_android.net.wifi.WifiInfo_getNetworkId', 'API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso', 'API_DeviceInfo_android.os.Debug_isDebuggerConnected', 'API_DeviceInfo_android.content.pm.PackageManager_getInstallerPackageName', 'API_DeviceInfo_android.content.pm.PackageManager_getInstalledApplications', 'API_DeviceInfo_android.content.pm.PackageManager_getInstalledPackages', 'API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream', 'API_DexClassLoader_dalvik.system.BaseDexClassLoader_findLibrary', 'API_DexClassLoader_dalvik.system.DexFile_loadDex', 'API_DexClassLoader_dalvik.system.DexFile_loadClass', 'API_DexClassLoader_dalvik.system.DexClassLoader_$init', 'API_Base64_android.util.Base64_decode', 'API_Base64_android.util.Base64_encodeToString', 'API_SystemManager_android.app.ApplicationPackageManager_setComponentEnabledSetting', 'API_SystemManager_android.content.BroadcastReceiver_abortBroadcast', 'API_SMS_android.telephony.SmsManager_sendTextMessage', 'API_SMS_android.telephony.SmsManager_sendMultipartTextMessage', 'API_DeviceData_android.content.ContentResolver_registerContentObserver', 'API_DeviceData_android.content.ContentResolver_insert', 'API_DeviceD ...
# Lasso: ['Memory_PssTotal', 'Memory_PssClean', 'Memory_SharedDirty', 'Memory_PrivateDirty', 'Memory_SharedClean', 'Memory_PrivateClean', 'Memory_HeapSize', 'Memory_HeapAlloc', 'Memory_HeapFree', 'Memory_Views', 'Memory_ViewRootImpl', 'Memory_AppContexts', 'Memory_Activities', 'Memory_Assets', 'Memory_LocalBinders', 'Memory_ProxyBinders', 'Memory_ParcelMemory', 'Memory_ParcelCount', 'Memory_DeathRecipients', 'Memory_OpenSSLSockets', 'Memory_WebViews', 'API_Process_android.app.ActivityManager_killBackgroundProcesses', 'API_Process_android.os.Process_killProcess', 'API_Command_java.lang.Runtime_exec', 'API_Command_java.lang.ProcessBuilder_start', 'API_WebView_android.webkit.WebView_loadUrl', 'API_WebView_android.webkit.WebView_loadDataWithBaseURL', 'API_WebView_android.webkit.WebView_addJavascriptInterface', 'API_WebView_android.webkit.WebView_evaluateJavascript', 'API_WebView_android.webkit.WebView_setWebContentsDebuggingEnabled', 'API_FileIO_libcore.io.IoBridge_open', 'API_FileIO_android.content.ContextWrapper_openFileInput', 'API_FileIO_android.content.ContextWrapper_openFileOutput', 'API_FileIO_android.content.ContextWrapper_deleteFile', 'API_Database_android.content.ContextWrapper_openOrCreateDatabase', 'API_Database_android.content.ContextWrapper_databaseList', 'API_Database_android.database.sqlite.SQLiteDatabase_execSQL', 'API_Database_android.database.sqlite.SQLiteDatabase_getPath', 'API_Database_android.database.sqlite.SQLiteDatabase_insert', 'API_Database_android.database.sqlite.SQLiteDatabase_insertOrThrow', 'API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict', 'API_Database_android.database.sqlite.SQLiteDatabase_openDatabase', 'API_Database_android.database.sqlite.SQLiteDatabase_openOrCreateDatabase', 'API_Database_android.database.sqlite.SQLiteDatabase_query', 'API_Database_android.database.sqlite.SQLiteDatabase_queryWithFactory', 'API_Database_android.database.sqlite.SQLiteDatabase_rawQuery', 'API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory', 'API_Database_android.database.sqlite.SQLiteDatabase_update', 'API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict', 'API_Database_android.database.sqlite.SQLiteDatabase_compileStatement', 'API_IPC_android.content.ContextWrapper_sendBroadcast', 'API_IPC_android.content.ContextWrapper_startActivity', 'API_IPC_android.content.ContextWrapper_startService', 'API_IPC_android.content.ContextWrapper_stopService', 'API_IPC_android.content.ContextWrapper_registerReceiver', 'API_Binder_android.app.ContextImpl_registerReceiver', 'API_Binder_android.app.ActivityThread_handleReceiver', 'API_Binder_android.app.Activity_startActivity', 'API_Crypto_javax.crypto.spec.SecretKeySpec_$init', 'API_Crypto_javax.crypto.Cipher_doFinal', 'API_Crypto-Hash_java.security.MessageDigest_digest', 'API_Crypto-Hash_java.security.MessageDigest_update', 'API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId', 'API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId', 'API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number', 'API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperator', 'API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperatorName', 'API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName', 'API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress', 'API_DeviceInfo_android.net.wifi.WifiInfo_getNetworkId', 'API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso', 'API_DeviceInfo_android.telephony.TelephonyManager_getSimSerialNumber', 'API_DeviceInfo_android.telephony.TelephonyManager_getNetworkCountryIso', 'API_DeviceInfo_android.telephony.TelephonyManager_getDeviceSoftwareVersion', 'API_DeviceInfo_android.os.Debug_isDebuggerConnected', 'API_Network_java.net.URL_openConnection', 'API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream', 'API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResource', 'API_DexClassLoader_dalvik.system. ...
# Ridge: ['Memory_PssTotal', 'Memory_PssClean', 'Memory_SharedDirty', 'Memory_PrivateDirty', 'Memory_SharedClean', 'Memory_PrivateClean', 'Memory_HeapSize', 'Memory_HeapAlloc', 'Memory_HeapFree', 'Memory_Views', 'Memory_ViewRootImpl', 'Memory_AppContexts', 'Memory_Activities', 'Memory_Assets', 'Memory_LocalBinders', 'Memory_ProxyBinders', 'Memory_ParcelMemory', 'Memory_ParcelCount', 'Memory_DeathRecipients', 'Memory_OpenSSLSockets', 'Memory_WebViews', 'API_Process_android.app.ActivityManager_killBackgroundProcesses', 'API_Process_android.os.Process_killProcess', 'API_Command_java.lang.Runtime_exec', 'API_Command_java.lang.ProcessBuilder_start', 'API_JavaNativeInterface_java.lang.Runtime_load', 'API_WebView_android.webkit.WebView_loadUrl', 'API_WebView_android.webkit.WebView_loadData', 'API_WebView_android.webkit.WebView_loadDataWithBaseURL', 'API_WebView_android.webkit.WebView_addJavascriptInterface', 'API_WebView_android.webkit.WebView_evaluateJavascript', 'API_WebView_android.webkit.WebView_postUrl', 'API_WebView_android.webkit.WebView_setWebContentsDebuggingEnabled', 'API_FileIO_libcore.io.IoBridge_open', 'API_FileIO_android.content.ContextWrapper_openFileInput', 'API_FileIO_android.content.ContextWrapper_openFileOutput', 'API_FileIO_android.content.ContextWrapper_deleteFile', 'API_Database_android.content.ContextWrapper_openOrCreateDatabase', 'API_Database_android.content.ContextWrapper_databaseList', 'API_Database_android.content.ContextWrapper_deleteDatabase', 'API_Database_android.database.sqlite.SQLiteDatabase_execSQL', 'API_Database_android.database.sqlite.SQLiteDatabase_deleteDatabase', 'API_Database_android.database.sqlite.SQLiteDatabase_getPath', 'API_Database_android.database.sqlite.SQLiteDatabase_insert', 'API_Database_android.database.sqlite.SQLiteDatabase_insertOrThrow', 'API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict', 'API_Database_android.database.sqlite.SQLiteDatabase_openDatabase', 'API_Database_android.database.sqlite.SQLiteDatabase_openOrCreateDatabase', 'API_Database_android.database.sqlite.SQLiteDatabase_query', 'API_Database_android.database.sqlite.SQLiteDatabase_queryWithFactory', 'API_Database_android.database.sqlite.SQLiteDatabase_rawQuery', 'API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory', 'API_Database_android.database.sqlite.SQLiteDatabase_update', 'API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict', 'API_Database_android.database.sqlite.SQLiteDatabase_compileStatement', 'API_IPC_android.content.ContextWrapper_sendBroadcast', 'API_IPC_android.content.ContextWrapper_sendStickyBroadcast', 'API_IPC_android.content.ContextWrapper_startActivity', 'API_IPC_android.content.ContextWrapper_startService', 'API_IPC_android.content.ContextWrapper_stopService', 'API_IPC_android.content.ContextWrapper_registerReceiver', 'API_Binder_android.app.ContextImpl_registerReceiver', 'API_Binder_android.app.ActivityThread_handleReceiver', 'API_Binder_android.app.Activity_startActivity', 'API_Crypto_javax.crypto.spec.SecretKeySpec_$init', 'API_Crypto_javax.crypto.Cipher_doFinal', 'API_Crypto-Hash_java.security.MessageDigest_digest', 'API_Crypto-Hash_java.security.MessageDigest_update', 'API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId', 'API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId', 'API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number', 'API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperator', 'API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperatorName', 'API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName', 'API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress', 'API_DeviceInfo_android.net.wifi.WifiInfo_getBSSID', 'API_DeviceInfo_android.net.wifi.WifiInfo_getIpAddress', 'API_DeviceInfo_android.net.wifi.WifiInfo_getNetworkId', 'API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso', 'API_DeviceInfo_android.telephony.TelephonyManager_getSimSeri ...
# Elastic Net: ['Memory_PssTotal', 'Memory_PssClean', 'Memory_SharedDirty', 'Memory_PrivateDirty', 'Memory_SharedClean', 'Memory_PrivateClean', 'Memory_HeapSize', 'Memory_HeapAlloc', 'Memory_HeapFree', 'Memory_Views', 'Memory_ViewRootImpl', 'Memory_LocalBinders', 'Memory_ProxyBinders', 'Memory_ParcelMemory', 'Memory_ParcelCount', 'Memory_OpenSSLSockets', 'API_Process_android.app.ActivityManager_killBackgroundProcesses', 'API_Command_java.lang.Runtime_exec', 'API_WebView_android.webkit.WebView_addJavascriptInterface', 'API_WebView_android.webkit.WebView_evaluateJavascript', 'API_FileIO_libcore.io.IoBridge_open', 'API_FileIO_android.content.ContextWrapper_openFileInput', 'API_FileIO_android.content.ContextWrapper_openFileOutput', 'API_FileIO_android.content.ContextWrapper_deleteFile', 'API_Database_android.database.sqlite.SQLiteDatabase_execSQL', 'API_Database_android.database.sqlite.SQLiteDatabase_getPath', 'API_Database_android.database.sqlite.SQLiteDatabase_insert', 'API_Database_android.database.sqlite.SQLiteDatabase_insertOrThrow', 'API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict', 'API_Database_android.database.sqlite.SQLiteDatabase_query', 'API_Database_android.database.sqlite.SQLiteDatabase_rawQuery', 'API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory', 'API_Database_android.database.sqlite.SQLiteDatabase_update', 'API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict', 'API_IPC_android.content.ContextWrapper_sendBroadcast', 'API_IPC_android.content.ContextWrapper_startActivity', 'API_IPC_android.content.ContextWrapper_startService', 'API_IPC_android.content.ContextWrapper_stopService', 'API_IPC_android.content.ContextWrapper_registerReceiver', 'API_Binder_android.app.ContextImpl_registerReceiver', 'API_Binder_android.app.ActivityThread_handleReceiver', 'API_Binder_android.app.Activity_startActivity', 'API_Crypto_javax.crypto.spec.SecretKeySpec_$init', 'API_Crypto_javax.crypto.Cipher_doFinal', 'API_Crypto-Hash_java.security.MessageDigest_digest', 'API_Crypto-Hash_java.security.MessageDigest_update', 'API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId', 'API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId', 'API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number', 'API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName', 'API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress', 'API_DeviceInfo_android.net.wifi.WifiInfo_getBSSID', 'API_DeviceInfo_android.telephony.TelephonyManager_getSimSerialNumber', 'API_DeviceInfo_android.telephony.TelephonyManager_getNetworkCountryIso', 'API_DeviceInfo_android.os.Debug_isDebuggerConnected', 'API_Network_java.net.URL_openConnection', 'API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream', 'API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResource', 'API_DexClassLoader_dalvik.system.BaseDexClassLoader_findLibrary', 'API_DexClassLoader_dalvik.system.DexFile_loadDex', 'API_DexClassLoader_dalvik.system.DexFile_loadClass', 'API_DexClassLoader_dalvik.system.DexClassLoader_$init', 'API_Base64_android.util.Base64_decode', 'API_Base64_android.util.Base64_encodeToString', 'API_SystemManager_android.app.ApplicationPackageManager_setComponentEnabledSetting', 'API_SystemManager_android.app.NotificationManager_notify', 'API_SMS_android.telephony.SmsManager_sendTextMessage', 'API_DeviceData_android.content.ContentResolver_query', 'API_DeviceData_android.content.ContentResolver_registerContentObserver', 'API_DeviceData_android.accounts.AccountManager_getAccountsByType', 'API_DeviceData_android.accounts.AccountManager_getAccounts', 'API_DeviceData_android.os.SystemProperties_get', 'API_DeviceData_android.app.ApplicationPackageManager_getInstalledPackages', 'API__sessions', 'Network_TotalReceivedBytes', 'Network_TotalReceivedPackets', 'Network_TotalTransmittedBytes', 'Network_TotalTransmittedPackets', 'Battery_wakelock', 'Battery_service', 'Logcat_debug', 'Lo ...
# Random Forest: ['Process_total', 'Battery_wakelock', 'Logcat_total', 'Memory_SharedClean', 'Memory_HeapAlloc']
# ExtraTreesClassifier: ['Battery_wakelock', 'Process_total', 'Memory_SharedClean', 'Memory_PrivateClean', 'Memory_PssClean', 'Logcat_total', 'Memory_HeapAlloc', 'Memory_SharedDirty', 'Memory_HeapSize', 'API_DeviceData_android.os.SystemProperties_get', 'Memory_PssTotal', 'API__sessions', 'API_Binder_android.app.ActivityThread_handleReceiver', 'Memory_PrivateDirty', 'API_Binder_android.app.Activity_startActivity', 'Battery_service', 'API_DeviceData_android.content.ContentResolver_registerContentObserver', 'Memory_HeapFree', 'Memory_ParcelCount', 'API_Database_android.database.sqlite.SQLiteDatabase_execSQL', 'API_IPC_android.content.ContextWrapper_registerReceiver', 'Memory_AppContexts', 'Memory_ParcelMemory', 'Memory_ProxyBinders', 'Memory_LocalBinders', 'API_Binder_android.app.ContextImpl_registerReceiver', 'Logcat_warning', 'Logcat_error', 'Logcat_verbose', 'API_IPC_android.content.ContextWrapper_startService', 'Logcat_debug', 'Logcat_info', 'Memory_Views', 'API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId', 'API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId', 'API_Crypto-Hash_java.security.MessageDigest_digest', 'API_Base64_android.util.Base64_decode', 'Memory_ViewRootImpl', 'API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress', 'Network_TotalTransmittedBytes', 'API_Network_java.net.URL_openConnection', 'Network_TotalTransmittedPackets', 'API_FileIO_android.content.ContextWrapper_deleteFile', 'Network_TotalReceivedBytes', 'API_Crypto-Hash_java.security.MessageDigest_update', 'API_DexClassLoader_dalvik.system.BaseDexClassLoader_findLibrary', 'Memory_Activities', 'API_Command_java.lang.Runtime_exec', 'API_Command_java.lang.ProcessBuilder_start', 'Network_TotalReceivedPackets', 'API_FileIO_android.content.ContextWrapper_openFileInput', 'API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResource', 'API_DeviceData_android.app.ApplicationPackageManager_getInstalledPackages', 'API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream', 'API_Database_android.database.sqlite.SQLiteDatabase_rawQuery', 'API_Crypto_javax.crypto.Cipher_doFinal', 'API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperatorName', 'API_DexClassLoader_dalvik.system.DexClassLoader_$init', 'API_Database_android.database.sqlite.SQLiteDatabase_openDatabase', 'API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number']

# %%
DM2.info('display.max_columns', None)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357805 entries, 0 to 357804
# Data columns (total 9505 columns):
#  #     Column  Dtype
# ---    ------  -----
#  0     F0      object
#  1     F1      int16
#  2     F2      int16
#  3     F3      int16
#  4     F4      int16
#  5     F5      int8
#  6     F6      int8
#  7     F7      int8
#  8     F8      int8
#  9     F9      int8
#  10    F10     int8
#  11    F11     int8
#  12    F12     int8
#  13    F13     int8
#  14    F14     int8
#  15    F15     int8
#  16    F16     int8
#  17    F17     int8
#  18    F18     int8
#  19    F19     int8
#  20    F20     int8
#  21    F21     int8
#  22    F22     int8
#  23    F23     int8
#  24    F24     int8
#  25    F25     int8
#  26    F26     int8
#  27    F27     int8
#  28    F28     int8
#  29    F29     int8
#  30    F30     int8
#  31    F31     int8
#  32    F32     int8
#  33    F33     int8
#  34    F34     int8
#  35    F35     int8
#  36    F36     int8
#  37    F37     int8
#  38    F38     int8
#  39    F39     int8
#  40    F40     int8
#  41    F41     int8
#  42    F42     int8
#  43    F43     int8
#  44    F44     int8
#  45    F45     int8
#  46    F46     int8
#  47    F47     int8
#  48    F48     int8
#  49    F49     int8
#  50    F50     int8
#  51    F51     int8
#  52    F52     int8
#  53    F53     int8
#  54    F54     int8
#  55    F55     int8
#  56    F56     int8
#  57    F57     int8
#  58    F58     int8
#  59    F59     int8
#  60    F60     int8
#  61    F61     int8
#  62    F62     int8
#  63    F63     int8
#  64    F64     int8
#  65    F65     int8
#  66    F66     int8
#  67    F67     int8
#  68    F68     int8
#  69    F69     int8
#  70    F70     int8
#  71    F71     int8
#  72    F72     int8
#  73    F73     int8
#  74    F74     int8
#  75    F75     int8
#  76    F76     int8
#  77    F77     int8
#  78    F78     int8
#  79    F79     int8
#  80    F80     int8
#  81    F81     int8
#  82    F82     int8
#  83    F83     int8
#  84    F84     int8
#  85    F85     int8
#  86    F86     int8
#  87    F87     int8
#  88    F88     int8
#  89    F89     int8
#  90    F90     int8
#  91    F91     int8
#  92    F92     int8
#  93    F93     int8
#  94    F94     int8
#  95    F95     int8
#  96    F96     int8
#  97    F97     int8
#  98    F98     int8
#  99    F99     int8
#  100   F100    int8
#  101   F101    int8
#  102   F102    int8
#  103   F103    int8
#  104   F104    int8
#  105   F105    int8
#  106   F106    int8
#  107   F107    int8
#  108   F108    int8
#  109   F109    int8
#  110   F110    int8
#  111   F111    int8
#  112   F112    int8
#  113   F113    int8
#  114   F114    int8
#  115   F115    int8
#  116   F116    int8
#  117   F117    int8
#  118   F118    int8
#  119   F119    int8
#  120   F120    int8
#  121   F121    int8
#  122   F122    int8
#  123   F123    int8
#  124   F124    int8
#  125   F125    int8
#  126   F126    int8
#  127   F127    int8
#  128   F128    int8
#  129   F129    int8
#  130   F130    int8
#  131   F131    int8
#  132   F132    int8
#  133   F133    int8
#  134   F134    int8
#  135   F135    int8
#  136   F136    int8
#  137   F137    int8
#  138   F138    int8
#  139   F139    int8
#  140   F140    int8
#  141   F141    int8
#  142   F142    int8
#  143   F143    int8
#  144   F144    int8
#  145   F145    int8
#  146   F146    int8
#  147   F147    int8
#  148   F148    int8
#  149   F149    int8
#  150   F150    int8
#  151   F151    int8
#  152   F152    int8
#  153   F153    int8
#  154   F154    int8
#  155   F155    int8
#  156   F156    int8
#  157   F157    int8
#  158   F158    int8
#  159   F159    int8
#  160   F160    int8
#  161   F161    int8
#  162   F162    int8
#  163   F163    int8
#  164   F164    int8
#  165   F165    int8
#  166   F166    int8
#  167   F167    int8
#  168   F168    int8
#  169   F169    int8
#  170   F170    int8
#  171   F171    int8
#  172   F172    int8
#  173   F173    int8
#  174   F174    int8
#  175   F175    int8
#  176   F176    int8
#  177   F177    int8
#  178   F178    int8
#  179   F179    int8
#  180   F180    int8
#  181   F181    int8
#  182   F182    int8
#  183   F183    int8
#  184   F184    int8
#  185   F185    int8
#  186   F186    int8
#  187   F187    int8
#  188   F188    int8
#  189   F189    int8
#  190   F190    int8
#  191   F191    int8
#  192   F192    int8
#  193   F193    int8
#  194   F194    int8
#  195   F195    int8
#  196   F196    int8
#  197   F197    int8
#  198   F198    int8
#  199   F199    int8
#  200   F200    int8
#  201   F201    int8
#  202   F202    int8
#  203   F203    int8
#  204   F204    int8
#  205   F205    int8
#  206   F206    int8
#  207   F207    int8
#  208   F208    int8
#  209   F209    int8
#  210   F210    int8
#  211   F211    int8
#  212   F212    int8
#  213   F213    int8
#  214   F214    int8
#  215   F215    int8
#  216   F216    int8
#  217   F217    int8
#  218   F218    int8
#  219   F219    int8
#  220   F220    int8
#  221   F221    int8
#  222   F222    int8
#  223   F223    int8
#  224   F224    int8
#  225   F225    int8
#  226   F226    int8
#  227   F227    int8
#  228   F228    int8
#  229   F229    int8
#  230   F230    int8
#  231   F231    int8
#  232   F232    int8
#  233   F233    int8
#  234   F234    int8
#  235   F235    int8
#  236   F236    int8
#  237   F237    int8
#  238   F238    int8
#  239   F239    int8
#  240   F240    int8
#  241   F241    int8
#  242   F242    int8
#  243   F243    int8
#  244   F244    int8
#  245   F245    int8
#  246   F246    int8
#  247   F247    int8
#  248   F248    int8
#  249   F249    int8
#  250   F250    int8
#  251   F251    int8
#  252   F252    int8
#  253   F253    int8
#  254   F254    int8
#  255   F255    int8
#  256   F256    int8
#  257   F257    int8
#  258   F258    int8
#  259   F259    int8
#  260   F260    int8
#  261   F261    int8
#  262   F262    int8
#  263   F263    int8
#  264   F264    int8
#  265   F265    int8
#  266   F266    int8
#  267   F267    int8
#  268   F268    int8
#  269   F269    int8
#  270   F270    int8
#  271   F271    int8
#  272   F272    int8
#  273   F273    int8
#  274   F274    int8
#  275   F275    int8
#  276   F276    int8
#  277   F277    int8
#  278   F278    int8
#  279   F279    int8
#  280   F280    int8
#  281   F281    int8
#  282   F282    int8
#  283   F283    int8
#  284   F284    int8
#  285   F285    int8
#  286   F286    int8
#  287   F287    int8
#  288   F288    int8
#  289   F289    int8
#  290   F290    int8
#  291   F291    int8
#  292   F292    int8
#  293   F293    int8
#  294   F294    int8
#  295   F295    int8
#  296   F296    int8
#  297   F297    int8
#  298   F298    int8
#  299   F299    int8
#  300   F300    int8
#  301   F301    int8
#  302   F302    int8
#  303   F303    int8
#  304   F304    int8
#  305   F305    int8
#  306   F306    int8
#  307   F307    int8
#  308   F308    int8
#  309   F309    int8
#  310   F310    int8
#  311   F311    int8
#  312   F312    int8
#  313   F313    int8
#  314   F314    int8
#  315   F315    int8
#  316   F316    int8
#  317   F317    int8
#  318   F318    int8
#  319   F319    int8
#  320   F320    int8
#  321   F321    int8
#  322   F322    int8
#  323   F323    int8
#  324   F324    int8
#  325   F325    int8
#  326   F326    int8
#  327   F327    int8
#  328   F328    int8
#  329   F329    int8
#  330   F330    int8
#  331   F331    int8
#  332   F332    int8
#  333   F333    int8
#  334   F334    int8
#  335   F335    int8
#  336   F336    int8
#  337   F337    int8
#  338   F338    int8
#  339   F339    int8
#  340   F340    int8
#  341   F341    int8
#  342   F342    int8
#  343   F343    int8
#  344   F344    int8
#  345   F345    int8
#  346   F346    int8
#  347   F347    int8
#  348   F348    int8
#  349   F349    int8
#  350   F350    int8
#  351   F351    int8
#  352   F352    int8
#  353   F353    int8
#  354   F354    int8
#  355   F355    int8
#  356   F356    int8
#  357   F357    int8
#  358   F358    int8
#  359   F359    int8
#  360   F360    int8
#  361   F361    int8
#  362   F362    int8
#  363   F363    int8
#  364   F364    int8
#  365   F365    int8
#  366   F366    int8
#  367   F367    int8
#  368   F368    int8
#  369   F369    int8
#  370   F370    int8
#  371   F371    int8
#  372   F372    int8
#  373   F373    int8
#  374   F374    int8
#  375   F375    int8
#  376   F376    int8
#  377   F377    int8
#  378   F378    int8
#  379   F379    int8
#  380   F380    int8
#  381   F381    int8
#  382   F382    int8
#  383   F383    int8
#  384   F384    int8
#  385   F385    int8
#  386   F386    int8
#  387   F387    int8
#  388   F388    int8
#  389   F389    int8
#  390   F390    int8
#  391   F391    int8
#  392   F392    int8
#  393   F393    int8
#  394   F394    int8
#  395   F395    int8
#  396   F396    int8
#  397   F397    int8
#  398   F398    int8
#  399   F399    int8
#  400   F400    int8
#  401   F401    int8
#  402   F402    int8
#  403   F403    int8
#  404   F404    int8
#  405   F405    int8
#  406   F406    int8
#  407   F407    int8
#  408   F408    int8
#  409   F409    int8
#  410   F410    int8
#  411   F411    int8
#  412   F412    int8
#  413   F413    int8
#  414   F414    int8
#  415   F415    int8
#  416   F416    int8
#  417   F417    int8
#  418   F418    int8
#  419   F419    int8
#  420   F420    int8
#  421   F421    int8
#  422   F422    int8
#  423   F423    int8
#  424   F424    int8
#  425   F425    int8
#  426   F426    int8
#  427   F427    int8
#  428   F428    int8
#  429   F429    int8
#  430   F430    int8
#  431   F431    int8
#  432   F432    int8
#  433   F433    int8
#  434   F434    int8
#  435   F435    int8
#  436   F436    int8
#  437   F437    int8
#  438   F438    int8
#  439   F439    int8
#  440   F440    int8
#  441   F441    int8
#  442   F442    int8
#  443   F443    int8
#  444   F444    int8
#  445   F445    int8
#  446   F446    int8
#  447   F447    int8
#  448   F448    int8
#  449   F449    int8
#  450   F450    int8
#  451   F451    int8
#  452   F452    int8
#  453   F453    int8
#  454   F454    int8
#  455   F455    int8
#  456   F456    int8
#  457   F457    int8
#  458   F458    int8
#  459   F459    int8
#  460   F460    int8
#  461   F461    int8
#  462   F462    int8
#  463   F463    int8
#  464   F464    int8
#  465   F465    int8
#  466   F466    int8
#  467   F467    int8
#  468   F468    int8
#  469   F469    int8
#  470   F470    int8
#  471   F471    int8
#  472   F472    int8
#  473   F473    int8
#  474   F474    int8
#  475   F475    int8
#  476   F476    int8
#  477   F477    int8
#  478   F478    int8
#  479   F479    int8
#  480   F480    int8
#  481   F481    int8
#  482   F482    int8
#  483   F483    int8
#  484   F484    int8
#  485   F485    int8
#  486   F486    int8
#  487   F487    int8
#  488   F488    int8
#  489   F489    int8
#  490   F490    int8
#  491   F491    int8
#  492   F492    int8
#  493   F493    int8
#  494   F494    int8
#  495   F495    int8
#  496   F496    int8
#  497   F497    int8
#  498   F498    int8
#  499   F499    int8
#  500   F500    int8
#  501   F501    int8
#  502   F502    int8
#  503   F503    int8
#  504   F504    int8
#  505   F505    int8
#  506   F506    int8
#  507   F507    int8
#  508   F508    int8
#  509   F509    int8
#  510   F510    int8
#  511   F511    int8
#  512   F512    int8
#  513   F513    int8
#  514   F514    int8
#  515   F515    int8
#  516   F516    int8
#  517   F517    int8
#  518   F518    int8
#  519   F519    int8
#  520   F520    int8
#  521   F521    int8
#  522   F522    int8
#  523   F523    int8
#  524   F524    int8
#  525   F525    int8
#  526   F526    int8
#  527   F527    int8
#  528   F528    int8
#  529   F529    int8
#  530   F530    int8
#  531   F531    int8
#  532   F532    int8
#  533   F533    int8
#  534   F534    int8
#  535   F535    int8
#  536   F536    int8
#  537   F537    int8
#  538   F538    int8
#  539   F539    int8
#  540   F540    int8
#  541   F541    int8
#  542   F542    int8
#  543   F543    int8
#  544   F544    int8
#  545   F545    int8
#  546   F546    int8
#  547   F547    int8
#  548   F548    int8
#  549   F549    int8
#  550   F550    int8
#  551   F551    int8
#  552   F552    int8
#  553   F553    int8
#  554   F554    int8
#  555   F555    int8
#  556   F556    int8
#  557   F557    int8
#  558   F558    int8
#  559   F559    int8
#  560   F560    int8
#  561   F561    int8
#  562   F562    int8
#  563   F563    int8
#  564   F564    int8
#  565   F565    int8
#  566   F566    int8
#  567   F567    int8
#  568   F568    int8
#  569   F569    int8
#  570   F570    int8
#  571   F571    int8
#  572   F572    int8
#  573   F573    int8
#  574   F574    int8
#  575   F575    int8
#  576   F576    int8
#  577   F577    int8
#  578   F578    int8
#  579   F579    int8
#  580   F580    int8
#  581   F581    int8
#  582   F582    int8
#  583   F583    int8
#  584   F584    int8
#  585   F585    int8
#  586   F586    int8
#  587   F587    int8
#  588   F588    int8
#  589   F589    int8
#  590   F590    int8
#  591   F591    int8
#  592   F592    int8
#  593   F593    int8
#  594   F594    int8
#  595   F595    int8
#  596   F596    int8
#  597   F597    int8
#  598   F598    int8
#  599   F599    int8
#  600   F600    int8
#  601   F601    int8
#  602   F602    int8
#  603   F603    int8
#  604   F604    int8
#  605   F605    int8
#  606   F606    int8
#  607   F607    int8
#  608   F608    int8
#  609   F609    int8
#  610   F610    int8
#  611   F611    int8
#  612   F612    int8
#  613   F613    int8
#  614   F614    int8
#  615   F615    int8
#  616   F616    int8
#  617   F617    int8
#  618   F618    int8
#  619   F619    int8
#  620   F620    int8
#  621   F621    int8
#  622   F622    int8
#  623   F623    int8
#  624   F624    int8
#  625   F625    int8
#  626   F626    int8
#  627   F627    int8
#  628   F628    int8
#  629   F629    int8
#  630   F630    int8
#  631   F631    int8
#  632   F632    int8
#  633   F633    int8
#  634   F634    int8
#  635   F635    int8
#  636   F636    int8
#  637   F637    int8
#  638   F638    int8
#  639   F639    int8
#  640   F640    int8
#  641   F641    int8
#  642   F642    int8
#  643   F643    int8
#  644   F644    int8
#  645   F645    int8
#  646   F646    int8
#  647   F647    int8
#  648   F648    int8
#  649   F649    int8
#  650   F650    int8
#  651   F651    int8
#  652   F652    int8
#  653   F653    int8
#  654   F654    int8
#  655   F655    int8
#  656   F656    int8
#  657   F657    int8
#  658   F658    int8
#  659   F659    int8
#  660   F660    int8
#  661   F661    int8
#  662   F662    int8
#  663   F663    int8
#  664   F664    int8
#  665   F665    int8
#  666   F666    int8
#  667   F667    int8
#  668   F668    int8
#  669   F669    int8
#  670   F670    int8
#  671   F671    int8
#  672   F672    int8
#  673   F673    int8
#  674   F674    int8
#  675   F675    int8
#  676   F676    int8
#  677   F677    int8
#  678   F678    int8
#  679   F679    int8
#  680   F680    int8
#  681   F681    int8
#  682   F682    int8
#  683   F683    int8
#  684   F684    int8
#  685   F685    int8
#  686   F686    int8
#  687   F687    int8
#  688   F688    int8
#  689   F689    int8
#  690   F690    int8
#  691   F691    int8
#  692   F692    int8
#  693   F693    int8
#  694   F694    int8
#  695   F695    int8
#  696   F696    int8
#  697   F697    int8
#  698   F698    int8
#  699   F699    int8
#  700   F700    int8
#  701   F701    int8
#  702   F702    int8
#  703   F703    int8
#  704   F704    int8
#  705   F705    int8
#  706   F706    int8
#  707   F707    int8
#  708   F708    int8
#  709   F709    int8
#  710   F710    int8
#  711   F711    int8
#  712   F712    int8
#  713   F713    int8
#  714   F714    int8
#  715   F715    int8
#  716   F716    int8
#  717   F717    int8
#  718   F718    int8
#  719   F719    int8
#  720   F720    int8
#  721   F721    int8
#  722   F722    int8
#  723   F723    int8
#  724   F724    int8
#  725   F725    int8
#  726   F726    int8
#  727   F727    int8
#  728   F728    int8
#  729   F729    int8
#  730   F730    int8
#  731   F731    int8
#  732   F732    int8
#  733   F733    int8
#  734   F734    int8
#  735   F735    int8
#  736   F736    int8
#  737   F737    int8
#  738   F738    int8
#  739   F739    int8
#  740   F740    int8
#  741   F741    int8
#  742   F742    int8
#  743   F743    int8
#  744   F744    int8
#  745   F745    int8
#  746   F746    int8
#  747   F747    int8
#  748   F748    int8
#  749   F749    int8
#  750   F750    int8
#  751   F751    int8
#  752   F752    int8
#  753   F753    int8
#  754   F754    int8
#  755   F755    int8
#  756   F756    int8
#  757   F757    int8
#  758   F758    int8
#  759   F759    int8
#  760   F760    int8
#  761   F761    int8
#  762   F762    int8
#  763   F763    int8
#  764   F764    int8
#  765   F765    int8
#  766   F766    int8
#  767   F767    int8
#  768   F768    int8
#  769   F769    int8
#  770   F770    int8
#  771   F771    int8
#  772   F772    int8
#  773   F773    int8
#  774   F774    int8
#  775   F775    int8
#  776   F776    int8
#  777   F777    int8
#  778   F778    int8
#  779   F779    int8
#  780   F780    int8
#  781   F781    int8
#  782   F782    int8
#  783   F783    int8
#  784   F784    int8
#  785   F785    int8
#  786   F786    int8
#  787   F787    int8
#  788   F788    int8
#  789   F789    int8
#  790   F790    int8
#  791   F791    int8
#  792   F792    int8
#  793   F793    int8
#  794   F794    int8
#  795   F795    int8
#  796   F796    int8
#  797   F797    int8
#  798   F798    int8
#  799   F799    int8
#  800   F800    int8
#  801   F801    int8
#  802   F802    int8
#  803   F803    int8
#  804   F804    int8
#  805   F805    int8
#  806   F806    int8
#  807   F807    int8
#  808   F808    int8
#  809   F809    int8
#  810   F810    int8
#  811   F811    int8
#  812   F812    int8
#  813   F813    int8
#  814   F814    int8
#  815   F815    int8
#  816   F816    int8
#  817   F817    int8
#  818   F818    int8
#  819   F819    int8
#  820   F820    int8
#  821   F821    int8
#  822   F822    int8
#  823   F823    int8
#  824   F824    int8
#  825   F825    int8
#  826   F826    int8
#  827   F827    int8
#  828   F828    int8
#  829   F829    int8
#  830   F830    int8
#  831   F831    int8
#  832   F832    int8
#  833   F833    int8
#  834   F834    int8
#  835   F835    int8
#  836   F836    int8
#  837   F837    int8
#  838   F838    int8
#  839   F839    int8
#  840   F840    int8
#  841   F841    int8
#  842   F842    int8
#  843   F843    int8
#  844   F844    int8
#  845   F845    int8
#  846   F846    int8
#  847   F847    int8
#  848   F848    int8
#  849   F849    int8
#  850   F850    int8
#  851   F851    int8
#  852   F852    int8
#  853   F853    int8
#  854   F854    int8
#  855   F855    int8
#  856   F856    int8
#  857   F857    int8
#  858   F858    int8
#  859   F859    int8
#  860   F860    int8
#  861   F861    int8
#  862   F862    int8
#  863   F863    int8
#  864   F864    int8
#  865   F865    int8
#  866   F866    int8
#  867   F867    int8
#  868   F868    int8
#  869   F869    int8
#  870   F870    int8
#  871   F871    int8
#  872   F872    int8
#  873   F873    int8
#  874   F874    int8
#  875   F875    int8
#  876   F876    int8
#  877   F877    int8
#  878   F878    int8
#  879   F879    int8
#  880   F880    int8
#  881   F881    int8
#  882   F882    int8
#  883   F883    int8
#  884   F884    int8
#  885   F885    int8
#  886   F886    int8
#  887   F887    int8
#  888   F888    int8
#  889   F889    int8
#  890   F890    int8
#  891   F891    int8
#  892   F892    int8
#  893   F893    int8
#  894   F894    int8
#  895   F895    int8
#  896   F896    int8
#  897   F897    int8
#  898   F898    int8
#  899   F899    int8
#  900   F900    int8
#  901   F901    int8
#  902   F902    int8
#  903   F903    int8
#  904   F904    int8
#  905   F905    int8
#  906   F906    int8
#  907   F907    int8
#  908   F908    int8
#  909   F909    int8
#  910   F910    int8
#  911   F911    int8
#  912   F912    int8
#  913   F913    int8
#  914   F914    int8
#  915   F915    int8
#  916   F916    int8
#  917   F917    int8
#  918   F918    int8
#  919   F919    int8
#  920   F920    int8
#  921   F921    int8
#  922   F922    int8
#  923   F923    int8
#  924   F924    int8
#  925   F925    int8
#  926   F926    int8
#  927   F927    int8
#  928   F928    int8
#  929   F929    int8
#  930   F930    int8
#  931   F931    int8
#  932   F932    int8
#  933   F933    int8
#  934   F934    int8
#  935   F935    int8
#  936   F936    int8
#  937   F937    int8
#  938   F938    int8
#  939   F939    int8
#  940   F940    int8
#  941   F941    int8
#  942   F942    int8
#  943   F943    int8
#  944   F944    int8
#  945   F945    int8
#  946   F946    int8
#  947   F947    int8
#  948   F948    int8
#  949   F949    int8
#  950   F950    int8
#  951   F951    int8
#  952   F952    int8
#  953   F953    int8
#  954   F954    int8
#  955   F955    int8
#  956   F956    int8
#  957   F957    int8
#  958   F958    int8
#  959   F959    int8
#  960   F960    int8
#  961   F961    int8
#  962   F962    int8
#  963   F963    int8
#  964   F964    int8
#  965   F965    int8
#  966   F966    int8
#  967   F967    int8
#  968   F968    int8
#  969   F969    int8
#  970   F970    int8
#  971   F971    int8
#  972   F972    int8
#  973   F973    int8
#  974   F974    int8
#  975   F975    int8
#  976   F976    int8
#  977   F977    int8
#  978   F978    int8
#  979   F979    int8
#  980   F980    int8
#  981   F981    int8
#  982   F982    int8
#  983   F983    int8
#  984   F984    int8
#  985   F985    int8
#  986   F986    int8
#  987   F987    int8
#  988   F988    int8
#  989   F989    int8
#  990   F990    int8
#  991   F991    int8
#  992   F992    int8
#  993   F993    int8
#  994   F994    int8
#  995   F995    int8
#  996   F996    int8
#  997   F997    int8
#  998   F998    int8
#  999   F999    int8
#  1000  F1000   int8
#  1001  F1001   int8
#  1002  F1002   int8
#  1003  F1003   int8
#  1004  F1004   int8
#  1005  F1005   int8
#  1006  F1006   int8
#  1007  F1007   int8
#  1008  F1008   int8
#  1009  F1009   int8
#  1010  F1010   int8
#  1011  F1011   int8
#  1012  F1012   int8
#  1013  F1013   int8
#  1014  F1014   int8
#  1015  F1015   int8
#  1016  F1016   int8
#  1017  F1017   int8
#  1018  F1018   int8
#  1019  F1019   int8
#  1020  F1020   int8
#  1021  F1021   int8
#  1022  F1022   int8
#  1023  F1023   int8
#  1024  F1024   int8
#  1025  F1025   int8
#  1026  F1026   int8
#  1027  F1027   int8
#  1028  F1028   int8
#  1029  F1029   int8
#  1030  F1030   int8
#  1031  F1031   int8
#  1032  F1032   int8
#  1033  F1033   int8
#  1034  F1034   int8
#  1035  F1035   int8
#  1036  F1036   int8
#  1037  F1037   int8
#  1038  F1038   int8
#  1039  F1039   int8
#  1040  F1040   int8
#  1041  F1041   int8
#  1042  F1042   int8
#  1043  F1043   int8
#  1044  F1044   int8
#  1045  F1045   int8
#  1046  F1046   int8
#  1047  F1047   int8
#  1048  F1048   int8
#  1049  F1049   int8
#  1050  F1050   int8
#  1051  F1051   int8
#  1052  F1052   int8
#  1053  F1053   int8
#  1054  F1054   int8
#  1055  F1055   int8
#  1056  F1056   int8
#  1057  F1057   int8
#  1058  F1058   int8
#  1059  F1059   int8
#  1060  F1060   int8
#  1061  F1061   int8
#  1062  F1062   int8
#  1063  F1063   int8
#  1064  F1064   int8
#  1065  F1065   int8
#  1066  F1066   int8
#  1067  F1067   int8
#  1068  F1068   int8
#  1069  F1069   int8
#  1070  F1070   int8
#  1071  F1071   int8
#  1072  F1072   int8
#  1073  F1073   int8
#  1074  F1074   int8
#  1075  F1075   int8
#  1203  F1203   int8
#  1204  F1204   int8
#  1205  F1205   int8
#  1206  F1206   int8
#  1207  F1207   int8
#  1208  F1208   int8
#  1209  F1209   int8
#  1210  F1210   int8
#  1211  F1211   int8
#  1212  F1212   int8
#  1213  F1213   int8
#  1214  F1214   int8
#  1215  F1215   int8
#  1216  F1216   int8
#  1217  F1217   int8
#  1218  F1218   int8
#  1219  F1219   int8
#  1220  F1220   int8
#  1221  F1221   int8
#  1222  F1222   int8
#  1223  F1223   int8
#  1224  F1224   int8
#  1225  F1225   int8
#  1226  F1226   int8
#  1227  F1227   int8
#  1228  F1228   int8
#  1229  F1229   int8
#  1230  F1230   int8
#  1231  F1231   int8
#  1232  F1232   int8
#  1233  F1233   int8
#  1234  F1234   int8
#  1235  F1235   int8
#  1236  F1236   int8
#  1237  F1237   int8
#  1238  F1238   int8
#  1239  F1239   int8
#  1240  F1240   int8
#  1241  F1241   int8
#  1242  F1242   int8
#  1243  F1243   int8
#  1244  F1244   int8
#  1245  F1245   int8
#  1246  F1246   int8
#  1247  F1247   int8
#  1248  F1248   int8
#  1249  F1249   int8
#  1250  F1250   int8
#  1251  F1251   int8
#  1252  F1252   int8
#  1253  F1253   int8
#  1254  F1254   int8
#  1255  F1255   int8
#  1256  F1256   int8
#  1257  F1257   int8
#  1258  F1258   int8
#  1259  F1259   int8
#  1260  F1260   int8
#  1261  F1261   int8
#  1262  F1262   int8
#  1263  F1263   int8
#  1264  F1264   int8
#  1265  F1265   int8
#  1266  F1266   int8
#  1267  F1267   int8
#  1268  F1268   int8
#  1269  F1269   int8
#  1270  F1270   int8
#  1271  F1271   int8
#  1272  F1272   int8
#  1273  F1273   int8
#  1274  F1274   int8
#  1275  F1275   int8
#  1276  F1276   int8
#  1277  F1277   int8
#  1278  F1278   int8
#  1279  F1279   int8
#  1280  F1280   int8
#  1281  F1281   int8
#  1282  F1282   int8
#  1283  F1283   int8
#  1284  F1284   int8
#  1285  F1285   int8
#  1286  F1286   int8
#  1287  F1287   int8
#  1288  F1288   int8
#  1289  F1289   int8
#  1290  F1290   int8
#  1291  F1291   int8
#  1292  F1292   int8
#  1293  F1293   int8
#  1294  F1294   int8
#  1295  F1295   int8
#  1296  F1296   int8
#  1297  F1297   int8
#  1298  F1298   int8
#  1299  F1299   int8
#  1300  F1300   int8
#  1301  F1301   int8
#  1302  F1302   int8
#  1303  F1303   int8
#  1304  F1304   int8
#  1305  F1305   int8
#  1306  F1306   int8
#  1307  F1307   int8
#  1308  F1308   int8
#  1309  F1309   int8
#  1310  F1310   int8
#  1311  F1311   int8
#  1312  F1312   int8
#  1313  F1313   int8
#  1314  F1314   int8
#  1315  F1315   int8
#  1316  F1316   int8
#  1317  F1317   int8
#  1318  F1318   int8
#  1319  F1319   int8
#  1320  F1320   int8
#  1321  F1321   int8
#  1322  F1322   int8
#  1323  F1323   int8
#  1324  F1324   int8
#  1325  F1325   int8
#  1326  F1326   int8
#  1327  F1327   int8
#  1328  F1328   int8
#  1329  F1329   int8
#  1330  F1330   int8
#  1586  F1586   int8
#  1587  F1587   int8
#  1588  F1588   int8
#  1589  F1589   int8
#  1590  F1590   int8
#  1591  F1591   int8
#  1592  F1592   int8
#  1593  F1593   int8
#  1594  F1594   int8
#  1595  F1595   int8
#  1596  F1596   int8
#  1597  F1597   int8
#  1598  F1598   int8
#  1599  F1599   int8
#  1600  F1600   int8
#  1601  F1601   int8
#  1602  F1602   int8
#  1603  F1603   int8
#  1604  F1604   int8
#  1605  F1605   int8
#  1606  F1606   int8
#  1607  F1607   int8
#  1608  F1608   int8
#  1609  F1609   int8
#  1610  F1610   int8
#  1611  F1611   int8
#  1612  F1612   int8
#  1613  F1613   int8
#  1614  F1614   int8
#  1615  F1615   int8
#  1616  F1616   int8
#  1617  F1617   int8
#  1618  F1618   int8
#  1619  F1619   int8
#  1620  F1620   int8
#  1621  F1621   int8
#  1622  F1622   int8
#  1623  F1623   int8
#  1624  F1624   int8
#  1625  F1625   int8
#  1626  F1626   int8
#  1627  F1627   int8
#  1628  F1628   int8
#  1629  F1629   int8
#  1630  F1630   int8
#  1631  F1631   int8
#  1632  F1632   int8
#  1633  F1633   int8
#  1634  F1634   int8
#  1635  F1635   int8
#  1636  F1636   int8
#  1637  F1637   int8
#  1638  F1638   int8
#  1639  F1639   int8
#  1640  F1640   int8
#  1641  F1641   int8
#  1642  F1642   int8
#  1643  F1643   int8
#  1644  F1644   int8
#  1645  F1645   int8
#  1646  F1646   int8
#  1647  F1647   int8
#  1648  F1648   int8
#  1649  F1649   int8
#  1650  F1650   int8
#  1651  F1651   int8
#  1652  F1652   int8
#  1653  F1653   int8
#  1654  F1654   int8
#  1655  F1655   int8
#  1656  F1656   int8
#  1657  F1657   int8
#  1658  F1658   int8
#  1659  F1659   int8
#  1660  F1660   int8
#  1661  F1661   int8
#  1662  F1662   int8
#  1663  F1663   int8
#  1664  F1664   int8
#  1665  F1665   int8
#  1666  F1666   int8
#  1667  F1667   int8
#  1668  F1668   int8
#  1669  F1669   int8
#  1670  F1670   int8
#  1671  F1671   int8
#  1672  F1672   int8
#  1673  F1673   int8
#  1674  F1674   int8
#  1675  F1675   int8
#  1676  F1676   int8
#  1677  F1677   int8
#  1678  F1678   int8
#  1679  F1679   int8
#  1680  F1680   int8
#  1681  F1681   int8
#  1682  F1682   int8
#  1683  F1683   int8
#  1684  F1684   int8
#  1685  F1685   int8
#  1686  F1686   int8
#  1687  F1687   int8
#  1688  F1688   int8
#  1689  F1689   int8
#  1690  F1690   int8
#  1691  F1691   int8
#  1692  F1692   int8
#  1693  F1693   int8
#  1694  F1694   int8
#  1695  F1695   int8
#  1696  F1696   int8
#  1697  F1697   int8
#  1698  F1698   int8
#  1699  F1699   int8
#  1700  F1700   int8
#  1701  F1701   int8
#  1702  F1702   int8
#  1703  F1703   int8
#  1704  F1704   int8
#  1705  F1705   int8
#  1706  F1706   int8
#  1707  F1707   int8
#  1708  F1708   int8
#  1709  F1709   int8
#  1710  F1710   int8
#  1711  F1711   int8
#  1712  F1712   int8
#  1841  F1841   int8
#  1842  F1842   int8
#  1843  F1843   int8
#  1844  F1844   int8
#  1845  F1845   int8
#  1846  F1846   int8
#  1847  F1847   int8
#  1848  F1848   int8
#  1849  F1849   int8
#  1850  F1850   int8
#  1851  F1851   int8
#  1852  F1852   int8
#  1853  F1853   int8
#  1854  F1854   int8
#  1855  F1855   int8
#  1856  F1856   int8
#  1857  F1857   int8
#  1858  F1858   int8
#  1859  F1859   int8
#  1860  F1860   int8
#  1861  F1861   int8
#  1862  F1862   int8
#  1863  F1863   int8
#  1864  F1864   int8
#  1865  F1865   int8
#  1866  F1866   int8
#  1867  F1867   int8
#  1868  F1868   int8
#  1869  F1869   int8
#  1870  F1870   int8
#  1871  F1871   int8
#  1872  F1872   int8
#  1873  F1873   int8
#  1874  F1874   int8
#  1875  F1875   int8
#  1876  F1876   int8
#  1877  F1877   int8
#  1878  F1878   int8
#  1879  F1879   int8
#  1880  F1880   int8
#  1881  F1881   int8
#  1882  F1882   int8
#  1883  F1883   int8
#  1884  F1884   int8
#  1885  F1885   int8
#  1886  F1886   int8
#  1887  F1887   int8
#  1888  F1888   int8
#  1889  F1889   int8
#  1890  F1890   int8
#  1891  F1891   int8
#  1892  F1892   int8
#  1893  F1893   int8
#  1894  F1894   int8
#  1895  F1895   int8
#  1896  F1896   int8
#  1897  F1897   int8
#  1898  F1898   int8
#  1899  F1899   int8
#  1900  F1900   int8
#  1901  F1901   int8
#  1902  F1902   int8
#  1903  F1903   int8
#  1904  F1904   int8
#  1905  F1905   int8
#  1906  F1906   int8
#  1907  F1907   int8
#  1908  F1908   int8
#  1909  F1909   int8
#  1910  F1910   int8
#  1911  F1911   int8
#  1912  F1912   int8
#  1913  F1913   int8
#  1914  F1914   int8
#  1915  F1915   int8
#  1916  F1916   int8
#  1917  F1917   int8
#  1918  F1918   int8
#  1919  F1919   int8
#  1920  F1920   int8
#  1921  F1921   int8
#  1922  F1922   int8
#  1923  F1923   int8
#  1924  F1924   int8
#  1925  F1925   int8
#  1926  F1926   int8
#  1927  F1927   int8
#  1928  F1928   int8
#  1929  F1929   int8
#  1930  F1930   int8
#  1931  F1931   int8
#  1932  F1932   int8
#  1933  F1933   int8
#  1934  F1934   int8
#  1935  F1935   int8
#  1936  F1936   int8
#  1937  F1937   int8
#  1938  F1938   int8
#  1939  F1939   int8
#  1940  F1940   int8
#  1941  F1941   int8
#  1942  F1942   int8
#  1943  F1943   int8
#  1944  F1944   int8
#  1945  F1945   int8
#  1946  F1946   int8
#  1947  F1947   int8
#  1948  F1948   int8
#  1949  F1949   int8
#  1950  F1950   int8
#  1951  F1951   int8
#  1952  F1952   int8
#  1953  F1953   int8
#  1954  F1954   int8
#  1955  F1955   int8
#  1956  F1956   int8
#  1957  F1957   int8
#  1958  F1958   int8
#  1959  F1959   int8
#  1960  F1960   int8
#  1961  F1961   int8
#  1962  F1962   int8
#  1963  F1963   int8
#  1964  F1964   int8
#  1965  F1965   int8
#  1966  F1966   int8
#  1967  F1967   int8
#  9466  F9466   int8
#  9467  F9467   int8
#  9468  F9468   int8
#  9469  F9469   int8
#  9470  F9470   int8
#  9471  F9471   int8
#  9472  F9472   int8
#  9473  F9473   int8
#  9474  F9474   int8
#  9475  F9475   int8
#  9476  F9476   int8
#  9477  F9477   int8
#  9478  F9478   int8
#  9479  F9479   int8
#  9480  F9480   int8
#  9481  F9481   int8
#  9482  F9482   int8
#  9483  F9483   int8
#  9484  F9484   int8
#  9485  F9485   int8
#  9486  F9486   int8
#  9487  F9487   int8
#  9488  F9488   int8
#  9489  F9489   int8
#  9490  F9490   int8
#  9491  F9491   int8
#  9492  F9492   int8
#  9493  F9493   int8
#  9494  F9494   int8
#  9495  F9495   int8
#  9496  F9496   int8
#  9497  F9497   int8
#  9498  F9498   int8
#  9499  F9499   int8
#  9500  F9500   float32
#  9501  F9501   float32
#  9502  F9502   float32
#  9503  F9503   float32
#  9504  Label   object
# dtypes: float32(4), int16(4), int8(9495), object(2)
# memory usage: 3.2+ GB

# %%
#Feature Selection
X = DM2.drop(['Hash', 'Family', 'Category','Label'],axis=1).values    #Droping this because classification model will not accept object type elements (float and int only)
# Target variable
y = DM2['Label'].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 2
#       1 #Feature Selection
# ----> 2 X = DM2.drop(['Hash', 'Family', 'Category','Label'],axis=1).values    #Droping this because classification model will not accept object type elements (float and int only)
#       3 # Target variable
#       4 y = DM2['Label'].values
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['Hash', 'Family', 'Category'] not found in axis"

# %%
# Store selected features
features = {}

# %%
# Function to print and append selected features
def print_selected_features(method_name, selected_indices, importance=None):
    selected_features = []
    print(f"\n{method_name} Selected Features:")
    for i, idx in enumerate(selected_indices):
        feature_name = DM2.columns[idx]
        if importance is not None:
            print(f"{i + 1}. Feature {feature_name} (Importance: {importance[idx]:.6f})")
        else:
            print(f"{i + 1}. Feature {feature_name}")
        selected_features.append(feature_name)
    features[method_name] = selected_features

# %%
# Apply Min-Max scaling to make X non-negative
scaler = MinMaxScaler()
X_chi2 = scaler.fit_transform(X)

# 1. Chi-Square Test (Filter)
chi2_selector = chi2(X_chi2, y)
chi2_scores = chi2_selector[0]
chi2_top_features = np.argsort(chi2_scores)[::-1][:5]
print_selected_features("Chi-Square", chi2_top_features, chi2_scores)
# Out:
# Chi-Square Selected Features:
# 1. Feature F92 (Importance: nan)
# 2. Feature F23 (Importance: nan)
# 3. Feature F63 (Importance: nan)
# 4. Feature F97 (Importance: nan)
# 5. Feature F95 (Importance: nan)

# %%
# 2. ANOVA F-test (Filter)
anova_selector = f_classif(X, y)
anova_scores = anova_selector[0]
anova_top_features = np.argsort(anova_scores)[::-1][:5]
print_selected_features("ANOVA", anova_top_features, anova_scores)
# Out:
# ANOVA Selected Features:
# 1. Feature F38 (Importance: nan)
# 2. Feature F63 (Importance: nan)
# 3. Feature F99 (Importance: nan)
# 4. Feature F6 (Importance: nan)
# 5. Feature F15 (Importance: nan)
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [ 6 15 23 28 36 37 38 39 63 92 93 94 95 97 99] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw

# %%
# 3. Mutual Information (Filter)
mutual_info_scores = mutual_info_classif(X, y)
mutual_info_top_features = np.argsort(mutual_info_scores)[::-1][:5]
print_selected_features("Mutual Information", mutual_info_top_features, mutual_info_scores)
# Out:
# Mutual Information Selected Features:
# 1. Feature F7 (Importance: 0.502548)
# 2. Feature F128 (Importance: 0.461379)
# 3. Feature F130 (Importance: 0.364948)
# 4. Feature F10 (Importance: 0.341874)
# 5. Feature F76 (Importance: 0.324805)

# %%
# 4. Variance Threshold (Filter)
vt_selector = VarianceThreshold(threshold=0.1)  # You can adjust the threshold
X_vt = vt_selector.fit_transform(X)
vt_top_features = np.where(vt_selector.get_support())[0]
print_selected_features("Variance Threshold", vt_top_features)
# Out:
# Variance Threshold Selected Features:
# 1. Feature F0
# 2. Feature F1
# 3. Feature F2
# 4. Feature F3
# 5. Feature F4
# 6. Feature F5
# 7. Feature F7
# 8. Feature F8
# 9. Feature F9
# 10. Feature F10
# 11. Feature F11
# 12. Feature F12
# 13. Feature F13
# 14. Feature F14
# 15. Feature F16
# 16. Feature F17
# 17. Feature F18
# 18. Feature F19
# 19. Feature F20
# 20. Feature F21
# 21. Feature F22
# 22. Feature F24
# 23. Feature F25
# 24. Feature F26
# 25. Feature F27
# 26. Feature F30
# 27. Feature F31
# 28. Feature F32
# 29. Feature F33
# 30. Feature F34
# 31. Feature F40
# 32. Feature F41
# 33. Feature F42
# 34. Feature F43
# 35. Feature F44
# 36. Feature F45
# 37. Feature F48
# 38. Feature F50
# 39. Feature F51
# 40. Feature F52
# 41. Feature F53
# 42. Feature F54
# 43. Feature F55
# 44. Feature F56
# 45. Feature F57
# 46. Feature F58
# 47. Feature F59
# 48. Feature F60
# 49. Feature F61
# 50. Feature F62
# 51. Feature F64
# 52. Feature F66
# 53. Feature F67
# 54. Feature F68
# 55. Feature F69
# 56. Feature F70
# 57. Feature F71
# 58. Feature F72
# 59. Feature F73
# 60. Feature F74
# 61. Feature F75
# 62. Feature F76
# 63. Feature F77
# 64. Feature F78
# 65. Feature F79
# 66. Feature F80
# 67. Feature F81
# 68. Feature F82
# 69. Feature F83
# 70. Feature F84
# 71. Feature F85
# 72. Feature F86
# 73. Feature F87
# 74. Feature F88
# 75. Feature F89
# 76. Feature F90
# 77. Feature F91
# 78. Feature F96
# 79. Feature F98
# 80. Feature F100
# 81. Feature F101
# 82. Feature F102
# 83. Feature F103
# 84. Feature F104
# 85. Feature F105
# 86. Feature F106
# 87. Feature F107
# 88. Feature F108
# 89. Feature F109
# 90. Feature F110
# 91. Feature F111
# 92. Feature F113
# 93. Feature F114
# 94. Feature F115
# 95. Feature F116
# 96. Feature F117
# 97. Feature F118
# 98. Feature F119
# 99. Feature F120
# 100. Feature F121
# 101. Feature F122
# 102. Feature F123
# 103. Feature F125
# 104. Feature F126
# 105. Feature F127
# 106. Feature F128
# 107. Feature F129
# 108. Feature F130
# 109. Feature F131
# 110. Feature F132
# 111. Feature F133
# 112. Feature F134
# 113. Feature F135
# 114. Feature F136
# 115. Feature F137
# 116. Feature F138
# 117. Feature F139
# 118. Feature F140

# %%
# 5. Recursive Feature Elimination (RFE) - Wrapper
rfe_selector = RFE(estimator=RandomForestClassifier(), n_features_to_select=5)
X_rfe = rfe_selector.fit_transform(X, y)
rfe_top_features = np.where(rfe_selector.support_)[0]
print_selected_features("RFE", rfe_top_features)
# Out:
# RFE Selected Features:
# 1. Feature F2
# 2. Feature F3
# 3. Feature F4
# 4. Feature F5
# 5. Feature F8

# %%
# 6. Sequential Feature Selector (SFS) - Wrapper (Running too Long)

# Encode the target variable (Y Still contain String)
#label_encoder = LabelEncoder()
#y_encoded = label_encoder.fit_transform(y)

# Sequential Feature Selector
#sfs_selector = SequentialFeatureSelector(estimator=SVR(kernel="linear"), n_features_to_select=5)
#X_sfs = sfs_selector.fit_transform(X, y_encoded)
#sfs_top_features = np.where(sfs_selector.get_support())[0]
#print_selected_features("SFS", sfs_top_features)

# %%
# 6. Sequential Feature Selector (SFS) - Wrapper

# Function to run SFS
def run_sfs(X, y_encoded):
    global sfs_selector, X_sfs
    sfs_selector = SequentialFeatureSelector(estimator=SVR(kernel="linear"),n_features_to_select=5, direction='forward', n_jobs=-1)
    X_sfs = sfs_selector.fit_transform(X, y_encoded)

# Encode the target variable (Y Still contain String)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Set a timeout duration (in seconds)
timeout_duration = 600  # 600 seconds = 10 minutes

# Create a thread for running SFS
sfs_thread = threading.Thread(target=run_sfs, args=(X, y_encoded))

# Start the thread
sfs_thread.start()

# Wait for the thread to complete or timeout
sfs_thread.join(timeout=timeout_duration)

# Check if the thread is still active
if sfs_thread.is_alive():
    print("SFS did not complete within the time limit of 10 minutes. Terminating...")
    # Optionally, raise an error or take other actions
else:
    # If the thread finished in time, print selected features
    sfs_top_features = np.where(sfs_selector.get_support())[0]
    print_selected_features("SFS", sfs_top_features)
# Out:
# SFS did not complete within the time limit of 10 minutes. Terminating...

# %%
# 7. Genetic Algorithm (DEAP) - Wrapper (Running to Long)
#def evaluate(individual):
#    """ Evaluation function for genetic algorithm """
#    selected_features = [i for i, value in enumerate(individual) if value > 0]
#    if len(selected_features) == 0:
#        return 1000,  # Penalty for selecting no features
#    estimator = RandomForestClassifier()
#    X_selected = X.iloc[:, selected_features]
#    estimator.fit(X_selected, y)
#    return 1 - estimator.score(X_selected, y),

# Genetic Algorithm setup
#creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
#creator.create("Individual", list, fitness=creator.FitnessMin)
#toolbox = base.Toolbox()
#toolbox.register("attr_bool", np.random.randint, 0, 2)
#toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, n=len(X.columns))
#toolbox.register("population", tools.initRepeat, list, toolbox.individual)
#toolbox.register("evaluate", evaluate)
#toolbox.register("mate", tools.cxTwoPoint)
#toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
#toolbox.register("select", tools.selTournament, tournsize=3)

#population = toolbox.population(n=50)
#algorithms.eaSimple(population, toolbox, cxpb=0.5, mutpb=0.2, ngen=20, verbose=False)
#best_individual = tools.selBest(population, k=1)[0]
#genetic_selected_features = [i for i, value in enumerate(best_individual) if value > 0]
#print_selected_features("Genetic Algorithm", genetic_selected_features)

# %%
# 7. Genetic Algorithm (DEAP) - Wrapper
def evaluate(individual):
    """Evaluation function for genetic algorithm"""
    selected_features = [i for i, value in enumerate(individual) if value > 0]
    if len(selected_features) == 0:
        return 1000,  # Penalty for selecting no features
    estimator = RandomForestClassifier()
    X_selected = X.iloc[:, selected_features]
    estimator.fit(X_selected, y)
    return 1 - estimator.score(X_selected, y),

# Genetic Algorithm setup
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)
toolbox = base.Toolbox()
toolbox.register("attr_bool", np.random.randint, 0, 2)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, n=len(X.columns))
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", evaluate)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)

# Function to run Genetic Algorithm (GA)
def run_ga():
    global population
    population = toolbox.population(n=50)
    algorithms.eaSimple(population, toolbox, cxpb=0.5, mutpb=0.2, ngen=20, verbose=False)

# Set a timeout duration (in seconds)
timeout_duration = 600  # 600 seconds = 10 minutes

# Create a thread for running the GA
ga_thread = threading.Thread(target=run_ga)

# Start the thread
ga_thread.start()

# Wait for the thread to complete or timeout
ga_thread.join(timeout=timeout_duration)

# Check if the thread is still active
if ga_thread.is_alive():
    print("Genetic Algorithm did not complete within the time limit of 10 minutes. Terminating...")
    # Optionally, raise an error or take other actions
else:
    # If the thread finished in time, print the selected features
    best_individual = tools.selBest(population, k=1)[0]
    genetic_selected_features = [i for i, value in enumerate(best_individual) if value > 0]
    print_selected_features("Genetic Algorithm", genetic_selected_features)
# Out:
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# Genetic Algorithm did not complete within the time limit of 10 minutes. Terminating...

# %%
# 8. Boruta Algorithm (Wrapper)
rf = RandomForestClassifier(n_estimators=1000, n_jobs=-1, class_weight='balanced')
boruta_selector = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=42)
boruta_selector.fit(X, y)
boruta_selected_features = np.where(boruta_selector.support_)[0]
print_selected_features("Boruta", boruta_selected_features)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	141
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	141
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	141
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	141
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	141
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	141
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	141
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	48
# Tentative: 	4
# Rejected: 	89
# Iteration: 	9 / 100
# Confirmed: 	48
# Tentative: 	4
# Rejected: 	89
# Iteration: 	10 / 100
# Confirmed: 	48
# Tentative: 	4
# Rejected: 	89
# Iteration: 	11 / 100
# Confirmed: 	48
# Tentative: 	4
# Rejected: 	89
# Iteration: 	12 / 100
# Confirmed: 	50
# Tentative: 	2
# Rejected: 	89
# Iteration: 	13 / 100
# Confirmed: 	50
# Tentative: 	2
# Rejected: 	89
# Iteration: 	14 / 100
# Confirmed: 	50
# Tentative: 	2
# Rejected: 	89
# Iteration: 	15 / 100
# Confirmed: 	50
# Tentative: 	2
# Rejected: 	89
# Iteration: 	16 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	17 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	18 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	19 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	20 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	21 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	22 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	23 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	24 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	25 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	26 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	27 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	28 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	29 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	30 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	31 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	32 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	33 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	34 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	35 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	36 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	37 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	38 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	39 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	40 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	41 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	42 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	43 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	44 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	45 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	46 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	47 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	48 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	49 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	50 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	51 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	52 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	53 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	54 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	55 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	56 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	57 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	58 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	59 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	60 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	61 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	62 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	63 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	64 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	65 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	66 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	67 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	68 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	69 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	70 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	71 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	72 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	73 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	74 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	75 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	76 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	77 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	78 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	79 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	80 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	81 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	82 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	83 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	84 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	85 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	86 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	87 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	88 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	89 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	90 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	91 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	92 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	93 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	94 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	95 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	96 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	97 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	98 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
# Iteration: 	99 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	51
# Tentative: 	1
# Rejected: 	89
#
# Boruta Selected Features:
# 1. Feature F0
# 2. Feature F1
# 3. Feature F2
# 4. Feature F3
# 5. Feature F4
# 6. Feature F5
# 7. Feature F7
# 8. Feature F8
# 9. Feature F9
# 10. Feature F10
# 11. Feature F11
# 12. Feature F12
# 13. Feature F13
# 14. Feature F16
# 15. Feature F17
# 16. Feature F18
# 17. Feature F19
# 18. Feature F26
# 19. Feature F27
# 20. Feature F30
# 21. Feature F41
# 22. Feature F48
# 23. Feature F67
# 24. Feature F69
# 25. Feature F70
# 26. Feature F71
# 27. Feature F72
# 28. Feature F74
# 29. Feature F75
# 30. Feature F76
# 31. Feature F77
# 32. Feature F78
# 33. Feature F89
# 34. Feature F96
# 35. Feature F102
# 36. Feature F116
# 37. Feature F125
# 38. Feature F127
# 39. Feature F128
# 40. Feature F129
# 41. Feature F130
# 42. Feature F131
# 43. Feature F132
# 44. Feature F133
# 45. Feature F134
# 46. Feature F135
# 47. Feature F136
# 48. Feature F137
# 49. Feature F138
# 50. Feature F139
# 51. Feature F140

# %%
# could not convert string to float for Lasso, Ridge, and Elastic Net so need to change the y variable
# Assuming y is your target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# 9. Lasso (L1 Regularization) - Embedded
lasso = Lasso(alpha=0.01)
lasso.fit(X, y_encoded)
lasso_support = np.where(lasso.coef_ != 0)[0]
print_selected_features("Lasso", lasso_support)
# Out:
# Lasso Selected Features:
# 1. Feature F0
# 2. Feature F1
# 3. Feature F2
# 4. Feature F3
# 5. Feature F4
# 6. Feature F5
# 7. Feature F7
# 8. Feature F8
# 9. Feature F9
# 10. Feature F10
# 11. Feature F11
# 12. Feature F12
# 13. Feature F13
# 14. Feature F14
# 15. Feature F16
# 16. Feature F17
# 17. Feature F18
# 18. Feature F19
# 19. Feature F20
# 20. Feature F21
# 21. Feature F22
# 22. Feature F24
# 23. Feature F25
# 24. Feature F26
# 25. Feature F27
# 26. Feature F30
# 27. Feature F32
# 28. Feature F33
# 29. Feature F34
# 30. Feature F40
# 31. Feature F41
# 32. Feature F42
# 33. Feature F43
# 34. Feature F44
# 35. Feature F45
# 36. Feature F46
# 37. Feature F48
# 38. Feature F50
# 39. Feature F51
# 40. Feature F52
# 41. Feature F53
# 42. Feature F54
# 43. Feature F55
# 44. Feature F56
# 45. Feature F57
# 46. Feature F58
# 47. Feature F59
# 48. Feature F60
# 49. Feature F61
# 50. Feature F62
# 51. Feature F64
# 52. Feature F66
# 53. Feature F67
# 54. Feature F68
# 55. Feature F69
# 56. Feature F70
# 57. Feature F71
# 58. Feature F72
# 59. Feature F73
# 60. Feature F74
# 61. Feature F75
# 62. Feature F76
# 63. Feature F77
# 64. Feature F78
# 65. Feature F79
# 66. Feature F80
# 67. Feature F81
# 68. Feature F82
# 69. Feature F83
# 70. Feature F86
# 71. Feature F87
# 72. Feature F88
# 73. Feature F89
# 74. Feature F90
# 75. Feature F91
# 76. Feature F96
# 77. Feature F98
# 78. Feature F100
# 79. Feature F101
# 80. Feature F102
# 81. Feature F103
# 82. Feature F104
# 83. Feature F105
# 84. Feature F106
# 85. Feature F107
# 86. Feature F108
# 87. Feature F109
# 88. Feature F110
# 89. Feature F111
# 90. Feature F113
# 91. Feature F114
# 92. Feature F115
# 93. Feature F116
# 94. Feature F117
# 95. Feature F118
# 96. Feature F119
# 97. Feature F120
# 98. Feature F121
# 99. Feature F122
# 100. Feature F123
# 101. Feature F125
# 102. Feature F126
# 103. Feature F127
# 104. Feature F128
# 105. Feature F129
# 106. Feature F130
# 107. Feature F131
# 108. Feature F132
# 109. Feature F133
# 110. Feature F134
# 111. Feature F135
# 112. Feature F136
# 113. Feature F137
# 114. Feature F138
# 115. Feature F139
# 116. Feature F140
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.671e+06, tolerance: 4.345e+02
#   model = cd_fast.enet_coordinate_descent(

# %%
# 10. Ridge (L2 Regularization) - Embedded
ridge = Ridge(alpha=1.0)
ridge.fit(X, y_encoded)
ridge_support = np.where(ridge.coef_ != 0)[0]
print_selected_features("Ridge", ridge_support)
# Out:
# Ridge Selected Features:
# 1. Feature F0
# 2. Feature F1
# 3. Feature F2
# 4. Feature F3
# 5. Feature F4
# 6. Feature F5
# 7. Feature F7
# 8. Feature F8
# 9. Feature F9
# 10. Feature F10
# 11. Feature F11
# 12. Feature F12
# 13. Feature F13
# 14. Feature F14
# 15. Feature F16
# 16. Feature F17
# 17. Feature F18
# 18. Feature F19
# 19. Feature F20
# 20. Feature F21
# 21. Feature F22
# 22. Feature F24
# 23. Feature F25
# 24. Feature F26
# 25. Feature F27
# 26. Feature F29
# 27. Feature F30
# 28. Feature F31
# 29. Feature F32
# 30. Feature F33
# 31. Feature F34
# 32. Feature F35
# 33. Feature F40
# 34. Feature F41
# 35. Feature F42
# 36. Feature F43
# 37. Feature F44
# 38. Feature F45
# 39. Feature F46
# 40. Feature F47
# 41. Feature F48
# 42. Feature F49
# 43. Feature F50
# 44. Feature F51
# 45. Feature F52
# 46. Feature F53
# 47. Feature F54
# 48. Feature F55
# 49. Feature F56
# 50. Feature F57
# 51. Feature F58
# 52. Feature F59
# 53. Feature F60
# 54. Feature F61
# 55. Feature F62
# 56. Feature F64
# 57. Feature F65
# 58. Feature F66
# 59. Feature F67
# 60. Feature F68
# 61. Feature F69
# 62. Feature F70
# 63. Feature F71
# 64. Feature F72
# 65. Feature F73
# 66. Feature F74
# 67. Feature F75
# 68. Feature F76
# 69. Feature F77
# 70. Feature F78
# 71. Feature F79
# 72. Feature F80
# 73. Feature F81
# 74. Feature F82
# 75. Feature F83
# 76. Feature F84
# 77. Feature F85
# 78. Feature F86
# 79. Feature F87
# 80. Feature F88
# 81. Feature F89
# 82. Feature F90
# 83. Feature F91
# 84. Feature F96
# 85. Feature F98
# 86. Feature F100
# 87. Feature F101
# 88. Feature F102
# 89. Feature F103
# 90. Feature F104
# 91. Feature F105
# 92. Feature F106
# 93. Feature F107
# 94. Feature F108
# 95. Feature F109
# 96. Feature F110
# 97. Feature F111
# 98. Feature F112
# 99. Feature F113
# 100. Feature F114
# 101. Feature F115
# 102. Feature F116
# 103. Feature F117
# 104. Feature F118
# 105. Feature F119
# 106. Feature F120
# 107. Feature F121
# 108. Feature F122
# 109. Feature F123
# 110. Feature F124
# 111. Feature F125
# 112. Feature F126
# 113. Feature F127
# 114. Feature F128
# 115. Feature F129
# 116. Feature F130
# 117. Feature F131
# 118. Feature F132
# 119. Feature F133
# 120. Feature F134
# 121. Feature F135
# 122. Feature F136
# 123. Feature F137
# 124. Feature F138
# 125. Feature F139
# 126. Feature F140
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_ridge.py:200: LinAlgWarning: Ill-conditioned matrix (rcond=1.61896e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
# 11. Elastic Net - Embedded
elastic_net = ElasticNet(alpha=1.0, l1_ratio=0.5)
elastic_net.fit(X, y_encoded)
elastic_net_support = np.where(elastic_net.coef_ != 0)[0]
print_selected_features("Elastic Net", elastic_net_support)
# Out:
# Elastic Net Selected Features:
# 1. Feature F0
# 2. Feature F1
# 3. Feature F2
# 4. Feature F3
# 5. Feature F4
# 6. Feature F5
# 7. Feature F7
# 8. Feature F8
# 9. Feature F9
# 10. Feature F10
# 11. Feature F11
# 12. Feature F16
# 13. Feature F17
# 14. Feature F18
# 15. Feature F19
# 16. Feature F21
# 17. Feature F24
# 18. Feature F26
# 19. Feature F33
# 20. Feature F34
# 21. Feature F41
# 22. Feature F42
# 23. Feature F43
# 24. Feature F44
# 25. Feature F48
# 26. Feature F50
# 27. Feature F51
# 28. Feature F52
# 29. Feature F53
# 30. Feature F56
# 31. Feature F58
# 32. Feature F59
# 33. Feature F60
# 34. Feature F61
# 35. Feature F64
# 36. Feature F66
# 37. Feature F67
# 38. Feature F68
# 39. Feature F69
# 40. Feature F70
# 41. Feature F71
# 42. Feature F72
# 43. Feature F73
# 44. Feature F74
# 45. Feature F75
# 46. Feature F76
# 47. Feature F77
# 48. Feature F78
# 49. Feature F79
# 50. Feature F82
# 51. Feature F83
# 52. Feature F84
# 53. Feature F88
# 54. Feature F89
# 55. Feature F91
# 56. Feature F96
# 57. Feature F98
# 58. Feature F100
# 59. Feature F102
# 60. Feature F103
# 61. Feature F104
# 62. Feature F105
# 63. Feature F106
# 64. Feature F108
# 65. Feature F109
# 66. Feature F110
# 67. Feature F113
# 68. Feature F115
# 69. Feature F116
# 70. Feature F119
# 71. Feature F120
# 72. Feature F125
# 73. Feature F126
# 74. Feature F127
# 75. Feature F128
# 76. Feature F129
# 77. Feature F130
# 78. Feature F131
# 79. Feature F132
# 80. Feature F133
# 81. Feature F134
# 82. Feature F135
# 83. Feature F136
# 84. Feature F137
# 85. Feature F138
# 86. Feature F139
# 87. Feature F140
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.816e+06, tolerance: 4.345e+02
#   model = cd_fast.enet_coordinate_descent(

# %%
# 12. Random Forest Feature Importance - Embedded
rf_model = RandomForestClassifier().fit(X, y)
rf_importances = rf_model.feature_importances_
rf_top_features = np.argsort(rf_importances)[::-1][:5]
print_selected_features("Random Forest", rf_top_features, rf_importances)
# Out:
# Random Forest Selected Features:
# 1. Feature F140 (Importance: 0.042680)
# 2. Feature F132 (Importance: 0.039407)
# 3. Feature F139 (Importance: 0.023495)
# 4. Feature F4 (Importance: 0.023476)
# 5. Feature F8 (Importance: 0.021292)

# %%
# 13. ExtraTreesClassifier - Embedded (Already used in your code)
extratrees = ExtraTreesClassifier().fit(X, y)
model = SelectFromModel(extratrees, prefit=True)
X_new = model.transform(X)
nbfeatures = X_new.shape[1]
index = np.argsort(extratrees.feature_importances_)[::-1][:nbfeatures]
print_selected_features("ExtraTreesClassifier", index, extratrees.feature_importances_)
# Out:
# ExtraTreesClassifier Selected Features:
# 1. Feature F132 (Importance: 0.055655)
# 2. Feature F140 (Importance: 0.039951)
# 3. Feature F4 (Importance: 0.025627)
# 4. Feature F1 (Importance: 0.020466)
# 5. Feature F5 (Importance: 0.020362)
# 6. Feature F139 (Importance: 0.019542)
# 7. Feature F8 (Importance: 0.018300)
# 8. Feature F2 (Importance: 0.017107)
# 9. Feature F7 (Importance: 0.016837)
# 10. Feature F0 (Importance: 0.016437)
# 11. Feature F127 (Importance: 0.016246)
# 12. Feature F125 (Importance: 0.016058)
# 13. Feature F3 (Importance: 0.015432)
# 14. Feature F72 (Importance: 0.015099)
# 15. Feature F71 (Importance: 0.014716)
# 16. Feature F9 (Importance: 0.014057)
# 17. Feature F19 (Importance: 0.014038)
# 18. Feature F133 (Importance: 0.014011)
# 19. Feature F12 (Importance: 0.013290)
# 20. Feature F48 (Importance: 0.013284)
# 21. Feature F18 (Importance: 0.013248)
# 22. Feature F17 (Importance: 0.013113)
# 23. Feature F69 (Importance: 0.013096)
# 24. Feature F116 (Importance: 0.013089)
# 25. Feature F134 (Importance: 0.012453)
# 26. Feature F16 (Importance: 0.012408)
# 27. Feature F138 (Importance: 0.012221)
# 28. Feature F70 (Importance: 0.012191)
# 29. Feature F135 (Importance: 0.012168)
# 30. Feature F137 (Importance: 0.012116)
# 31. Feature F136 (Importance: 0.012005)
# 32. Feature F67 (Importance: 0.011931)
# 33. Feature F10 (Importance: 0.011908)
# 34. Feature F77 (Importance: 0.011749)
# 35. Feature F78 (Importance: 0.011579)
# 36. Feature F75 (Importance: 0.010870)
# 37. Feature F11 (Importance: 0.010712)
# 38. Feature F131 (Importance: 0.010243)
# 39. Feature F102 (Importance: 0.010175)
# 40. Feature F130 (Importance: 0.009892)
# 41. Feature F76 (Importance: 0.009795)
# 42. Feature F96 (Importance: 0.009696)
# 43. Feature F128 (Importance: 0.009677)
# 44. Feature F83 (Importance: 0.009509)
# 45. Feature F106 (Importance: 0.009461)
# 46. Feature F13 (Importance: 0.009084)
# 47. Feature F27 (Importance: 0.009007)
# 48. Feature F129 (Importance: 0.008997)
# 49. Feature F44 (Importance: 0.008971)
# 50. Feature F26 (Importance: 0.008817)
# 51. Feature F100 (Importance: 0.008466)
# 52. Feature F98 (Importance: 0.008363)
# 53. Feature F42 (Importance: 0.008261)
# 54. Feature F126 (Importance: 0.007946)
# 55. Feature F58 (Importance: 0.007929)
# 56. Feature F74 (Importance: 0.007719)
# 57. Feature F54 (Importance: 0.007494)
# 58. Feature F105 (Importance: 0.007469)
# 59. Feature F81 (Importance: 0.007301)
# 60. Feature F79 (Importance: 0.007225)
# 61. Feature F62 (Importance: 0.007202)

# %%
# Compare all selected features
print("\nSummary of Selected Features for Each Method:")
