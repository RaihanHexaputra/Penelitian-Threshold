# %%
# Library untuk pengolahan data dan visualisasi
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import joblib
import threading

# Library untuk evaluasi dan model machine learning
from sklearn.metrics import confusion_matrix, classification_report
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import f_classif
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
import sklearn.ensemble as ek
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# Library untuk Explainable AI (XAI)
from lime.lime_tabular import LimeTabularExplainer
import shap

# Library untuk Deep Learning
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, LSTM, Dropout
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %%
# Input Dataset 

DM = pd.read_csv("C:\\Data Raihan\\Penelitian Threshold\\Dataset\\CIC-PDFMal2022\\PDFMalware2022.csv") #DM--> Dataset Malware

# %%
DM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10026 entries, 0 to 10025
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fine name         10026 non-null  object
#  1   pdfsize           10025 non-null  float64
#  2   metadata size     10025 non-null  float64
#  3   pages             10025 non-null  float64
#  4   xref Length       10025 non-null  float64
#  5   title characters  10025 non-null  float64
#  6   isEncrypted       10025 non-null  float64
#  7   embedded files    10025 non-null  float64
#  8   images            10025 non-null  object
#  9   text              10025 non-null  object
#  10  header            10025 non-null  object
#  11  obj               10023 non-null  object
#  12  endobj            10023 non-null  object
#  13  stream            10023 non-null  float64
#  14  endstream         10023 non-null  object
#  15  xref              10023 non-null  object
#  16  trailer           10023 non-null  float64
#  17  startxref         10023 non-null  object
#  18  pageno            10023 non-null  object
#  19  encrypt           10023 non-null  float64
#  20  ObjStm            10023 non-null  float64
#  21  JS                10023 non-null  object
#  22  Javascript        10023 non-null  object
#  23  AA                10023 non-null  object
#  24  OpenAction        10023 non-null  object
#  25  Acroform          10023 non-null  object
#  26  JBIG2Decode       10023 non-null  object
#  27  RichMedia         10023 non-null  object
#  28  launch            10023 non-null  object
#  29  EmbeddedFile      10023 non-null  object
#  30  XFA               10023 non-null  object
#  31  Colors            10023 non-null  float64
#  32  Class             10025 non-null  object
# dtypes: float64(12), object(21)
# memory usage: 2.5+ MB

# %%
#Feature Selection
features_to_drop = ['Fine name', 'images', 'text', 'header', 'obj', 'endobj', 'endstream', 
                    'xref', 'startxref', 'pageno', 'JS', 'Javascript', 'AA', 'OpenAction', 
                    'Acroform', 'JBIG2Decode', 'RichMedia', 'launch', 'EmbeddedFile', 'XFA', 'Class']

# Droping specified columns and target variable
X = DM.drop(features_to_drop, axis=1).values    
y = DM['Class'].values

# %%
#Remove Nan
X = pd.DataFrame(X).dropna()
y = y[X.index]

# %%
# Applying Min-Max scaling to make X non-negative
scaler = MinMaxScaler()
X_anova = scaler.fit_transform(X)

# %%
# Apply ANOVA F-test
anova_selector = f_classif(X_anova, y)
anova_scores = anova_selector[0]

# %%
# Select top features based on ANOVA F-test scores
anova_top_features = np.argsort(anova_scores)[::-1][:5]

# Mengambil nama kolom dari X yang sudah difilter
filtered_columns = DM.drop(features_to_drop, axis=1).columns

features = []
for idx in anova_top_features:
    print(f"Feature {filtered_columns[idx]} dengan skor ANOVA {anova_scores[idx]}")
    features.append(filtered_columns[idx])
# Out:
# Feature stream dengan skor ANOVA 1895.2945850407386
# Feature trailer dengan skor ANOVA 528.88717958334
# Feature ObjStm dengan skor ANOVA 355.8305083445803
# Feature encrypt dengan skor ANOVA 294.0387918502891
# Feature isEncrypted dengan skor ANOVA 170.26549998667738

# %%
# Memilih 100% data secara acak dari setiap fitur/column
sampled_data = DM.groupby('Class').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)
# Out:
# C:\Users\Muhammad Raihan\AppData\Local\Temp\ipykernel_22988\1069642451.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_data = DM.groupby('Class').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)

# %%
# Pisahkan data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X_anova, y, test_size=0.3, random_state=42)

# %%
# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
# Inisialisasi variabel untuk menyimpan hasil evaluasi
hasil_ml_dl = []
hasil_ml_dl_xai = []

# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Fungsi untuk mengevaluasi model ML/DL
def EvaluateModel(model_name, model, X_train, y_train, X_test, y_test, use_xai=False, is_dl_model=False):
    start_time = time.time()

    # Melatih model
    model.fit(X_train, y_train, epochs=5, batch_size=32, verbose=0) if is_dl_model else model.fit(X_train, y_train)
    
    if is_dl_model:
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    elif hasattr(model, 'predict_proba'):
        # Model dengan metode predict_proba
        y_pred_proba = model.predict_proba(X_test)
        if y_pred_proba.shape[1] > 1:  # Model klasifikasi multi-kelas
            y_pred = np.argmax(y_pred_proba, axis=1)
        else:  # Model klasifikasi biner
            y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    else:
        # Model tanpa metode predict_proba
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()

    # Menghitung confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

    # Menghitung metrik
    Precision = tp / (tp + fp) if (tp + fp) != 0 else 0
    Recall = tp / (tp + fn) if (tp + fn) != 0 else 0
    F1Score = 2 * ((Precision * Recall) / (Precision + Recall)) if (Precision + Recall) != 0 else 0
    Accuracy = (tp + tn) / (tp + fp + tn + fn) if (tp + fp + tn + fn) != 0 else 0

    # Menghitung waktu running
    run_time = time.time() - start_time

    # Jika XAI diperlukan, tambahkan analisis dengan SHAP
    if use_xai:
        # Periksa apakah X_train adalah DataFrame
        if isinstance(X_train, pd.DataFrame):
            feature_names = X_train.columns
        else:
            feature_names = [f"Feature_{i}" for i in range(X_train.shape[1])]
        
        # Perbaiki format X_train untuk SHAP
        if is_dl_model:
            X_train_for_xai = X_train.reshape((X_train.shape[0], X_train.shape[1]))
            X_test_for_xai = X_test.reshape((X_test.shape[0], X_test.shape[1]))
        else:
            X_train_for_xai = X_train
            X_test_for_xai = X_test

        # Gunakan SHAP
        try:
            if is_dl_model:
                explainer = shap.DeepExplainer(model, X_train_for_xai)
                shap_values = explainer.shap_values(X_test_for_xai)
                shap_summary = np.mean(shap_values[0], axis=0)
            else:
                explainer = shap.Explainer(model.predict_proba, X_train_for_xai)
                shap_values = explainer(X_test_for_xai)
                shap_summary = shap_values.values.mean(axis=0)
        except Exception as e:
            print(f"Error using SHAP with {model_name}: {e}")
            shap_summary = None

        # Simpan hasil evaluasi dengan XAI
        hasil_ml_dl_xai.append([model_name, Precision, Recall, F1Score, Accuracy, run_time, {'SHAP': shap_summary}])
    else:
        # Simpan hasil evaluasi tanpa XAI
        hasil_ml_dl.append([model_name, Precision, Recall, F1Score, Accuracy, run_time])

# Model ML dan DL yang akan dievaluasi
model_ml_dl = {
    "DecisionTree": DecisionTreeClassifier(max_depth=10),
    "RandomForest": RandomForestClassifier(n_estimators=50),
    "Logistic Regression": LogisticRegression(random_state=0, max_iter=10000),
    "Naive Bayes": GaussianNB(),
    "MLP": MLPClassifier(solver='adam', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1, max_iter=1000),
    "Stochastic Gradient Descent": SGDClassifier(loss='log_loss', random_state=42),
    "ADA Boost": AdaBoostClassifier(n_estimators=100),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "XGBoost": XGBClassifier(n_estimators=100),
    "LightGBM": LGBMClassifier(n_estimators=100),
    "CatBoost": CatBoostClassifier(iterations=100, depth=6, learning_rate=0.1, loss_function='Logloss')
}

model_dl = {
    "DNN": Sequential([
        Dense(128, input_shape=(X_train.shape[1],), activation='relu'),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "CNN": Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "RNN": Sequential([
        LSTM(100, input_shape=(X_train.shape[1], 1)),
        Dense(1, activation='sigmoid')
    ]),
}

# Pastikan X_train dan X_test memiliki bentuk yang sesuai untuk DL
X_train_dl = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_dl = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Mengevaluasi model ML tanpa XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=False)

# Mengevaluasi model DL tanpa XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=False, is_dl_model=True)

# Mengevaluasi model ML dengan XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=True)

# Mengevaluasi model DL dengan XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=True, is_dl_model=True)

# Print hasil evaluasi tanpa XAI
print("\nHasil Evaluasi ML/DL tanpa XAI:")
print(hasil_ml_dl)

# Print hasil evaluasi dengan XAI
print("\nHasil Evaluasi ML/DL dengan XAI:")
print(hasil_ml_dl_xai)

# Convert results to DataFrame and save to CSV
df_ml_dl = pd.DataFrame(hasil_ml_dl, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime"])
df_ml_dl_xai = pd.DataFrame(hasil_ml_dl_xai, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime", "XAI"])

df_ml_dl.to_csv("hasil_evaluasi_ml_dl_AFTFC.csv", index=False)
df_ml_dl_xai.to_csv("hasil_evaluasi_ml_dl_xai_AFTFC.csv", index=False)
# Out:
# [LightGBM] [Info] Number of positive: 3865, number of negative: 3151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003594 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1186
# [LightGBM] [Info] Number of data points in the train set: 7016, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.550884 -> initscore=0.204242
# [LightGBM] [Info] Start training from score 0.204242
# 0:	learn: 0.6233952	total: 148ms	remaining: 14.6s
# 1:	learn: 0.5667828	total: 150ms	remaining: 7.35s
# 2:	learn: 0.5158579	total: 152ms	remaining: 4.92s
# 3:	learn: 0.4701687	total: 154ms	remaining: 3.71s
# 4:	learn: 0.4331439	total: 157ms	remaining: 2.98s
# 5:	learn: 0.4001143	total: 159ms	remaining: 2.5s
# 6:	learn: 0.3720034	total: 162ms	remaining: 2.15s
# 7:	learn: 0.3466359	total: 195ms	remaining: 2.25s
# 8:	learn: 0.3234386	total: 204ms	remaining: 2.06s
# 9:	learn: 0.3037145	total: 213ms	remaining: 1.92s
# 10:	learn: 0.2849609	total: 224ms	remaining: 1.81s
# 11:	learn: 0.2686569	total: 242ms	remaining: 1.78s
# 12:	learn: 0.2537131	total: 248ms	remaining: 1.66s
# 13:	learn: 0.2402928	total: 254ms	remaining: 1.56s
# 14:	learn: 0.2283432	total: 277ms	remaining: 1.57s
# 15:	learn: 0.2181887	total: 286ms	remaining: 1.5s
# 16:	learn: 0.2071913	total: 290ms	remaining: 1.41s
# 17:	learn: 0.1986340	total: 293ms	remaining: 1.33s
# 18:	learn: 0.1898069	total: 295ms	remaining: 1.26s
# 19:	learn: 0.1823055	total: 298ms	remaining: 1.19s
# 20:	learn: 0.1753956	total: 300ms	remaining: 1.13s
# 21:	learn: 0.1696179	total: 302ms	remaining: 1.07s
# 22:	learn: 0.1640047	total: 305ms	remaining: 1.02s
# 23:	learn: 0.1589595	total: 307ms	remaining: 972ms
# 24:	learn: 0.1542838	total: 309ms	remaining: 928ms
# 25:	learn: 0.1500265	total: 312ms	remaining: 887ms
# 26:	learn: 0.1453649	total: 314ms	remaining: 850ms
# 27:	learn: 0.1416183	total: 317ms	remaining: 814ms
# 28:	learn: 0.1381484	total: 319ms	remaining: 781ms
# 29:	learn: 0.1346485	total: 321ms	remaining: 750ms
# 30:	learn: 0.1315079	total: 324ms	remaining: 721ms
# 31:	learn: 0.1290297	total: 326ms	remaining: 693ms
# 32:	learn: 0.1256832	total: 329ms	remaining: 668ms
# 33:	learn: 0.1234395	total: 332ms	remaining: 644ms
# 34:	learn: 0.1209019	total: 334ms	remaining: 620ms
# 35:	learn: 0.1187198	total: 336ms	remaining: 598ms
# 36:	learn: 0.1163355	total: 338ms	remaining: 576ms
# 37:	learn: 0.1140794	total: 341ms	remaining: 556ms
# 38:	learn: 0.1117700	total: 343ms	remaining: 536ms
# 39:	learn: 0.1095045	total: 390ms	remaining: 585ms
# 40:	learn: 0.1082528	total: 415ms	remaining: 596ms
# 41:	learn: 0.1069304	total: 426ms	remaining: 588ms
# 42:	learn: 0.1049211	total: 428ms	remaining: 568ms
# 43:	learn: 0.1035891	total: 431ms	remaining: 549ms
# 44:	learn: 0.1023829	total: 435ms	remaining: 531ms
# 45:	learn: 0.1014690	total: 437ms	remaining: 513ms
# 46:	learn: 0.1003434	total: 445ms	remaining: 502ms
# 47:	learn: 0.0996869	total: 460ms	remaining: 499ms
# 48:	learn: 0.0983416	total: 466ms	remaining: 485ms
# 49:	learn: 0.0962412	total: 471ms	remaining: 471ms
# 50:	learn: 0.0956501	total: 478ms	remaining: 460ms
# 51:	learn: 0.0946828	total: 482ms	remaining: 445ms
# 52:	learn: 0.0938801	total: 485ms	remaining: 430ms
# 53:	learn: 0.0928902	total: 488ms	remaining: 415ms
# 54:	learn: 0.0922551	total: 490ms	remaining: 401ms
# 55:	learn: 0.0913147	total: 493ms	remaining: 387ms
# 56:	learn: 0.0907956	total: 496ms	remaining: 374ms
# 57:	learn: 0.0897417	total: 498ms	remaining: 361ms
# 58:	learn: 0.0889070	total: 501ms	remaining: 348ms
# 59:	learn: 0.0883280	total: 503ms	remaining: 336ms
# 60:	learn: 0.0877093	total: 506ms	remaining: 324ms
# 61:	learn: 0.0870466	total: 509ms	remaining: 312ms
# 62:	learn: 0.0864922	total: 512ms	remaining: 301ms
# 63:	learn: 0.0858708	total: 515ms	remaining: 290ms
# 64:	learn: 0.0855633	total: 517ms	remaining: 278ms
# 65:	learn: 0.0846223	total: 519ms	remaining: 268ms
# 66:	learn: 0.0840513	total: 522ms	remaining: 257ms
# 67:	learn: 0.0836903	total: 524ms	remaining: 247ms
# 68:	learn: 0.0832687	total: 527ms	remaining: 237ms
# 69:	learn: 0.0825421	total: 529ms	remaining: 227ms
# 70:	learn: 0.0817523	total: 532ms	remaining: 217ms
# 71:	learn: 0.0808942	total: 576ms	remaining: 224ms
# 72:	learn: 0.0807383	total: 585ms	remaining: 217ms
# 73:	learn: 0.0800861	total: 593ms	remaining: 208ms
# 74:	learn: 0.0794294	total: 621ms	remaining: 207ms
# 75:	learn: 0.0788878	total: 624ms	remaining: 197ms
# 76:	learn: 0.0783219	total: 636ms	remaining: 190ms
# 77:	learn: 0.0779695	total: 660ms	remaining: 186ms
# 78:	learn: 0.0778128	total: 668ms	remaining: 178ms
# 79:	learn: 0.0772942	total: 671ms	remaining: 168ms
# 80:	learn: 0.0767109	total: 676ms	remaining: 159ms
# 81:	learn: 0.0765114	total: 679ms	remaining: 149ms
# 82:	learn: 0.0761029	total: 681ms	remaining: 139ms
# 83:	learn: 0.0756197	total: 683ms	remaining: 130ms
# 84:	learn: 0.0754426	total: 685ms	remaining: 121ms
# 85:	learn: 0.0752159	total: 688ms	remaining: 112ms
# 86:	learn: 0.0744049	total: 690ms	remaining: 103ms
# 87:	learn: 0.0739720	total: 693ms	remaining: 94.5ms
# 88:	learn: 0.0736518	total: 695ms	remaining: 85.9ms
# 89:	learn: 0.0734552	total: 698ms	remaining: 77.5ms
# 90:	learn: 0.0733091	total: 700ms	remaining: 69.2ms
# 91:	learn: 0.0728457	total: 702ms	remaining: 61.1ms
# 92:	learn: 0.0728055	total: 705ms	remaining: 53.1ms
# 93:	learn: 0.0725272	total: 708ms	remaining: 45.2ms
# 94:	learn: 0.0724081	total: 710ms	remaining: 37.4ms
# 95:	learn: 0.0723201	total: 712ms	remaining: 29.7ms
# 96:	learn: 0.0723011	total: 715ms	remaining: 22.1ms
# 97:	learn: 0.0721581	total: 717ms	remaining: 14.6ms
# 98:	learn: 0.0721017	total: 719ms	remaining: 7.26ms
# 99:	learn: 0.0720559	total: 721ms	remaining: 0us
# 94/94 [==============================] - 1s 3ms/step
# 94/94 [==============================] - 1s 4ms/step
# 94/94 [==============================] - 2s 9ms/step
# PermutationExplainer explainer: 3008it [01:42, 29.45it/s]
# PermutationExplainer explainer: 3008it [12:32,  3.95it/s]
# PermutationExplainer explainer: 3008it [00:59, 50.38it/s]
# PermutationExplainer explainer: 3008it [01:11, 36.16it/s]
# PermutationExplainer explainer: 3008it [00:54, 45.32it/s]
# PermutationExplainer explainer: 3008it [00:43, 53.93it/s]
# PermutationExplainer explainer: 3008it [50:34,  1.01s/it]
# PermutationExplainer explainer: 3008it [07:28,  6.56it/s]
# PermutationExplainer explainer: 3008it [25:59,  1.91it/s]
# [LightGBM] [Info] Number of positive: 3865, number of negative: 3151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.042576 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1186
# [LightGBM] [Info] Number of data points in the train set: 7016, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.550884 -> initscore=0.204242
# [LightGBM] [Info] Start training from score 0.204242
# PermutationExplainer explainer: 3008it [06:07,  8.13it/s]
# 0:	learn: 0.6233952	total: 2.12ms	remaining: 210ms
# 1:	learn: 0.5667828	total: 4.09ms	remaining: 200ms
# 2:	learn: 0.5158579	total: 6.03ms	remaining: 195ms
# 3:	learn: 0.4701687	total: 7.73ms	remaining: 185ms
# 4:	learn: 0.4331439	total: 9.58ms	remaining: 182ms
# 5:	learn: 0.4001143	total: 11.4ms	remaining: 179ms
# 6:	learn: 0.3720034	total: 13.4ms	remaining: 178ms
# 7:	learn: 0.3466359	total: 15.3ms	remaining: 176ms
# 8:	learn: 0.3234386	total: 17.4ms	remaining: 176ms
# 9:	learn: 0.3037145	total: 19.2ms	remaining: 173ms
# 10:	learn: 0.2849609	total: 21.2ms	remaining: 172ms
# 11:	learn: 0.2686569	total: 23ms	remaining: 169ms
# 12:	learn: 0.2537131	total: 24.8ms	remaining: 166ms
# 13:	learn: 0.2402928	total: 26.7ms	remaining: 164ms
# 14:	learn: 0.2283432	total: 28.6ms	remaining: 162ms
# 15:	learn: 0.2181887	total: 30.6ms	remaining: 160ms
# 16:	learn: 0.2071913	total: 32.6ms	remaining: 159ms
# 17:	learn: 0.1986340	total: 34.6ms	remaining: 158ms
# 18:	learn: 0.1898069	total: 36.7ms	remaining: 157ms
# 19:	learn: 0.1823055	total: 38.8ms	remaining: 155ms
# 20:	learn: 0.1753956	total: 40.7ms	remaining: 153ms
# 21:	learn: 0.1696179	total: 42.5ms	remaining: 151ms
# 22:	learn: 0.1640047	total: 44.3ms	remaining: 148ms
# 23:	learn: 0.1589595	total: 46.3ms	remaining: 147ms
# 24:	learn: 0.1542838	total: 48.2ms	remaining: 145ms
# 25:	learn: 0.1500265	total: 50.4ms	remaining: 144ms
# 26:	learn: 0.1453649	total: 52.3ms	remaining: 141ms
# 27:	learn: 0.1416183	total: 54.2ms	remaining: 139ms
# 28:	learn: 0.1381484	total: 56.3ms	remaining: 138ms
# 29:	learn: 0.1346485	total: 58.3ms	remaining: 136ms
# 30:	learn: 0.1315079	total: 60.3ms	remaining: 134ms
# 31:	learn: 0.1290297	total: 62.4ms	remaining: 133ms
# 32:	learn: 0.1256832	total: 64.5ms	remaining: 131ms
# 33:	learn: 0.1234395	total: 66.5ms	remaining: 129ms
# 34:	learn: 0.1209019	total: 68.4ms	remaining: 127ms
# 35:	learn: 0.1187198	total: 70.4ms	remaining: 125ms
# 36:	learn: 0.1163355	total: 72.3ms	remaining: 123ms
# 37:	learn: 0.1140794	total: 74.1ms	remaining: 121ms
# 38:	learn: 0.1117700	total: 76.1ms	remaining: 119ms
# 39:	learn: 0.1095045	total: 78ms	remaining: 117ms
# 40:	learn: 0.1082528	total: 80.1ms	remaining: 115ms
# 41:	learn: 0.1069304	total: 82ms	remaining: 113ms
# 42:	learn: 0.1049211	total: 84ms	remaining: 111ms
# 43:	learn: 0.1035891	total: 86ms	remaining: 109ms
# 44:	learn: 0.1023829	total: 87.9ms	remaining: 107ms
# 45:	learn: 0.1014690	total: 89.8ms	remaining: 105ms
# 46:	learn: 0.1003434	total: 91.7ms	remaining: 103ms
# 47:	learn: 0.0996869	total: 93.7ms	remaining: 101ms
# 48:	learn: 0.0983416	total: 95.6ms	remaining: 99.5ms
# 49:	learn: 0.0962412	total: 97.4ms	remaining: 97.4ms
# 50:	learn: 0.0956501	total: 99.3ms	remaining: 95.4ms
# 51:	learn: 0.0946828	total: 101ms	remaining: 93.3ms
# 52:	learn: 0.0938801	total: 103ms	remaining: 91.2ms
# 53:	learn: 0.0928902	total: 105ms	remaining: 89.2ms
# 54:	learn: 0.0922551	total: 106ms	remaining: 87.1ms
# 55:	learn: 0.0913147	total: 108ms	remaining: 85.1ms
# 56:	learn: 0.0907956	total: 110ms	remaining: 83.1ms
# 57:	learn: 0.0897417	total: 112ms	remaining: 81ms
# 58:	learn: 0.0889070	total: 114ms	remaining: 79ms
# 59:	learn: 0.0883280	total: 115ms	remaining: 77ms
# 60:	learn: 0.0877093	total: 117ms	remaining: 75ms
# 61:	learn: 0.0870466	total: 119ms	remaining: 73ms
# 62:	learn: 0.0864922	total: 121ms	remaining: 71ms
# 63:	learn: 0.0858708	total: 123ms	remaining: 69ms
# 64:	learn: 0.0855633	total: 125ms	remaining: 67ms
# 65:	learn: 0.0846223	total: 126ms	remaining: 65.1ms
# 66:	learn: 0.0840513	total: 128ms	remaining: 63.1ms
# 67:	learn: 0.0836903	total: 130ms	remaining: 61.2ms
# 68:	learn: 0.0832687	total: 132ms	remaining: 59.3ms
# 69:	learn: 0.0825421	total: 134ms	remaining: 57.4ms
# 70:	learn: 0.0817523	total: 136ms	remaining: 55.6ms
# 71:	learn: 0.0808942	total: 138ms	remaining: 53.7ms
# 72:	learn: 0.0807383	total: 140ms	remaining: 51.8ms
# 73:	learn: 0.0800861	total: 142ms	remaining: 49.9ms
# 74:	learn: 0.0794294	total: 144ms	remaining: 48ms
# 75:	learn: 0.0788878	total: 146ms	remaining: 46ms
# 76:	learn: 0.0783219	total: 148ms	remaining: 44.1ms
# 77:	learn: 0.0779695	total: 149ms	remaining: 42.1ms
# 78:	learn: 0.0778128	total: 151ms	remaining: 40.2ms
# 79:	learn: 0.0772942	total: 153ms	remaining: 38.3ms
# 80:	learn: 0.0767109	total: 155ms	remaining: 36.4ms
# 81:	learn: 0.0765114	total: 157ms	remaining: 34.5ms
# 82:	learn: 0.0761029	total: 159ms	remaining: 32.6ms
# 83:	learn: 0.0756197	total: 161ms	remaining: 30.6ms
# 84:	learn: 0.0754426	total: 163ms	remaining: 28.7ms
# 85:	learn: 0.0752159	total: 165ms	remaining: 26.8ms
# 86:	learn: 0.0744049	total: 167ms	remaining: 24.9ms
# 87:	learn: 0.0739720	total: 168ms	remaining: 23ms
# 88:	learn: 0.0736518	total: 170ms	remaining: 21ms
# 89:	learn: 0.0734552	total: 172ms	remaining: 19.1ms
# 90:	learn: 0.0733091	total: 174ms	remaining: 17.2ms
# 91:	learn: 0.0728457	total: 176ms	remaining: 15.3ms
# 92:	learn: 0.0728055	total: 178ms	remaining: 13.4ms
# 93:	learn: 0.0725272	total: 180ms	remaining: 11.5ms
# 94:	learn: 0.0724081	total: 181ms	remaining: 9.55ms
# 95:	learn: 0.0723201	total: 183ms	remaining: 7.63ms
# 96:	learn: 0.0723011	total: 185ms	remaining: 5.72ms
# 97:	learn: 0.0721581	total: 187ms	remaining: 3.81ms
# 98:	learn: 0.0721017	total: 189ms	remaining: 1.91ms
# 99:	learn: 0.0720559	total: 191ms	remaining: 0us
# PermutationExplainer explainer: 3008it [05:13,  9.32it/s]
# 94/94 [==============================] - 0s 607us/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# 94/94 [==============================] - 0s 3ms/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Error using SHAP with CNN: operands could not be broadcast together with shapes (7016,12,1) (7016,12)
# 94/94 [==============================] - 2s 7ms/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Error using SHAP with RNN: in user code:
#
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 244, in grad_graph  *
#         out = self.model(shap_rAnD)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler  **
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 371, in custom_grad
#         out = op_handlers[type_name](self, op, *grads) # we cut off the shap_ prefix before the lookup
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 663, in handler
#         return linearity_with_excluded_handler(input_inds, explainer, op, *grads)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 670, in linearity_with_excluded_handler
#         assert not explainer._variable_inputs(op)[i], str(i) + "th input to " + op.name + " cannot vary!"
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 222, in _variable_inputs
#         out[i] = t.name in self.between_tensors
#
#     AttributeError: Exception encountered when calling layer 'lstm' (type LSTM).
#
#     'TFDeep' object has no attribute 'between_tensors'
#
#     Call arguments received by layer 'lstm' (type LSTM):
#       • inputs=tf.Tensor(shape=(14032, 12, 1), dtype=float32)
#       • mask=None
#       • training=False
#       • initial_state=None
#
#
# Hasil Evaluasi ML/DL tanpa XAI:
# [['DecisionTree', 0.9745712596096984, 0.9751479289940829, 0.9748595090209996, 0.9717326238776189, 0.11081862449645996], ['RandomForest', 0.9794961921499707, 0.9893491124260355, 0.9843979982337357, 0.98237445959428, 0.9843218326568604], ['Logistic Regression', 0.7622211675367822, 0.9502958579881656, 0.8459309981564392, 0.8054539408047888, 0.1006629467010498], ['Naive Bayes', 0.9118387909319899, 0.21420118343195266, 0.3469094393866794, 0.5467243099434652, 0.005579710006713867], ['MLP', 0.8914127423822714, 0.9520710059171598, 0.9207439198855507, 0.9078816095776522, 40.95618939399719], ['Stochastic Gradient Descent', 0.8784624081401922, 0.919526627218935, 0.8985255854293149, 0.8832723644828733, 0.017693758010864258], ['ADA Boost', 0.9734513274336283, 0.9763313609467456, 0.9748892171344165, 0.9717326238776189, 1.7563517093658447], ['Gradient Boosting', 0.9776207302709069, 0.9822485207100592, 0.9799291617473436, 0.9773860991020951, 2.0035455226898193], ['XGBoost', 0.9818075117370892, 0.9899408284023669, 0.9858573954036536, 0.9840372464250083, 2.752798557281494], ['LightGBM', 0.982373678025852, 0.9893491124260355, 0.9858490566037736, 0.9840372464250083, 0.824209451675415], ['CatBoost', 0.9741480611045829, 0.9810650887573964, 0.9775943396226414, 0.9747256401729298, 1.042436122894287], ['DNN', 0.8816091954022989, 0.9076923076923077, 0.894460641399417, 0.879614233455271, 6.469491004943848], ['CNN', 0.8700629650829994, 0.8994082840236687, 0.8844922897876055, 0.867974725640173, 7.369205474853516], ['RNN', 0.6458333333333334, 0.9538461538461539, 0.7701863354037267, 0.680079813767875, 25.285779237747192]]
#
# Hasil Evaluasi ML/DL dengan XAI:
# [['DecisionTree', 0.9745411486086442, 0.9739644970414201, 0.9742527374963006, 0.9710675091453276, 0.03430914878845215, {'SHAP': array([[-0.00448625,  0.00448625],
#        [-0.0060353 ,  0.0060353 ],
#        [-0.00205818,  0.00205818],
#        [-0.0109595 ,  0.0109595 ],
#        [-0.00274274,  0.00274274],
#        [ 0.        ,  0.        ],
#        [ 0.00528126, -0.00528126],
#        [-0.01040528,  0.01040528],
#        [ 0.00554105, -0.00554105],
#        [ 0.        ,  0.        ],
#        [-0.00216754,  0.00216754],
#        [-0.0006052 ,  0.0006052 ]])}], ['RandomForest', 0.9817968291250734, 0.9893491124260355, 0.985558502799882, 0.9837046890588627, 0.8258152008056641, {'SHAP': array([[-0.00697734,  0.00697734],
#        [ 0.00121184, -0.00121184],
#        [-0.00377401,  0.00377401],
#        [-0.00720007,  0.00720007],
#        [-0.00275632,  0.00275632],
#        [-0.00055902,  0.00055902],
#        [ 0.00169186, -0.00169186],
#        [-0.00559258,  0.00559258],
#        [-0.00032612,  0.00032612],
#        [-0.00075635,  0.00075635],
#        [-0.00128214,  0.00128214],
#        [-0.00173636,  0.00173636]])}], ['Logistic Regression', 0.7622211675367822, 0.9502958579881656, 0.8459309981564392, 0.8054539408047888, 0.03300762176513672, {'SHAP': array([[-3.83621111e-04,  3.83621111e-04],
#        [ 1.92110861e-04, -1.92110861e-04],
#        [-1.57080779e-03,  1.57080779e-03],
#        [-6.20878745e-04,  6.20878745e-04],
#        [-1.24133046e-04,  1.24133046e-04],
#        [ 8.79356994e-04, -8.79356994e-04],
#        [-5.42146475e-04,  5.42146475e-04],
#        [-1.83735429e-02,  1.83735429e-02],
#        [-1.34814728e-04,  1.34814728e-04],
#        [-6.86982253e-03,  6.86982253e-03],
#        [-7.78193138e-05,  7.78193138e-05],
#        [-9.42826703e-07,  9.42826703e-07]])}], ['Naive Bayes', 0.9118387909319899, 0.21420118343195266, 0.3469094393866794, 0.5467243099434652, 0.005001068115234375, {'SHAP': array([[-1.40933129e-03,  1.40933129e-03],
#        [ 1.02674329e-02, -1.02674329e-02],
#        [ 6.21414419e-06, -6.21414419e-06],
#        [-1.03620811e-03,  1.03620811e-03],
#        [-5.38986532e-03,  5.38986532e-03],
#        [ 2.03063428e-02, -2.03063428e-02],
#        [ 1.54209550e-02, -1.54209550e-02],
#        [-1.15907716e-03,  1.15907716e-03],
#        [-6.65427142e-04,  6.65427142e-04],
#        [-1.94278585e-04,  1.94278585e-04],
#        [-5.01090122e-04,  5.01090122e-04],
#        [ 5.61185159e-04, -5.61185159e-04]])}], ['MLP', 0.8914127423822714, 0.9520710059171598, 0.9207439198855507, 0.9078816095776522, 21.38907551765442, {'SHAP': array([[-5.20465280e-03,  5.20465280e-03],
#        [ 7.89095210e-03, -7.89095210e-03],
#        [-3.20838308e-03,  3.20838308e-03],
#        [-3.26287095e-03,  3.26287095e-03],
#        [-2.55690064e-03,  2.55690064e-03],
#        [-5.29961936e-03,  5.29961936e-03],
#        [ 9.72866366e-03, -9.72866366e-03],
#        [-2.00322686e-02,  2.00322686e-02],
#        [ 5.65281351e-03, -5.65281351e-03],
#        [ 1.15014099e-03, -1.15014099e-03],
#        [-3.68291302e-03,  3.68291302e-03],
#        [ 4.12660353e-05, -4.12660353e-05]])}], ['Stochastic Gradient Descent', 0.8784624081401922, 0.919526627218935, 0.8985255854293149, 0.8832723644828733, 0.01750969886779785, {'SHAP': array([[-4.35272168e-04,  4.35272168e-04],
#        [ 2.35855535e-04, -2.35855535e-04],
#        [-2.02773336e-03,  2.02773336e-03],
#        [-6.80001713e-04,  6.80001713e-04],
#        [-1.53536855e-04,  1.53536855e-04],
#        [ 7.39293980e-04, -7.39293980e-04],
#        [-7.50198290e-04,  7.50198290e-04],
#        [-1.99835535e-02,  1.99835535e-02],
#        [-7.87956611e-04,  7.87956611e-04],
#        [-6.01419277e-03,  6.01419277e-03],
#        [-1.07777220e-04,  1.07777220e-04],
#        [-1.82513412e-06,  1.82513412e-06]])}], ['ADA Boost', 0.9734513274336283, 0.9763313609467456, 0.9748892171344165, 0.9717326238776189, 0.760261058807373, {'SHAP': array([[-2.94414904e-04,  2.94414904e-04],
#        [ 4.43543901e-04, -4.43543901e-04],
#        [ 1.09782823e-04, -1.09782823e-04],
#        [-6.11652885e-04,  6.11652885e-04],
#        [-4.82373956e-04,  4.82373956e-04],
#        [-7.07253831e-05,  7.07253831e-05],
#        [ 9.35765358e-05, -9.35765358e-05],
#        [-5.19868598e-04,  5.19868598e-04],
#        [ 3.32931054e-04, -3.32931054e-04],
#        [ 0.00000000e+00,  0.00000000e+00],
#        [-2.81303559e-04,  2.81303559e-04],
#        [ 2.06568240e-05, -2.06568240e-05]])}], ['Gradient Boosting', 0.9776207302709069, 0.9822485207100592, 0.9799291617473436, 0.9773860991020951, 2.6619198322296143, {'SHAP': array([[-0.00081994,  0.00081994],
#        [ 0.00307343, -0.00307343],
#        [-0.00382662,  0.00382662],
#        [-0.01064392,  0.01064392],
#        [-0.00217333,  0.00217333],
#        [-0.00088468,  0.00088468],
#        [ 0.00243447, -0.00243447],
#        [-0.00928996,  0.00928996],
#        [-0.0005078 ,  0.0005078 ],
#        [-0.00015702,  0.00015702],
#        [-0.00035132,  0.00035132],
#        [-0.00108125,  0.00108125]])}], ['XGBoost', 0.9818075117370892, 0.9899408284023669, 0.9858573954036536, 0.9840372464250083, 0.5202093124389648, {'SHAP': array([[-0.00492409,  0.00492409],
#        [-0.00033955,  0.00033955],
#        [-0.00565504,  0.00565504],
#        [-0.0158541 ,  0.0158541 ],
#        [-0.00377932,  0.00377932],
#        [ 0.        ,  0.        ],
#        [ 0.00157566, -0.00157566],
#        [-0.00658001,  0.00658001],
#        [ 0.00078674, -0.00078674],
#        [ 0.        ,  0.        ],
#        [ 0.00093724, -0.00093724],
#        [-0.00041459,  0.00041459]])}], ['LightGBM', 0.982373678025852, 0.9893491124260355, 0.9858490566037736, 0.9840372464250083, 67.38570141792297, {'SHAP': array([[-1.91196551e-03,  1.91196551e-03],
#        [ 1.12888901e-03, -1.12888901e-03],
#        [-4.58408455e-03,  4.58408455e-03],
#        [-1.50229457e-02,  1.50229457e-02],
#        [-6.60555521e-03,  6.60555521e-03],
#        [-3.93554757e-05,  3.93554757e-05],
#        [ 1.73399081e-03, -1.73399081e-03],
#        [-3.29245722e-03,  3.29245722e-03],
#        [-3.86356515e-03,  3.86356515e-03],
#        [-3.62185030e-05,  3.62185030e-05],
#        [ 3.60578102e-05, -3.60578102e-05],
#        [-6.41413039e-04,  6.41413039e-04]])}], ['CatBoost', 0.9741480611045829, 0.9810650887573964, 0.9775943396226414, 0.9747256401729298, 0.2641575336456299, {'SHAP': array([[-9.63490814e-04,  9.63490814e-04],
#        [ 5.27037158e-03, -5.27037158e-03],
#        [-3.17137036e-03,  3.17137036e-03],
#        [-6.07026136e-03,  6.07026136e-03],
#        [-1.21289938e-03,  1.21289938e-03],
#        [-3.23754787e-05,  3.23754787e-05],
#        [ 2.84997684e-03, -2.84997684e-03],
#        [-1.46195319e-02,  1.46195319e-02],
#        [ 1.49540911e-03, -1.49540911e-03],
#        [ 8.88050984e-05, -8.88050984e-05],
#        [-1.60147597e-04,  1.60147597e-04],
#        [-8.91011782e-04,  8.91011782e-04]])}], ['DNN', 0.8824194460146976, 0.9236686390532545, 0.9025729979762936, 0.8879281676089126, 1.9102749824523926, {'SHAP': array([0.02584697])}], ['CNN', 0.8744892002335085, 0.8863905325443787, 0.8803996473699676, 0.8646491519787163, 6.650081396102905, {'SHAP': None}], ['RNN', 0.7294776119402985, 0.9254437869822485, 0.8158581116327595, 0.7652144995011639, 23.720741987228394, {'SHAP': None}]]
