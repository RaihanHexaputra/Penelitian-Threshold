# %%
# Library untuk pengolahan data dan visualisasi
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import joblib
import threading

# Library untuk evaluasi dan model machine learning
from sklearn.metrics import confusion_matrix, classification_report
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
import sklearn.ensemble as ek
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# Library untuk Explainable AI (XAI)
from lime.lime_tabular import LimeTabularExplainer
import shap

# Library untuk Deep Learning
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, LSTM, Dropout
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %%
# Input Dataset 

DM = pd.read_csv("C:\\Data Raihan\\Penelitian Threshold\\Dataset\\CIC-PDFMal2022\\PDFMalware2022.csv") #DM--> Dataset Malware

# %%
DM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10026 entries, 0 to 10025
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fine name         10026 non-null  object
#  1   pdfsize           10025 non-null  float64
#  2   metadata size     10025 non-null  float64
#  3   pages             10025 non-null  float64
#  4   xref Length       10025 non-null  float64
#  5   title characters  10025 non-null  float64
#  6   isEncrypted       10025 non-null  float64
#  7   embedded files    10025 non-null  float64
#  8   images            10025 non-null  object
#  9   text              10025 non-null  object
#  10  header            10025 non-null  object
#  11  obj               10023 non-null  object
#  12  endobj            10023 non-null  object
#  13  stream            10023 non-null  float64
#  14  endstream         10023 non-null  object
#  15  xref              10023 non-null  object
#  16  trailer           10023 non-null  float64
#  17  startxref         10023 non-null  object
#  18  pageno            10023 non-null  object
#  19  encrypt           10023 non-null  float64
#  20  ObjStm            10023 non-null  float64
#  21  JS                10023 non-null  object
#  22  Javascript        10023 non-null  object
#  23  AA                10023 non-null  object
#  24  OpenAction        10023 non-null  object
#  25  Acroform          10023 non-null  object
#  26  JBIG2Decode       10023 non-null  object
#  27  RichMedia         10023 non-null  object
#  28  launch            10023 non-null  object
#  29  EmbeddedFile      10023 non-null  object
#  30  XFA               10023 non-null  object
#  31  Colors            10023 non-null  float64
#  32  Class             10025 non-null  object
# dtypes: float64(12), object(21)
# memory usage: 2.5+ MB

# %%
#Feature Selection
features_to_drop = ['Fine name', 'images', 'text', 'header', 'obj', 'endobj', 'endstream', 
                    'xref', 'startxref', 'pageno', 'JS', 'Javascript', 'AA', 'OpenAction', 
                    'Acroform', 'JBIG2Decode', 'RichMedia', 'launch', 'EmbeddedFile', 'XFA', 'Class']

# Droping specified columns and target variable
X = DM.drop(features_to_drop, axis=1).values    
y = DM['Class'].values

# %%
#Remove Nan
X = pd.DataFrame(X).dropna()
y = y[X.index]

# %%
# Applying Min-Max scaling to make X non-negative
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Recursive Feature Elimination (RFE)
rfe_selector = RFE(estimator=RandomForestClassifier(), n_features_to_select=5)
rfe_selector.fit(X_scaled, y)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=5)

# %%
# Get top features selected by RFE
rfe_top_features_indices = np.where(rfe_selector.support_)[0]

# Retrieve names of the selected features
filtered_columns = DM.drop(features_to_drop, axis=1).columns
features = [filtered_columns[idx] for idx in rfe_top_features_indices]

# Output the selected features and their ranking
print("Selected Features using RFE:")
for feature, rank in zip(features, rfe_selector.ranking_[rfe_top_features_indices]):
    print(f"Feature: {feature} - RFE Rank: {rank}")
# Out:
# Selected Features using RFE:
# Feature: pdfsize - RFE Rank: 1
# Feature: metadata size - RFE Rank: 1
# Feature: xref Length - RFE Rank: 1
# Feature: stream - RFE Rank: 1
# Feature: trailer - RFE Rank: 1

# %%
# Memilih 100% data secara acak dari setiap fitur/column
sampled_data = DM.groupby('Class').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)
# Out:
# C:\Users\Muhammad Raihan\AppData\Local\Temp\ipykernel_14708\1069642451.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_data = DM.groupby('Class').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)

# %%
# Pisahkan data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
# Inisialisasi variabel untuk menyimpan hasil evaluasi
hasil_ml_dl = []
hasil_ml_dl_xai = []

# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Fungsi untuk mengevaluasi model ML/DL
def EvaluateModel(model_name, model, X_train, y_train, X_test, y_test, use_xai=False, is_dl_model=False):
    start_time = time.time()

    # Melatih model
    model.fit(X_train, y_train, epochs=5, batch_size=32, verbose=0) if is_dl_model else model.fit(X_train, y_train)
    
    if is_dl_model:
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    elif hasattr(model, 'predict_proba'):
        # Model dengan metode predict_proba
        y_pred_proba = model.predict_proba(X_test)
        if y_pred_proba.shape[1] > 1:  # Model klasifikasi multi-kelas
            y_pred = np.argmax(y_pred_proba, axis=1)
        else:  # Model klasifikasi biner
            y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    else:
        # Model tanpa metode predict_proba
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()

    # Menghitung confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

    # Menghitung metrik
    Precision = tp / (tp + fp) if (tp + fp) != 0 else 0
    Recall = tp / (tp + fn) if (tp + fn) != 0 else 0
    F1Score = 2 * ((Precision * Recall) / (Precision + Recall)) if (Precision + Recall) != 0 else 0
    Accuracy = (tp + tn) / (tp + fp + tn + fn) if (tp + fp + tn + fn) != 0 else 0

    # Menghitung waktu running
    run_time = time.time() - start_time

    # Jika XAI diperlukan, tambahkan analisis dengan SHAP
    if use_xai:
        # Periksa apakah X_train adalah DataFrame
        if isinstance(X_train, pd.DataFrame):
            feature_names = X_train.columns
        else:
            feature_names = [f"Feature_{i}" for i in range(X_train.shape[1])]
        
        # Perbaiki format X_train untuk SHAP
        if is_dl_model:
            X_train_for_xai = X_train.reshape((X_train.shape[0], X_train.shape[1]))
            X_test_for_xai = X_test.reshape((X_test.shape[0], X_test.shape[1]))
        else:
            X_train_for_xai = X_train
            X_test_for_xai = X_test

        # Gunakan SHAP
        try:
            if is_dl_model:
                explainer = shap.DeepExplainer(model, X_train_for_xai)
                shap_values = explainer.shap_values(X_test_for_xai)
                shap_summary = np.mean(shap_values[0], axis=0)
            else:
                explainer = shap.Explainer(model.predict_proba, X_train_for_xai)
                shap_values = explainer(X_test_for_xai)
                shap_summary = shap_values.values.mean(axis=0)
        except Exception as e:
            print(f"Error using SHAP with {model_name}: {e}")
            shap_summary = None

        # Simpan hasil evaluasi dengan XAI
        hasil_ml_dl_xai.append([model_name, Precision, Recall, F1Score, Accuracy, run_time, {'SHAP': shap_summary}])
    else:
        # Simpan hasil evaluasi tanpa XAI
        hasil_ml_dl.append([model_name, Precision, Recall, F1Score, Accuracy, run_time])

# Model ML dan DL yang akan dievaluasi
model_ml_dl = {
    "DecisionTree": DecisionTreeClassifier(max_depth=10),
    "RandomForest": RandomForestClassifier(n_estimators=50),
    "Logistic Regression": LogisticRegression(random_state=0, max_iter=10000),
    "Naive Bayes": GaussianNB(),
    "MLP": MLPClassifier(solver='adam', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1, max_iter=1000),
    "Stochastic Gradient Descent": SGDClassifier(loss='log_loss', random_state=42),
    "ADA Boost": AdaBoostClassifier(n_estimators=100),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "XGBoost": XGBClassifier(n_estimators=100),
    "LightGBM": LGBMClassifier(n_estimators=100),
    "CatBoost": CatBoostClassifier(iterations=100, depth=6, learning_rate=0.1, loss_function='Logloss')
}

model_dl = {
    "DNN": Sequential([
        Dense(128, input_shape=(X_train.shape[1],), activation='relu'),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "CNN": Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "RNN": Sequential([
        LSTM(100, input_shape=(X_train.shape[1], 1)),
        Dense(1, activation='sigmoid')
    ]),
}

# Pastikan X_train dan X_test memiliki bentuk yang sesuai untuk DL
X_train_dl = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_dl = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Mengevaluasi model ML tanpa XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=False)

# Mengevaluasi model DL tanpa XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=False, is_dl_model=True)

# Mengevaluasi model ML dengan XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=True)

# Mengevaluasi model DL dengan XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=True, is_dl_model=True)

# Print hasil evaluasi tanpa XAI
print("\nHasil Evaluasi ML/DL tanpa XAI:")
print(hasil_ml_dl)

# Print hasil evaluasi dengan XAI
print("\nHasil Evaluasi ML/DL dengan XAI:")
print(hasil_ml_dl_xai)

# Convert results to DataFrame and save to CSV
df_ml_dl = pd.DataFrame(hasil_ml_dl, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime"])
df_ml_dl_xai = pd.DataFrame(hasil_ml_dl_xai, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime", "XAI"])

df_ml_dl.to_csv("hasil_evaluasi_ml_dl_RFEFC.csv", index=False)
df_ml_dl_xai.to_csv("hasil_evaluasi_ml_dl_xai_RFEFC.csv", index=False)
# Out:
# [LightGBM] [Info] Number of positive: 3865, number of negative: 3151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000289 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1186
# [LightGBM] [Info] Number of data points in the train set: 7016, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.550884 -> initscore=0.204242
# [LightGBM] [Info] Start training from score 0.204242
# 0:	learn: 0.6233952	total: 138ms	remaining: 13.7s
# 1:	learn: 0.5667828	total: 140ms	remaining: 6.86s
# 2:	learn: 0.5158579	total: 142ms	remaining: 4.59s
# 3:	learn: 0.4701687	total: 144ms	remaining: 3.45s
# 4:	learn: 0.4331439	total: 146ms	remaining: 2.77s
# 5:	learn: 0.4001143	total: 148ms	remaining: 2.31s
# 6:	learn: 0.3720034	total: 150ms	remaining: 1.99s
# 7:	learn: 0.3466359	total: 152ms	remaining: 1.75s
# 8:	learn: 0.3234386	total: 155ms	remaining: 1.56s
# 9:	learn: 0.3037145	total: 158ms	remaining: 1.42s
# 10:	learn: 0.2849609	total: 161ms	remaining: 1.3s
# 11:	learn: 0.2686569	total: 164ms	remaining: 1.2s
# 12:	learn: 0.2537131	total: 166ms	remaining: 1.11s
# 13:	learn: 0.2402928	total: 170ms	remaining: 1.04s
# 14:	learn: 0.2283432	total: 173ms	remaining: 978ms
# 15:	learn: 0.2181887	total: 175ms	remaining: 917ms
# 16:	learn: 0.2071913	total: 178ms	remaining: 867ms
# 17:	learn: 0.1986340	total: 180ms	remaining: 819ms
# 18:	learn: 0.1898069	total: 182ms	remaining: 778ms
# 19:	learn: 0.1823055	total: 185ms	remaining: 741ms
# 20:	learn: 0.1753956	total: 187ms	remaining: 705ms
# 21:	learn: 0.1696179	total: 190ms	remaining: 673ms
# 22:	learn: 0.1640047	total: 192ms	remaining: 643ms
# 23:	learn: 0.1589595	total: 194ms	remaining: 615ms
# 24:	learn: 0.1542838	total: 196ms	remaining: 589ms
# 25:	learn: 0.1500265	total: 199ms	remaining: 565ms
# 26:	learn: 0.1453649	total: 201ms	remaining: 542ms
# 27:	learn: 0.1416183	total: 203ms	remaining: 521ms
# 28:	learn: 0.1381484	total: 204ms	remaining: 500ms
# 29:	learn: 0.1346485	total: 206ms	remaining: 481ms
# 30:	learn: 0.1315079	total: 208ms	remaining: 463ms
# 31:	learn: 0.1290297	total: 210ms	remaining: 447ms
# 32:	learn: 0.1256832	total: 212ms	remaining: 431ms
# 33:	learn: 0.1234395	total: 214ms	remaining: 415ms
# 34:	learn: 0.1209019	total: 216ms	remaining: 401ms
# 35:	learn: 0.1187198	total: 218ms	remaining: 388ms
# 36:	learn: 0.1163355	total: 220ms	remaining: 374ms
# 37:	learn: 0.1140794	total: 222ms	remaining: 362ms
# 38:	learn: 0.1117700	total: 224ms	remaining: 350ms
# 39:	learn: 0.1095045	total: 226ms	remaining: 338ms
# 40:	learn: 0.1082528	total: 228ms	remaining: 327ms
# 41:	learn: 0.1069304	total: 230ms	remaining: 317ms
# 42:	learn: 0.1049211	total: 232ms	remaining: 307ms
# 43:	learn: 0.1035891	total: 234ms	remaining: 297ms
# 44:	learn: 0.1023829	total: 236ms	remaining: 288ms
# 45:	learn: 0.1014690	total: 238ms	remaining: 279ms
# 46:	learn: 0.1003434	total: 240ms	remaining: 271ms
# 47:	learn: 0.0996869	total: 243ms	remaining: 263ms
# 48:	learn: 0.0983416	total: 245ms	remaining: 255ms
# 49:	learn: 0.0962412	total: 247ms	remaining: 247ms
# 50:	learn: 0.0956501	total: 250ms	remaining: 240ms
# 51:	learn: 0.0946828	total: 253ms	remaining: 233ms
# 52:	learn: 0.0938801	total: 255ms	remaining: 226ms
# 53:	learn: 0.0928902	total: 257ms	remaining: 219ms
# 54:	learn: 0.0922551	total: 260ms	remaining: 213ms
# 55:	learn: 0.0913147	total: 262ms	remaining: 206ms
# 56:	learn: 0.0907956	total: 265ms	remaining: 200ms
# 57:	learn: 0.0897417	total: 267ms	remaining: 194ms
# 58:	learn: 0.0889070	total: 270ms	remaining: 188ms
# 59:	learn: 0.0883280	total: 273ms	remaining: 182ms
# 60:	learn: 0.0877093	total: 275ms	remaining: 176ms
# 61:	learn: 0.0870466	total: 278ms	remaining: 170ms
# 62:	learn: 0.0864922	total: 281ms	remaining: 165ms
# 63:	learn: 0.0858708	total: 284ms	remaining: 160ms
# 64:	learn: 0.0855633	total: 286ms	remaining: 154ms
# 65:	learn: 0.0846223	total: 289ms	remaining: 149ms
# 66:	learn: 0.0840513	total: 292ms	remaining: 144ms
# 67:	learn: 0.0836903	total: 294ms	remaining: 139ms
# 68:	learn: 0.0832687	total: 297ms	remaining: 134ms
# 69:	learn: 0.0825421	total: 300ms	remaining: 129ms
# 70:	learn: 0.0817523	total: 303ms	remaining: 124ms
# 71:	learn: 0.0808942	total: 306ms	remaining: 119ms
# 72:	learn: 0.0807383	total: 309ms	remaining: 114ms
# 73:	learn: 0.0800861	total: 312ms	remaining: 110ms
# 74:	learn: 0.0794294	total: 315ms	remaining: 105ms
# 75:	learn: 0.0788878	total: 317ms	remaining: 100ms
# 76:	learn: 0.0783219	total: 320ms	remaining: 95.5ms
# 77:	learn: 0.0779695	total: 322ms	remaining: 90.9ms
# 78:	learn: 0.0778128	total: 325ms	remaining: 86.5ms
# 79:	learn: 0.0772942	total: 328ms	remaining: 82ms
# 80:	learn: 0.0767109	total: 330ms	remaining: 77.5ms
# 81:	learn: 0.0765114	total: 333ms	remaining: 73.1ms
# 82:	learn: 0.0761029	total: 336ms	remaining: 68.8ms
# 83:	learn: 0.0756197	total: 339ms	remaining: 64.7ms
# 84:	learn: 0.0754426	total: 343ms	remaining: 60.6ms
# 85:	learn: 0.0752159	total: 347ms	remaining: 56.5ms
# 86:	learn: 0.0744049	total: 351ms	remaining: 52.5ms
# 87:	learn: 0.0739720	total: 356ms	remaining: 48.5ms
# 88:	learn: 0.0736518	total: 359ms	remaining: 44.3ms
# 89:	learn: 0.0734552	total: 361ms	remaining: 40.1ms
# 90:	learn: 0.0733091	total: 363ms	remaining: 35.9ms
# 91:	learn: 0.0728457	total: 365ms	remaining: 31.8ms
# 92:	learn: 0.0728055	total: 367ms	remaining: 27.6ms
# 93:	learn: 0.0725272	total: 369ms	remaining: 23.6ms
# 94:	learn: 0.0724081	total: 371ms	remaining: 19.6ms
# 95:	learn: 0.0723201	total: 374ms	remaining: 15.6ms
# 96:	learn: 0.0723011	total: 376ms	remaining: 11.6ms
# 97:	learn: 0.0721581	total: 378ms	remaining: 7.71ms
# 98:	learn: 0.0721017	total: 379ms	remaining: 3.83ms
# 99:	learn: 0.0720559	total: 382ms	remaining: 0us
# 94/94 [==============================] - 0s 713us/step
# 94/94 [==============================] - 0s 805us/step
# 94/94 [==============================] - 1s 3ms/step
# PermutationExplainer explainer: 3008it [00:39, 66.65it/s]
# PermutationExplainer explainer: 3008it [11:27,  4.30it/s]
# PermutationExplainer explainer: 3008it [00:50, 51.63it/s]
# PermutationExplainer explainer: 3008it [02:55, 14.01it/s]
# PermutationExplainer explainer: 3008it [00:34, 62.45it/s]
# PermutationExplainer explainer: 3008it [01:38, 26.10it/s]
# PermutationExplainer explainer: 3008it [1:04:03,  1.28s/it]
# PermutationExplainer explainer: 3008it [03:17, 14.52it/s]
# PermutationExplainer explainer: 3008it [18:12,  2.75it/s]
# [LightGBM] [Info] Number of positive: 3865, number of negative: 3151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.103777 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1186
# [LightGBM] [Info] Number of data points in the train set: 7016, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.550884 -> initscore=0.204242
# [LightGBM] [Info] Start training from score 0.204242
# PermutationExplainer explainer: 3008it [09:36,  5.15it/s]
# 0:	learn: 0.6233952	total: 2.76ms	remaining: 273ms
# 1:	learn: 0.5667828	total: 5.04ms	remaining: 247ms
# 2:	learn: 0.5158579	total: 7.24ms	remaining: 234ms
# 3:	learn: 0.4701687	total: 9.97ms	remaining: 239ms
# 4:	learn: 0.4331439	total: 12.7ms	remaining: 241ms
# 5:	learn: 0.4001143	total: 14.9ms	remaining: 233ms
# 6:	learn: 0.3720034	total: 17.4ms	remaining: 231ms
# 7:	learn: 0.3466359	total: 19.5ms	remaining: 225ms
# 8:	learn: 0.3234386	total: 21.6ms	remaining: 218ms
# 9:	learn: 0.3037145	total: 24.7ms	remaining: 222ms
# 10:	learn: 0.2849609	total: 27.4ms	remaining: 221ms
# 11:	learn: 0.2686569	total: 30ms	remaining: 220ms
# 12:	learn: 0.2537131	total: 32.2ms	remaining: 215ms
# 13:	learn: 0.2402928	total: 34.8ms	remaining: 214ms
# 14:	learn: 0.2283432	total: 37.2ms	remaining: 211ms
# 15:	learn: 0.2181887	total: 39.8ms	remaining: 209ms
# 16:	learn: 0.2071913	total: 42.2ms	remaining: 206ms
# 17:	learn: 0.1986340	total: 44.4ms	remaining: 202ms
# 18:	learn: 0.1898069	total: 47.2ms	remaining: 201ms
# 19:	learn: 0.1823055	total: 49.8ms	remaining: 199ms
# 20:	learn: 0.1753956	total: 53.8ms	remaining: 202ms
# 21:	learn: 0.1696179	total: 56.1ms	remaining: 199ms
# 22:	learn: 0.1640047	total: 59.2ms	remaining: 198ms
# 23:	learn: 0.1589595	total: 62.6ms	remaining: 198ms
# 24:	learn: 0.1542838	total: 66.1ms	remaining: 198ms
# 25:	learn: 0.1500265	total: 69ms	remaining: 196ms
# 26:	learn: 0.1453649	total: 72ms	remaining: 195ms
# 27:	learn: 0.1416183	total: 74.3ms	remaining: 191ms
# 28:	learn: 0.1381484	total: 76.9ms	remaining: 188ms
# 29:	learn: 0.1346485	total: 79ms	remaining: 184ms
# 30:	learn: 0.1315079	total: 81.9ms	remaining: 182ms
# 31:	learn: 0.1290297	total: 84.8ms	remaining: 180ms
# 32:	learn: 0.1256832	total: 87ms	remaining: 177ms
# 33:	learn: 0.1234395	total: 89.3ms	remaining: 173ms
# 34:	learn: 0.1209019	total: 92.3ms	remaining: 171ms
# 35:	learn: 0.1187198	total: 94.4ms	remaining: 168ms
# 36:	learn: 0.1163355	total: 96.8ms	remaining: 165ms
# 37:	learn: 0.1140794	total: 99.3ms	remaining: 162ms
# 38:	learn: 0.1117700	total: 102ms	remaining: 159ms
# 39:	learn: 0.1095045	total: 104ms	remaining: 157ms
# 40:	learn: 0.1082528	total: 109ms	remaining: 157ms
# 41:	learn: 0.1069304	total: 112ms	remaining: 155ms
# 42:	learn: 0.1049211	total: 114ms	remaining: 151ms
# 43:	learn: 0.1035891	total: 119ms	remaining: 151ms
# 44:	learn: 0.1023829	total: 122ms	remaining: 149ms
# 45:	learn: 0.1014690	total: 125ms	remaining: 147ms
# 46:	learn: 0.1003434	total: 131ms	remaining: 147ms
# 47:	learn: 0.0996869	total: 133ms	remaining: 144ms
# 48:	learn: 0.0983416	total: 136ms	remaining: 141ms
# 49:	learn: 0.0962412	total: 138ms	remaining: 138ms
# 50:	learn: 0.0956501	total: 140ms	remaining: 135ms
# 51:	learn: 0.0946828	total: 143ms	remaining: 132ms
# 52:	learn: 0.0938801	total: 145ms	remaining: 129ms
# 53:	learn: 0.0928902	total: 148ms	remaining: 126ms
# 54:	learn: 0.0922551	total: 150ms	remaining: 123ms
# 55:	learn: 0.0913147	total: 152ms	remaining: 120ms
# 56:	learn: 0.0907956	total: 155ms	remaining: 117ms
# 57:	learn: 0.0897417	total: 157ms	remaining: 114ms
# 58:	learn: 0.0889070	total: 159ms	remaining: 111ms
# 59:	learn: 0.0883280	total: 162ms	remaining: 108ms
# 60:	learn: 0.0877093	total: 165ms	remaining: 105ms
# 61:	learn: 0.0870466	total: 167ms	remaining: 102ms
# 62:	learn: 0.0864922	total: 169ms	remaining: 99.4ms
# 63:	learn: 0.0858708	total: 172ms	remaining: 96.6ms
# 64:	learn: 0.0855633	total: 174ms	remaining: 93.9ms
# 65:	learn: 0.0846223	total: 177ms	remaining: 91.2ms
# 66:	learn: 0.0840513	total: 179ms	remaining: 88.4ms
# 67:	learn: 0.0836903	total: 182ms	remaining: 85.7ms
# 68:	learn: 0.0832687	total: 185ms	remaining: 83ms
# 69:	learn: 0.0825421	total: 187ms	remaining: 80.1ms
# 70:	learn: 0.0817523	total: 189ms	remaining: 77.4ms
# 71:	learn: 0.0808942	total: 193ms	remaining: 75ms
# 72:	learn: 0.0807383	total: 195ms	remaining: 72.1ms
# 73:	learn: 0.0800861	total: 197ms	remaining: 69.3ms
# 74:	learn: 0.0794294	total: 199ms	remaining: 66.5ms
# 75:	learn: 0.0788878	total: 202ms	remaining: 63.8ms
# 76:	learn: 0.0783219	total: 204ms	remaining: 61ms
# 77:	learn: 0.0779695	total: 207ms	remaining: 58.4ms
# 78:	learn: 0.0778128	total: 210ms	remaining: 55.8ms
# 79:	learn: 0.0772942	total: 213ms	remaining: 53.3ms
# 80:	learn: 0.0767109	total: 216ms	remaining: 50.7ms
# 81:	learn: 0.0765114	total: 220ms	remaining: 48.3ms
# 82:	learn: 0.0761029	total: 223ms	remaining: 45.6ms
# 83:	learn: 0.0756197	total: 225ms	remaining: 42.9ms
# 84:	learn: 0.0754426	total: 228ms	remaining: 40.2ms
# 85:	learn: 0.0752159	total: 231ms	remaining: 37.5ms
# 86:	learn: 0.0744049	total: 233ms	remaining: 34.8ms
# 87:	learn: 0.0739720	total: 236ms	remaining: 32.2ms
# 88:	learn: 0.0736518	total: 239ms	remaining: 29.5ms
# 89:	learn: 0.0734552	total: 241ms	remaining: 26.8ms
# 90:	learn: 0.0733091	total: 245ms	remaining: 24.2ms
# 91:	learn: 0.0728457	total: 251ms	remaining: 21.9ms
# 92:	learn: 0.0728055	total: 258ms	remaining: 19.4ms
# 93:	learn: 0.0725272	total: 261ms	remaining: 16.7ms
# 94:	learn: 0.0724081	total: 264ms	remaining: 13.9ms
# 95:	learn: 0.0723201	total: 266ms	remaining: 11.1ms
# 96:	learn: 0.0723011	total: 269ms	remaining: 8.33ms
# 97:	learn: 0.0721581	total: 273ms	remaining: 5.56ms
# 98:	learn: 0.0721017	total: 275ms	remaining: 2.78ms
# 99:	learn: 0.0720559	total: 278ms	remaining: 0us
# PermutationExplainer explainer: 3008it [08:59,  5.47it/s]
# 94/94 [==============================] - 0s 718us/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# 94/94 [==============================] - 0s 845us/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Error using SHAP with CNN: operands could not be broadcast together with shapes (7016,12,1) (7016,12)
# 94/94 [==============================] - 1s 2ms/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Error using SHAP with RNN: in user code:
#
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 244, in grad_graph  *
#         out = self.model(shap_rAnD)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler  **
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 371, in custom_grad
#         out = op_handlers[type_name](self, op, *grads) # we cut off the shap_ prefix before the lookup
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 663, in handler
#         return linearity_with_excluded_handler(input_inds, explainer, op, *grads)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 670, in linearity_with_excluded_handler
#         assert not explainer._variable_inputs(op)[i], str(i) + "th input to " + op.name + " cannot vary!"
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 222, in _variable_inputs
#         out[i] = t.name in self.between_tensors
#
#     AttributeError: Exception encountered when calling layer 'lstm' (type LSTM).
#
#     'TFDeep' object has no attribute 'between_tensors'
#
#     Call arguments received by layer 'lstm' (type LSTM):
#       • inputs=tf.Tensor(shape=(14032, 12, 1), dtype=float32)
#       • mask=None
#       • training=False
#       • initial_state=None
#
#
# Hasil Evaluasi ML/DL tanpa XAI:
# [['DecisionTree', 0.97397989355411, 0.9745562130177515, 0.9742679680567881, 0.9710675091453276, 0.03173041343688965], ['RandomForest', 0.9800936768149883, 0.9905325443786982, 0.985285462036492, 0.983372131692717, 0.3976247310638428], ['Logistic Regression', 0.7622211675367822, 0.9502958579881656, 0.8459309981564392, 0.8054539408047888, 0.021672964096069336], ['Naive Bayes', 0.9118387909319899, 0.21420118343195266, 0.3469094393866794, 0.5467243099434652, 0.0052642822265625], ['MLP', 0.8914127423822714, 0.9520710059171598, 0.9207439198855507, 0.9078816095776522, 13.759016036987305], ['Stochastic Gradient Descent', 0.8784624081401922, 0.919526627218935, 0.8985255854293149, 0.8832723644828733, 0.016383647918701172], ['ADA Boost', 0.9734513274336283, 0.9763313609467456, 0.9748892171344165, 0.9717326238776189, 0.6280169486999512], ['Gradient Boosting', 0.9776207302709069, 0.9822485207100592, 0.9799291617473436, 0.9773860991020951, 0.9091196060180664], ['XGBoost', 0.9818075117370892, 0.9899408284023669, 0.9858573954036536, 0.9840372464250083, 1.4116604328155518], ['LightGBM', 0.982373678025852, 0.9893491124260355, 0.9858490566037736, 0.9840372464250083, 0.246323823928833], ['CatBoost', 0.9741480611045829, 0.9810650887573964, 0.9775943396226414, 0.9747256401729298, 0.4869668483734131], ['DNN', 0.870950027457441, 0.9384615384615385, 0.903446311592139, 0.8872630528766212, 1.9541041851043701], ['CNN', 0.8777341559169939, 0.9260355029585798, 0.901238122660524, 0.8859328234120386, 2.19989275932312], ['RNN', 0.9504289799809342, 0.5899408284023668, 0.7280029207740051, 0.7522447622214832, 8.555505990982056]]
#
# Hasil Evaluasi ML/DL dengan XAI:
# [['DecisionTree', 0.9745411486086442, 0.9739644970414201, 0.9742527374963006, 0.9710675091453276, 0.023806333541870117, {'SHAP': array([[-0.0038826 ,  0.0038826 ],
#        [-0.00899927,  0.00899927],
#        [-0.00251357,  0.00251357],
#        [-0.01043857,  0.01043857],
#        [-0.00154062,  0.00154062],
#        [ 0.        ,  0.        ],
#        [ 0.00573364, -0.00573364],
#        [-0.01039117,  0.01039117],
#        [ 0.00525222, -0.00525222],
#        [ 0.        ,  0.        ],
#        [-0.00146011,  0.00146011],
#        [-0.00056392,  0.00056392]])}], ['RandomForest', 0.981786133960047, 0.9887573964497042, 0.9852594339622641, 0.983372131692717, 0.3702712059020996, {'SHAP': array([[-0.0055818 ,  0.0055818 ],
#        [-0.00243128,  0.00243128],
#        [-0.00408579,  0.00408579],
#        [-0.00811917,  0.00811917],
#        [-0.00300989,  0.00300989],
#        [-0.00054031,  0.00054031],
#        [ 0.00180558, -0.00180558],
#        [-0.00625976,  0.00625976],
#        [-0.00087401,  0.00087401],
#        [-0.00017226,  0.00017226],
#        [-0.00138689,  0.00138689],
#        [-0.00154643,  0.00154643]])}], ['Logistic Regression', 0.7622211675367822, 0.9502958579881656, 0.8459309981564392, 0.8054539408047888, 0.027512073516845703, {'SHAP': array([[-3.82981523e-04,  3.82981523e-04],
#        [ 1.91406222e-04, -1.91406222e-04],
#        [-1.56979646e-03,  1.56979646e-03],
#        [-6.23219766e-04,  6.23219766e-04],
#        [-1.23940790e-04,  1.23940790e-04],
#        [ 8.64329602e-04, -8.64329602e-04],
#        [-5.43949914e-04,  5.43949914e-04],
#        [-1.83627742e-02,  1.83627742e-02],
#        [-1.23645364e-04,  1.23645364e-04],
#        [-6.87467800e-03,  6.87467800e-03],
#        [-7.68603685e-05,  7.68603685e-05],
#        [-9.51077520e-07,  9.51077520e-07]])}], ['Naive Bayes', 0.9118387909319899, 0.21420118343195266, 0.3469094393866794, 0.5467243099434652, 0.005002021789550781, {'SHAP': array([[-1.42277470e-03,  1.42277470e-03],
#        [ 1.02914766e-02, -1.02914766e-02],
#        [-1.21593726e-06,  1.21593726e-06],
#        [-1.02230721e-03,  1.02230721e-03],
#        [-5.43342935e-03,  5.43342935e-03],
#        [ 2.03050057e-02, -2.03050057e-02],
#        [ 1.55108209e-02, -1.55108209e-02],
#        [-1.12358088e-03,  1.12358088e-03],
#        [-6.47687963e-04,  6.47687963e-04],
#        [-3.19538586e-04,  3.19538586e-04],
#        [-4.68718329e-04,  4.68718329e-04],
#        [ 5.38801986e-04, -5.38801986e-04]])}], ['MLP', 0.8914127423822714, 0.9520710059171598, 0.9207439198855507, 0.9078816095776522, 14.844472885131836, {'SHAP': array([[-5.42615081e-03,  5.42615081e-03],
#        [ 7.95711658e-03, -7.95711658e-03],
#        [-3.06761374e-03,  3.06761374e-03],
#        [-3.23784184e-03,  3.23784184e-03],
#        [-2.53208852e-03,  2.53208852e-03],
#        [-5.35862634e-03,  5.35862634e-03],
#        [ 9.65165524e-03, -9.65165524e-03],
#        [-2.01428045e-02,  2.01428045e-02],
#        [ 5.36651930e-03, -5.36651930e-03],
#        [ 1.52422864e-03, -1.52422864e-03],
#        [-3.56014676e-03,  3.56014676e-03],
#        [ 4.19805993e-05, -4.19805993e-05]])}], ['Stochastic Gradient Descent', 0.8784624081401922, 0.919526627218935, 0.8985255854293149, 0.8832723644828733, 0.014179229736328125, {'SHAP': array([[-4.36074614e-04,  4.36074614e-04],
#        [ 2.35721803e-04, -2.35721803e-04],
#        [-2.02717215e-03,  2.02717215e-03],
#        [-6.80620886e-04,  6.80620886e-04],
#        [-1.53514829e-04,  1.53514829e-04],
#        [ 7.35444128e-04, -7.35444128e-04],
#        [-7.55774140e-04,  7.55774140e-04],
#        [-2.00063704e-02,  2.00063704e-02],
#        [-7.67303821e-04,  7.67303821e-04],
#        [-5.99977199e-03,  5.99977199e-03],
#        [-1.09607803e-04,  1.09607803e-04],
#        [-1.85333868e-06,  1.85333868e-06]])}], ['ADA Boost', 0.9734513274336283, 0.9763313609467456, 0.9748892171344165, 0.9717326238776189, 1.621863842010498, {'SHAP': array([[-2.94415896e-04,  2.94415896e-04],
#        [ 4.43525940e-04, -4.43525940e-04],
#        [ 1.09786374e-04, -1.09786374e-04],
#        [-6.11658362e-04,  6.11658362e-04],
#        [-4.82365437e-04,  4.82365437e-04],
#        [-7.07253571e-05,  7.07253571e-05],
#        [ 9.35773104e-05, -9.35773104e-05],
#        [-5.19860136e-04,  5.19860136e-04],
#        [ 3.32934164e-04, -3.32934164e-04],
#        [ 0.00000000e+00,  0.00000000e+00],
#        [-2.81306861e-04,  2.81306861e-04],
#        [ 2.06601121e-05, -2.06601121e-05]])}], ['Gradient Boosting', 0.9776207302709069, 0.9822485207100592, 0.9799291617473436, 0.9773860991020951, 1.4464271068572998, {'SHAP': array([[-0.00079615,  0.00079615],
#        [ 0.00296599, -0.00296599],
#        [-0.00376812,  0.00376812],
#        [-0.01080068,  0.01080068],
#        [-0.00211086,  0.00211086],
#        [-0.0008878 ,  0.0008878 ],
#        [ 0.00245249, -0.00245249],
#        [-0.00939614,  0.00939614],
#        [-0.00033376,  0.00033376],
#        [-0.00017426,  0.00017426],
#        [-0.00033031,  0.00033031],
#        [-0.00104923,  0.00104923]])}], ['XGBoost', 0.9818075117370892, 0.9899408284023669, 0.9858573954036536, 0.9840372464250083, 24.117756366729736, {'SHAP': array([[-0.00444406,  0.00444406],
#        [-0.00058895,  0.00058895],
#        [-0.00585099,  0.00585099],
#        [-0.01589603,  0.01589603],
#        [-0.00371031,  0.00371031],
#        [ 0.        ,  0.        ],
#        [ 0.00160811, -0.00160811],
#        [-0.00668862,  0.00668862],
#        [ 0.00081881, -0.00081881],
#        [ 0.        ,  0.        ],
#        [ 0.00089368, -0.00089368],
#        [-0.00038872,  0.00038872]])}], ['LightGBM', 0.982373678025852, 0.9893491124260355, 0.9858490566037736, 0.9840372464250083, 113.99168848991394, {'SHAP': array([[-1.72343709e-03,  1.72343709e-03],
#        [ 3.17542037e-04, -3.17542037e-04],
#        [-4.54394578e-03,  4.54394578e-03],
#        [-1.46544000e-02,  1.46544000e-02],
#        [-6.41350707e-03,  6.41350707e-03],
#        [-4.29176457e-05,  4.29176457e-05],
#        [ 1.68079069e-03, -1.68079069e-03],
#        [-3.39638934e-03,  3.39638934e-03],
#        [-3.69984943e-03,  3.69984943e-03],
#        [-3.59006762e-05,  3.59006762e-05],
#        [ 9.26124247e-05, -9.26124247e-05],
#        [-6.79220803e-04,  6.79220803e-04]])}], ['CatBoost', 0.9741480611045829, 0.9810650887573964, 0.9775943396226414, 0.9747256401729298, 0.38844943046569824, {'SHAP': array([[-1.14212616e-03,  1.14212616e-03],
#        [ 5.68635157e-03, -5.68635157e-03],
#        [-3.15142732e-03,  3.15142732e-03],
#        [-6.15457980e-03,  6.15457980e-03],
#        [-1.22311375e-03,  1.22311375e-03],
#        [-3.34313444e-05,  3.34313444e-05],
#        [ 2.83669450e-03, -2.83669450e-03],
#        [-1.47470288e-02,  1.47470288e-02],
#        [ 1.46898160e-03, -1.46898160e-03],
#        [ 9.22123307e-05, -9.22123307e-05],
#        [-1.51831876e-04,  1.51831876e-04],
#        [-8.97227040e-04,  8.97227040e-04]])}], ['DNN', 0.8823198198198198, 0.9272189349112426, 0.9042123485285631, 0.8895909544396409, 1.906747579574585, {'SHAP': array([0.02688335])}], ['CNN', 0.8767198679141442, 0.942603550295858, 0.9084687767322498, 0.8932490854672431, 2.2772819995880127, {'SHAP': None}], ['RNN', 0.7957362419434805, 0.9497041420118343, 0.8659293229026167, 0.8347189890256069, 8.805590867996216, {'SHAP': None}]]
