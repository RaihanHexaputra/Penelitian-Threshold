# %%
# Library untuk pengolahan data dan visualisasi
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import joblib
import threading

# Library untuk evaluasi dan model machine learning
from sklearn.metrics import confusion_matrix, classification_report
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import mutual_info_classif
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
import sklearn.ensemble as ek
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# Library untuk Explainable AI (XAI)
from lime.lime_tabular import LimeTabularExplainer
import shap

# Library untuk Deep Learning
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, LSTM, Dropout
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %%
# Input Dataset 

DM = pd.read_csv("C:\\Data Raihan\\Penelitian Threshold\\Dataset\\CIC-PDFMal2022\\PDFMalware2022.csv") #DM--> Dataset Malware

# %%
DM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10026 entries, 0 to 10025
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fine name         10026 non-null  object
#  1   pdfsize           10025 non-null  float64
#  2   metadata size     10025 non-null  float64
#  3   pages             10025 non-null  float64
#  4   xref Length       10025 non-null  float64
#  5   title characters  10025 non-null  float64
#  6   isEncrypted       10025 non-null  float64
#  7   embedded files    10025 non-null  float64
#  8   images            10025 non-null  object
#  9   text              10025 non-null  object
#  10  header            10025 non-null  object
#  11  obj               10023 non-null  object
#  12  endobj            10023 non-null  object
#  13  stream            10023 non-null  float64
#  14  endstream         10023 non-null  object
#  15  xref              10023 non-null  object
#  16  trailer           10023 non-null  float64
#  17  startxref         10023 non-null  object
#  18  pageno            10023 non-null  object
#  19  encrypt           10023 non-null  float64
#  20  ObjStm            10023 non-null  float64
#  21  JS                10023 non-null  object
#  22  Javascript        10023 non-null  object
#  23  AA                10023 non-null  object
#  24  OpenAction        10023 non-null  object
#  25  Acroform          10023 non-null  object
#  26  JBIG2Decode       10023 non-null  object
#  27  RichMedia         10023 non-null  object
#  28  launch            10023 non-null  object
#  29  EmbeddedFile      10023 non-null  object
#  30  XFA               10023 non-null  object
#  31  Colors            10023 non-null  float64
#  32  Class             10025 non-null  object
# dtypes: float64(12), object(21)
# memory usage: 2.5+ MB

# %%
#Feature Selection
features_to_drop = ['Fine name', 'images', 'text', 'header', 'obj', 'endobj', 'endstream', 
                    'xref', 'startxref', 'pageno', 'JS', 'Javascript', 'AA', 'OpenAction', 
                    'Acroform', 'JBIG2Decode', 'RichMedia', 'launch', 'EmbeddedFile', 'XFA', 'Class']

# Droping specified columns and target variable
X = DM.drop(features_to_drop, axis=1).values    
y = DM['Class'].values

# %%
#Remove Nan
X = pd.DataFrame(X).dropna()
y = y[X.index]

# %%
# Menerapkan Min-Max scaling untuk membuat X non-negatif
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Mutual Information (Filter)
mutual_info_scores = mutual_info_classif(X_scaled, y)
mutual_info_top_features = np.argsort(mutual_info_scores)[::-1][:5]

# %%
# Getting column names from X that have been filtered
filtered_columns = DM.drop(features_to_drop, axis=1).columns

# Print top features based on Mutual Information scores
features = []
for idx in mutual_info_top_features:
    print(f"Feature {filtered_columns[idx]} dengan skor Mutual Information {mutual_info_scores[idx]}")
    features.append(filtered_columns[idx])
# Out:
# Feature metadata size dengan skor Mutual Information 0.4120018929865006
# Feature xref Length dengan skor Mutual Information 0.4013233863341501
# Feature pdfsize dengan skor Mutual Information 0.3234577270732517
# Feature stream dengan skor Mutual Information 0.2809861817900887
# Feature trailer dengan skor Mutual Information 0.24604935422932117

# %%
# Memilih 100% data secara acak dari setiap fitur/column
sampled_data = DM.groupby('Class').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)
# Out:
# C:\Users\Muhammad Raihan\AppData\Local\Temp\ipykernel_22184\1069642451.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_data = DM.groupby('Class').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)

# %%
# Pisahkan data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
# Inisialisasi variabel untuk menyimpan hasil evaluasi
hasil_ml_dl = []
hasil_ml_dl_xai = []

# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Fungsi untuk mengevaluasi model ML/DL
def EvaluateModel(model_name, model, X_train, y_train, X_test, y_test, use_xai=False, is_dl_model=False):
    start_time = time.time()

    # Melatih model
    model.fit(X_train, y_train, epochs=5, batch_size=32, verbose=0) if is_dl_model else model.fit(X_train, y_train)
    
    if is_dl_model:
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    elif hasattr(model, 'predict_proba'):
        # Model dengan metode predict_proba
        y_pred_proba = model.predict_proba(X_test)
        if y_pred_proba.shape[1] > 1:  # Model klasifikasi multi-kelas
            y_pred = np.argmax(y_pred_proba, axis=1)
        else:  # Model klasifikasi biner
            y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    else:
        # Model tanpa metode predict_proba
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()

    # Menghitung confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

    # Menghitung metrik
    Precision = tp / (tp + fp) if (tp + fp) != 0 else 0
    Recall = tp / (tp + fn) if (tp + fn) != 0 else 0
    F1Score = 2 * ((Precision * Recall) / (Precision + Recall)) if (Precision + Recall) != 0 else 0
    Accuracy = (tp + tn) / (tp + fp + tn + fn) if (tp + fp + tn + fn) != 0 else 0

    # Menghitung waktu running
    run_time = time.time() - start_time

    # Jika XAI diperlukan, tambahkan analisis dengan SHAP
    if use_xai:
        # Periksa apakah X_train adalah DataFrame
        if isinstance(X_train, pd.DataFrame):
            feature_names = X_train.columns
        else:
            feature_names = [f"Feature_{i}" for i in range(X_train.shape[1])]
        
        # Perbaiki format X_train untuk SHAP
        if is_dl_model:
            X_train_for_xai = X_train.reshape((X_train.shape[0], X_train.shape[1]))
            X_test_for_xai = X_test.reshape((X_test.shape[0], X_test.shape[1]))
        else:
            X_train_for_xai = X_train
            X_test_for_xai = X_test

        # Gunakan SHAP
        try:
            if is_dl_model:
                explainer = shap.DeepExplainer(model, X_train_for_xai)
                shap_values = explainer.shap_values(X_test_for_xai)
                shap_summary = np.mean(shap_values[0], axis=0)
            else:
                explainer = shap.Explainer(model.predict_proba, X_train_for_xai)
                shap_values = explainer(X_test_for_xai)
                shap_summary = shap_values.values.mean(axis=0)
        except Exception as e:
            print(f"Error using SHAP with {model_name}: {e}")
            shap_summary = None

        # Simpan hasil evaluasi dengan XAI
        hasil_ml_dl_xai.append([model_name, Precision, Recall, F1Score, Accuracy, run_time, {'SHAP': shap_summary}])
    else:
        # Simpan hasil evaluasi tanpa XAI
        hasil_ml_dl.append([model_name, Precision, Recall, F1Score, Accuracy, run_time])

# Model ML dan DL yang akan dievaluasi
model_ml_dl = {
    "DecisionTree": DecisionTreeClassifier(max_depth=10),
    "RandomForest": RandomForestClassifier(n_estimators=50),
    "Logistic Regression": LogisticRegression(random_state=0, max_iter=10000),
    "Naive Bayes": GaussianNB(),
    "MLP": MLPClassifier(solver='adam', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1, max_iter=1000),
    "Stochastic Gradient Descent": SGDClassifier(loss='log_loss', random_state=42),
    "ADA Boost": AdaBoostClassifier(n_estimators=100),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "XGBoost": XGBClassifier(n_estimators=100),
    "LightGBM": LGBMClassifier(n_estimators=100),
    "CatBoost": CatBoostClassifier(iterations=100, depth=6, learning_rate=0.1, loss_function='Logloss')
}

model_dl = {
    "DNN": Sequential([
        Dense(128, input_shape=(X_train.shape[1],), activation='relu'),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "CNN": Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "RNN": Sequential([
        LSTM(100, input_shape=(X_train.shape[1], 1)),
        Dense(1, activation='sigmoid')
    ]),
}

# Pastikan X_train dan X_test memiliki bentuk yang sesuai untuk DL
X_train_dl = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_dl = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Mengevaluasi model ML tanpa XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=False)

# Mengevaluasi model DL tanpa XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=False, is_dl_model=True)

# Mengevaluasi model ML dengan XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=True)

# Mengevaluasi model DL dengan XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=True, is_dl_model=True)

# Print hasil evaluasi tanpa XAI
print("\nHasil Evaluasi ML/DL tanpa XAI:")
print(hasil_ml_dl)

# Print hasil evaluasi dengan XAI
print("\nHasil Evaluasi ML/DL dengan XAI:")
print(hasil_ml_dl_xai)

# Convert results to DataFrame and save to CSV
df_ml_dl = pd.DataFrame(hasil_ml_dl, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime"])
df_ml_dl_xai = pd.DataFrame(hasil_ml_dl_xai, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime", "XAI"])

df_ml_dl.to_csv("hasil_evaluasi_ml_dl_MIFC.csv", index=False)
df_ml_dl_xai.to_csv("hasil_evaluasi_ml_dl_xai_MIFC.csv", index=False)
# Out:
# [LightGBM] [Info] Number of positive: 3865, number of negative: 3151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000422 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1186
# [LightGBM] [Info] Number of data points in the train set: 7016, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.550884 -> initscore=0.204242
# [LightGBM] [Info] Start training from score 0.204242
# 0:	learn: 0.6233952	total: 151ms	remaining: 15s
# 1:	learn: 0.5667828	total: 160ms	remaining: 7.85s
# 2:	learn: 0.5158579	total: 163ms	remaining: 5.26s
# 3:	learn: 0.4701687	total: 165ms	remaining: 3.97s
# 4:	learn: 0.4331439	total: 168ms	remaining: 3.19s
# 5:	learn: 0.4001143	total: 170ms	remaining: 2.66s
# 6:	learn: 0.3720034	total: 172ms	remaining: 2.29s
# 7:	learn: 0.3466359	total: 174ms	remaining: 2s
# 8:	learn: 0.3234386	total: 176ms	remaining: 1.78s
# 9:	learn: 0.3037145	total: 178ms	remaining: 1.6s
# 10:	learn: 0.2849609	total: 182ms	remaining: 1.47s
# 11:	learn: 0.2686569	total: 184ms	remaining: 1.35s
# 12:	learn: 0.2537131	total: 186ms	remaining: 1.25s
# 13:	learn: 0.2402928	total: 189ms	remaining: 1.16s
# 14:	learn: 0.2283432	total: 192ms	remaining: 1.08s
# 15:	learn: 0.2181887	total: 194ms	remaining: 1.02s
# 16:	learn: 0.2071913	total: 197ms	remaining: 964ms
# 17:	learn: 0.1986340	total: 200ms	remaining: 910ms
# 18:	learn: 0.1898069	total: 202ms	remaining: 862ms
# 19:	learn: 0.1823055	total: 205ms	remaining: 819ms
# 20:	learn: 0.1753956	total: 207ms	remaining: 778ms
# 21:	learn: 0.1696179	total: 209ms	remaining: 743ms
# 22:	learn: 0.1640047	total: 212ms	remaining: 711ms
# 23:	learn: 0.1589595	total: 215ms	remaining: 680ms
# 24:	learn: 0.1542838	total: 251ms	remaining: 753ms
# 25:	learn: 0.1500265	total: 259ms	remaining: 736ms
# 26:	learn: 0.1453649	total: 269ms	remaining: 728ms
# 27:	learn: 0.1416183	total: 285ms	remaining: 733ms
# 28:	learn: 0.1381484	total: 299ms	remaining: 733ms
# 29:	learn: 0.1346485	total: 321ms	remaining: 749ms
# 30:	learn: 0.1315079	total: 328ms	remaining: 731ms
# 31:	learn: 0.1290297	total: 331ms	remaining: 703ms
# 32:	learn: 0.1256832	total: 333ms	remaining: 677ms
# 33:	learn: 0.1234395	total: 335ms	remaining: 651ms
# 34:	learn: 0.1209019	total: 338ms	remaining: 627ms
# 35:	learn: 0.1187198	total: 340ms	remaining: 605ms
# 36:	learn: 0.1163355	total: 343ms	remaining: 583ms
# 37:	learn: 0.1140794	total: 345ms	remaining: 563ms
# 38:	learn: 0.1117700	total: 348ms	remaining: 544ms
# 39:	learn: 0.1095045	total: 350ms	remaining: 525ms
# 40:	learn: 0.1082528	total: 353ms	remaining: 508ms
# 41:	learn: 0.1069304	total: 356ms	remaining: 492ms
# 42:	learn: 0.1049211	total: 359ms	remaining: 476ms
# 43:	learn: 0.1035891	total: 361ms	remaining: 459ms
# 44:	learn: 0.1023829	total: 363ms	remaining: 444ms
# 45:	learn: 0.1014690	total: 366ms	remaining: 429ms
# 46:	learn: 0.1003434	total: 368ms	remaining: 415ms
# 47:	learn: 0.0996869	total: 370ms	remaining: 401ms
# 48:	learn: 0.0983416	total: 373ms	remaining: 388ms
# 49:	learn: 0.0962412	total: 376ms	remaining: 376ms
# 50:	learn: 0.0956501	total: 378ms	remaining: 363ms
# 51:	learn: 0.0946828	total: 381ms	remaining: 352ms
# 52:	learn: 0.0938801	total: 384ms	remaining: 340ms
# 53:	learn: 0.0928902	total: 413ms	remaining: 352ms
# 54:	learn: 0.0922551	total: 437ms	remaining: 357ms
# 55:	learn: 0.0913147	total: 439ms	remaining: 345ms
# 56:	learn: 0.0907956	total: 466ms	remaining: 352ms
# 57:	learn: 0.0897417	total: 471ms	remaining: 341ms
# 58:	learn: 0.0889070	total: 482ms	remaining: 335ms
# 59:	learn: 0.0883280	total: 505ms	remaining: 336ms
# 60:	learn: 0.0877093	total: 513ms	remaining: 328ms
# 61:	learn: 0.0870466	total: 516ms	remaining: 316ms
# 62:	learn: 0.0864922	total: 523ms	remaining: 307ms
# 63:	learn: 0.0858708	total: 525ms	remaining: 295ms
# 64:	learn: 0.0855633	total: 527ms	remaining: 284ms
# 65:	learn: 0.0846223	total: 530ms	remaining: 273ms
# 66:	learn: 0.0840513	total: 532ms	remaining: 262ms
# 67:	learn: 0.0836903	total: 534ms	remaining: 252ms
# 68:	learn: 0.0832687	total: 537ms	remaining: 241ms
# 69:	learn: 0.0825421	total: 540ms	remaining: 231ms
# 70:	learn: 0.0817523	total: 543ms	remaining: 222ms
# 71:	learn: 0.0808942	total: 545ms	remaining: 212ms
# 72:	learn: 0.0807383	total: 548ms	remaining: 203ms
# 73:	learn: 0.0800861	total: 550ms	remaining: 193ms
# 74:	learn: 0.0794294	total: 552ms	remaining: 184ms
# 75:	learn: 0.0788878	total: 555ms	remaining: 175ms
# 76:	learn: 0.0783219	total: 557ms	remaining: 166ms
# 77:	learn: 0.0779695	total: 559ms	remaining: 158ms
# 78:	learn: 0.0778128	total: 561ms	remaining: 149ms
# 79:	learn: 0.0772942	total: 563ms	remaining: 141ms
# 80:	learn: 0.0767109	total: 565ms	remaining: 133ms
# 81:	learn: 0.0765114	total: 567ms	remaining: 125ms
# 82:	learn: 0.0761029	total: 570ms	remaining: 117ms
# 83:	learn: 0.0756197	total: 572ms	remaining: 109ms
# 84:	learn: 0.0754426	total: 574ms	remaining: 101ms
# 85:	learn: 0.0752159	total: 576ms	remaining: 93.7ms
# 86:	learn: 0.0744049	total: 658ms	remaining: 98.4ms
# 87:	learn: 0.0739720	total: 667ms	remaining: 90.9ms
# 88:	learn: 0.0736518	total: 669ms	remaining: 82.7ms
# 89:	learn: 0.0734552	total: 671ms	remaining: 74.6ms
# 90:	learn: 0.0733091	total: 683ms	remaining: 67.5ms
# 91:	learn: 0.0728457	total: 705ms	remaining: 61.3ms
# 92:	learn: 0.0728055	total: 715ms	remaining: 53.8ms
# 93:	learn: 0.0725272	total: 717ms	remaining: 45.8ms
# 94:	learn: 0.0724081	total: 723ms	remaining: 38.1ms
# 95:	learn: 0.0723201	total: 726ms	remaining: 30.2ms
# 96:	learn: 0.0723011	total: 728ms	remaining: 22.5ms
# 97:	learn: 0.0721581	total: 732ms	remaining: 14.9ms
# 98:	learn: 0.0721017	total: 735ms	remaining: 7.43ms
# 99:	learn: 0.0720559	total: 740ms	remaining: 0us
# 94/94 [==============================] - 0s 3ms/step
# 94/94 [==============================] - 1s 4ms/step
# 94/94 [==============================] - 2s 7ms/step
# PermutationExplainer explainer: 3008it [01:49, 27.41it/s]
# PermutationExplainer explainer: 3008it [12:58,  3.84it/s]
# PermutationExplainer explainer: 3008it [01:04, 46.68it/s]
# PermutationExplainer explainer: 3008it [01:12, 35.95it/s]
# PermutationExplainer explainer: 3008it [00:54, 44.54it/s]
# PermutationExplainer explainer: 3008it [00:48, 49.63it/s]
# PermutationExplainer explainer: 3008it [52:12,  1.05s/it]
# PermutationExplainer explainer: 3008it [07:48,  6.26it/s]
# PermutationExplainer explainer: 3008it [28:46,  1.74it/s]
# [LightGBM] [Info] Number of positive: 3865, number of negative: 3151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.062104 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1186
# [LightGBM] [Info] Number of data points in the train set: 7016, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.550884 -> initscore=0.204242
# [LightGBM] [Info] Start training from score 0.204242
# PermutationExplainer explainer: 3008it [03:03, 16.20it/s]
# 0:	learn: 0.6233952	total: 1.91ms	remaining: 189ms
# 1:	learn: 0.5667828	total: 3.86ms	remaining: 189ms
# 2:	learn: 0.5158579	total: 5.4ms	remaining: 175ms
# 3:	learn: 0.4701687	total: 7.25ms	remaining: 174ms
# 4:	learn: 0.4331439	total: 8.87ms	remaining: 169ms
# 5:	learn: 0.4001143	total: 10.4ms	remaining: 163ms
# 6:	learn: 0.3720034	total: 12ms	remaining: 159ms
# 7:	learn: 0.3466359	total: 13.7ms	remaining: 157ms
# 8:	learn: 0.3234386	total: 15.2ms	remaining: 154ms
# 9:	learn: 0.3037145	total: 16.9ms	remaining: 152ms
# 10:	learn: 0.2849609	total: 18.6ms	remaining: 150ms
# 11:	learn: 0.2686569	total: 20.3ms	remaining: 149ms
# 12:	learn: 0.2537131	total: 22ms	remaining: 147ms
# 13:	learn: 0.2402928	total: 23.6ms	remaining: 145ms
# 14:	learn: 0.2283432	total: 25.3ms	remaining: 143ms
# 15:	learn: 0.2181887	total: 27ms	remaining: 142ms
# 16:	learn: 0.2071913	total: 28.7ms	remaining: 140ms
# 17:	learn: 0.1986340	total: 30.4ms	remaining: 138ms
# 18:	learn: 0.1898069	total: 32ms	remaining: 136ms
# 19:	learn: 0.1823055	total: 33.8ms	remaining: 135ms
# 20:	learn: 0.1753956	total: 35.5ms	remaining: 133ms
# 21:	learn: 0.1696179	total: 37.2ms	remaining: 132ms
# 22:	learn: 0.1640047	total: 38.9ms	remaining: 130ms
# 23:	learn: 0.1589595	total: 40.6ms	remaining: 129ms
# 24:	learn: 0.1542838	total: 42.3ms	remaining: 127ms
# 25:	learn: 0.1500265	total: 43.9ms	remaining: 125ms
# 26:	learn: 0.1453649	total: 45.6ms	remaining: 123ms
# 27:	learn: 0.1416183	total: 47.4ms	remaining: 122ms
# 28:	learn: 0.1381484	total: 49.1ms	remaining: 120ms
# 29:	learn: 0.1346485	total: 50.8ms	remaining: 118ms
# 30:	learn: 0.1315079	total: 52.5ms	remaining: 117ms
# 31:	learn: 0.1290297	total: 54.4ms	remaining: 116ms
# 32:	learn: 0.1256832	total: 56ms	remaining: 114ms
# 33:	learn: 0.1234395	total: 57.6ms	remaining: 112ms
# 34:	learn: 0.1209019	total: 59.3ms	remaining: 110ms
# 35:	learn: 0.1187198	total: 60.9ms	remaining: 108ms
# 36:	learn: 0.1163355	total: 62.5ms	remaining: 106ms
# 37:	learn: 0.1140794	total: 64ms	remaining: 104ms
# 38:	learn: 0.1117700	total: 65.7ms	remaining: 103ms
# 39:	learn: 0.1095045	total: 67.5ms	remaining: 101ms
# 40:	learn: 0.1082528	total: 69.1ms	remaining: 99.5ms
# 41:	learn: 0.1069304	total: 70.7ms	remaining: 97.7ms
# 42:	learn: 0.1049211	total: 72.4ms	remaining: 96ms
# 43:	learn: 0.1035891	total: 74.1ms	remaining: 94.3ms
# 44:	learn: 0.1023829	total: 75.7ms	remaining: 92.6ms
# 45:	learn: 0.1014690	total: 77.4ms	remaining: 90.9ms
# 46:	learn: 0.1003434	total: 79.1ms	remaining: 89.2ms
# 47:	learn: 0.0996869	total: 80.8ms	remaining: 87.5ms
# 48:	learn: 0.0983416	total: 82.5ms	remaining: 85.9ms
# 49:	learn: 0.0962412	total: 84.2ms	remaining: 84.2ms
# 50:	learn: 0.0956501	total: 85.8ms	remaining: 82.5ms
# 51:	learn: 0.0946828	total: 87.5ms	remaining: 80.7ms
# 52:	learn: 0.0938801	total: 89.2ms	remaining: 79.1ms
# 53:	learn: 0.0928902	total: 90.8ms	remaining: 77.4ms
# 54:	learn: 0.0922551	total: 92.5ms	remaining: 75.7ms
# 55:	learn: 0.0913147	total: 94.2ms	remaining: 74ms
# 56:	learn: 0.0907956	total: 95.9ms	remaining: 72.3ms
# 57:	learn: 0.0897417	total: 97.6ms	remaining: 70.7ms
# 58:	learn: 0.0889070	total: 99.2ms	remaining: 68.9ms
# 59:	learn: 0.0883280	total: 101ms	remaining: 67.2ms
# 60:	learn: 0.0877093	total: 103ms	remaining: 65.6ms
# 61:	learn: 0.0870466	total: 104ms	remaining: 63.9ms
# 62:	learn: 0.0864922	total: 106ms	remaining: 62.2ms
# 63:	learn: 0.0858708	total: 108ms	remaining: 60.5ms
# 64:	learn: 0.0855633	total: 109ms	remaining: 58.9ms
# 65:	learn: 0.0846223	total: 111ms	remaining: 57.2ms
# 66:	learn: 0.0840513	total: 113ms	remaining: 55.5ms
# 67:	learn: 0.0836903	total: 114ms	remaining: 53.9ms
# 68:	learn: 0.0832687	total: 116ms	remaining: 52.2ms
# 69:	learn: 0.0825421	total: 118ms	remaining: 50.6ms
# 70:	learn: 0.0817523	total: 120ms	remaining: 48.9ms
# 71:	learn: 0.0808942	total: 122ms	remaining: 47.3ms
# 72:	learn: 0.0807383	total: 123ms	remaining: 45.6ms
# 73:	learn: 0.0800861	total: 125ms	remaining: 43.9ms
# 74:	learn: 0.0794294	total: 127ms	remaining: 42.3ms
# 75:	learn: 0.0788878	total: 129ms	remaining: 40.6ms
# 76:	learn: 0.0783219	total: 130ms	remaining: 39ms
# 77:	learn: 0.0779695	total: 132ms	remaining: 37.3ms
# 78:	learn: 0.0778128	total: 134ms	remaining: 35.5ms
# 79:	learn: 0.0772942	total: 135ms	remaining: 33.8ms
# 80:	learn: 0.0767109	total: 137ms	remaining: 32.2ms
# 81:	learn: 0.0765114	total: 139ms	remaining: 30.5ms
# 82:	learn: 0.0761029	total: 140ms	remaining: 28.8ms
# 83:	learn: 0.0756197	total: 142ms	remaining: 27.1ms
# 84:	learn: 0.0754426	total: 144ms	remaining: 25.4ms
# 85:	learn: 0.0752159	total: 146ms	remaining: 23.8ms
# 86:	learn: 0.0744049	total: 148ms	remaining: 22.1ms
# 87:	learn: 0.0739720	total: 149ms	remaining: 20.4ms
# 88:	learn: 0.0736518	total: 151ms	remaining: 18.7ms
# 89:	learn: 0.0734552	total: 153ms	remaining: 17ms
# 90:	learn: 0.0733091	total: 155ms	remaining: 15.3ms
# 91:	learn: 0.0728457	total: 156ms	remaining: 13.6ms
# 92:	learn: 0.0728055	total: 158ms	remaining: 11.9ms
# 93:	learn: 0.0725272	total: 160ms	remaining: 10.2ms
# 94:	learn: 0.0724081	total: 161ms	remaining: 8.49ms
# 95:	learn: 0.0723201	total: 163ms	remaining: 6.79ms
# 96:	learn: 0.0723011	total: 165ms	remaining: 5.1ms
# 97:	learn: 0.0721581	total: 166ms	remaining: 3.4ms
# 98:	learn: 0.0721017	total: 168ms	remaining: 1.7ms
# 99:	learn: 0.0720559	total: 170ms	remaining: 0us
# PermutationExplainer explainer: 3008it [05:31,  8.77it/s]
# 94/94 [==============================] - 0s 2ms/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# 94/94 [==============================] - 0s 703us/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Error using SHAP with CNN: operands could not be broadcast together with shapes (7016,12,1) (7016,12)
# 94/94 [==============================] - 0s 2ms/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# Error using SHAP with RNN: in user code:
#
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 244, in grad_graph  *
#         out = self.model(shap_rAnD)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler  **
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 371, in custom_grad
#         out = op_handlers[type_name](self, op, *grads) # we cut off the shap_ prefix before the lookup
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 663, in handler
#         return linearity_with_excluded_handler(input_inds, explainer, op, *grads)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 670, in linearity_with_excluded_handler
#         assert not explainer._variable_inputs(op)[i], str(i) + "th input to " + op.name + " cannot vary!"
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 222, in _variable_inputs
#         out[i] = t.name in self.between_tensors
#
#     AttributeError: Exception encountered when calling layer 'lstm' (type LSTM).
#
#     'TFDeep' object has no attribute 'between_tensors'
#
#     Call arguments received by layer 'lstm' (type LSTM):
#       • inputs=tf.Tensor(shape=(14032, 12, 1), dtype=float32)
#       • mask=None
#       • training=False
#       • initial_state=None
#
#
# Hasil Evaluasi ML/DL tanpa XAI:
# [['DecisionTree', 0.9739490822972173, 0.9733727810650887, 0.9736608464042615, 0.9704023944130362, 0.06058168411254883], ['RandomForest', 0.9806904622586308, 0.991715976331361, 0.9861724036481319, 0.984369803791154, 0.9345235824584961], ['Logistic Regression', 0.7622211675367822, 0.9502958579881656, 0.8459309981564392, 0.8054539408047888, 0.028437376022338867], ['Naive Bayes', 0.9118387909319899, 0.21420118343195266, 0.3469094393866794, 0.5467243099434652, 0.07754254341125488], ['MLP', 0.8914127423822714, 0.9520710059171598, 0.9207439198855507, 0.9078816095776522, 36.15297484397888], ['Stochastic Gradient Descent', 0.8784624081401922, 0.919526627218935, 0.8985255854293149, 0.8832723644828733, 0.01588606834411621], ['ADA Boost', 0.9734513274336283, 0.9763313609467456, 0.9748892171344165, 0.9717326238776189, 1.746241807937622], ['Gradient Boosting', 0.9776207302709069, 0.9822485207100592, 0.9799291617473436, 0.9773860991020951, 2.267674207687378], ['XGBoost', 0.9818075117370892, 0.9899408284023669, 0.9858573954036536, 0.9840372464250083, 2.560962200164795], ['LightGBM', 0.982373678025852, 0.9893491124260355, 0.9858490566037736, 0.9840372464250083, 0.9226877689361572], ['CatBoost', 0.9741480611045829, 0.9810650887573964, 0.9775943396226414, 0.9747256401729298, 1.0499277114868164], ['DNN', 0.880656108597285, 0.921301775147929, 0.9005205320994794, 0.8856002660458929, 6.723361492156982], ['CNN', 0.875, 0.9402366863905326, 0.9064460924130063, 0.8909211839042235, 8.551880598068237], ['RNN', 0.6197447447447447, 0.9769230769230769, 0.7583830960036747, 0.6501496508147655, 26.393776416778564]]
#
# Hasil Evaluasi ML/DL dengan XAI:
# [['DecisionTree', 0.9745562130177515, 0.9745562130177515, 0.9745562130177515, 0.9714000665114733, 0.021597623825073242, {'SHAP': array([[-0.00490005,  0.00490005],
#        [-0.01088119,  0.01088119],
#        [-0.00012939,  0.00012939],
#        [-0.00804197,  0.00804197],
#        [-0.00282307,  0.00282307],
#        [ 0.        ,  0.        ],
#        [ 0.0054344 , -0.0054344 ],
#        [-0.00940102,  0.00940102],
#        [ 0.00436425, -0.00436425],
#        [-0.00224526,  0.00224526],
#        [ 0.00043697, -0.00043697],
#        [-0.00095019,  0.00095019]])}], ['RandomForest', 0.9835294117647059, 0.9893491124260355, 0.9864306784660767, 0.9847023611572996, 0.8685219287872314, {'SHAP': array([[-6.45314100e-03,  6.45314100e-03],
#        [-8.87911540e-05,  8.87911540e-05],
#        [-3.59190223e-03,  3.59190223e-03],
#        [-7.61892418e-03,  7.61892418e-03],
#        [-3.03265713e-03,  3.03265713e-03],
#        [-6.01594613e-04,  6.01594613e-04],
#        [ 1.82039075e-03, -1.82039075e-03],
#        [-6.09749751e-03,  6.09749751e-03],
#        [-9.60292650e-04,  9.60292650e-04],
#        [-6.93506817e-04,  6.93506817e-04],
#        [-1.30727469e-03,  1.30727469e-03],
#        [-1.34308281e-03,  1.34308281e-03]])}], ['Logistic Regression', 0.7622211675367822, 0.9502958579881656, 0.8459309981564392, 0.8054539408047888, 0.0345149040222168, {'SHAP': array([[-3.83096577e-04,  3.83096577e-04],
#        [ 1.91922856e-04, -1.91922856e-04],
#        [-1.56930868e-03,  1.56930868e-03],
#        [-6.21841876e-04,  6.21841876e-04],
#        [-1.23392878e-04,  1.23392878e-04],
#        [ 8.76913859e-04, -8.76913859e-04],
#        [-5.47121199e-04,  5.47121199e-04],
#        [-1.83757268e-02,  1.83757268e-02],
#        [-1.27161881e-04,  1.27161881e-04],
#        [-6.87238992e-03,  6.87238992e-03],
#        [-7.49243788e-05,  7.49243788e-05],
#        [-9.34071850e-07,  9.34071850e-07]])}], ['Naive Bayes', 0.9118387909319899, 0.21420118343195266, 0.3469094393866794, 0.5467243099434652, 0.006001949310302734, {'SHAP': array([[-1.43037079e-03,  1.43037079e-03],
#        [ 1.02682955e-02, -1.02682955e-02],
#        [ 3.11075575e-06, -3.11075575e-06],
#        [-1.00930272e-03,  1.00930272e-03],
#        [-5.43335725e-03,  5.43335725e-03],
#        [ 2.02718808e-02, -2.02718808e-02],
#        [ 1.54718028e-02, -1.54718028e-02],
#        [-1.17744163e-03,  1.17744163e-03],
#        [-5.81486935e-04,  5.81486935e-04],
#        [-2.29910010e-04,  2.29910010e-04],
#        [-5.20841300e-04,  5.20841300e-04],
#        [ 5.74473082e-04, -5.74473082e-04]])}], ['MLP', 0.8914127423822714, 0.9520710059171598, 0.9207439198855507, 0.9078816095776522, 20.970896244049072, {'SHAP': array([[-5.16973318e-03,  5.16973318e-03],
#        [ 7.75634131e-03, -7.75634131e-03],
#        [-3.11277351e-03,  3.11277351e-03],
#        [-3.29119693e-03,  3.29119693e-03],
#        [-2.52135764e-03,  2.52135764e-03],
#        [-5.38461253e-03,  5.38461253e-03],
#        [ 9.72733229e-03, -9.72733229e-03],
#        [-2.04622309e-02,  2.04622309e-02],
#        [ 5.64837278e-03, -5.64837278e-03],
#        [ 1.38343745e-03, -1.38343745e-03],
#        [-3.38578115e-03,  3.38578115e-03],
#        [ 2.84298773e-05, -2.84298773e-05]])}], ['Stochastic Gradient Descent', 0.8784624081401922, 0.919526627218935, 0.8985255854293149, 0.8832723644828733, 0.017508983612060547, {'SHAP': array([[-4.35230932e-04,  4.35230932e-04],
#        [ 2.35495517e-04, -2.35495517e-04],
#        [-2.03044192e-03,  2.03044192e-03],
#        [-6.82553847e-04,  6.82553847e-04],
#        [-1.51962847e-04,  1.51962847e-04],
#        [ 7.33294041e-04, -7.33294041e-04],
#        [-7.50651191e-04,  7.50651191e-04],
#        [-1.99923025e-02,  1.99923025e-02],
#        [-7.66731111e-04,  7.66731111e-04],
#        [-6.01216582e-03,  6.01216582e-03],
#        [-1.11815485e-04,  1.11815485e-04],
#        [-1.83199972e-06,  1.83199972e-06]])}], ['ADA Boost', 0.9734513274336283, 0.9763313609467456, 0.9748892171344165, 0.9717326238776189, 0.8616716861724854, {'SHAP': array([[-2.94414625e-04,  2.94414625e-04],
#        [ 4.43522950e-04, -4.43522950e-04],
#        [ 1.09788848e-04, -1.09788848e-04],
#        [-6.11652167e-04,  6.11652167e-04],
#        [-4.82375582e-04,  4.82375582e-04],
#        [-7.07251278e-05,  7.07251278e-05],
#        [ 9.35775985e-05, -9.35775985e-05],
#        [-5.19860375e-04,  5.19860375e-04],
#        [ 3.32933884e-04, -3.32933884e-04],
#        [ 0.00000000e+00,  0.00000000e+00],
#        [-2.81301468e-04,  2.81301468e-04],
#        [ 2.06579150e-05, -2.06579150e-05]])}], ['Gradient Boosting', 0.9776207302709069, 0.9822485207100592, 0.9799291617473436, 0.9773860991020951, 2.3633761405944824, {'SHAP': array([[-5.43879364e-04,  5.43879364e-04],
#        [ 3.07744466e-03, -3.07744466e-03],
#        [-4.13588765e-03,  4.13588765e-03],
#        [-1.06772611e-02,  1.06772611e-02],
#        [-2.13311330e-03,  2.13311330e-03],
#        [-8.96675399e-04,  8.96675399e-04],
#        [ 2.42987621e-03, -2.42987621e-03],
#        [-9.35959453e-03,  9.35959453e-03],
#        [-3.02729224e-04,  3.02729224e-04],
#        [-1.76458679e-05,  1.76458679e-05],
#        [-4.48444219e-04,  4.48444219e-04],
#        [-1.21619787e-03,  1.21619787e-03]])}], ['XGBoost', 0.9818075117370892, 0.9899408284023669, 0.9858573954036536, 0.9840372464250083, 1.3063316345214844, {'SHAP': array([[-0.00468517,  0.00468517],
#        [-0.00071376,  0.00071376],
#        [-0.00566449,  0.00566449],
#        [-0.01563445,  0.01563445],
#        [-0.00362294,  0.00362294],
#        [ 0.        ,  0.        ],
#        [ 0.0015524 , -0.0015524 ],
#        [-0.00675881,  0.00675882],
#        [ 0.00077761, -0.00077761],
#        [ 0.        ,  0.        ],
#        [ 0.00094075, -0.00094075],
#        [-0.00043821,  0.00043821]])}], ['LightGBM', 0.982373678025852, 0.9893491124260355, 0.9858490566037736, 0.9840372464250083, 3.0022976398468018, {'SHAP': array([[-2.05282568e-03,  2.05282568e-03],
#        [ 6.03570419e-04, -6.03570419e-04],
#        [-4.40697806e-03,  4.40697806e-03],
#        [-1.47122740e-02,  1.47122740e-02],
#        [-6.34560752e-03,  6.34560752e-03],
#        [-4.25233035e-05,  4.25233035e-05],
#        [ 1.73086092e-03, -1.73086092e-03],
#        [-3.44874300e-03,  3.44874300e-03],
#        [-3.77933781e-03,  3.77933781e-03],
#        [-4.11374022e-05,  4.11374022e-05],
#        [ 7.96013750e-05, -7.96013750e-05],
#        [-6.83228669e-04,  6.83228669e-04]])}], ['CatBoost', 0.9741480611045829, 0.9810650887573964, 0.9775943396226414, 0.9747256401729298, 0.24483251571655273, {'SHAP': array([[-1.06106650e-03,  1.06106650e-03],
#        [ 5.48606649e-03, -5.48606649e-03],
#        [-3.21983550e-03,  3.21983550e-03],
#        [-6.20873157e-03,  6.20873157e-03],
#        [-1.12911153e-03,  1.12911153e-03],
#        [-3.33789456e-05,  3.33789456e-05],
#        [ 2.87611895e-03, -2.87611895e-03],
#        [-1.45538573e-02,  1.45538573e-02],
#        [ 1.41776214e-03, -1.41776214e-03],
#        [ 9.26916009e-05, -9.26916009e-05],
#        [-1.58782520e-04,  1.58782520e-04],
#        [-9.24401356e-04,  9.24401356e-04]])}], ['DNN', 0.8329022245214692, 0.9526627218934911, 0.8887662158432239, 0.865979381443299, 5.562406301498413, {'SHAP': array([0.02701907])}], ['CNN', 0.8755841121495327, 0.8869822485207101, 0.8812463256907702, 0.8656468240771533, 1.971548318862915, {'SHAP': None}], ['RNN', 0.8586266589728794, 0.8804733727810651, 0.8694127957931639, 0.85134685733289, 6.787338972091675, {'SHAP': None}]]
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
