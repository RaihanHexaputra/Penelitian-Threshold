# %%
# Library untuk pengolahan data dan visualisasi
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import joblib
import threading

# Library untuk evaluasi dan model machine learning
from sklearn.metrics import confusion_matrix, classification_report
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Lasso
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
import sklearn.ensemble as ek
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# Library untuk Explainable AI (XAI)
from lime.lime_tabular import LimeTabularExplainer
import shap

# Library untuk Deep Learning
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, LSTM, Dropout
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %%
# Input Dataset 

DM = pd.read_csv("C:\\Data Raihan\\Penelitian Threshold\\Dataset\\CIC-PDFMal2022\\PDFMalware2022.csv") #DM--> Dataset Malware

# %%
DM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10026 entries, 0 to 10025
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fine name         10026 non-null  object
#  1   pdfsize           10025 non-null  float64
#  2   metadata size     10025 non-null  float64
#  3   pages             10025 non-null  float64
#  4   xref Length       10025 non-null  float64
#  5   title characters  10025 non-null  float64
#  6   isEncrypted       10025 non-null  float64
#  7   embedded files    10025 non-null  float64
#  8   images            10025 non-null  object
#  9   text              10025 non-null  object
#  10  header            10025 non-null  object
#  11  obj               10023 non-null  object
#  12  endobj            10023 non-null  object
#  13  stream            10023 non-null  float64
#  14  endstream         10023 non-null  object
#  15  xref              10023 non-null  object
#  16  trailer           10023 non-null  float64
#  17  startxref         10023 non-null  object
#  18  pageno            10023 non-null  object
#  19  encrypt           10023 non-null  float64
#  20  ObjStm            10023 non-null  float64
#  21  JS                10023 non-null  object
#  22  Javascript        10023 non-null  object
#  23  AA                10023 non-null  object
#  24  OpenAction        10023 non-null  object
#  25  Acroform          10023 non-null  object
#  26  JBIG2Decode       10023 non-null  object
#  27  RichMedia         10023 non-null  object
#  28  launch            10023 non-null  object
#  29  EmbeddedFile      10023 non-null  object
#  30  XFA               10023 non-null  object
#  31  Colors            10023 non-null  float64
#  32  Class             10025 non-null  object
# dtypes: float64(12), object(21)
# memory usage: 2.5+ MB

# %%
#Feature Selection
features_to_drop = ['Fine name', 'images', 'text', 'header', 'obj', 'endobj', 'endstream', 
                    'xref', 'startxref', 'pageno', 'JS', 'Javascript', 'AA', 'OpenAction', 
                    'Acroform', 'JBIG2Decode', 'RichMedia', 'launch', 'EmbeddedFile', 'XFA', 'Class']

# Droping specified columns and target variable
X = DM.drop(features_to_drop, axis=1).values    
y = DM['Class'].values

# %%
#Remove Nan
X = pd.DataFrame(X).dropna()
y = y[X.index]

# %%
# Applying Min-Max scaling to make X non-negative
scaler = MinMaxScaler()
X_lasso = scaler.fit_transform(X)

# %%
# Encode target variable if it's categorical
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Applying Lasso (L1 Regularization)
lasso = Lasso(alpha=0.001)
lasso.fit(X_lasso, y_encoded)
# Out:
# Lasso(alpha=0.001)

# %%
# Getting the indices of features selected by Lasso (where the coefficients are non-zero)
lasso_support = np.where(lasso.coef_ != 0)[0]

# Mengambil nama kolom dari X yang sudah difilter
filtered_columns = DM.drop(features_to_drop, axis=1).columns

features = []
for idx in lasso_support:
    print(f"Feature {filtered_columns[idx]} dipilih dengan koefisien Lasso {lasso.coef_[idx]}")
    features.append(filtered_columns[idx])
# Out:
# Feature xref Length dipilih dengan koefisien Lasso 0.5716592813261737
# Feature isEncrypted dipilih dengan koefisien Lasso -0.9834152468611262
# Feature stream dipilih dengan koefisien Lasso -3.771354582507884
# Feature trailer dipilih dengan koefisien Lasso -1.5923835409796896
# Feature encrypt dipilih dengan koefisien Lasso -0.42155864595417547

# %%
# Memilih 100% data secara acak dari setiap fitur/column
sampled_data = DM.groupby('Class').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)
# Out:
# C:\Users\Muhammad Raihan\AppData\Local\Temp\ipykernel_2316\1069642451.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_data = DM.groupby('Class').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)

# %%
# Pisahkan data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X_lasso, y, test_size=0.3, random_state=42)

# %%
# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
# Inisialisasi variabel untuk menyimpan hasil evaluasi
hasil_ml_dl = []
hasil_ml_dl_xai = []

# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Fungsi untuk mengevaluasi model ML/DL
def EvaluateModel(model_name, model, X_train, y_train, X_test, y_test, use_xai=False, is_dl_model=False):
    start_time = time.time()

    # Melatih model
    model.fit(X_train, y_train, epochs=5, batch_size=32, verbose=0) if is_dl_model else model.fit(X_train, y_train)
    
    if is_dl_model:
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    elif hasattr(model, 'predict_proba'):
        # Model dengan metode predict_proba
        y_pred_proba = model.predict_proba(X_test)
        if y_pred_proba.shape[1] > 1:  # Model klasifikasi multi-kelas
            y_pred = np.argmax(y_pred_proba, axis=1)
        else:  # Model klasifikasi biner
            y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    else:
        # Model tanpa metode predict_proba
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()

    # Menghitung confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

    # Menghitung metrik
    Precision = tp / (tp + fp) if (tp + fp) != 0 else 0
    Recall = tp / (tp + fn) if (tp + fn) != 0 else 0
    F1Score = 2 * ((Precision * Recall) / (Precision + Recall)) if (Precision + Recall) != 0 else 0
    Accuracy = (tp + tn) / (tp + fp + tn + fn) if (tp + fp + tn + fn) != 0 else 0

    # Menghitung waktu running
    run_time = time.time() - start_time

    # Jika XAI diperlukan, tambahkan analisis dengan SHAP
    if use_xai:
        # Periksa apakah X_train adalah DataFrame
        if isinstance(X_train, pd.DataFrame):
            feature_names = X_train.columns
        else:
            feature_names = [f"Feature_{i}" for i in range(X_train.shape[1])]
        
        # Perbaiki format X_train untuk SHAP
        if is_dl_model:
            X_train_for_xai = X_train.reshape((X_train.shape[0], X_train.shape[1]))
            X_test_for_xai = X_test.reshape((X_test.shape[0], X_test.shape[1]))
        else:
            X_train_for_xai = X_train
            X_test_for_xai = X_test

        # Gunakan SHAP
        try:
            if is_dl_model:
                explainer = shap.DeepExplainer(model, X_train_for_xai)
                shap_values = explainer.shap_values(X_test_for_xai)
                shap_summary = np.mean(shap_values[0], axis=0)
            else:
                explainer = shap.Explainer(model.predict_proba, X_train_for_xai)
                shap_values = explainer(X_test_for_xai)
                shap_summary = shap_values.values.mean(axis=0)
        except Exception as e:
            print(f"Error using SHAP with {model_name}: {e}")
            shap_summary = None

        # Simpan hasil evaluasi dengan XAI
        hasil_ml_dl_xai.append([model_name, Precision, Recall, F1Score, Accuracy, run_time, {'SHAP': shap_summary}])
    else:
        # Simpan hasil evaluasi tanpa XAI
        hasil_ml_dl.append([model_name, Precision, Recall, F1Score, Accuracy, run_time])

# Model ML dan DL yang akan dievaluasi
model_ml_dl = {
    "DecisionTree": DecisionTreeClassifier(max_depth=10),
    "RandomForest": RandomForestClassifier(n_estimators=50),
    "Logistic Regression": LogisticRegression(random_state=0, max_iter=10000),
    "Naive Bayes": GaussianNB(),
    "MLP": MLPClassifier(solver='adam', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1, max_iter=1000),
    "Stochastic Gradient Descent": SGDClassifier(loss='log_loss', random_state=42),
    "ADA Boost": AdaBoostClassifier(n_estimators=100),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "XGBoost": XGBClassifier(n_estimators=100),
    "LightGBM": LGBMClassifier(n_estimators=100),
    "CatBoost": CatBoostClassifier(iterations=100, depth=6, learning_rate=0.1, loss_function='Logloss')
}

model_dl = {
    "DNN": Sequential([
        Dense(128, input_shape=(X_train.shape[1],), activation='relu'),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "CNN": Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "RNN": Sequential([
        LSTM(100, input_shape=(X_train.shape[1], 1)),
        Dense(1, activation='sigmoid')
    ]),
}

# Pastikan X_train dan X_test memiliki bentuk yang sesuai untuk DL
X_train_dl = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_dl = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Mengevaluasi model ML tanpa XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=False)

# Mengevaluasi model DL tanpa XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=False, is_dl_model=True)

# Mengevaluasi model ML dengan XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=True)

# Mengevaluasi model DL dengan XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=True, is_dl_model=True)

# Print hasil evaluasi tanpa XAI
print("\nHasil Evaluasi ML/DL tanpa XAI:")
print(hasil_ml_dl)

# Print hasil evaluasi dengan XAI
print("\nHasil Evaluasi ML/DL dengan XAI:")
print(hasil_ml_dl_xai)

# Convert results to DataFrame and save to CSV
df_ml_dl = pd.DataFrame(hasil_ml_dl, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime"])
df_ml_dl_xai = pd.DataFrame(hasil_ml_dl_xai, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime", "XAI"])

df_ml_dl.to_csv("hasil_evaluasi_ml_dl_LFC.csv", index=False)
df_ml_dl_xai.to_csv("hasil_evaluasi_ml_dl_xai_LFC.csv", index=False)
# Out:
# [LightGBM] [Info] Number of positive: 3865, number of negative: 3151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000342 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1186
# [LightGBM] [Info] Number of data points in the train set: 7016, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.550884 -> initscore=0.204242
# [LightGBM] [Info] Start training from score 0.204242
# 0:	learn: 0.6233952	total: 136ms	remaining: 13.4s
# 1:	learn: 0.5667828	total: 138ms	remaining: 6.74s
# 2:	learn: 0.5158579	total: 139ms	remaining: 4.5s
# 3:	learn: 0.4701687	total: 141ms	remaining: 3.38s
# 4:	learn: 0.4331439	total: 143ms	remaining: 2.71s
# 5:	learn: 0.4001143	total: 144ms	remaining: 2.26s
# 6:	learn: 0.3720034	total: 146ms	remaining: 1.94s
# 7:	learn: 0.3466359	total: 148ms	remaining: 1.7s
# 8:	learn: 0.3234386	total: 150ms	remaining: 1.51s
# 9:	learn: 0.3037145	total: 151ms	remaining: 1.36s
# 10:	learn: 0.2849609	total: 153ms	remaining: 1.24s
# 11:	learn: 0.2686569	total: 155ms	remaining: 1.13s
# 12:	learn: 0.2537131	total: 156ms	remaining: 1.05s
# 13:	learn: 0.2402928	total: 158ms	remaining: 970ms
# 14:	learn: 0.2283432	total: 160ms	remaining: 904ms
# 15:	learn: 0.2181887	total: 161ms	remaining: 846ms
# 16:	learn: 0.2071913	total: 163ms	remaining: 796ms
# 17:	learn: 0.1986340	total: 165ms	remaining: 750ms
# 18:	learn: 0.1898069	total: 166ms	remaining: 709ms
# 19:	learn: 0.1823055	total: 168ms	remaining: 672ms
# 20:	learn: 0.1753956	total: 170ms	remaining: 638ms
# 21:	learn: 0.1696179	total: 171ms	remaining: 606ms
# 22:	learn: 0.1640047	total: 173ms	remaining: 578ms
# 23:	learn: 0.1589595	total: 174ms	remaining: 552ms
# 24:	learn: 0.1542838	total: 176ms	remaining: 528ms
# 25:	learn: 0.1500265	total: 178ms	remaining: 506ms
# 26:	learn: 0.1453649	total: 179ms	remaining: 485ms
# 27:	learn: 0.1416183	total: 181ms	remaining: 465ms
# 28:	learn: 0.1381484	total: 183ms	remaining: 447ms
# 29:	learn: 0.1346485	total: 184ms	remaining: 430ms
# 30:	learn: 0.1315079	total: 186ms	remaining: 413ms
# 31:	learn: 0.1290297	total: 187ms	remaining: 398ms
# 32:	learn: 0.1256832	total: 189ms	remaining: 384ms
# 33:	learn: 0.1234395	total: 191ms	remaining: 370ms
# 34:	learn: 0.1209019	total: 192ms	remaining: 357ms
# 35:	learn: 0.1187198	total: 194ms	remaining: 345ms
# 36:	learn: 0.1163355	total: 196ms	remaining: 333ms
# 37:	learn: 0.1140794	total: 197ms	remaining: 322ms
# 38:	learn: 0.1117700	total: 199ms	remaining: 312ms
# 39:	learn: 0.1095045	total: 201ms	remaining: 302ms
# 40:	learn: 0.1082528	total: 203ms	remaining: 292ms
# 41:	learn: 0.1069304	total: 204ms	remaining: 282ms
# 42:	learn: 0.1049211	total: 206ms	remaining: 273ms
# 43:	learn: 0.1035891	total: 208ms	remaining: 264ms
# 44:	learn: 0.1023829	total: 209ms	remaining: 256ms
# 45:	learn: 0.1014690	total: 211ms	remaining: 248ms
# 46:	learn: 0.1003434	total: 212ms	remaining: 240ms
# 47:	learn: 0.0996869	total: 214ms	remaining: 232ms
# 48:	learn: 0.0983416	total: 216ms	remaining: 224ms
# 49:	learn: 0.0962412	total: 217ms	remaining: 217ms
# 50:	learn: 0.0956501	total: 219ms	remaining: 210ms
# 51:	learn: 0.0946828	total: 220ms	remaining: 203ms
# 52:	learn: 0.0938801	total: 222ms	remaining: 197ms
# 53:	learn: 0.0928902	total: 224ms	remaining: 191ms
# 54:	learn: 0.0922551	total: 226ms	remaining: 185ms
# 55:	learn: 0.0913147	total: 227ms	remaining: 179ms
# 56:	learn: 0.0907956	total: 229ms	remaining: 173ms
# 57:	learn: 0.0897417	total: 231ms	remaining: 167ms
# 58:	learn: 0.0889070	total: 232ms	remaining: 161ms
# 59:	learn: 0.0883280	total: 234ms	remaining: 156ms
# 60:	learn: 0.0877093	total: 236ms	remaining: 151ms
# 61:	learn: 0.0870466	total: 237ms	remaining: 146ms
# 62:	learn: 0.0864922	total: 239ms	remaining: 140ms
# 63:	learn: 0.0858708	total: 241ms	remaining: 135ms
# 64:	learn: 0.0855633	total: 242ms	remaining: 131ms
# 65:	learn: 0.0846223	total: 244ms	remaining: 126ms
# 66:	learn: 0.0840513	total: 246ms	remaining: 121ms
# 67:	learn: 0.0836903	total: 247ms	remaining: 116ms
# 68:	learn: 0.0832687	total: 249ms	remaining: 112ms
# 69:	learn: 0.0825421	total: 251ms	remaining: 107ms
# 70:	learn: 0.0817523	total: 253ms	remaining: 103ms
# 71:	learn: 0.0808942	total: 254ms	remaining: 98.9ms
# 72:	learn: 0.0807383	total: 256ms	remaining: 94.7ms
# 73:	learn: 0.0800861	total: 258ms	remaining: 90.5ms
# 74:	learn: 0.0794294	total: 259ms	remaining: 86.5ms
# 75:	learn: 0.0788878	total: 261ms	remaining: 82.4ms
# 76:	learn: 0.0783219	total: 263ms	remaining: 78.5ms
# 77:	learn: 0.0779695	total: 264ms	remaining: 74.6ms
# 78:	learn: 0.0778128	total: 266ms	remaining: 70.7ms
# 79:	learn: 0.0772942	total: 268ms	remaining: 66.9ms
# 80:	learn: 0.0767109	total: 270ms	remaining: 63.2ms
# 81:	learn: 0.0765114	total: 271ms	remaining: 59.5ms
# 82:	learn: 0.0761029	total: 273ms	remaining: 55.9ms
# 83:	learn: 0.0756197	total: 275ms	remaining: 52.3ms
# 84:	learn: 0.0754426	total: 276ms	remaining: 48.8ms
# 85:	learn: 0.0752159	total: 278ms	remaining: 45.3ms
# 86:	learn: 0.0744049	total: 280ms	remaining: 41.8ms
# 87:	learn: 0.0739720	total: 282ms	remaining: 38.4ms
# 88:	learn: 0.0736518	total: 283ms	remaining: 35ms
# 89:	learn: 0.0734552	total: 285ms	remaining: 31.7ms
# 90:	learn: 0.0733091	total: 287ms	remaining: 28.4ms
# 91:	learn: 0.0728457	total: 288ms	remaining: 25.1ms
# 92:	learn: 0.0728055	total: 290ms	remaining: 21.8ms
# 93:	learn: 0.0725272	total: 292ms	remaining: 18.6ms
# 94:	learn: 0.0724081	total: 293ms	remaining: 15.4ms
# 95:	learn: 0.0723201	total: 295ms	remaining: 12.3ms
# 96:	learn: 0.0723011	total: 297ms	remaining: 9.17ms
# 97:	learn: 0.0721581	total: 298ms	remaining: 6.09ms
# 98:	learn: 0.0721017	total: 300ms	remaining: 3.03ms
# 99:	learn: 0.0720559	total: 301ms	remaining: 0us
# 94/94 [==============================] - 0s 630us/step
# 94/94 [==============================] - 0s 665us/step
# 94/94 [==============================] - 0s 2ms/step
# PermutationExplainer explainer: 3008it [00:32, 76.79it/s]
# PermutationExplainer explainer: 3008it [09:13,  5.32it/s]
# PermutationExplainer explainer: 3008it [00:39, 57.90it/s]
# PermutationExplainer explainer: 3008it [00:48, 49.17it/s]
# PermutationExplainer explainer: 3008it [00:38, 56.49it/s]
# PermutationExplainer explainer: 3008it [00:39, 56.88it/s]
# PermutationExplainer explainer: 3008it [1:07:00,  1.34s/it]
# PermutationExplainer explainer: 3008it [02:26, 19.48it/s]
# PermutationExplainer explainer: 3008it [14:26,  3.34it/s]
# [LightGBM] [Info] Number of positive: 3865, number of negative: 3151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.112088 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1186
# [LightGBM] [Info] Number of data points in the train set: 7016, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.550884 -> initscore=0.204242
# [LightGBM] [Info] Start training from score 0.204242
# PermutationExplainer explainer: 3008it [10:12,  4.79it/s]
# 0:	learn: 0.6233952	total: 17.5ms	remaining: 1.73s
# 1:	learn: 0.5667828	total: 31.9ms	remaining: 1.56s
# 2:	learn: 0.5158579	total: 49.5ms	remaining: 1.6s
# 3:	learn: 0.4701687	total: 57.5ms	remaining: 1.38s
# 4:	learn: 0.4331439	total: 64.6ms	remaining: 1.23s
# 5:	learn: 0.4001143	total: 84.2ms	remaining: 1.32s
# 6:	learn: 0.3720034	total: 95.8ms	remaining: 1.27s
# 7:	learn: 0.3466359	total: 108ms	remaining: 1.24s
# 8:	learn: 0.3234386	total: 118ms	remaining: 1.2s
# 9:	learn: 0.3037145	total: 130ms	remaining: 1.17s
# 10:	learn: 0.2849609	total: 143ms	remaining: 1.16s
# 11:	learn: 0.2686569	total: 159ms	remaining: 1.16s
# 12:	learn: 0.2537131	total: 167ms	remaining: 1.11s
# 13:	learn: 0.2402928	total: 179ms	remaining: 1.1s
# 14:	learn: 0.2283432	total: 203ms	remaining: 1.15s
# 15:	learn: 0.2181887	total: 218ms	remaining: 1.15s
# 16:	learn: 0.2071913	total: 248ms	remaining: 1.21s
# 17:	learn: 0.1986340	total: 301ms	remaining: 1.37s
# 18:	learn: 0.1898069	total: 326ms	remaining: 1.39s
# 19:	learn: 0.1823055	total: 338ms	remaining: 1.35s
# 20:	learn: 0.1753956	total: 348ms	remaining: 1.31s
# 21:	learn: 0.1696179	total: 361ms	remaining: 1.28s
# 22:	learn: 0.1640047	total: 371ms	remaining: 1.24s
# 23:	learn: 0.1589595	total: 381ms	remaining: 1.21s
# 24:	learn: 0.1542838	total: 396ms	remaining: 1.19s
# 25:	learn: 0.1500265	total: 410ms	remaining: 1.17s
# 26:	learn: 0.1453649	total: 423ms	remaining: 1.14s
# 27:	learn: 0.1416183	total: 430ms	remaining: 1.11s
# 28:	learn: 0.1381484	total: 439ms	remaining: 1.07s
# 29:	learn: 0.1346485	total: 449ms	remaining: 1.05s
# 30:	learn: 0.1315079	total: 467ms	remaining: 1.04s
# 31:	learn: 0.1290297	total: 481ms	remaining: 1.02s
# 32:	learn: 0.1256832	total: 493ms	remaining: 1s
# 33:	learn: 0.1234395	total: 508ms	remaining: 985ms
# 34:	learn: 0.1209019	total: 547ms	remaining: 1.01s
# 35:	learn: 0.1187198	total: 565ms	remaining: 1s
# 36:	learn: 0.1163355	total: 569ms	remaining: 969ms
# 37:	learn: 0.1140794	total: 585ms	remaining: 954ms
# 38:	learn: 0.1117700	total: 605ms	remaining: 947ms
# 39:	learn: 0.1095045	total: 617ms	remaining: 925ms
# 40:	learn: 0.1082528	total: 637ms	remaining: 917ms
# 41:	learn: 0.1069304	total: 647ms	remaining: 893ms
# 42:	learn: 0.1049211	total: 665ms	remaining: 881ms
# 43:	learn: 0.1035891	total: 675ms	remaining: 859ms
# 44:	learn: 0.1023829	total: 690ms	remaining: 844ms
# 45:	learn: 0.1014690	total: 696ms	remaining: 817ms
# 46:	learn: 0.1003434	total: 709ms	remaining: 800ms
# 47:	learn: 0.0996869	total: 722ms	remaining: 783ms
# 48:	learn: 0.0983416	total: 738ms	remaining: 768ms
# 49:	learn: 0.0962412	total: 755ms	remaining: 755ms
# 50:	learn: 0.0956501	total: 770ms	remaining: 739ms
# 51:	learn: 0.0946828	total: 795ms	remaining: 734ms
# 52:	learn: 0.0938801	total: 813ms	remaining: 721ms
# 53:	learn: 0.0928902	total: 819ms	remaining: 698ms
# 54:	learn: 0.0922551	total: 831ms	remaining: 680ms
# 55:	learn: 0.0913147	total: 868ms	remaining: 682ms
# 56:	learn: 0.0907956	total: 920ms	remaining: 694ms
# 57:	learn: 0.0897417	total: 961ms	remaining: 696ms
# 58:	learn: 0.0889070	total: 984ms	remaining: 684ms
# 59:	learn: 0.0883280	total: 1s	remaining: 668ms
# 60:	learn: 0.0877093	total: 1.04s	remaining: 664ms
# 61:	learn: 0.0870466	total: 1.08s	remaining: 662ms
# 62:	learn: 0.0864922	total: 1.09s	remaining: 639ms
# 63:	learn: 0.0858708	total: 1.1s	remaining: 618ms
# 64:	learn: 0.0855633	total: 1.12s	remaining: 602ms
# 65:	learn: 0.0846223	total: 1.14s	remaining: 585ms
# 66:	learn: 0.0840513	total: 1.15s	remaining: 566ms
# 67:	learn: 0.0836903	total: 1.16s	remaining: 545ms
# 68:	learn: 0.0832687	total: 1.18s	remaining: 529ms
# 69:	learn: 0.0825421	total: 1.2s	remaining: 516ms
# 70:	learn: 0.0817523	total: 1.24s	remaining: 505ms
# 71:	learn: 0.0808942	total: 1.25s	remaining: 485ms
# 72:	learn: 0.0807383	total: 1.26s	remaining: 467ms
# 73:	learn: 0.0800861	total: 1.27s	remaining: 448ms
# 74:	learn: 0.0794294	total: 1.28s	remaining: 427ms
# 75:	learn: 0.0788878	total: 1.29s	remaining: 409ms
# 76:	learn: 0.0783219	total: 1.31s	remaining: 390ms
# 77:	learn: 0.0779695	total: 1.32s	remaining: 372ms
# 78:	learn: 0.0778128	total: 1.32s	remaining: 351ms
# 79:	learn: 0.0772942	total: 1.33s	remaining: 332ms
# 80:	learn: 0.0767109	total: 1.34s	remaining: 315ms
# 81:	learn: 0.0765114	total: 1.36s	remaining: 298ms
# 82:	learn: 0.0761029	total: 1.37s	remaining: 282ms
# 83:	learn: 0.0756197	total: 1.39s	remaining: 264ms
# 84:	learn: 0.0754426	total: 1.41s	remaining: 248ms
# 85:	learn: 0.0752159	total: 1.42s	remaining: 231ms
# 86:	learn: 0.0744049	total: 1.42s	remaining: 212ms
# 87:	learn: 0.0739720	total: 1.43s	remaining: 195ms
# 88:	learn: 0.0736518	total: 1.45s	remaining: 179ms
# 89:	learn: 0.0734552	total: 1.46s	remaining: 162ms
# 90:	learn: 0.0733091	total: 1.47s	remaining: 146ms
# 91:	learn: 0.0728457	total: 1.51s	remaining: 132ms
# 92:	learn: 0.0728055	total: 1.53s	remaining: 115ms
# 93:	learn: 0.0725272	total: 1.54s	remaining: 98.7ms
# 94:	learn: 0.0724081	total: 1.56s	remaining: 82.2ms
# 95:	learn: 0.0723201	total: 1.57s	remaining: 65.6ms
# 96:	learn: 0.0723011	total: 1.59s	remaining: 49.2ms
# 97:	learn: 0.0721581	total: 1.61s	remaining: 32.9ms
# 98:	learn: 0.0721017	total: 1.62s	remaining: 16.4ms
# 99:	learn: 0.0720559	total: 1.64s	remaining: 0us
# PermutationExplainer explainer: 3008it [16:58,  2.92it/s]
# 94/94 [==============================] - 0s 737us/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# 94/94 [==============================] - 0s 855us/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Error using SHAP with CNN: operands could not be broadcast together with shapes (7016,12,1) (7016,12)
# 94/94 [==============================] - 1s 2ms/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Error using SHAP with RNN: in user code:
#
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 244, in grad_graph  *
#         out = self.model(shap_rAnD)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler  **
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 371, in custom_grad
#         out = op_handlers[type_name](self, op, *grads) # we cut off the shap_ prefix before the lookup
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 663, in handler
#         return linearity_with_excluded_handler(input_inds, explainer, op, *grads)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 670, in linearity_with_excluded_handler
#         assert not explainer._variable_inputs(op)[i], str(i) + "th input to " + op.name + " cannot vary!"
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 222, in _variable_inputs
#         out[i] = t.name in self.between_tensors
#
#     AttributeError: Exception encountered when calling layer 'lstm' (type LSTM).
#
#     'TFDeep' object has no attribute 'between_tensors'
#
#     Call arguments received by layer 'lstm' (type LSTM):
#       • inputs=tf.Tensor(shape=(14032, 12, 1), dtype=float32)
#       • mask=None
#       • training=False
#       • initial_state=None
#
#
# Hasil Evaluasi ML/DL tanpa XAI:
# [['DecisionTree', 0.9745260663507109, 0.9733727810650887, 0.9739490822972173, 0.9707349517791819, 0.025162458419799805], ['RandomForest', 0.9829512051734274, 0.9893491124260355, 0.9861397817752875, 0.984369803791154, 0.2906770706176758], ['Logistic Regression', 0.7622211675367822, 0.9502958579881656, 0.8459309981564392, 0.8054539408047888, 0.025781869888305664], ['Naive Bayes', 0.9118387909319899, 0.21420118343195266, 0.3469094393866794, 0.5467243099434652, 0.0036649703979492188], ['MLP', 0.8914127423822714, 0.9520710059171598, 0.9207439198855507, 0.9078816095776522, 10.909969091415405], ['Stochastic Gradient Descent', 0.8784624081401922, 0.919526627218935, 0.8985255854293149, 0.8832723644828733, 0.018472909927368164], ['ADA Boost', 0.9734513274336283, 0.9763313609467456, 0.9748892171344165, 0.9717326238776189, 0.6264784336090088], ['Gradient Boosting', 0.9776207302709069, 0.9822485207100592, 0.9799291617473436, 0.9773860991020951, 0.7696666717529297], ['XGBoost', 0.9818075117370892, 0.9899408284023669, 0.9858573954036536, 0.9840372464250083, 1.3370625972747803], ['LightGBM', 0.982373678025852, 0.9893491124260355, 0.9858490566037736, 0.9840372464250083, 0.1738574504852295], ['CatBoost', 0.9741480611045829, 0.9810650887573964, 0.9775943396226414, 0.9747256401729298, 0.3874330520629883], ['DNN', 0.8798866855524079, 0.9189349112426035, 0.898986975397974, 0.8839374792151646, 1.764749526977539], ['CNN', 0.8372703412073491, 0.9437869822485208, 0.8873435326842838, 0.8653142667110076, 1.9016740322113037], ['RNN', 0.6623481781376518, 0.9680473372781065, 0.7865384615384615, 0.7046890588626538, 7.845363140106201]]
#
# Hasil Evaluasi ML/DL dengan XAI:
# [['DecisionTree', 0.9739490822972173, 0.9733727810650887, 0.9736608464042615, 0.9704023944130362, 0.023339509963989258, {'SHAP': array([[-0.00613438,  0.00613438],
#        [-0.00827693,  0.00827693],
#        [ 0.00026802, -0.00026802],
#        [-0.00949784,  0.00949784],
#        [-0.00362969,  0.00362969],
#        [ 0.        ,  0.        ],
#        [ 0.00575353, -0.00575353],
#        [-0.00970179,  0.00970179],
#        [ 0.00535475, -0.00535475],
#        [ 0.        ,  0.        ],
#        [-0.00189773,  0.00189773],
#        [-0.0010419 ,  0.0010419 ]])}], ['RandomForest', 0.9795441262419637, 0.991715976331361, 0.985592472802117, 0.9837046890588627, 0.25186967849731445, {'SHAP': array([[-0.00607364,  0.00607364],
#        [ 0.00078658, -0.00078658],
#        [-0.0034217 ,  0.0034217 ],
#        [-0.0071    ,  0.0071    ],
#        [-0.00283132,  0.00283132],
#        [-0.00065268,  0.00065268],
#        [ 0.00173654, -0.00173654],
#        [-0.0059706 ,  0.0059706 ],
#        [-0.00144566,  0.00144566],
#        [-0.00051188,  0.00051188],
#        [-0.00085536,  0.00085536],
#        [-0.00181758,  0.00181758]])}], ['Logistic Regression', 0.7622211675367822, 0.9502958579881656, 0.8459309981564392, 0.8054539408047888, 0.023432493209838867, {'SHAP': array([[-3.83310608e-04,  3.83310608e-04],
#        [ 1.92383618e-04, -1.92383618e-04],
#        [-1.57133886e-03,  1.57133886e-03],
#        [-6.18914939e-04,  6.18914939e-04],
#        [-1.23863947e-04,  1.23863947e-04],
#        [ 8.69388734e-04, -8.69388734e-04],
#        [-5.38479553e-04,  5.38479553e-04],
#        [-1.83715555e-02,  1.83715555e-02],
#        [-1.31535594e-04,  1.31535594e-04],
#        [-6.87064533e-03,  6.87064533e-03],
#        [-7.82295869e-05,  7.82295869e-05],
#        [-9.60005438e-07,  9.60005438e-07]])}], ['Naive Bayes', 0.9118387909319899, 0.21420118343195266, 0.3469094393866794, 0.5467243099434652, 0.005001068115234375, {'SHAP': array([[-1.40562639e-03,  1.40562639e-03],
#        [ 1.02620938e-02, -1.02620938e-02],
#        [ 6.31720826e-06, -6.31720826e-06],
#        [-1.00607545e-03,  1.00607545e-03],
#        [-5.35245960e-03,  5.35245960e-03],
#        [ 2.02292444e-02, -2.02292444e-02],
#        [ 1.54967107e-02, -1.54967107e-02],
#        [-1.18527430e-03,  1.18527430e-03],
#        [-6.35937147e-04,  6.35937147e-04],
#        [-3.00111174e-04,  3.00111174e-04],
#        [-4.66814691e-04,  4.66814691e-04],
#        [ 5.64784910e-04, -5.64784910e-04]])}], ['MLP', 0.8914127423822714, 0.9520710059171598, 0.9207439198855507, 0.9078816095776522, 13.97350549697876, {'SHAP': array([[-5.41379347e-03,  5.41379347e-03],
#        [ 7.88106053e-03, -7.88106053e-03],
#        [-3.08392409e-03,  3.08392409e-03],
#        [-3.25389060e-03,  3.25389060e-03],
#        [-2.53695866e-03,  2.53695866e-03],
#        [-5.47590572e-03,  5.47590572e-03],
#        [ 9.67303361e-03, -9.67303361e-03],
#        [-2.00014639e-02,  2.00014639e-02],
#        [ 5.57000235e-03, -5.57000235e-03],
#        [ 1.48431867e-03, -1.48431867e-03],
#        [-3.65902493e-03,  3.65902493e-03],
#        [ 3.27740398e-05, -3.27740398e-05]])}], ['Stochastic Gradient Descent', 0.8784624081401922, 0.919526627218935, 0.8985255854293149, 0.8832723644828733, 0.020354032516479492, {'SHAP': array([[-4.35167542e-04,  4.35167542e-04],
#        [ 2.35574075e-04, -2.35574075e-04],
#        [-2.03075431e-03,  2.03075431e-03],
#        [-6.84431182e-04,  6.84431182e-04],
#        [-1.52360411e-04,  1.52360411e-04],
#        [ 7.46717525e-04, -7.46717525e-04],
#        [-7.51065433e-04,  7.51065433e-04],
#        [-2.00013409e-02,  2.00013409e-02],
#        [-7.75566142e-04,  7.75566142e-04],
#        [-6.00827007e-03,  6.00827007e-03],
#        [-1.08404360e-04,  1.08404360e-04],
#        [-1.82931536e-06,  1.82931536e-06]])}], ['ADA Boost', 0.9734513274336283, 0.9763313609467456, 0.9748892171344165, 0.9717326238776189, 0.8260922431945801, {'SHAP': array([[-2.94421520e-04,  2.94421520e-04],
#        [ 4.43511979e-04, -4.43511979e-04],
#        [ 1.09789425e-04, -1.09789425e-04],
#        [-6.11626010e-04,  6.11626010e-04],
#        [-4.82376224e-04,  4.82376224e-04],
#        [-7.07259118e-05,  7.07259118e-05],
#        [ 9.35774548e-05, -9.35774548e-05],
#        [-5.19862213e-04,  5.19862213e-04],
#        [ 3.32928852e-04, -3.32928852e-04],
#        [ 0.00000000e+00,  0.00000000e+00],
#        [-2.81302038e-04,  2.81302038e-04],
#        [ 2.06580566e-05, -2.06580566e-05]])}], ['Gradient Boosting', 0.9776207302709069, 0.9822485207100592, 0.9799291617473436, 0.9773860991020951, 1.244549036026001, {'SHAP': array([[-6.22217569e-04,  6.22217569e-04],
#        [ 2.73327731e-03, -2.73327731e-03],
#        [-3.90629273e-03,  3.90629273e-03],
#        [-1.04134055e-02,  1.04134055e-02],
#        [-2.18040516e-03,  2.18040516e-03],
#        [-9.04278573e-04,  9.04278573e-04],
#        [ 2.43909759e-03, -2.43909759e-03],
#        [-9.35787211e-03,  9.35787211e-03],
#        [-6.24847904e-04,  6.24847904e-04],
#        [-1.98097191e-05,  1.98097191e-05],
#        [-3.02125093e-04,  3.02125093e-04],
#        [-1.06037220e-03,  1.06037220e-03]])}], ['XGBoost', 0.9818075117370892, 0.9899408284023669, 0.9858573954036536, 0.9840372464250083, 0.18319201469421387, {'SHAP': array([[-0.00483773,  0.00483773],
#        [-0.00037323,  0.00037323],
#        [-0.00583168,  0.00583168],
#        [-0.01536776,  0.01536776],
#        [-0.00369995,  0.00369995],
#        [ 0.        ,  0.        ],
#        [ 0.00160771, -0.00160771],
#        [-0.0068937 ,  0.00689371],
#        [ 0.00067576, -0.00067576],
#        [ 0.        ,  0.        ],
#        [ 0.00085373, -0.00085373],
#        [-0.00038022,  0.00038022]])}], ['LightGBM', 0.982373678025852, 0.9893491124260355, 0.9858490566037736, 0.9840372464250083, 56.776331424713135, {'SHAP': array([[-1.88845259e-03,  1.88845259e-03],
#        [ 7.94738685e-04, -7.94738685e-04],
#        [-4.61915945e-03,  4.61915945e-03],
#        [-1.48880122e-02,  1.48880122e-02],
#        [-6.65086548e-03,  6.65086548e-03],
#        [-4.66180734e-05,  4.66180734e-05],
#        [ 1.72725580e-03, -1.72725580e-03],
#        [-3.17962602e-03,  3.17962602e-03],
#        [-3.67890658e-03,  3.67890658e-03],
#        [-3.75289702e-05,  3.75289702e-05],
#        [ 5.03270993e-05, -5.03270993e-05],
#        [-6.81774936e-04,  6.81774936e-04]])}], ['CatBoost', 0.9741480611045829, 0.9810650887573964, 0.9775943396226414, 0.9747256401729298, 1.7657229900360107, {'SHAP': array([[-1.08025020e-03,  1.08025020e-03],
#        [ 5.25899142e-03, -5.25899142e-03],
#        [-3.10551973e-03,  3.10551973e-03],
#        [-5.94195779e-03,  5.94195779e-03],
#        [-1.26209235e-03,  1.26209235e-03],
#        [-3.19630579e-05,  3.19630579e-05],
#        [ 2.85077819e-03, -2.85077819e-03],
#        [-1.46110975e-02,  1.46110975e-02],
#        [ 1.49836538e-03, -1.49836538e-03],
#        [ 8.61018004e-05, -8.61018004e-05],
#        [-1.57650383e-04,  1.57650383e-04],
#        [-9.20231896e-04,  9.20231896e-04]])}], ['DNN', 0.8387096774193549, 0.9538461538461539, 0.8925802879291251, 0.8709677419354839, 2.7908577919006348, {'SHAP': array([0.02691116])}], ['CNN', 0.8755841121495327, 0.8869822485207101, 0.8812463256907702, 0.8656468240771533, 2.3930227756500244, {'SHAP': None}], ['RNN', 0.8204188481675393, 0.9272189349112426, 0.8705555555555555, 0.8450282673761224, 8.910653829574585, {'SHAP': None}]]
