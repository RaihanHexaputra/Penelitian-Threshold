# %%
# Library untuk pengolahan data dan visualisasi
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import joblib
import threading

# Library untuk evaluasi dan model machine learning
from sklearn.metrics import confusion_matrix, classification_report
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
import sklearn.ensemble as ek
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# Library untuk Explainable AI (XAI)
from lime.lime_tabular import LimeTabularExplainer
import shap

# Library untuk Deep Learning
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, LSTM, Dropout
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %%
# Input Dataset 

DM = pd.read_csv("C:\\Data Raihan\\Penelitian Threshold\\Dataset\\CIC-PDFMal2022\\PDFMalware2022.csv") #DM--> Dataset Malware

# %%
DM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10026 entries, 0 to 10025
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fine name         10026 non-null  object
#  1   pdfsize           10025 non-null  float64
#  2   metadata size     10025 non-null  float64
#  3   pages             10025 non-null  float64
#  4   xref Length       10025 non-null  float64
#  5   title characters  10025 non-null  float64
#  6   isEncrypted       10025 non-null  float64
#  7   embedded files    10025 non-null  float64
#  8   images            10025 non-null  object
#  9   text              10025 non-null  object
#  10  header            10025 non-null  object
#  11  obj               10023 non-null  object
#  12  endobj            10023 non-null  object
#  13  stream            10023 non-null  float64
#  14  endstream         10023 non-null  object
#  15  xref              10023 non-null  object
#  16  trailer           10023 non-null  float64
#  17  startxref         10023 non-null  object
#  18  pageno            10023 non-null  object
#  19  encrypt           10023 non-null  float64
#  20  ObjStm            10023 non-null  float64
#  21  JS                10023 non-null  object
#  22  Javascript        10023 non-null  object
#  23  AA                10023 non-null  object
#  24  OpenAction        10023 non-null  object
#  25  Acroform          10023 non-null  object
#  26  JBIG2Decode       10023 non-null  object
#  27  RichMedia         10023 non-null  object
#  28  launch            10023 non-null  object
#  29  EmbeddedFile      10023 non-null  object
#  30  XFA               10023 non-null  object
#  31  Colors            10023 non-null  float64
#  32  Class             10025 non-null  object
# dtypes: float64(12), object(21)
# memory usage: 2.5+ MB

# %%
#Feature Selection
features_to_drop = ['Fine name', 'images', 'text', 'header', 'obj', 'endobj', 'endstream', 
                    'xref', 'startxref', 'pageno', 'JS', 'Javascript', 'AA', 'OpenAction', 
                    'Acroform', 'JBIG2Decode', 'RichMedia', 'launch', 'EmbeddedFile', 'XFA', 'Class']

# Droping specified columns and target variable
X = DM.drop(features_to_drop, axis=1).values    
y = DM['Class'].values

# %%
#Remove Nan
X = pd.DataFrame(X).dropna()
y = y[X.index]

# %%
# Applying Min-Max scaling to make X non-negative
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Random Forest Feature Importance - Embedded
rf_model = RandomForestClassifier().fit(X_scaled, y)
rf_importances = rf_model.feature_importances_

# %%
# Select top 5 features based on Random Forest importance
rf_top_features = np.argsort(rf_importances)[::-1][:5]

# Mengambil nama kolom dari X yang sudah difilter
filtered_columns = DM.drop(features_to_drop, axis=1).columns

features = []
for idx in rf_top_features:
    print(f"Feature {filtered_columns[idx]} dengan skor Random Forest {rf_importances[idx]}")
    features.append(filtered_columns[idx])
# Out:
# Feature metadata size dengan skor Random Forest 0.23586944541960195
# Feature stream dengan skor Random Forest 0.2074750715370842
# Feature pdfsize dengan skor Random Forest 0.15788923694617502
# Feature xref Length dengan skor Random Forest 0.1457232893744682
# Feature trailer dengan skor Random Forest 0.1076250428467495

# %%
# Memilih 100% data secara acak dari setiap fitur/column
sampled_data = DM.groupby('Class').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)
# Out:
# C:\Users\Muhammad Raihan\AppData\Local\Temp\ipykernel_26832\1069642451.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_data = DM.groupby('Class').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)

# %%
# Pisahkan data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
# Inisialisasi variabel untuk menyimpan hasil evaluasi
hasil_ml_dl = []
hasil_ml_dl_xai = []

# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Fungsi untuk mengevaluasi model ML/DL
def EvaluateModel(model_name, model, X_train, y_train, X_test, y_test, use_xai=False, is_dl_model=False):
    start_time = time.time()

    # Melatih model
    model.fit(X_train, y_train, epochs=5, batch_size=32, verbose=0) if is_dl_model else model.fit(X_train, y_train)
    
    if is_dl_model:
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    elif hasattr(model, 'predict_proba'):
        # Model dengan metode predict_proba
        y_pred_proba = model.predict_proba(X_test)
        if y_pred_proba.shape[1] > 1:  # Model klasifikasi multi-kelas
            y_pred = np.argmax(y_pred_proba, axis=1)
        else:  # Model klasifikasi biner
            y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    else:
        # Model tanpa metode predict_proba
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()

    # Menghitung confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

    # Menghitung metrik
    Precision = tp / (tp + fp) if (tp + fp) != 0 else 0
    Recall = tp / (tp + fn) if (tp + fn) != 0 else 0
    F1Score = 2 * ((Precision * Recall) / (Precision + Recall)) if (Precision + Recall) != 0 else 0
    Accuracy = (tp + tn) / (tp + fp + tn + fn) if (tp + fp + tn + fn) != 0 else 0

    # Menghitung waktu running
    run_time = time.time() - start_time

    # Jika XAI diperlukan, tambahkan analisis dengan SHAP
    if use_xai:
        # Periksa apakah X_train adalah DataFrame
        if isinstance(X_train, pd.DataFrame):
            feature_names = X_train.columns
        else:
            feature_names = [f"Feature_{i}" for i in range(X_train.shape[1])]
        
        # Perbaiki format X_train untuk SHAP
        if is_dl_model:
            X_train_for_xai = X_train.reshape((X_train.shape[0], X_train.shape[1]))
            X_test_for_xai = X_test.reshape((X_test.shape[0], X_test.shape[1]))
        else:
            X_train_for_xai = X_train
            X_test_for_xai = X_test

        # Gunakan SHAP
        try:
            if is_dl_model:
                explainer = shap.DeepExplainer(model, X_train_for_xai)
                shap_values = explainer.shap_values(X_test_for_xai)
                shap_summary = np.mean(shap_values[0], axis=0)
            else:
                explainer = shap.Explainer(model.predict_proba, X_train_for_xai)
                shap_values = explainer(X_test_for_xai)
                shap_summary = shap_values.values.mean(axis=0)
        except Exception as e:
            print(f"Error using SHAP with {model_name}: {e}")
            shap_summary = None

        # Simpan hasil evaluasi dengan XAI
        hasil_ml_dl_xai.append([model_name, Precision, Recall, F1Score, Accuracy, run_time, {'SHAP': shap_summary}])
    else:
        # Simpan hasil evaluasi tanpa XAI
        hasil_ml_dl.append([model_name, Precision, Recall, F1Score, Accuracy, run_time])

# Model ML dan DL yang akan dievaluasi
model_ml_dl = {
    "DecisionTree": DecisionTreeClassifier(max_depth=10),
    "RandomForest": RandomForestClassifier(n_estimators=50),
    "Logistic Regression": LogisticRegression(random_state=0, max_iter=10000),
    "Naive Bayes": GaussianNB(),
    "MLP": MLPClassifier(solver='adam', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1, max_iter=1000),
    "Stochastic Gradient Descent": SGDClassifier(loss='log_loss', random_state=42),
    "ADA Boost": AdaBoostClassifier(n_estimators=100),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "XGBoost": XGBClassifier(n_estimators=100),
    "LightGBM": LGBMClassifier(n_estimators=100),
    "CatBoost": CatBoostClassifier(iterations=100, depth=6, learning_rate=0.1, loss_function='Logloss')
}

model_dl = {
    "DNN": Sequential([
        Dense(128, input_shape=(X_train.shape[1],), activation='relu'),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "CNN": Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "RNN": Sequential([
        LSTM(100, input_shape=(X_train.shape[1], 1)),
        Dense(1, activation='sigmoid')
    ]),
}

# Pastikan X_train dan X_test memiliki bentuk yang sesuai untuk DL
X_train_dl = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_dl = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Mengevaluasi model ML tanpa XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=False)

# Mengevaluasi model DL tanpa XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=False, is_dl_model=True)

# Mengevaluasi model ML dengan XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=True)

# Mengevaluasi model DL dengan XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=True, is_dl_model=True)

# Print hasil evaluasi tanpa XAI
print("\nHasil Evaluasi ML/DL tanpa XAI:")
print(hasil_ml_dl)

# Print hasil evaluasi dengan XAI
print("\nHasil Evaluasi ML/DL dengan XAI:")
print(hasil_ml_dl_xai)

# Convert results to DataFrame and save to CSV
df_ml_dl = pd.DataFrame(hasil_ml_dl, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime"])
df_ml_dl_xai = pd.DataFrame(hasil_ml_dl_xai, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime", "XAI"])

df_ml_dl.to_csv("hasil_evaluasi_ml_dl_RFFC.csv", index=False)
df_ml_dl_xai.to_csv("hasil_evaluasi_ml_dl_xai_RFFC.csv", index=False)
# Out:
# [LightGBM] [Info] Number of positive: 3865, number of negative: 3151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000221 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1186
# [LightGBM] [Info] Number of data points in the train set: 7016, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.550884 -> initscore=0.204242
# [LightGBM] [Info] Start training from score 0.204242
# 0:	learn: 0.6233952	total: 144ms	remaining: 14.3s
# 1:	learn: 0.5667828	total: 147ms	remaining: 7.2s
# 2:	learn: 0.5158579	total: 149ms	remaining: 4.81s
# 3:	learn: 0.4701687	total: 151ms	remaining: 3.63s
# 4:	learn: 0.4331439	total: 153ms	remaining: 2.91s
# 5:	learn: 0.4001143	total: 155ms	remaining: 2.43s
# 6:	learn: 0.3720034	total: 158ms	remaining: 2.1s
# 7:	learn: 0.3466359	total: 161ms	remaining: 1.85s
# 8:	learn: 0.3234386	total: 162ms	remaining: 1.64s
# 9:	learn: 0.3037145	total: 164ms	remaining: 1.48s
# 10:	learn: 0.2849609	total: 166ms	remaining: 1.34s
# 11:	learn: 0.2686569	total: 168ms	remaining: 1.23s
# 12:	learn: 0.2537131	total: 170ms	remaining: 1.14s
# 13:	learn: 0.2402928	total: 171ms	remaining: 1.05s
# 14:	learn: 0.2283432	total: 174ms	remaining: 985ms
# 15:	learn: 0.2181887	total: 176ms	remaining: 923ms
# 16:	learn: 0.2071913	total: 178ms	remaining: 869ms
# 17:	learn: 0.1986340	total: 180ms	remaining: 820ms
# 18:	learn: 0.1898069	total: 182ms	remaining: 775ms
# 19:	learn: 0.1823055	total: 184ms	remaining: 735ms
# 20:	learn: 0.1753956	total: 186ms	remaining: 700ms
# 21:	learn: 0.1696179	total: 188ms	remaining: 666ms
# 22:	learn: 0.1640047	total: 190ms	remaining: 636ms
# 23:	learn: 0.1589595	total: 192ms	remaining: 607ms
# 24:	learn: 0.1542838	total: 194ms	remaining: 581ms
# 25:	learn: 0.1500265	total: 196ms	remaining: 557ms
# 26:	learn: 0.1453649	total: 197ms	remaining: 534ms
# 27:	learn: 0.1416183	total: 199ms	remaining: 513ms
# 28:	learn: 0.1381484	total: 201ms	remaining: 493ms
# 29:	learn: 0.1346485	total: 204ms	remaining: 477ms
# 30:	learn: 0.1315079	total: 206ms	remaining: 459ms
# 31:	learn: 0.1290297	total: 208ms	remaining: 442ms
# 32:	learn: 0.1256832	total: 210ms	remaining: 426ms
# 33:	learn: 0.1234395	total: 212ms	remaining: 411ms
# 34:	learn: 0.1209019	total: 214ms	remaining: 397ms
# 35:	learn: 0.1187198	total: 216ms	remaining: 384ms
# 36:	learn: 0.1163355	total: 218ms	remaining: 371ms
# 37:	learn: 0.1140794	total: 219ms	remaining: 358ms
# 38:	learn: 0.1117700	total: 221ms	remaining: 346ms
# 39:	learn: 0.1095045	total: 223ms	remaining: 335ms
# 40:	learn: 0.1082528	total: 226ms	remaining: 325ms
# 41:	learn: 0.1069304	total: 227ms	remaining: 314ms
# 42:	learn: 0.1049211	total: 229ms	remaining: 304ms
# 43:	learn: 0.1035891	total: 231ms	remaining: 294ms
# 44:	learn: 0.1023829	total: 233ms	remaining: 285ms
# 45:	learn: 0.1014690	total: 235ms	remaining: 276ms
# 46:	learn: 0.1003434	total: 236ms	remaining: 267ms
# 47:	learn: 0.0996869	total: 238ms	remaining: 258ms
# 48:	learn: 0.0983416	total: 240ms	remaining: 250ms
# 49:	learn: 0.0962412	total: 242ms	remaining: 242ms
# 50:	learn: 0.0956501	total: 243ms	remaining: 234ms
# 51:	learn: 0.0946828	total: 245ms	remaining: 226ms
# 52:	learn: 0.0938801	total: 247ms	remaining: 219ms
# 53:	learn: 0.0928902	total: 249ms	remaining: 212ms
# 54:	learn: 0.0922551	total: 250ms	remaining: 205ms
# 55:	learn: 0.0913147	total: 252ms	remaining: 198ms
# 56:	learn: 0.0907956	total: 254ms	remaining: 192ms
# 57:	learn: 0.0897417	total: 256ms	remaining: 185ms
# 58:	learn: 0.0889070	total: 257ms	remaining: 179ms
# 59:	learn: 0.0883280	total: 259ms	remaining: 173ms
# 60:	learn: 0.0877093	total: 261ms	remaining: 167ms
# 61:	learn: 0.0870466	total: 263ms	remaining: 161ms
# 62:	learn: 0.0864922	total: 264ms	remaining: 155ms
# 63:	learn: 0.0858708	total: 267ms	remaining: 150ms
# 64:	learn: 0.0855633	total: 269ms	remaining: 145ms
# 65:	learn: 0.0846223	total: 271ms	remaining: 140ms
# 66:	learn: 0.0840513	total: 273ms	remaining: 134ms
# 67:	learn: 0.0836903	total: 275ms	remaining: 129ms
# 68:	learn: 0.0832687	total: 277ms	remaining: 124ms
# 69:	learn: 0.0825421	total: 279ms	remaining: 119ms
# 70:	learn: 0.0817523	total: 280ms	remaining: 115ms
# 71:	learn: 0.0808942	total: 282ms	remaining: 110ms
# 72:	learn: 0.0807383	total: 284ms	remaining: 105ms
# 73:	learn: 0.0800861	total: 286ms	remaining: 100ms
# 74:	learn: 0.0794294	total: 288ms	remaining: 95.9ms
# 75:	learn: 0.0788878	total: 290ms	remaining: 91.5ms
# 76:	learn: 0.0783219	total: 291ms	remaining: 87ms
# 77:	learn: 0.0779695	total: 293ms	remaining: 82.7ms
# 78:	learn: 0.0778128	total: 295ms	remaining: 78.4ms
# 79:	learn: 0.0772942	total: 297ms	remaining: 74.3ms
# 80:	learn: 0.0767109	total: 299ms	remaining: 70.1ms
# 81:	learn: 0.0765114	total: 301ms	remaining: 66ms
# 82:	learn: 0.0761029	total: 303ms	remaining: 62ms
# 83:	learn: 0.0756197	total: 304ms	remaining: 58ms
# 84:	learn: 0.0754426	total: 306ms	remaining: 54ms
# 85:	learn: 0.0752159	total: 308ms	remaining: 50.2ms
# 86:	learn: 0.0744049	total: 310ms	remaining: 46.3ms
# 87:	learn: 0.0739720	total: 312ms	remaining: 42.5ms
# 88:	learn: 0.0736518	total: 314ms	remaining: 38.8ms
# 89:	learn: 0.0734552	total: 315ms	remaining: 35ms
# 90:	learn: 0.0733091	total: 317ms	remaining: 31.4ms
# 91:	learn: 0.0728457	total: 319ms	remaining: 27.7ms
# 92:	learn: 0.0728055	total: 321ms	remaining: 24.1ms
# 93:	learn: 0.0725272	total: 322ms	remaining: 20.6ms
# 94:	learn: 0.0724081	total: 324ms	remaining: 17.1ms
# 95:	learn: 0.0723201	total: 326ms	remaining: 13.6ms
# 96:	learn: 0.0723011	total: 328ms	remaining: 10.1ms
# 97:	learn: 0.0721581	total: 329ms	remaining: 6.72ms
# 98:	learn: 0.0721017	total: 331ms	remaining: 3.35ms
# 99:	learn: 0.0720559	total: 333ms	remaining: 0us
# 94/94 [==============================] - 0s 862us/step
# 94/94 [==============================] - 0s 753us/step
# 94/94 [==============================] - 1s 2ms/step
# PermutationExplainer explainer: 3008it [00:39, 67.74it/s]
# PermutationExplainer explainer: 3008it [09:31,  5.17it/s]
# PermutationExplainer explainer: 3008it [00:36, 61.72it/s]
# PermutationExplainer explainer: 3008it [00:44, 52.66it/s]
# PermutationExplainer explainer: 3008it [00:34, 61.52it/s]
# PermutationExplainer explainer: 3008it [00:35, 60.70it/s]
# PermutationExplainer explainer: 3008it [57:32,  1.15s/it]
# PermutationExplainer explainer: 3008it [08:34,  5.73it/s]
# PermutationExplainer explainer: 3008it [1:04:28,  1.29s/it]
# [LightGBM] [Info] Number of positive: 3865, number of negative: 3151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.063073 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1186
# [LightGBM] [Info] Number of data points in the train set: 7016, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.550884 -> initscore=0.204242
# [LightGBM] [Info] Start training from score 0.204242
# PermutationExplainer explainer: 3008it [04:41, 10.43it/s]
# 0:	learn: 0.6233952	total: 2.57ms	remaining: 255ms
# 1:	learn: 0.5667828	total: 4.92ms	remaining: 241ms
# 2:	learn: 0.5158579	total: 7.41ms	remaining: 240ms
# 3:	learn: 0.4701687	total: 9.86ms	remaining: 237ms
# 4:	learn: 0.4331439	total: 12.2ms	remaining: 232ms
# 5:	learn: 0.4001143	total: 14.7ms	remaining: 230ms
# 6:	learn: 0.3720034	total: 17ms	remaining: 226ms
# 7:	learn: 0.3466359	total: 18.8ms	remaining: 216ms
# 8:	learn: 0.3234386	total: 20.9ms	remaining: 211ms
# 9:	learn: 0.3037145	total: 23.1ms	remaining: 208ms
# 10:	learn: 0.2849609	total: 25.5ms	remaining: 206ms
# 11:	learn: 0.2686569	total: 27.9ms	remaining: 204ms
# 12:	learn: 0.2537131	total: 30.2ms	remaining: 202ms
# 13:	learn: 0.2402928	total: 32.5ms	remaining: 199ms
# 14:	learn: 0.2283432	total: 34.5ms	remaining: 195ms
# 15:	learn: 0.2181887	total: 36.7ms	remaining: 193ms
# 16:	learn: 0.2071913	total: 39.6ms	remaining: 193ms
# 17:	learn: 0.1986340	total: 42.6ms	remaining: 194ms
# 18:	learn: 0.1898069	total: 45.3ms	remaining: 193ms
# 19:	learn: 0.1823055	total: 47.4ms	remaining: 190ms
# 20:	learn: 0.1753956	total: 49.9ms	remaining: 188ms
# 21:	learn: 0.1696179	total: 52.1ms	remaining: 185ms
# 22:	learn: 0.1640047	total: 54.6ms	remaining: 183ms
# 23:	learn: 0.1589595	total: 58.5ms	remaining: 185ms
# 24:	learn: 0.1542838	total: 62.5ms	remaining: 188ms
# 25:	learn: 0.1500265	total: 65.5ms	remaining: 186ms
# 26:	learn: 0.1453649	total: 68.5ms	remaining: 185ms
# 27:	learn: 0.1416183	total: 71.5ms	remaining: 184ms
# 28:	learn: 0.1381484	total: 73.9ms	remaining: 181ms
# 29:	learn: 0.1346485	total: 76.4ms	remaining: 178ms
# 30:	learn: 0.1315079	total: 78.8ms	remaining: 175ms
# 31:	learn: 0.1290297	total: 82.5ms	remaining: 175ms
# 32:	learn: 0.1256832	total: 85.8ms	remaining: 174ms
# 33:	learn: 0.1234395	total: 88.5ms	remaining: 172ms
# 34:	learn: 0.1209019	total: 91ms	remaining: 169ms
# 35:	learn: 0.1187198	total: 93.4ms	remaining: 166ms
# 36:	learn: 0.1163355	total: 95.5ms	remaining: 163ms
# 37:	learn: 0.1140794	total: 98.1ms	remaining: 160ms
# 38:	learn: 0.1117700	total: 101ms	remaining: 157ms
# 39:	learn: 0.1095045	total: 103ms	remaining: 154ms
# 40:	learn: 0.1082528	total: 105ms	remaining: 151ms
# 41:	learn: 0.1069304	total: 108ms	remaining: 149ms
# 42:	learn: 0.1049211	total: 110ms	remaining: 146ms
# 43:	learn: 0.1035891	total: 113ms	remaining: 143ms
# 44:	learn: 0.1023829	total: 115ms	remaining: 141ms
# 45:	learn: 0.1014690	total: 117ms	remaining: 138ms
# 46:	learn: 0.1003434	total: 120ms	remaining: 135ms
# 47:	learn: 0.0996869	total: 122ms	remaining: 132ms
# 48:	learn: 0.0983416	total: 124ms	remaining: 129ms
# 49:	learn: 0.0962412	total: 126ms	remaining: 126ms
# 50:	learn: 0.0956501	total: 129ms	remaining: 124ms
# 51:	learn: 0.0946828	total: 131ms	remaining: 121ms
# 52:	learn: 0.0938801	total: 134ms	remaining: 119ms
# 53:	learn: 0.0928902	total: 136ms	remaining: 116ms
# 54:	learn: 0.0922551	total: 138ms	remaining: 113ms
# 55:	learn: 0.0913147	total: 141ms	remaining: 111ms
# 56:	learn: 0.0907956	total: 143ms	remaining: 108ms
# 57:	learn: 0.0897417	total: 146ms	remaining: 106ms
# 58:	learn: 0.0889070	total: 148ms	remaining: 103ms
# 59:	learn: 0.0883280	total: 151ms	remaining: 101ms
# 60:	learn: 0.0877093	total: 154ms	remaining: 98.2ms
# 61:	learn: 0.0870466	total: 156ms	remaining: 95.7ms
# 62:	learn: 0.0864922	total: 159ms	remaining: 93.2ms
# 63:	learn: 0.0858708	total: 162ms	remaining: 90.9ms
# 64:	learn: 0.0855633	total: 164ms	remaining: 88.4ms
# 65:	learn: 0.0846223	total: 167ms	remaining: 85.9ms
# 66:	learn: 0.0840513	total: 169ms	remaining: 83.4ms
# 67:	learn: 0.0836903	total: 172ms	remaining: 80.9ms
# 68:	learn: 0.0832687	total: 175ms	remaining: 78.5ms
# 69:	learn: 0.0825421	total: 177ms	remaining: 76.1ms
# 70:	learn: 0.0817523	total: 180ms	remaining: 73.5ms
# 71:	learn: 0.0808942	total: 182ms	remaining: 70.8ms
# 72:	learn: 0.0807383	total: 184ms	remaining: 68.1ms
# 73:	learn: 0.0800861	total: 187ms	remaining: 65.6ms
# 74:	learn: 0.0794294	total: 189ms	remaining: 63ms
# 75:	learn: 0.0788878	total: 192ms	remaining: 60.6ms
# 76:	learn: 0.0783219	total: 194ms	remaining: 58.1ms
# 77:	learn: 0.0779695	total: 197ms	remaining: 55.6ms
# 78:	learn: 0.0778128	total: 199ms	remaining: 53ms
# 79:	learn: 0.0772942	total: 201ms	remaining: 50.3ms
# 80:	learn: 0.0767109	total: 204ms	remaining: 47.8ms
# 81:	learn: 0.0765114	total: 206ms	remaining: 45.3ms
# 82:	learn: 0.0761029	total: 209ms	remaining: 42.8ms
# 83:	learn: 0.0756197	total: 211ms	remaining: 40.2ms
# 84:	learn: 0.0754426	total: 214ms	remaining: 37.7ms
# 85:	learn: 0.0752159	total: 216ms	remaining: 35.2ms
# 86:	learn: 0.0744049	total: 218ms	remaining: 32.6ms
# 87:	learn: 0.0739720	total: 221ms	remaining: 30.1ms
# 88:	learn: 0.0736518	total: 224ms	remaining: 27.7ms
# 89:	learn: 0.0734552	total: 226ms	remaining: 25.1ms
# 90:	learn: 0.0733091	total: 229ms	remaining: 22.7ms
# 91:	learn: 0.0728457	total: 232ms	remaining: 20.1ms
# 92:	learn: 0.0728055	total: 234ms	remaining: 17.6ms
# 93:	learn: 0.0725272	total: 236ms	remaining: 15.1ms
# 94:	learn: 0.0724081	total: 239ms	remaining: 12.6ms
# 95:	learn: 0.0723201	total: 241ms	remaining: 10ms
# 96:	learn: 0.0723011	total: 243ms	remaining: 7.53ms
# 97:	learn: 0.0721581	total: 246ms	remaining: 5.02ms
# 98:	learn: 0.0721017	total: 248ms	remaining: 2.51ms
# 99:	learn: 0.0720559	total: 251ms	remaining: 0us
# PermutationExplainer explainer: 3008it [07:11,  6.79it/s]
# 94/94 [==============================] - 0s 651us/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# 94/94 [==============================] - 0s 774us/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Error using SHAP with CNN: operands could not be broadcast together with shapes (7016,12,1) (7016,12)
# 94/94 [==============================] - 1s 2ms/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Error using SHAP with RNN: in user code:
#
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 244, in grad_graph  *
#         out = self.model(shap_rAnD)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler  **
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 371, in custom_grad
#         out = op_handlers[type_name](self, op, *grads) # we cut off the shap_ prefix before the lookup
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 663, in handler
#         return linearity_with_excluded_handler(input_inds, explainer, op, *grads)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 670, in linearity_with_excluded_handler
#         assert not explainer._variable_inputs(op)[i], str(i) + "th input to " + op.name + " cannot vary!"
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 222, in _variable_inputs
#         out[i] = t.name in self.between_tensors
#
#     AttributeError: Exception encountered when calling layer 'lstm' (type LSTM).
#
#     'TFDeep' object has no attribute 'between_tensors'
#
#     Call arguments received by layer 'lstm' (type LSTM):
#       • inputs=tf.Tensor(shape=(14032, 12, 1), dtype=float32)
#       • mask=None
#       • training=False
#       • initial_state=None
#
#
# Hasil Evaluasi ML/DL tanpa XAI:
# [['DecisionTree', 0.9739952718676123, 0.9751479289940829, 0.9745712596096985, 0.9714000665114733, 0.024408578872680664], ['RandomForest', 0.9818075117370892, 0.9899408284023669, 0.9858573954036536, 0.9840372464250083, 0.36107754707336426], ['Logistic Regression', 0.7622211675367822, 0.9502958579881656, 0.8459309981564392, 0.8054539408047888, 0.024396896362304688], ['Naive Bayes', 0.9118387909319899, 0.21420118343195266, 0.3469094393866794, 0.5467243099434652, 0.0034971237182617188], ['MLP', 0.8914127423822714, 0.9520710059171598, 0.9207439198855507, 0.9078816095776522, 12.813583135604858], ['Stochastic Gradient Descent', 0.8784624081401922, 0.919526627218935, 0.8985255854293149, 0.8832723644828733, 0.014988899230957031], ['ADA Boost', 0.9734513274336283, 0.9763313609467456, 0.9748892171344165, 0.9717326238776189, 0.6042630672454834], ['Gradient Boosting', 0.9776207302709069, 0.9822485207100592, 0.9799291617473436, 0.9773860991020951, 0.8766589164733887], ['XGBoost', 0.9818075117370892, 0.9899408284023669, 0.9858573954036536, 0.9840372464250083, 1.4629123210906982], ['LightGBM', 0.982373678025852, 0.9893491124260355, 0.9858490566037736, 0.9840372464250083, 0.22797203063964844], ['CatBoost', 0.9741480611045829, 0.9810650887573964, 0.9775943396226414, 0.9747256401729298, 0.4339308738708496], ['DNN', 0.825706940874036, 0.9502958579881656, 0.8836313617606603, 0.8593282341203857, 1.9635157585144043], ['CNN', 0.8268733850129198, 0.9467455621301775, 0.8827586206896552, 0.8586631193880945, 2.117441177368164], ['RNN', 0.5903003981179877, 0.9650887573964497, 0.7325398607680217, 0.6039241769205188, 8.31868839263916]]
#
# Hasil Evaluasi ML/DL dengan XAI:
# [['DecisionTree', 0.9751479289940829, 0.9751479289940829, 0.9751479289940829, 0.9720651812437645, 0.027196407318115234, {'SHAP': array([[-8.94125818e-03,  8.94125818e-03],
#        [-9.34234520e-03,  9.34234520e-03],
#        [-2.51095601e-03,  2.51095601e-03],
#        [-5.33728249e-03,  5.33728249e-03],
#        [-2.87296144e-03,  2.87296144e-03],
#        [ 0.00000000e+00,  0.00000000e+00],
#        [ 5.26666306e-03, -5.26666306e-03],
#        [-1.02019777e-02,  1.02019777e-02],
#        [ 4.08305558e-03, -4.08305558e-03],
#        [-7.73195876e-06,  7.73195876e-06],
#        [ 1.43296695e-03, -1.43296695e-03],
#        [-7.04694997e-04,  7.04694997e-04]])}], ['RandomForest', 0.9841549295774648, 0.9923076923076923, 0.9882144961697112, 0.9866977053541736, 0.3657560348510742, {'SHAP': array([[-0.00647897,  0.00647897],
#        [-0.00149809,  0.00149809],
#        [-0.0040257 ,  0.0040257 ],
#        [-0.00854724,  0.00854724],
#        [-0.00291994,  0.00291994],
#        [-0.00042552,  0.00042552],
#        [ 0.00178071, -0.00178071],
#        [-0.006286  ,  0.006286  ],
#        [-0.00055102,  0.00055102],
#        [-0.00031535,  0.00031535],
#        [-0.00146405,  0.00146405],
#        [-0.00161763,  0.00161763]])}], ['Logistic Regression', 0.7622211675367822, 0.9502958579881656, 0.8459309981564392, 0.8054539408047888, 0.020116806030273438, {'SHAP': array([[-3.83213595e-04,  3.83213595e-04],
#        [ 1.91500140e-04, -1.91500140e-04],
#        [-1.56898580e-03,  1.56898580e-03],
#        [-6.18793565e-04,  6.18793565e-04],
#        [-1.23413075e-04,  1.23413075e-04],
#        [ 8.68532144e-04, -8.68532144e-04],
#        [-5.43578540e-04,  5.43578540e-04],
#        [-1.83663135e-02,  1.83663135e-02],
#        [-1.31211647e-04,  1.31211647e-04],
#        [-6.87293285e-03,  6.87293285e-03],
#        [-7.76967352e-05,  7.76967352e-05],
#        [-9.54600858e-07,  9.54600858e-07]])}], ['Naive Bayes', 0.9118387909319899, 0.21420118343195266, 0.3469094393866794, 0.5467243099434652, 0.005053043365478516, {'SHAP': array([[-1.44217375e-03,  1.44217375e-03],
#        [ 1.02470761e-02, -1.02470761e-02],
#        [ 5.77889904e-06, -5.77889904e-06],
#        [-1.01284165e-03,  1.01284165e-03],
#        [-5.38948624e-03,  5.38948624e-03],
#        [ 2.02297635e-02, -2.02297635e-02],
#        [ 1.54877407e-02, -1.54877407e-02],
#        [-1.16595980e-03,  1.16595980e-03],
#        [-5.69187571e-04,  5.69187571e-04],
#        [-3.04468203e-04,  3.04468203e-04],
#        [-4.62013447e-04,  4.62013447e-04],
#        [ 5.82623707e-04, -5.82623707e-04]])}], ['MLP', 0.8914127423822714, 0.9520710059171598, 0.9207439198855507, 0.9078816095776522, 12.862939357757568, {'SHAP': array([[-5.22021471e-03,  5.22021471e-03],
#        [ 7.88093332e-03, -7.88093332e-03],
#        [-3.19070279e-03,  3.19070279e-03],
#        [-3.25782082e-03,  3.25782082e-03],
#        [-2.53492107e-03,  2.53492107e-03],
#        [-5.38063906e-03,  5.38063906e-03],
#        [ 9.72014743e-03, -9.72014743e-03],
#        [-2.01472130e-02,  2.01472130e-02],
#        [ 5.64436413e-03, -5.64436413e-03],
#        [ 1.22477947e-03, -1.22477947e-03],
#        [-3.53925104e-03,  3.53925104e-03],
#        [ 1.67660119e-05, -1.67660119e-05]])}], ['Stochastic Gradient Descent', 0.8784624081401922, 0.919526627218935, 0.8985255854293149, 0.8832723644828733, 0.013398170471191406, {'SHAP': array([[-4.35567572e-04,  4.35567572e-04],
#        [ 2.35275352e-04, -2.35275352e-04],
#        [-2.02882701e-03,  2.02882701e-03],
#        [-6.82048469e-04,  6.82048469e-04],
#        [-1.53600204e-04,  1.53600204e-04],
#        [ 7.49090864e-04, -7.49090864e-04],
#        [-7.53956548e-04,  7.53956548e-04],
#        [-2.00108860e-02,  2.00108860e-02],
#        [-7.72081386e-04,  7.72081386e-04],
#        [-6.00514453e-03,  6.00514453e-03],
#        [-1.07308291e-04,  1.07308291e-04],
#        [-1.84426773e-06,  1.84426773e-06]])}], ['ADA Boost', 0.9734513274336283, 0.9763313609467456, 0.9748892171344165, 0.9717326238776189, 0.6049232482910156, {'SHAP': array([[-2.94411598e-04,  2.94411598e-04],
#        [ 4.43534072e-04, -4.43534072e-04],
#        [ 1.09770986e-04, -1.09770986e-04],
#        [-6.11644297e-04,  6.11644297e-04],
#        [-4.82360953e-04,  4.82360953e-04],
#        [-7.07259954e-05,  7.07259954e-05],
#        [ 9.35764666e-05, -9.35764666e-05],
#        [-5.19875035e-04,  5.19875035e-04],
#        [ 3.32932389e-04, -3.32932389e-04],
#        [ 0.00000000e+00,  0.00000000e+00],
#        [-2.81303527e-04,  2.81303527e-04],
#        [ 2.06593436e-05, -2.06593436e-05]])}], ['Gradient Boosting', 0.9776207302709069, 0.9822485207100592, 0.9799291617473436, 0.9773860991020951, 3.1224231719970703, {'SHAP': array([[-0.00027796,  0.00027796],
#        [ 0.0027335 , -0.0027335 ],
#        [-0.00397244,  0.00397244],
#        [-0.01063641,  0.01063641],
#        [-0.00214989,  0.00214989],
#        [-0.00089117,  0.00089117],
#        [ 0.00246423, -0.00246423],
#        [-0.00942204,  0.00942204],
#        [-0.00038419,  0.00038419],
#        [-0.00031316,  0.00031316],
#        [-0.00033054,  0.00033054],
#        [-0.00103866,  0.00103866]])}], ['XGBoost', 0.9818075117370892, 0.9899408284023669, 0.9858573954036536, 0.9840372464250083, 115.9801025390625, {'SHAP': array([[-0.00482773,  0.00482773],
#        [-0.00029652,  0.00029652],
#        [-0.00580441,  0.00580441],
#        [-0.01566842,  0.01566842],
#        [-0.00382885,  0.00382885],
#        [ 0.        ,  0.        ],
#        [ 0.00161046, -0.00161046],
#        [-0.00681767,  0.00681767],
#        [ 0.0009367 , -0.0009367 ],
#        [ 0.        ,  0.        ],
#        [ 0.00089596, -0.00089596],
#        [-0.0004466 ,  0.0004466 ]])}], ['LightGBM', 0.982373678025852, 0.9893491124260355, 0.9858490566037736, 0.9840372464250083, 18.44178533554077, {'SHAP': array([[-2.01988066e-03,  2.01988066e-03],
#        [ 8.09578744e-04, -8.09578744e-04],
#        [-4.71653862e-03,  4.71653862e-03],
#        [-1.47493067e-02,  1.47493067e-02],
#        [-6.65421689e-03,  6.65421689e-03],
#        [-4.31514388e-05,  4.31514388e-05],
#        [ 1.68528022e-03, -1.68528022e-03],
#        [-3.24398510e-03,  3.24398510e-03],
#        [-3.57113833e-03,  3.57113833e-03],
#        [-3.80127067e-05,  3.80127067e-05],
#        [ 6.82229234e-05, -6.82229234e-05],
#        [-6.25474128e-04,  6.25474128e-04]])}], ['CatBoost', 0.9741480611045829, 0.9810650887573964, 0.9775943396226414, 0.9747256401729298, 0.36103057861328125, {'SHAP': array([[-9.23930629e-04,  9.23930629e-04],
#        [ 5.38467283e-03, -5.38467283e-03],
#        [-3.14741706e-03,  3.14741706e-03],
#        [-6.15247197e-03,  6.15247197e-03],
#        [-1.19869776e-03,  1.19869776e-03],
#        [-3.35123852e-05,  3.35123852e-05],
#        [ 2.84318372e-03, -2.84318372e-03],
#        [-1.46213997e-02,  1.46213997e-02],
#        [ 1.42614183e-03, -1.42614183e-03],
#        [ 8.67864619e-05, -8.67864619e-05],
#        [-1.56981702e-04,  1.56981702e-04],
#        [-9.22899677e-04,  9.22899677e-04]])}], ['DNN', 0.87651598676957, 0.9408284023668639, 0.9075342465753424, 0.8922514133688061, 1.667919635772705, {'SHAP': array([0.02770755])}], ['CNN', 0.8766157461809636, 0.8828402366863906, 0.8797169811320755, 0.8643165946125707, 6.287029027938843, {'SHAP': None}], ['RNN', 0.9475308641975309, 0.3633136094674556, 0.525235243798118, 0.6308613235783173, 8.562753200531006, {'SHAP': None}]]
