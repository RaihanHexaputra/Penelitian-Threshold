# %%
# Library untuk pengolahan data dan visualisasi
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import joblib
import threading

# Library untuk evaluasi dan model machine learning
from sklearn.metrics import confusion_matrix, classification_report
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
import sklearn.ensemble as ek
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# Library untuk Explainable AI (XAI)
from lime.lime_tabular import LimeTabularExplainer
import shap

# Library untuk Deep Learning
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, LSTM, Dropout
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %%
# Input Dataset 

DM = pd.read_csv("C:\\Data Raihan\\Penelitian Threshold\\Dataset\\CIC-PDFMal2022\\PDFMalware2022.csv") #DM--> Dataset Malware

# %%
DM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10026 entries, 0 to 10025
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fine name         10026 non-null  object
#  1   pdfsize           10025 non-null  float64
#  2   metadata size     10025 non-null  float64
#  3   pages             10025 non-null  float64
#  4   xref Length       10025 non-null  float64
#  5   title characters  10025 non-null  float64
#  6   isEncrypted       10025 non-null  float64
#  7   embedded files    10025 non-null  float64
#  8   images            10025 non-null  object
#  9   text              10025 non-null  object
#  10  header            10025 non-null  object
#  11  obj               10023 non-null  object
#  12  endobj            10023 non-null  object
#  13  stream            10023 non-null  float64
#  14  endstream         10023 non-null  object
#  15  xref              10023 non-null  object
#  16  trailer           10023 non-null  float64
#  17  startxref         10023 non-null  object
#  18  pageno            10023 non-null  object
#  19  encrypt           10023 non-null  float64
#  20  ObjStm            10023 non-null  float64
#  21  JS                10023 non-null  object
#  22  Javascript        10023 non-null  object
#  23  AA                10023 non-null  object
#  24  OpenAction        10023 non-null  object
#  25  Acroform          10023 non-null  object
#  26  JBIG2Decode       10023 non-null  object
#  27  RichMedia         10023 non-null  object
#  28  launch            10023 non-null  object
#  29  EmbeddedFile      10023 non-null  object
#  30  XFA               10023 non-null  object
#  31  Colors            10023 non-null  float64
#  32  Class             10025 non-null  object
# dtypes: float64(12), object(21)
# memory usage: 2.5+ MB

# %%
#Feature Selection
features_to_drop = ['Fine name', 'images', 'text', 'header', 'obj', 'endobj', 'endstream', 
                    'xref', 'startxref', 'pageno', 'JS', 'Javascript', 'AA', 'OpenAction', 
                    'Acroform', 'JBIG2Decode', 'RichMedia', 'launch', 'EmbeddedFile', 'XFA', 'Class']

# Droping specified columns and target variable
X = DM.drop(features_to_drop, axis=1).values    
y = DM['Class'].values

# %%
#Remove Nan
X = pd.DataFrame(X).dropna()
y = y[X.index]

# %%
# Apply Min-Max scaling to make X non-negative
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Encoding y dengan LabelEncoder
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Elastic Net - Embedded
elastic_net = ElasticNet(alpha=0.01, l1_ratio=0.05)
elastic_net.fit(X_scaled, y_encoded)
# Out:
# ElasticNet(alpha=0.01, l1_ratio=0.05)

# %%
# Mendapatkan support dari Elastic Net (fitur yang koefisiennya tidak 0)
elastic_net_support = np.where(elastic_net.coef_ != 0)[0]

# Mengambil nama kolom dari X yang sudah difilter
filtered_columns = DM.drop(features_to_drop, axis=1).columns

features = []
for idx in elastic_net_support:
    print(f"Feature {filtered_columns[idx]} dengan koefisien Elastic Net {elastic_net.coef_[idx]}")
    features.append(filtered_columns[idx])
# Out:
# Feature pages dengan koefisien Elastic Net -0.06755604724387979
# Feature xref Length dengan koefisien Elastic Net 0.25503865722299784
# Feature isEncrypted dengan koefisien Elastic Net -0.18987981007825527
# Feature stream dengan koefisien Elastic Net -0.6913376596403144
# Feature trailer dengan koefisien Elastic Net -0.22426127753455224
# Feature encrypt dengan koefisien Elastic Net -0.36673584400075954
# Feature ObjStm dengan koefisien Elastic Net -0.05176707708350864

# %%
# Memilih 100% data secara acak dari setiap fitur/column
sampled_data = DM.groupby('Class').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)
# Out:
# C:\Users\Muhammad Raihan\AppData\Local\Temp\ipykernel_6336\1069642451.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_data = DM.groupby('Class').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)

# %%
# Pisahkan data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
# Inisialisasi variabel untuk menyimpan hasil evaluasi
hasil_ml_dl = []
hasil_ml_dl_xai = []

# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Fungsi untuk mengevaluasi model ML/DL
def EvaluateModel(model_name, model, X_train, y_train, X_test, y_test, use_xai=False, is_dl_model=False):
    start_time = time.time()

    # Melatih model
    model.fit(X_train, y_train, epochs=5, batch_size=32, verbose=0) if is_dl_model else model.fit(X_train, y_train)
    
    if is_dl_model:
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    elif hasattr(model, 'predict_proba'):
        # Model dengan metode predict_proba
        y_pred_proba = model.predict_proba(X_test)
        if y_pred_proba.shape[1] > 1:  # Model klasifikasi multi-kelas
            y_pred = np.argmax(y_pred_proba, axis=1)
        else:  # Model klasifikasi biner
            y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    else:
        # Model tanpa metode predict_proba
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()

    # Menghitung confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

    # Menghitung metrik
    Precision = tp / (tp + fp) if (tp + fp) != 0 else 0
    Recall = tp / (tp + fn) if (tp + fn) != 0 else 0
    F1Score = 2 * ((Precision * Recall) / (Precision + Recall)) if (Precision + Recall) != 0 else 0
    Accuracy = (tp + tn) / (tp + fp + tn + fn) if (tp + fp + tn + fn) != 0 else 0

    # Menghitung waktu running
    run_time = time.time() - start_time

    # Jika XAI diperlukan, tambahkan analisis dengan SHAP
    if use_xai:
        # Periksa apakah X_train adalah DataFrame
        if isinstance(X_train, pd.DataFrame):
            feature_names = X_train.columns
        else:
            feature_names = [f"Feature_{i}" for i in range(X_train.shape[1])]
        
        # Perbaiki format X_train untuk SHAP
        if is_dl_model:
            X_train_for_xai = X_train.reshape((X_train.shape[0], X_train.shape[1]))
            X_test_for_xai = X_test.reshape((X_test.shape[0], X_test.shape[1]))
        else:
            X_train_for_xai = X_train
            X_test_for_xai = X_test

        # Gunakan SHAP
        try:
            if is_dl_model:
                explainer = shap.DeepExplainer(model, X_train_for_xai)
                shap_values = explainer.shap_values(X_test_for_xai)
                shap_summary = np.mean(shap_values[0], axis=0)
            else:
                explainer = shap.Explainer(model.predict_proba, X_train_for_xai)
                shap_values = explainer(X_test_for_xai)
                shap_summary = shap_values.values.mean(axis=0)
        except Exception as e:
            print(f"Error using SHAP with {model_name}: {e}")
            shap_summary = None

        # Simpan hasil evaluasi dengan XAI
        hasil_ml_dl_xai.append([model_name, Precision, Recall, F1Score, Accuracy, run_time, {'SHAP': shap_summary}])
    else:
        # Simpan hasil evaluasi tanpa XAI
        hasil_ml_dl.append([model_name, Precision, Recall, F1Score, Accuracy, run_time])

# Model ML dan DL yang akan dievaluasi
model_ml_dl = {
    "DecisionTree": DecisionTreeClassifier(max_depth=10),
    "RandomForest": RandomForestClassifier(n_estimators=50),
    "Logistic Regression": LogisticRegression(random_state=0, max_iter=10000),
    "Naive Bayes": GaussianNB(),
    "MLP": MLPClassifier(solver='adam', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1, max_iter=1000),
    "Stochastic Gradient Descent": SGDClassifier(loss='log_loss', random_state=42),
    "ADA Boost": AdaBoostClassifier(n_estimators=100),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "XGBoost": XGBClassifier(n_estimators=100),
    "LightGBM": LGBMClassifier(n_estimators=100),
    "CatBoost": CatBoostClassifier(iterations=100, depth=6, learning_rate=0.1, loss_function='Logloss')
}

model_dl = {
    "DNN": Sequential([
        Dense(128, input_shape=(X_train.shape[1],), activation='relu'),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "CNN": Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "RNN": Sequential([
        LSTM(100, input_shape=(X_train.shape[1], 1)),
        Dense(1, activation='sigmoid')
    ]),
}

# Pastikan X_train dan X_test memiliki bentuk yang sesuai untuk DL
X_train_dl = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_dl = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Mengevaluasi model ML tanpa XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=False)

# Mengevaluasi model DL tanpa XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=False, is_dl_model=True)

# Mengevaluasi model ML dengan XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=True)

# Mengevaluasi model DL dengan XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=True, is_dl_model=True)

# Print hasil evaluasi tanpa XAI
print("\nHasil Evaluasi ML/DL tanpa XAI:")
print(hasil_ml_dl)

# Print hasil evaluasi dengan XAI
print("\nHasil Evaluasi ML/DL dengan XAI:")
print(hasil_ml_dl_xai)

# Convert results to DataFrame and save to CSV
df_ml_dl = pd.DataFrame(hasil_ml_dl, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime"])
df_ml_dl_xai = pd.DataFrame(hasil_ml_dl_xai, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime", "XAI"])

df_ml_dl.to_csv("hasil_evaluasi_ml_dl_ENFC.csv", index=False)
df_ml_dl_xai.to_csv("hasil_evaluasi_ml_dl_xai_ENFC.csv", index=False)
# Out:
# [LightGBM] [Info] Number of positive: 3865, number of negative: 3151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000324 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1186
# [LightGBM] [Info] Number of data points in the train set: 7016, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.550884 -> initscore=0.204242
# [LightGBM] [Info] Start training from score 0.204242
# 0:	learn: 0.6233952	total: 144ms	remaining: 14.3s
# 1:	learn: 0.5667828	total: 147ms	remaining: 7.19s
# 2:	learn: 0.5158579	total: 148ms	remaining: 4.8s
# 3:	learn: 0.4701687	total: 151ms	remaining: 3.61s
# 4:	learn: 0.4331439	total: 153ms	remaining: 2.9s
# 5:	learn: 0.4001143	total: 155ms	remaining: 2.42s
# 6:	learn: 0.3720034	total: 158ms	remaining: 2.09s
# 7:	learn: 0.3466359	total: 161ms	remaining: 1.85s
# 8:	learn: 0.3234386	total: 166ms	remaining: 1.67s
# 9:	learn: 0.3037145	total: 169ms	remaining: 1.52s
# 10:	learn: 0.2849609	total: 171ms	remaining: 1.38s
# 11:	learn: 0.2686569	total: 173ms	remaining: 1.27s
# 12:	learn: 0.2537131	total: 175ms	remaining: 1.17s
# 13:	learn: 0.2402928	total: 177ms	remaining: 1.09s
# 14:	learn: 0.2283432	total: 179ms	remaining: 1.02s
# 15:	learn: 0.2181887	total: 182ms	remaining: 954ms
# 16:	learn: 0.2071913	total: 186ms	remaining: 908ms
# 17:	learn: 0.1986340	total: 189ms	remaining: 862ms
# 18:	learn: 0.1898069	total: 192ms	remaining: 820ms
# 19:	learn: 0.1823055	total: 195ms	remaining: 781ms
# 20:	learn: 0.1753956	total: 198ms	remaining: 745ms
# 21:	learn: 0.1696179	total: 201ms	remaining: 714ms
# 22:	learn: 0.1640047	total: 205ms	remaining: 685ms
# 23:	learn: 0.1589595	total: 208ms	remaining: 658ms
# 24:	learn: 0.1542838	total: 211ms	remaining: 632ms
# 25:	learn: 0.1500265	total: 214ms	remaining: 608ms
# 26:	learn: 0.1453649	total: 217ms	remaining: 587ms
# 27:	learn: 0.1416183	total: 220ms	remaining: 565ms
# 28:	learn: 0.1381484	total: 223ms	remaining: 546ms
# 29:	learn: 0.1346485	total: 231ms	remaining: 539ms
# 30:	learn: 0.1315079	total: 235ms	remaining: 522ms
# 31:	learn: 0.1290297	total: 240ms	remaining: 509ms
# 32:	learn: 0.1256832	total: 243ms	remaining: 493ms
# 33:	learn: 0.1234395	total: 246ms	remaining: 477ms
# 34:	learn: 0.1209019	total: 249ms	remaining: 462ms
# 35:	learn: 0.1187198	total: 251ms	remaining: 447ms
# 36:	learn: 0.1163355	total: 255ms	remaining: 434ms
# 37:	learn: 0.1140794	total: 260ms	remaining: 424ms
# 38:	learn: 0.1117700	total: 263ms	remaining: 411ms
# 39:	learn: 0.1095045	total: 266ms	remaining: 399ms
# 40:	learn: 0.1082528	total: 269ms	remaining: 387ms
# 41:	learn: 0.1069304	total: 271ms	remaining: 374ms
# 42:	learn: 0.1049211	total: 273ms	remaining: 362ms
# 43:	learn: 0.1035891	total: 276ms	remaining: 351ms
# 44:	learn: 0.1023829	total: 278ms	remaining: 340ms
# 45:	learn: 0.1014690	total: 281ms	remaining: 330ms
# 46:	learn: 0.1003434	total: 283ms	remaining: 319ms
# 47:	learn: 0.0996869	total: 285ms	remaining: 309ms
# 48:	learn: 0.0983416	total: 287ms	remaining: 299ms
# 49:	learn: 0.0962412	total: 290ms	remaining: 290ms
# 50:	learn: 0.0956501	total: 292ms	remaining: 281ms
# 51:	learn: 0.0946828	total: 294ms	remaining: 272ms
# 52:	learn: 0.0938801	total: 296ms	remaining: 263ms
# 53:	learn: 0.0928902	total: 298ms	remaining: 254ms
# 54:	learn: 0.0922551	total: 301ms	remaining: 246ms
# 55:	learn: 0.0913147	total: 303ms	remaining: 238ms
# 56:	learn: 0.0907956	total: 306ms	remaining: 231ms
# 57:	learn: 0.0897417	total: 308ms	remaining: 223ms
# 58:	learn: 0.0889070	total: 310ms	remaining: 215ms
# 59:	learn: 0.0883280	total: 312ms	remaining: 208ms
# 60:	learn: 0.0877093	total: 314ms	remaining: 201ms
# 61:	learn: 0.0870466	total: 316ms	remaining: 194ms
# 62:	learn: 0.0864922	total: 318ms	remaining: 187ms
# 63:	learn: 0.0858708	total: 320ms	remaining: 180ms
# 64:	learn: 0.0855633	total: 322ms	remaining: 173ms
# 65:	learn: 0.0846223	total: 324ms	remaining: 167ms
# 66:	learn: 0.0840513	total: 326ms	remaining: 161ms
# 67:	learn: 0.0836903	total: 328ms	remaining: 155ms
# 68:	learn: 0.0832687	total: 330ms	remaining: 148ms
# 69:	learn: 0.0825421	total: 333ms	remaining: 143ms
# 70:	learn: 0.0817523	total: 336ms	remaining: 137ms
# 71:	learn: 0.0808942	total: 339ms	remaining: 132ms
# 72:	learn: 0.0807383	total: 341ms	remaining: 126ms
# 73:	learn: 0.0800861	total: 345ms	remaining: 121ms
# 74:	learn: 0.0794294	total: 347ms	remaining: 116ms
# 75:	learn: 0.0788878	total: 349ms	remaining: 110ms
# 76:	learn: 0.0783219	total: 353ms	remaining: 105ms
# 77:	learn: 0.0779695	total: 355ms	remaining: 100ms
# 78:	learn: 0.0778128	total: 358ms	remaining: 95ms
# 79:	learn: 0.0772942	total: 360ms	remaining: 89.9ms
# 80:	learn: 0.0767109	total: 362ms	remaining: 84.8ms
# 81:	learn: 0.0765114	total: 364ms	remaining: 79.8ms
# 82:	learn: 0.0761029	total: 366ms	remaining: 74.9ms
# 83:	learn: 0.0756197	total: 368ms	remaining: 70.1ms
# 84:	learn: 0.0754426	total: 370ms	remaining: 65.3ms
# 85:	learn: 0.0752159	total: 372ms	remaining: 60.6ms
# 86:	learn: 0.0744049	total: 375ms	remaining: 56ms
# 87:	learn: 0.0739720	total: 377ms	remaining: 51.4ms
# 88:	learn: 0.0736518	total: 379ms	remaining: 46.9ms
# 89:	learn: 0.0734552	total: 381ms	remaining: 42.4ms
# 90:	learn: 0.0733091	total: 383ms	remaining: 37.9ms
# 91:	learn: 0.0728457	total: 386ms	remaining: 33.5ms
# 92:	learn: 0.0728055	total: 388ms	remaining: 29.2ms
# 93:	learn: 0.0725272	total: 390ms	remaining: 24.9ms
# 94:	learn: 0.0724081	total: 392ms	remaining: 20.6ms
# 95:	learn: 0.0723201	total: 394ms	remaining: 16.4ms
# 96:	learn: 0.0723011	total: 396ms	remaining: 12.3ms
# 97:	learn: 0.0721581	total: 399ms	remaining: 8.13ms
# 98:	learn: 0.0721017	total: 401ms	remaining: 4.05ms
# 99:	learn: 0.0720559	total: 403ms	remaining: 0us
# 94/94 [==============================] - 0s 702us/step
# 94/94 [==============================] - 0s 848us/step
# 94/94 [==============================] - 1s 2ms/step
# PermutationExplainer explainer: 3008it [00:37, 69.55it/s]
# PermutationExplainer explainer: 3008it [09:21,  5.26it/s]
# PermutationExplainer explainer: 3008it [00:36, 60.95it/s]
# PermutationExplainer explainer: 3008it [00:44, 52.90it/s]
# PermutationExplainer explainer: 3008it [00:34, 61.91it/s]
# PermutationExplainer explainer: 3008it [00:35, 60.57it/s]
# PermutationExplainer explainer: 3008it [1:03:52,  1.28s/it]
# PermutationExplainer explainer: 3008it [08:50,  5.56it/s]
# PermutationExplainer explainer: 3008it [56:17,  1.12s/it]
# [LightGBM] [Info] Number of positive: 3865, number of negative: 3151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003849 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1186
# [LightGBM] [Info] Number of data points in the train set: 7016, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.550884 -> initscore=0.204242
# [LightGBM] [Info] Start training from score 0.204242
# PermutationExplainer explainer: 3008it [04:05, 11.73it/s]
# 0:	learn: 0.6233952	total: 2.07ms	remaining: 205ms
# 1:	learn: 0.5667828	total: 4.1ms	remaining: 201ms
# 2:	learn: 0.5158579	total: 5.95ms	remaining: 192ms
# 3:	learn: 0.4701687	total: 7.77ms	remaining: 186ms
# 4:	learn: 0.4331439	total: 9.63ms	remaining: 183ms
# 5:	learn: 0.4001143	total: 11.7ms	remaining: 183ms
# 6:	learn: 0.3720034	total: 13.5ms	remaining: 180ms
# 7:	learn: 0.3466359	total: 15.3ms	remaining: 175ms
# 8:	learn: 0.3234386	total: 17.1ms	remaining: 173ms
# 9:	learn: 0.3037145	total: 19.3ms	remaining: 174ms
# 10:	learn: 0.2849609	total: 21.2ms	remaining: 172ms
# 11:	learn: 0.2686569	total: 23.1ms	remaining: 170ms
# 12:	learn: 0.2537131	total: 25ms	remaining: 168ms
# 13:	learn: 0.2402928	total: 27.1ms	remaining: 167ms
# 14:	learn: 0.2283432	total: 29.1ms	remaining: 165ms
# 15:	learn: 0.2181887	total: 30.9ms	remaining: 162ms
# 16:	learn: 0.2071913	total: 32.8ms	remaining: 160ms
# 17:	learn: 0.1986340	total: 34.8ms	remaining: 159ms
# 18:	learn: 0.1898069	total: 36.9ms	remaining: 157ms
# 19:	learn: 0.1823055	total: 38.8ms	remaining: 155ms
# 20:	learn: 0.1753956	total: 40.7ms	remaining: 153ms
# 21:	learn: 0.1696179	total: 42.7ms	remaining: 152ms
# 22:	learn: 0.1640047	total: 44.7ms	remaining: 150ms
# 23:	learn: 0.1589595	total: 46.7ms	remaining: 148ms
# 24:	learn: 0.1542838	total: 48.8ms	remaining: 146ms
# 25:	learn: 0.1500265	total: 50.8ms	remaining: 145ms
# 26:	learn: 0.1453649	total: 52.7ms	remaining: 143ms
# 27:	learn: 0.1416183	total: 54.5ms	remaining: 140ms
# 28:	learn: 0.1381484	total: 56.3ms	remaining: 138ms
# 29:	learn: 0.1346485	total: 58.6ms	remaining: 137ms
# 30:	learn: 0.1315079	total: 60.8ms	remaining: 135ms
# 31:	learn: 0.1290297	total: 62.8ms	remaining: 134ms
# 32:	learn: 0.1256832	total: 64.6ms	remaining: 131ms
# 33:	learn: 0.1234395	total: 66.6ms	remaining: 129ms
# 34:	learn: 0.1209019	total: 68.8ms	remaining: 128ms
# 35:	learn: 0.1187198	total: 70.5ms	remaining: 125ms
# 36:	learn: 0.1163355	total: 72.3ms	remaining: 123ms
# 37:	learn: 0.1140794	total: 74.4ms	remaining: 121ms
# 38:	learn: 0.1117700	total: 76.2ms	remaining: 119ms
# 39:	learn: 0.1095045	total: 78.4ms	remaining: 118ms
# 40:	learn: 0.1082528	total: 80.3ms	remaining: 116ms
# 41:	learn: 0.1069304	total: 82.4ms	remaining: 114ms
# 42:	learn: 0.1049211	total: 84.4ms	remaining: 112ms
# 43:	learn: 0.1035891	total: 86.2ms	remaining: 110ms
# 44:	learn: 0.1023829	total: 88.2ms	remaining: 108ms
# 45:	learn: 0.1014690	total: 90ms	remaining: 106ms
# 46:	learn: 0.1003434	total: 91.8ms	remaining: 103ms
# 47:	learn: 0.0996869	total: 93.6ms	remaining: 101ms
# 48:	learn: 0.0983416	total: 95.5ms	remaining: 99.4ms
# 49:	learn: 0.0962412	total: 97.5ms	remaining: 97.5ms
# 50:	learn: 0.0956501	total: 99.2ms	remaining: 95.3ms
# 51:	learn: 0.0946828	total: 101ms	remaining: 93.4ms
# 52:	learn: 0.0938801	total: 103ms	remaining: 91.5ms
# 53:	learn: 0.0928902	total: 105ms	remaining: 89.5ms
# 54:	learn: 0.0922551	total: 107ms	remaining: 87.5ms
# 55:	learn: 0.0913147	total: 109ms	remaining: 85.6ms
# 56:	learn: 0.0907956	total: 111ms	remaining: 83.7ms
# 57:	learn: 0.0897417	total: 113ms	remaining: 81.7ms
# 58:	learn: 0.0889070	total: 115ms	remaining: 79.7ms
# 59:	learn: 0.0883280	total: 117ms	remaining: 78ms
# 60:	learn: 0.0877093	total: 119ms	remaining: 76.1ms
# 61:	learn: 0.0870466	total: 121ms	remaining: 74ms
# 62:	learn: 0.0864922	total: 123ms	remaining: 72.3ms
# 63:	learn: 0.0858708	total: 125ms	remaining: 70.3ms
# 64:	learn: 0.0855633	total: 127ms	remaining: 68.5ms
# 65:	learn: 0.0846223	total: 129ms	remaining: 66.7ms
# 66:	learn: 0.0840513	total: 131ms	remaining: 64.7ms
# 67:	learn: 0.0836903	total: 133ms	remaining: 62.7ms
# 68:	learn: 0.0832687	total: 135ms	remaining: 60.9ms
# 69:	learn: 0.0825421	total: 137ms	remaining: 58.9ms
# 70:	learn: 0.0817523	total: 139ms	remaining: 56.9ms
# 71:	learn: 0.0808942	total: 142ms	remaining: 55.1ms
# 72:	learn: 0.0807383	total: 144ms	remaining: 53.1ms
# 73:	learn: 0.0800861	total: 146ms	remaining: 51.2ms
# 74:	learn: 0.0794294	total: 148ms	remaining: 49.3ms
# 75:	learn: 0.0788878	total: 150ms	remaining: 47.3ms
# 76:	learn: 0.0783219	total: 152ms	remaining: 45.3ms
# 77:	learn: 0.0779695	total: 154ms	remaining: 43.3ms
# 78:	learn: 0.0778128	total: 156ms	remaining: 41.4ms
# 79:	learn: 0.0772942	total: 157ms	remaining: 39.3ms
# 80:	learn: 0.0767109	total: 159ms	remaining: 37.3ms
# 81:	learn: 0.0765114	total: 161ms	remaining: 35.4ms
# 82:	learn: 0.0761029	total: 163ms	remaining: 33.4ms
# 83:	learn: 0.0756197	total: 165ms	remaining: 31.4ms
# 84:	learn: 0.0754426	total: 167ms	remaining: 29.4ms
# 85:	learn: 0.0752159	total: 169ms	remaining: 27.5ms
# 86:	learn: 0.0744049	total: 171ms	remaining: 25.5ms
# 87:	learn: 0.0739720	total: 172ms	remaining: 23.5ms
# 88:	learn: 0.0736518	total: 175ms	remaining: 21.6ms
# 89:	learn: 0.0734552	total: 176ms	remaining: 19.6ms
# 90:	learn: 0.0733091	total: 178ms	remaining: 17.6ms
# 91:	learn: 0.0728457	total: 180ms	remaining: 15.7ms
# 92:	learn: 0.0728055	total: 182ms	remaining: 13.7ms
# 93:	learn: 0.0725272	total: 184ms	remaining: 11.8ms
# 94:	learn: 0.0724081	total: 188ms	remaining: 9.87ms
# 95:	learn: 0.0723201	total: 190ms	remaining: 7.91ms
# 96:	learn: 0.0723011	total: 192ms	remaining: 5.93ms
# 97:	learn: 0.0721581	total: 194ms	remaining: 3.95ms
# 98:	learn: 0.0721017	total: 195ms	remaining: 1.97ms
# 99:	learn: 0.0720559	total: 197ms	remaining: 0us
# PermutationExplainer explainer: 3008it [07:11,  6.79it/s]
# 94/94 [==============================] - 0s 3ms/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# 94/94 [==============================] - 0s 693us/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Error using SHAP with CNN: operands could not be broadcast together with shapes (7016,12,1) (7016,12)
# 94/94 [==============================] - 1s 2ms/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# Error using SHAP with RNN: in user code:
#
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 244, in grad_graph  *
#         out = self.model(shap_rAnD)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler  **
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 371, in custom_grad
#         out = op_handlers[type_name](self, op, *grads) # we cut off the shap_ prefix before the lookup
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 663, in handler
#         return linearity_with_excluded_handler(input_inds, explainer, op, *grads)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 670, in linearity_with_excluded_handler
#         assert not explainer._variable_inputs(op)[i], str(i) + "th input to " + op.name + " cannot vary!"
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 222, in _variable_inputs
#         out[i] = t.name in self.between_tensors
#
#     AttributeError: Exception encountered when calling layer 'lstm' (type LSTM).
#
#     'TFDeep' object has no attribute 'between_tensors'
#
#     Call arguments received by layer 'lstm' (type LSTM):
#       • inputs=tf.Tensor(shape=(14032, 12, 1), dtype=float32)
#       • mask=None
#       • training=False
#       • initial_state=None
#
#
# Hasil Evaluasi ML/DL tanpa XAI:
# [['DecisionTree', 0.9739490822972173, 0.9733727810650887, 0.9736608464042615, 0.9704023944130362, 0.023705005645751953], ['RandomForest', 0.9800936768149883, 0.9905325443786982, 0.985285462036492, 0.983372131692717, 0.3688185214996338], ['Logistic Regression', 0.7622211675367822, 0.9502958579881656, 0.8459309981564392, 0.8054539408047888, 0.023932218551635742], ['Naive Bayes', 0.9118387909319899, 0.21420118343195266, 0.3469094393866794, 0.5467243099434652, 0.0050008296966552734], ['MLP', 0.8914127423822714, 0.9520710059171598, 0.9207439198855507, 0.9078816095776522, 13.329168796539307], ['Stochastic Gradient Descent', 0.8784624081401922, 0.919526627218935, 0.8985255854293149, 0.8832723644828733, 0.015756845474243164], ['ADA Boost', 0.9734513274336283, 0.9763313609467456, 0.9748892171344165, 0.9717326238776189, 0.6455717086791992], ['Gradient Boosting', 0.9776207302709069, 0.9822485207100592, 0.9799291617473436, 0.9773860991020951, 0.8797163963317871], ['XGBoost', 0.9818075117370892, 0.9899408284023669, 0.9858573954036536, 0.9840372464250083, 1.5943517684936523], ['LightGBM', 0.982373678025852, 0.9893491124260355, 0.9858490566037736, 0.9840372464250083, 0.2681093215942383], ['CatBoost', 0.9741480611045829, 0.9810650887573964, 0.9775943396226414, 0.9747256401729298, 0.514101505279541], ['DNN', 0.8781302170283807, 0.9337278106508876, 0.9050759965586465, 0.8899235118057865, 1.9202759265899658], ['CNN', 0.8768971332209107, 0.9230769230769231, 0.8993946382242722, 0.8839374792151646, 2.1751039028167725], ['RNN', 0.6557114228456914, 0.9680473372781065, 0.7818399044205495, 0.6963751247090123, 8.704907894134521]]
#
# Hasil Evaluasi ML/DL dengan XAI:
# [['DecisionTree', 0.9733727810650887, 0.9733727810650887, 0.9733727810650887, 0.9700698370468905, 0.021486759185791016, {'SHAP': array([[-0.00467403,  0.00467403],
#        [-0.00498369,  0.00498369],
#        [-0.00439711,  0.00439711],
#        [-0.0097515 ,  0.0097515 ],
#        [-0.0016659 ,  0.0016659 ],
#        [ 0.        ,  0.        ],
#        [ 0.00528598, -0.00528598],
#        [-0.01238467,  0.01238467],
#        [ 0.00495515, -0.00495515],
#        [-0.00214907,  0.00214907],
#        [ 0.0014108 , -0.0014108 ],
#        [-0.00061619,  0.00061619]])}], ['RandomForest', 0.9812206572769953, 0.9893491124260355, 0.985268120212139, 0.983372131692717, 0.3664727210998535, {'SHAP': array([[-6.11901064e-03,  6.11901064e-03],
#        [-1.37906884e-03,  1.37906884e-03],
#        [-3.49514300e-03,  3.49514300e-03],
#        [-7.91190223e-03,  7.91190223e-03],
#        [-3.62705687e-03,  3.62705687e-03],
#        [-7.32401064e-04,  7.32401064e-04],
#        [ 1.97937313e-03, -1.97937313e-03],
#        [-6.19865314e-03,  6.19865314e-03],
#        [ 1.69936814e-05, -1.69936814e-05],
#        [-2.86558031e-04,  2.86558031e-04],
#        [-9.40650150e-04,  9.40650150e-04],
#        [-1.86894247e-03,  1.86894247e-03]])}], ['Logistic Regression', 0.7622211675367822, 0.9502958579881656, 0.8459309981564392, 0.8054539408047888, 0.023129701614379883, {'SHAP': array([[-3.83447814e-04,  3.83447814e-04],
#        [ 1.92167704e-04, -1.92167704e-04],
#        [-1.56974751e-03,  1.56974751e-03],
#        [-6.21750335e-04,  6.21750335e-04],
#        [-1.23810548e-04,  1.23810548e-04],
#        [ 8.74484629e-04, -8.74484629e-04],
#        [-5.41762741e-04,  5.41762741e-04],
#        [-1.83689184e-02,  1.83689184e-02],
#        [-1.25135797e-04,  1.25135797e-04],
#        [-6.87957488e-03,  6.87957488e-03],
#        [-7.86244849e-05,  7.86244849e-05],
#        [-9.41433678e-07,  9.41433678e-07]])}], ['Naive Bayes', 0.9118387909319899, 0.21420118343195266, 0.3469094393866794, 0.5467243099434652, 0.005756855010986328, {'SHAP': array([[-1.40535636e-03,  1.40535636e-03],
#        [ 1.02571493e-02, -1.02571493e-02],
#        [ 9.16458852e-06, -9.16458852e-06],
#        [-1.03947507e-03,  1.03947507e-03],
#        [-5.42529972e-03,  5.42529972e-03],
#        [ 2.03947066e-02, -2.03947066e-02],
#        [ 1.53857878e-02, -1.53857878e-02],
#        [-1.08021679e-03,  1.08021679e-03],
#        [-6.51275982e-04,  6.51275982e-04],
#        [-3.11691022e-04,  3.11691022e-04],
#        [-5.25556651e-04,  5.25556651e-04],
#        [ 5.98915480e-04, -5.98915480e-04]])}], ['MLP', 0.8914127423822714, 0.9520710059171598, 0.9207439198855507, 0.9078816095776522, 12.666761875152588, {'SHAP': array([[-5.16107616e-03,  5.16107616e-03],
#        [ 8.04128672e-03, -8.04128672e-03],
#        [-3.23226463e-03,  3.23226463e-03],
#        [-3.23234816e-03,  3.23234816e-03],
#        [-2.54505899e-03,  2.54505899e-03],
#        [-5.45775102e-03,  5.45775102e-03],
#        [ 9.65142832e-03, -9.65142832e-03],
#        [-2.00147132e-02,  2.00147132e-02],
#        [ 5.43615760e-03, -5.43615760e-03],
#        [ 1.43103496e-03, -1.43103496e-03],
#        [-3.72685904e-03,  3.72685904e-03],
#        [ 2.63914670e-05, -2.63914670e-05]])}], ['Stochastic Gradient Descent', 0.8784624081401922, 0.919526627218935, 0.8985255854293149, 0.8832723644828733, 0.0156705379486084, {'SHAP': array([[-4.35612710e-04,  4.35612710e-04],
#        [ 2.35019660e-04, -2.35019660e-04],
#        [-2.03005365e-03,  2.03005365e-03],
#        [-6.81257905e-04,  6.81257905e-04],
#        [-1.52310035e-04,  1.52310035e-04],
#        [ 7.41552275e-04, -7.41552275e-04],
#        [-7.48410711e-04,  7.48410711e-04],
#        [-2.00031414e-02,  2.00031414e-02],
#        [-7.76270230e-04,  7.76270230e-04],
#        [-6.00649615e-03,  6.00649615e-03],
#        [-1.08064297e-04,  1.08064297e-04],
#        [-1.85291628e-06,  1.85291628e-06]])}], ['ADA Boost', 0.9734513274336283, 0.9763313609467456, 0.9748892171344165, 0.9717326238776189, 0.6418991088867188, {'SHAP': array([[-2.94400222e-04,  2.94400222e-04],
#        [ 4.43517684e-04, -4.43517684e-04],
#        [ 1.09779628e-04, -1.09779628e-04],
#        [-6.11640866e-04,  6.11640866e-04],
#        [-4.82364357e-04,  4.82364357e-04],
#        [-7.07268940e-05,  7.07268940e-05],
#        [ 9.35771530e-05, -9.35771530e-05],
#        [-5.19870555e-04,  5.19870555e-04],
#        [ 3.32924324e-04, -3.32924324e-04],
#        [ 0.00000000e+00,  0.00000000e+00],
#        [-2.81304878e-04,  2.81304878e-04],
#        [ 2.06608369e-05, -2.06608369e-05]])}], ['Gradient Boosting', 0.9776207302709069, 0.9822485207100592, 0.9799291617473436, 0.9773860991020951, 2.627213478088379, {'SHAP': array([[-0.00056144,  0.00056144],
#        [ 0.00298448, -0.00298448],
#        [-0.00415718,  0.00415718],
#        [-0.01059093,  0.01059093],
#        [-0.00213658,  0.00213658],
#        [-0.00092216,  0.00092216],
#        [ 0.00245191, -0.00245191],
#        [-0.00939846,  0.00939846],
#        [-0.00028231,  0.00028231],
#        [-0.00017122,  0.00017122],
#        [-0.0003244 ,  0.0003244 ],
#        [-0.00111565,  0.00111565]])}], ['XGBoost', 0.9818075117370892, 0.9899408284023669, 0.9858573954036536, 0.9840372464250083, 136.020751953125, {'SHAP': array([[-0.00475774,  0.00475774],
#        [-0.00030633,  0.00030633],
#        [-0.00568045,  0.00568045],
#        [-0.01560195,  0.01560195],
#        [-0.00375795,  0.00375795],
#        [ 0.        ,  0.        ],
#        [ 0.00162154, -0.00162154],
#        [-0.00693238,  0.00693238],
#        [ 0.00059682, -0.00059682],
#        [ 0.        ,  0.        ],
#        [ 0.00098955, -0.00098955],
#        [-0.00041818,  0.00041818]])}], ['LightGBM', 0.982373678025852, 0.9893491124260355, 0.9858490566037736, 0.9840372464250083, 12.029494762420654, {'SHAP': array([[-1.81547918e-03,  1.81547918e-03],
#        [ 3.77462044e-04, -3.77462044e-04],
#        [-4.44445529e-03,  4.44445529e-03],
#        [-1.47475057e-02,  1.47475057e-02],
#        [-6.44769025e-03,  6.44769025e-03],
#        [-3.61515806e-05,  3.61515806e-05],
#        [ 1.73662926e-03, -1.73662926e-03],
#        [-3.41157646e-03,  3.41157646e-03],
#        [-3.76159027e-03,  3.76159027e-03],
#        [-3.87917017e-05,  3.87917017e-05],
#        [ 1.52910933e-04, -1.52910933e-04],
#        [-6.62384567e-04,  6.62384567e-04]])}], ['CatBoost', 0.9741480611045829, 0.9810650887573964, 0.9775943396226414, 0.9747256401729298, 0.2936885356903076, {'SHAP': array([[-1.10361857e-03,  1.10361857e-03],
#        [ 5.35347040e-03, -5.35347040e-03],
#        [-3.06067217e-03,  3.06067217e-03],
#        [-6.06993021e-03,  6.06993021e-03],
#        [-1.16748661e-03,  1.16748661e-03],
#        [-3.37091715e-05,  3.37091715e-05],
#        [ 2.83723476e-03, -2.83723476e-03],
#        [-1.45391984e-02,  1.45391984e-02],
#        [ 1.37037081e-03, -1.37037081e-03],
#        [ 8.86045584e-05, -8.86045584e-05],
#        [-1.60839885e-04,  1.60839885e-04],
#        [-9.30751617e-04,  9.30751617e-04]])}], ['DNN', 0.8838150289017341, 0.9047337278106509, 0.8941520467836257, 0.879614233455271, 4.46881628036499, {'SHAP': array([0.02673868])}], ['CNN', 0.8640303358613218, 0.9437869822485208, 0.9021493212669683, 0.8849351513136016, 2.1250765323638916, {'SHAP': None}], ['RNN', 0.8596792668957618, 0.8881656804733727, 0.8736903376018627, 0.8556701030927835, 8.879886150360107, {'SHAP': None}]]
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
