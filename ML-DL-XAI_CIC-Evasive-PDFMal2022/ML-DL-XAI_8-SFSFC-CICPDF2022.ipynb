# %%
# Library untuk pengolahan data dan visualisasi
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import joblib
import threading

# Library untuk evaluasi dan model machine learning
from sklearn.metrics import confusion_matrix, classification_report
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVR
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
import sklearn.ensemble as ek
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# Library untuk Explainable AI (XAI)
from lime.lime_tabular import LimeTabularExplainer
import shap

# Library untuk Deep Learning
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, LSTM, Dropout
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %%
# Input Dataset 

DM = pd.read_csv("C:\\Data Raihan\\Penelitian Threshold\\Dataset\\CIC-PDFMal2022\\PDFMalware2022.csv") #DM--> Dataset Malware

# %%
DM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10026 entries, 0 to 10025
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fine name         10026 non-null  object
#  1   pdfsize           10025 non-null  float64
#  2   metadata size     10025 non-null  float64
#  3   pages             10025 non-null  float64
#  4   xref Length       10025 non-null  float64
#  5   title characters  10025 non-null  float64
#  6   isEncrypted       10025 non-null  float64
#  7   embedded files    10025 non-null  float64
#  8   images            10025 non-null  object
#  9   text              10025 non-null  object
#  10  header            10025 non-null  object
#  11  obj               10023 non-null  object
#  12  endobj            10023 non-null  object
#  13  stream            10023 non-null  float64
#  14  endstream         10023 non-null  object
#  15  xref              10023 non-null  object
#  16  trailer           10023 non-null  float64
#  17  startxref         10023 non-null  object
#  18  pageno            10023 non-null  object
#  19  encrypt           10023 non-null  float64
#  20  ObjStm            10023 non-null  float64
#  21  JS                10023 non-null  object
#  22  Javascript        10023 non-null  object
#  23  AA                10023 non-null  object
#  24  OpenAction        10023 non-null  object
#  25  Acroform          10023 non-null  object
#  26  JBIG2Decode       10023 non-null  object
#  27  RichMedia         10023 non-null  object
#  28  launch            10023 non-null  object
#  29  EmbeddedFile      10023 non-null  object
#  30  XFA               10023 non-null  object
#  31  Colors            10023 non-null  float64
#  32  Class             10025 non-null  object
# dtypes: float64(12), object(21)
# memory usage: 2.5+ MB

# %%
#Feature Selection
features_to_drop = ['Fine name', 'images', 'text', 'header', 'obj', 'endobj', 'endstream', 
                    'xref', 'startxref', 'pageno', 'JS', 'Javascript', 'AA', 'OpenAction', 
                    'Acroform', 'JBIG2Decode', 'RichMedia', 'launch', 'EmbeddedFile', 'XFA', 'Class']

# Droping specified columns and target variable
X = DM.drop(features_to_drop, axis=1).values    
y = DM['Class'].values

# %%
#Remove Nan
X = pd.DataFrame(X).dropna()
y = y[X.index]

# %%
# Applying Min-Max scaling to make X non-negative
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Encode the target variable (if still contains string values)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Sequential Feature Selector
sfs_selector = SequentialFeatureSelector(estimator=SVR(kernel="linear"), n_features_to_select=5)
X_sfs = sfs_selector.fit_transform(X_scaled, y_encoded)

# %%
# Get top features selected by SFS
sfs_top_features = np.where(sfs_selector.get_support())[0]

# Get names of selected features
filtered_columns = DM.drop(features_to_drop, axis=1).columns
features = filtered_columns[sfs_top_features]

print("Selected features using Sequential Feature Selector:")
for feature in features:
    print(feature)
# Out:
# Selected features using Sequential Feature Selector:
# isEncrypted
# stream
# trailer
# encrypt
# ObjStm

# %%
# Memilih 100% data secara acak dari setiap fitur/column
sampled_data = DM.groupby('Class').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)
hasil_threshold = []
# Out:
# C:\Users\Muhammad Raihan\AppData\Local\Temp\ipykernel_25812\3131084859.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_data = DM.groupby('Class').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)

# %%
# Pisahkan data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X_sfs, y, test_size=0.3, random_state=42)

# %%
# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
# Inisialisasi variabel untuk menyimpan hasil evaluasi
hasil_ml_dl = []
hasil_ml_dl_xai = []

# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Fungsi untuk mengevaluasi model ML/DL
def EvaluateModel(model_name, model, X_train, y_train, X_test, y_test, use_xai=False, is_dl_model=False):
    start_time = time.time()

    # Melatih model
    model.fit(X_train, y_train, epochs=5, batch_size=32, verbose=0) if is_dl_model else model.fit(X_train, y_train)
    
    if is_dl_model:
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    elif hasattr(model, 'predict_proba'):
        # Model dengan metode predict_proba
        y_pred_proba = model.predict_proba(X_test)
        if y_pred_proba.shape[1] > 1:  # Model klasifikasi multi-kelas
            y_pred = np.argmax(y_pred_proba, axis=1)
        else:  # Model klasifikasi biner
            y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    else:
        # Model tanpa metode predict_proba
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()

    # Menghitung confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

    # Menghitung metrik
    Precision = tp / (tp + fp) if (tp + fp) != 0 else 0
    Recall = tp / (tp + fn) if (tp + fn) != 0 else 0
    F1Score = 2 * ((Precision * Recall) / (Precision + Recall)) if (Precision + Recall) != 0 else 0
    Accuracy = (tp + tn) / (tp + fp + tn + fn) if (tp + fp + tn + fn) != 0 else 0

    # Menghitung waktu running
    run_time = time.time() - start_time

    # Jika XAI diperlukan, tambahkan analisis dengan SHAP
    if use_xai:
        # Periksa apakah X_train adalah DataFrame
        if isinstance(X_train, pd.DataFrame):
            feature_names = X_train.columns
        else:
            feature_names = [f"Feature_{i}" for i in range(X_train.shape[1])]
        
        # Perbaiki format X_train untuk SHAP
        if is_dl_model:
            X_train_for_xai = X_train.reshape((X_train.shape[0], X_train.shape[1]))
            X_test_for_xai = X_test.reshape((X_test.shape[0], X_test.shape[1]))
        else:
            X_train_for_xai = X_train
            X_test_for_xai = X_test

        # Gunakan SHAP
        try:
            if is_dl_model:
                explainer = shap.DeepExplainer(model, X_train_for_xai)
                shap_values = explainer.shap_values(X_test_for_xai)
                shap_summary = np.mean(shap_values[0], axis=0)
            else:
                explainer = shap.Explainer(model.predict_proba, X_train_for_xai)
                shap_values = explainer(X_test_for_xai)
                shap_summary = shap_values.values.mean(axis=0)
        except Exception as e:
            print(f"Error using SHAP with {model_name}: {e}")
            shap_summary = None

        # Simpan hasil evaluasi dengan XAI
        hasil_ml_dl_xai.append([model_name, Precision, Recall, F1Score, Accuracy, run_time, {'SHAP': shap_summary}])
    else:
        # Simpan hasil evaluasi tanpa XAI
        hasil_ml_dl.append([model_name, Precision, Recall, F1Score, Accuracy, run_time])

# Model ML dan DL yang akan dievaluasi
model_ml_dl = {
    "DecisionTree": DecisionTreeClassifier(max_depth=10),
    "RandomForest": RandomForestClassifier(n_estimators=50),
    "Logistic Regression": LogisticRegression(random_state=0, max_iter=10000),
    "Naive Bayes": GaussianNB(),
    "MLP": MLPClassifier(solver='adam', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1, max_iter=1000),
    "Stochastic Gradient Descent": SGDClassifier(loss='log_loss', random_state=42),
    "ADA Boost": AdaBoostClassifier(n_estimators=100),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "XGBoost": XGBClassifier(n_estimators=100),
    "LightGBM": LGBMClassifier(n_estimators=100),
    "CatBoost": CatBoostClassifier(iterations=100, depth=6, learning_rate=0.1, loss_function='Logloss')
}

model_dl = {
    "DNN": Sequential([
        Dense(128, input_shape=(X_train.shape[1],), activation='relu'),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "CNN": Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "RNN": Sequential([
        LSTM(100, input_shape=(X_train.shape[1], 1)),
        Dense(1, activation='sigmoid')
    ]),
}

# Pastikan X_train dan X_test memiliki bentuk yang sesuai untuk DL
X_train_dl = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_dl = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Mengevaluasi model ML tanpa XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=False)

# Mengevaluasi model DL tanpa XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=False, is_dl_model=True)

# Mengevaluasi model ML dengan XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=True)

# Mengevaluasi model DL dengan XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=True, is_dl_model=True)

# Print hasil evaluasi tanpa XAI
print("\nHasil Evaluasi ML/DL tanpa XAI:")
print(hasil_ml_dl)

# Print hasil evaluasi dengan XAI
print("\nHasil Evaluasi ML/DL dengan XAI:")
print(hasil_ml_dl_xai)

# Convert results to DataFrame and save to CSV
df_ml_dl = pd.DataFrame(hasil_ml_dl, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime"])
df_ml_dl_xai = pd.DataFrame(hasil_ml_dl_xai, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime", "XAI"])

df_ml_dl.to_csv("hasil_evaluasi_ml_dl_SFSFC.csv", index=False)
df_ml_dl_xai.to_csv("hasil_evaluasi_ml_dl_xai_SFSFC.csv", index=False)
# Out:
# [LightGBM] [Info] Number of positive: 3865, number of negative: 3151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000269 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 217
# [LightGBM] [Info] Number of data points in the train set: 7016, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.550884 -> initscore=0.204242
# [LightGBM] [Info] Start training from score 0.204242
# 0:	learn: 0.6353974	total: 143ms	remaining: 14.2s
# 1:	learn: 0.5878654	total: 145ms	remaining: 7.09s
# 2:	learn: 0.5515035	total: 146ms	remaining: 4.73s
# 3:	learn: 0.5191092	total: 148ms	remaining: 3.55s
# 4:	learn: 0.4933506	total: 150ms	remaining: 2.85s
# 5:	learn: 0.4687449	total: 152ms	remaining: 2.37s
# 6:	learn: 0.4483048	total: 153ms	remaining: 2.04s
# 7:	learn: 0.4295342	total: 155ms	remaining: 1.78s
# 8:	learn: 0.4132374	total: 157ms	remaining: 1.59s
# 9:	learn: 0.3999428	total: 159ms	remaining: 1.43s
# 10:	learn: 0.3890167	total: 160ms	remaining: 1.3s
# 11:	learn: 0.3785998	total: 162ms	remaining: 1.19s
# 12:	learn: 0.3702329	total: 164ms	remaining: 1.09s
# 13:	learn: 0.3639474	total: 165ms	remaining: 1.02s
# 14:	learn: 0.3567172	total: 167ms	remaining: 947ms
# 15:	learn: 0.3505565	total: 169ms	remaining: 887ms
# 16:	learn: 0.3461012	total: 171ms	remaining: 837ms
# 17:	learn: 0.3408864	total: 174ms	remaining: 792ms
# 18:	learn: 0.3373876	total: 176ms	remaining: 749ms
# 19:	learn: 0.3324490	total: 177ms	remaining: 710ms
# 20:	learn: 0.3288347	total: 179ms	remaining: 674ms
# 21:	learn: 0.3266470	total: 181ms	remaining: 642ms
# 22:	learn: 0.3231448	total: 183ms	remaining: 612ms
# 23:	learn: 0.3209032	total: 185ms	remaining: 584ms
# 24:	learn: 0.3184005	total: 187ms	remaining: 560ms
# 25:	learn: 0.3170469	total: 189ms	remaining: 537ms
# 26:	learn: 0.3140291	total: 191ms	remaining: 516ms
# 27:	learn: 0.3119483	total: 193ms	remaining: 496ms
# 28:	learn: 0.3103822	total: 195ms	remaining: 476ms
# 29:	learn: 0.3086339	total: 196ms	remaining: 458ms
# 30:	learn: 0.3062398	total: 198ms	remaining: 441ms
# 31:	learn: 0.3055883	total: 200ms	remaining: 425ms
# 32:	learn: 0.3043689	total: 202ms	remaining: 410ms
# 33:	learn: 0.3037816	total: 204ms	remaining: 396ms
# 34:	learn: 0.3030079	total: 206ms	remaining: 383ms
# 35:	learn: 0.3022696	total: 208ms	remaining: 370ms
# 36:	learn: 0.3011326	total: 210ms	remaining: 357ms
# 37:	learn: 0.3003387	total: 212ms	remaining: 345ms
# 38:	learn: 0.2996828	total: 214ms	remaining: 334ms
# 39:	learn: 0.2994086	total: 215ms	remaining: 322ms
# 40:	learn: 0.2987493	total: 217ms	remaining: 312ms
# 41:	learn: 0.2978520	total: 218ms	remaining: 302ms
# 42:	learn: 0.2975112	total: 220ms	remaining: 292ms
# 43:	learn: 0.2971419	total: 222ms	remaining: 283ms
# 44:	learn: 0.2961532	total: 224ms	remaining: 274ms
# 45:	learn: 0.2959341	total: 226ms	remaining: 265ms
# 46:	learn: 0.2953851	total: 227ms	remaining: 256ms
# 47:	learn: 0.2949814	total: 229ms	remaining: 248ms
# 48:	learn: 0.2945997	total: 231ms	remaining: 240ms
# 49:	learn: 0.2942346	total: 233ms	remaining: 233ms
# 50:	learn: 0.2939419	total: 234ms	remaining: 225ms
# 51:	learn: 0.2937573	total: 236ms	remaining: 218ms
# 52:	learn: 0.2934329	total: 238ms	remaining: 211ms
# 53:	learn: 0.2927908	total: 240ms	remaining: 204ms
# 54:	learn: 0.2925444	total: 241ms	remaining: 197ms
# 55:	learn: 0.2923249	total: 243ms	remaining: 191ms
# 56:	learn: 0.2922862	total: 245ms	remaining: 185ms
# 57:	learn: 0.2921089	total: 247ms	remaining: 179ms
# 58:	learn: 0.2919632	total: 249ms	remaining: 173ms
# 59:	learn: 0.2903667	total: 250ms	remaining: 167ms
# 60:	learn: 0.2903056	total: 252ms	remaining: 161ms
# 61:	learn: 0.2902101	total: 254ms	remaining: 155ms
# 62:	learn: 0.2899653	total: 255ms	remaining: 150ms
# 63:	learn: 0.2886554	total: 258ms	remaining: 145ms
# 64:	learn: 0.2883217	total: 259ms	remaining: 140ms
# 65:	learn: 0.2882624	total: 262ms	remaining: 135ms
# 66:	learn: 0.2880941	total: 264ms	remaining: 130ms
# 67:	learn: 0.2879511	total: 265ms	remaining: 125ms
# 68:	learn: 0.2876616	total: 267ms	remaining: 120ms
# 69:	learn: 0.2871904	total: 269ms	remaining: 115ms
# 70:	learn: 0.2871579	total: 270ms	remaining: 110ms
# 71:	learn: 0.2870447	total: 272ms	remaining: 106ms
# 72:	learn: 0.2868792	total: 274ms	remaining: 101ms
# 73:	learn: 0.2863772	total: 276ms	remaining: 96.8ms
# 74:	learn: 0.2858750	total: 277ms	remaining: 92.5ms
# 75:	learn: 0.2858157	total: 279ms	remaining: 88.1ms
# 76:	learn: 0.2857574	total: 281ms	remaining: 83.9ms
# 77:	learn: 0.2855031	total: 283ms	remaining: 79.7ms
# 78:	learn: 0.2849093	total: 284ms	remaining: 75.6ms
# 79:	learn: 0.2847675	total: 286ms	remaining: 71.6ms
# 80:	learn: 0.2831225	total: 288ms	remaining: 67.6ms
# 81:	learn: 0.2830744	total: 290ms	remaining: 63.7ms
# 82:	learn: 0.2821140	total: 292ms	remaining: 59.8ms
# 83:	learn: 0.2820657	total: 293ms	remaining: 55.9ms
# 84:	learn: 0.2818602	total: 295ms	remaining: 52.1ms
# 85:	learn: 0.2816946	total: 297ms	remaining: 48.3ms
# 86:	learn: 0.2813054	total: 298ms	remaining: 44.6ms
# 87:	learn: 0.2812710	total: 300ms	remaining: 40.9ms
# 88:	learn: 0.2811755	total: 302ms	remaining: 37.3ms
# 89:	learn: 0.2806630	total: 304ms	remaining: 33.7ms
# 90:	learn: 0.2803430	total: 305ms	remaining: 30.2ms
# 91:	learn: 0.2799175	total: 307ms	remaining: 26.7ms
# 92:	learn: 0.2795693	total: 309ms	remaining: 23.2ms
# 93:	learn: 0.2793277	total: 311ms	remaining: 19.8ms
# 94:	learn: 0.2790580	total: 312ms	remaining: 16.4ms
# 95:	learn: 0.2787528	total: 314ms	remaining: 13.1ms
# 96:	learn: 0.2785930	total: 316ms	remaining: 9.76ms
# 97:	learn: 0.2772350	total: 317ms	remaining: 6.48ms
# 98:	learn: 0.2771807	total: 319ms	remaining: 3.22ms
# 99:	learn: 0.2768583	total: 321ms	remaining: 0us
# 94/94 [==============================] - 0s 2ms/step
# 94/94 [==============================] - 0s 794us/step
# 94/94 [==============================] - 1s 2ms/step
# ExactExplainer explainer: 3008it [00:10, 37.78it/s]
# ExactExplainer explainer: 3008it [00:42, 54.22it/s]
# ExactExplainer explainer: 3008it [02:31, 18.42it/s]
# ExactExplainer explainer: 3008it [03:04, 15.72it/s]
# [LightGBM] [Info] Number of positive: 3865, number of negative: 3151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000296 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 217
# [LightGBM] [Info] Number of data points in the train set: 7016, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.550884 -> initscore=0.204242
# [LightGBM] [Info] Start training from score 0.204242
# ExactExplainer explainer: 3008it [00:26, 68.61it/s]
# 0:	learn: 0.6353974	total: 1.84ms	remaining: 182ms
# 1:	learn: 0.5878654	total: 3.58ms	remaining: 175ms
# 2:	learn: 0.5515035	total: 5.26ms	remaining: 170ms
# 3:	learn: 0.5191092	total: 7.07ms	remaining: 170ms
# 4:	learn: 0.4933506	total: 8.88ms	remaining: 169ms
# 5:	learn: 0.4687449	total: 10.9ms	remaining: 170ms
# 6:	learn: 0.4483048	total: 12.7ms	remaining: 169ms
# 7:	learn: 0.4295342	total: 14.6ms	remaining: 167ms
# 8:	learn: 0.4132374	total: 16.5ms	remaining: 167ms
# 9:	learn: 0.3999428	total: 18.4ms	remaining: 165ms
# 10:	learn: 0.3890167	total: 20.2ms	remaining: 164ms
# 11:	learn: 0.3785998	total: 22.2ms	remaining: 163ms
# 12:	learn: 0.3702329	total: 23.7ms	remaining: 159ms
# 13:	learn: 0.3639474	total: 25.8ms	remaining: 158ms
# 14:	learn: 0.3567172	total: 27.4ms	remaining: 155ms
# 15:	learn: 0.3505565	total: 29.3ms	remaining: 154ms
# 16:	learn: 0.3461012	total: 30.9ms	remaining: 151ms
# 17:	learn: 0.3408864	total: 32.8ms	remaining: 150ms
# 18:	learn: 0.3373876	total: 34.7ms	remaining: 148ms
# 19:	learn: 0.3324490	total: 36.5ms	remaining: 146ms
# 20:	learn: 0.3288347	total: 38.2ms	remaining: 144ms
# 21:	learn: 0.3266470	total: 40.5ms	remaining: 144ms
# 22:	learn: 0.3231448	total: 42.2ms	remaining: 141ms
# 23:	learn: 0.3209032	total: 43.9ms	remaining: 139ms
# 24:	learn: 0.3184005	total: 45.7ms	remaining: 137ms
# 25:	learn: 0.3170469	total: 47.4ms	remaining: 135ms
# 26:	learn: 0.3140291	total: 49.1ms	remaining: 133ms
# 27:	learn: 0.3119483	total: 50.8ms	remaining: 131ms
# 28:	learn: 0.3103822	total: 52.6ms	remaining: 129ms
# 29:	learn: 0.3086339	total: 54.5ms	remaining: 127ms
# 30:	learn: 0.3062398	total: 56.4ms	remaining: 125ms
# 31:	learn: 0.3055883	total: 58.1ms	remaining: 124ms
# 32:	learn: 0.3043689	total: 59.8ms	remaining: 121ms
# 33:	learn: 0.3037816	total: 61.6ms	remaining: 120ms
# 34:	learn: 0.3030079	total: 63.5ms	remaining: 118ms
# 35:	learn: 0.3022696	total: 65.3ms	remaining: 116ms
# 36:	learn: 0.3011326	total: 67.2ms	remaining: 114ms
# 37:	learn: 0.3003387	total: 69.1ms	remaining: 113ms
# 38:	learn: 0.2996828	total: 70.9ms	remaining: 111ms
# 39:	learn: 0.2994086	total: 72.1ms	remaining: 108ms
# 40:	learn: 0.2987493	total: 74.1ms	remaining: 107ms
# 41:	learn: 0.2978520	total: 75.8ms	remaining: 105ms
# 42:	learn: 0.2975112	total: 77.6ms	remaining: 103ms
# 43:	learn: 0.2971419	total: 79.2ms	remaining: 101ms
# 44:	learn: 0.2961532	total: 81.5ms	remaining: 99.6ms
# 45:	learn: 0.2959341	total: 83.8ms	remaining: 98.4ms
# 46:	learn: 0.2953851	total: 85.7ms	remaining: 96.6ms
# 47:	learn: 0.2949814	total: 87.5ms	remaining: 94.8ms
# 48:	learn: 0.2945997	total: 89.4ms	remaining: 93ms
# 49:	learn: 0.2942346	total: 91.3ms	remaining: 91.3ms
# 50:	learn: 0.2939419	total: 93ms	remaining: 89.3ms
# 51:	learn: 0.2937573	total: 94.6ms	remaining: 87.3ms
# 52:	learn: 0.2934329	total: 96.2ms	remaining: 85.3ms
# 53:	learn: 0.2927908	total: 97.9ms	remaining: 83.4ms
# 54:	learn: 0.2925444	total: 99.7ms	remaining: 81.5ms
# 55:	learn: 0.2923249	total: 101ms	remaining: 79.7ms
# 56:	learn: 0.2922862	total: 103ms	remaining: 77.7ms
# 57:	learn: 0.2921089	total: 105ms	remaining: 75.8ms
# 58:	learn: 0.2919632	total: 106ms	remaining: 74ms
# 59:	learn: 0.2903667	total: 108ms	remaining: 72.3ms
# 60:	learn: 0.2903056	total: 110ms	remaining: 70.2ms
# 61:	learn: 0.2902101	total: 111ms	remaining: 68.2ms
# 62:	learn: 0.2899653	total: 113ms	remaining: 66.4ms
# 63:	learn: 0.2886554	total: 115ms	remaining: 64.5ms
# 64:	learn: 0.2883217	total: 116ms	remaining: 62.7ms
# 65:	learn: 0.2882624	total: 118ms	remaining: 60.8ms
# 66:	learn: 0.2880941	total: 120ms	remaining: 59ms
# 67:	learn: 0.2879511	total: 122ms	remaining: 57.2ms
# 68:	learn: 0.2876616	total: 123ms	remaining: 55.3ms
# 69:	learn: 0.2871904	total: 125ms	remaining: 53.7ms
# 70:	learn: 0.2871579	total: 127ms	remaining: 51.8ms
# 71:	learn: 0.2870447	total: 128ms	remaining: 50ms
# 72:	learn: 0.2868792	total: 130ms	remaining: 48.1ms
# 73:	learn: 0.2863772	total: 132ms	remaining: 46.4ms
# 74:	learn: 0.2858750	total: 134ms	remaining: 44.6ms
# 75:	learn: 0.2858157	total: 135ms	remaining: 42.7ms
# 76:	learn: 0.2857574	total: 137ms	remaining: 40.9ms
# 77:	learn: 0.2855031	total: 139ms	remaining: 39.1ms
# 78:	learn: 0.2849093	total: 140ms	remaining: 37.3ms
# 79:	learn: 0.2847675	total: 142ms	remaining: 35.5ms
# 80:	learn: 0.2831225	total: 144ms	remaining: 33.7ms
# 81:	learn: 0.2830744	total: 146ms	remaining: 31.9ms
# 82:	learn: 0.2821140	total: 147ms	remaining: 30.2ms
# 83:	learn: 0.2820657	total: 149ms	remaining: 28.4ms
# 84:	learn: 0.2818602	total: 151ms	remaining: 26.6ms
# 85:	learn: 0.2816946	total: 152ms	remaining: 24.8ms
# 86:	learn: 0.2813054	total: 154ms	remaining: 23ms
# 87:	learn: 0.2812710	total: 156ms	remaining: 21.2ms
# 88:	learn: 0.2811755	total: 158ms	remaining: 19.5ms
# 89:	learn: 0.2806630	total: 159ms	remaining: 17.7ms
# 90:	learn: 0.2803430	total: 161ms	remaining: 16ms
# 91:	learn: 0.2799175	total: 163ms	remaining: 14.2ms
# 92:	learn: 0.2795693	total: 165ms	remaining: 12.4ms
# 93:	learn: 0.2793277	total: 167ms	remaining: 10.6ms
# 94:	learn: 0.2790580	total: 169ms	remaining: 8.88ms
# 95:	learn: 0.2787528	total: 171ms	remaining: 7.13ms
# 96:	learn: 0.2785930	total: 173ms	remaining: 5.35ms
# 97:	learn: 0.2772350	total: 175ms	remaining: 3.57ms
# 98:	learn: 0.2771807	total: 177ms	remaining: 1.78ms
# 99:	learn: 0.2768583	total: 179ms	remaining: 0us
# ExactExplainer explainer: 3008it [00:15, 65.97it/s]
# 94/94 [==============================] - 1s 3ms/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# 94/94 [==============================] - 0s 779us/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Error using SHAP with CNN: operands could not be broadcast together with shapes (7016,5,1) (7016,5)
# 94/94 [==============================] - 1s 2ms/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Error using SHAP with RNN: in user code:
#
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 244, in grad_graph  *
#         out = self.model(shap_rAnD)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler  **
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 371, in custom_grad
#         out = op_handlers[type_name](self, op, *grads) # we cut off the shap_ prefix before the lookup
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 663, in handler
#         return linearity_with_excluded_handler(input_inds, explainer, op, *grads)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 670, in linearity_with_excluded_handler
#         assert not explainer._variable_inputs(op)[i], str(i) + "th input to " + op.name + " cannot vary!"
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 222, in _variable_inputs
#         out[i] = t.name in self.between_tensors
#
#     AttributeError: Exception encountered when calling layer 'lstm' (type LSTM).
#
#     'TFDeep' object has no attribute 'between_tensors'
#
#     Call arguments received by layer 'lstm' (type LSTM):
#       • inputs=tf.Tensor(shape=(14032, 5, 1), dtype=float32)
#       • mask=None
#       • training=False
#       • initial_state=None
#
#
# Hasil Evaluasi ML/DL tanpa XAI:
# [['DecisionTree', 0.8711063372717508, 0.9597633136094674, 0.9132882882882883, 0.8975723312271366, 0.006014108657836914], ['RandomForest', 0.8755364806866953, 0.9656804733727811, 0.9184018007878446, 0.9035583638177586, 0.22819209098815918], ['Logistic Regression', 0.749185667752443, 0.9526627218934911, 0.8387600937744203, 0.7941469903558364, 0.019631624221801758], ['Naive Bayes', 0.7265486725663717, 0.9715976331360947, 0.8313924050632912, 0.7785167941469904, 0.005254507064819336], ['MLP', 0.8726042841037204, 0.9159763313609467, 0.8937644341801385, 0.877618889258397, 2.848597288131714], ['Stochastic Gradient Descent', 0.8269331930562862, 0.9301775147928995, 0.8755221386800334, 0.85134685733289, 0.01677846908569336], ['ADA Boost', 0.8719376391982183, 0.9266272189349113, 0.8984509466437177, 0.8822746923844363, 0.48793601989746094], ['Gradient Boosting', 0.8808347062053816, 0.9491124260355029, 0.913699800626602, 0.8992351180578649, 0.356616735458374], ['XGBoost', 0.8746637977407208, 0.9621301775147929, 0.9163144547759932, 0.9012304622547389, 1.3826229572296143], ['LightGBM', 0.8765498652291105, 0.9621301775147929, 0.917348377997179, 0.9025606917193216, 0.261091947555542], ['CatBoost', 0.8819290465631929, 0.9414201183431953, 0.9107040641099027, 0.896242101762554, 0.40825819969177246], ['DNN', 0.8735505245720596, 0.936094674556213, 0.903741788060554, 0.8879281676089126, 2.4612066745758057], ['CNN', 0.8316622691292876, 0.9325443786982248, 0.8792189679218968, 0.8560026604589291, 2.240431785583496], ['RNN', 0.7989974937343358, 0.9431952662721893, 0.8651289009497964, 0.8347189890256069, 6.658675193786621]]
#
# Hasil Evaluasi ML/DL dengan XAI:
# [['DecisionTree', 0.8729133010231557, 0.9591715976331361, 0.914011840992388, 0.8985700033255737, 0.009118795394897461, {'SHAP': array([[ 0.00923634, -0.00923634],
#        [ 0.00766944, -0.00766944],
#        [ 0.01569705, -0.01569705],
#        [ 0.00929791, -0.00929791],
#        [-0.00757811,  0.00757811]])}], ['RandomForest', 0.8746652383502946, 0.9662721893491124, 0.9181894855215069, 0.9032258064516129, 0.19826197624206543, {'SHAP': array([[ 0.00915641, -0.00915641],
#        [ 0.00122502, -0.00122502],
#        [ 0.01771516, -0.01771516],
#        [ 0.00778561, -0.00778561],
#        [-0.00369445,  0.00369445]])}], ['Logistic Regression', 0.749185667752443, 0.9526627218934911, 0.8387600937744203, 0.7941469903558364, 0.017861366271972656, {'SHAP': array([[ 8.55092600e-04, -8.55092600e-04],
#        [-1.86624772e-02,  1.86624772e-02],
#        [ 3.01809648e-06, -3.01809648e-06],
#        [-6.79474671e-03,  6.79474671e-03],
#        [-7.71906710e-05,  7.71906710e-05]])}], ['Naive Bayes', 0.7265486725663717, 0.9715976331360947, 0.8313924050632912, 0.7785167941469904, 0.004506111145019531, {'SHAP': array([[ 0.01359758, -0.01359758],
#        [-0.01725782,  0.01725782],
#        [ 0.00207975, -0.00207975],
#        [ 0.00677959, -0.00677959],
#        [-0.0065933 ,  0.0065933 ]])}], ['MLP', 0.8726042841037204, 0.9159763313609467, 0.8937644341801385, 0.877618889258397, 2.6390998363494873, {'SHAP': array([[-0.00611499,  0.00611499],
#        [-0.04019654,  0.04019654],
#        [ 0.00314054, -0.00314054],
#        [ 0.00511148, -0.00511148],
#        [-0.00452359,  0.00452359]])}], ['Stochastic Gradient Descent', 0.8269331930562862, 0.9301775147928995, 0.8755221386800334, 0.85134685733289, 0.014364004135131836, {'SHAP': array([[ 0.00063084, -0.00063084],
#        [-0.02037803,  0.02037803],
#        [-0.00053715,  0.00053715],
#        [-0.0058295 ,  0.0058295 ],
#        [-0.0001025 ,  0.0001025 ]])}], ['ADA Boost', 0.8719376391982183, 0.9266272189349113, 0.8984509466437177, 0.8822746923844363, 0.4623866081237793, {'SHAP': array([[ 0.00028873, -0.00028873],
#        [ 0.00023677, -0.00023677],
#        [ 0.00013382, -0.00013382],
#        [-0.00068777,  0.00068777],
#        [-0.00032824,  0.00032824]])}], ['Gradient Boosting', 0.8808347062053816, 0.9491124260355029, 0.913699800626602, 0.8992351180578649, 0.43712687492370605, {'SHAP': array([[ 0.00858352, -0.00858352],
#        [-0.02110441,  0.02110441],
#        [ 0.01735444, -0.01735444],
#        [ 0.00568837, -0.00568837],
#        [-0.00168611,  0.00168611]])}], ['XGBoost', 0.8746637977407208, 0.9621301775147929, 0.9163144547759932, 0.9012304622547389, 90.03077292442322, {'SHAP': array([[ 0.00840874, -0.00840874],
#        [-0.00265521,  0.00265521],
#        [ 0.01865007, -0.01865007],
#        [ 0.00762699, -0.00762699],
#        [-0.01035465,  0.01035465]])}], ['LightGBM', 0.8765498652291105, 0.9621301775147929, 0.917348377997179, 0.9025606917193216, 0.3149724006652832, {'SHAP': array([[ 0.00844738, -0.00844738],
#        [-0.00101061,  0.00101061],
#        [ 0.01937998, -0.01937998],
#        [ 0.00761368, -0.00761368],
#        [-0.00742069,  0.00742069]])}], ['CatBoost', 0.8819290465631929, 0.9414201183431953, 0.9107040641099027, 0.896242101762554, 0.24980616569519043, {'SHAP': array([[ 0.00917734, -0.00917734],
#        [-0.02432853,  0.02432853],
#        [ 0.01469612, -0.01469612],
#        [ 0.00395607, -0.00395607],
#        [-0.00140231,  0.00140231]])}], ['DNN', 0.8741721854304636, 0.9372781065088758, 0.9046259280411193, 0.8889258397073495, 5.673098564147949, {'SHAP': array([0.06478506])}], ['CNN', 0.8735244519392917, 0.919526627218935, 0.8959354280772557, 0.8799467908214167, 2.2990384101867676, {'SHAP': None}], ['RNN', 0.822303282959875, 0.9337278106508876, 0.8744804655029094, 0.849351513136016, 7.427557468414307, {'SHAP': None}]]
