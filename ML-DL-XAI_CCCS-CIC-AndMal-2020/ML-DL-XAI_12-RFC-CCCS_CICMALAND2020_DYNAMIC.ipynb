# %%
# Library untuk pengolahan data dan visualisasi
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import joblib
import threading

# Library untuk evaluasi dan model machine learning
from sklearn.metrics import confusion_matrix, classification_report
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Ridge
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
import sklearn.ensemble as ek
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# Library untuk Explainable AI (XAI)
from lime.lime_tabular import LimeTabularExplainer
import shap

# Library untuk Deep Learning
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, LSTM, Dropout
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %%
# Input Dataset 

DM = pd.read_parquet("C:\\Data Raihan\\Penelitian Threshold\\Dataset\\CCCS-CIC-AndMal-2020\\cicandmal2020-dynamic.parquet")

# %%
DM.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53439 entries, 0 to 53438
# Data columns (total 145 columns):
#  #    Column                                                                              Non-Null Count  Dtype
# ---   ------                                                                              --------------  -----
#  0    Memory_PssTotal                                                                     53439 non-null  int32
#  1    Memory_PssClean                                                                     53439 non-null  int32
#  2    Memory_SharedDirty                                                                  53439 non-null  int32
#  3    Memory_PrivateDirty                                                                 53439 non-null  int32
#  4    Memory_SharedClean                                                                  53439 non-null  int32
#  5    Memory_PrivateClean                                                                 53439 non-null  int32
#  6    Memory_SwapPssDirty                                                                 53439 non-null  int8
#  7    Memory_HeapSize                                                                     53439 non-null  int32
#  8    Memory_HeapAlloc                                                                    53439 non-null  int32
#  9    Memory_HeapFree                                                                     53439 non-null  int32
#  10   Memory_Views                                                                        53439 non-null  int16
#  11   Memory_ViewRootImpl                                                                 53439 non-null  int16
#  12   Memory_AppContexts                                                                  53439 non-null  int16
#  13   Memory_Activities                                                                   53439 non-null  int16
#  14   Memory_Assets                                                                       53439 non-null  int8
#  15   Memory_AssetManagers                                                                53439 non-null  int8
#  16   Memory_LocalBinders                                                                 53439 non-null  int16
#  17   Memory_ProxyBinders                                                                 53439 non-null  int16
#  18   Memory_ParcelMemory                                                                 53439 non-null  int16
#  19   Memory_ParcelCount                                                                  53439 non-null  int16
#  20   Memory_DeathRecipients                                                              53439 non-null  int8
#  21   Memory_OpenSSLSockets                                                               53439 non-null  int8
#  22   Memory_WebViews                                                                     53439 non-null  int8
#  23   API_Process_android.os.Process_start                                                53439 non-null  int8
#  24   API_Process_android.app.ActivityManager_killBackgroundProcesses                     53439 non-null  int16
#  25   API_Process_android.os.Process_killProcess                                          53439 non-null  int16
#  26   API_Command_java.lang.Runtime_exec                                                  53439 non-null  int16
#  27   API_Command_java.lang.ProcessBuilder_start                                          53439 non-null  int16
#  28   API_JavaNativeInterface_java.lang.Runtime_loadLibrary                               53439 non-null  int8
#  29   API_JavaNativeInterface_java.lang.Runtime_load                                      53439 non-null  int8
#  30   API_WebView_android.webkit.WebView_loadUrl                                          53439 non-null  int16
#  31   API_WebView_android.webkit.WebView_loadData                                         53439 non-null  int8
#  32   API_WebView_android.webkit.WebView_loadDataWithBaseURL                              53439 non-null  int16
#  33   API_WebView_android.webkit.WebView_addJavascriptInterface                           53439 non-null  int16
#  34   API_WebView_android.webkit.WebView_evaluateJavascript                               53439 non-null  int16
#  35   API_WebView_android.webkit.WebView_postUrl                                          53439 non-null  int8
#  36   API_WebView_android.webkit.WebView_postWebMessage                                   53439 non-null  int8
#  37   API_WebView_android.webkit.WebView_savePassword                                     53439 non-null  int8
#  38   API_WebView_android.webkit.WebView_setHttpAuthUsernamePassword                      53439 non-null  int8
#  39   API_WebView_android.webkit.WebView_getHttpAuthUsernamePassword                      53439 non-null  int8
#  40   API_WebView_android.webkit.WebView_setWebContentsDebuggingEnabled                   53439 non-null  int16
#  41   API_FileIO_libcore.io.IoBridge_open                                                 53439 non-null  int16
#  42   API_FileIO_android.content.ContextWrapper_openFileInput                             53439 non-null  int16
#  43   API_FileIO_android.content.ContextWrapper_openFileOutput                            53439 non-null  int16
#  44   API_FileIO_android.content.ContextWrapper_deleteFile                                53439 non-null  int8
#  45   API_Database_android.content.ContextWrapper_openOrCreateDatabase                    53439 non-null  int16
#  46   API_Database_android.content.ContextWrapper_databaseList                            53439 non-null  int8
#  47   API_Database_android.content.ContextWrapper_deleteDatabase                          53439 non-null  int8
#  48   API_Database_android.database.sqlite.SQLiteDatabase_execSQL                         53439 non-null  int16
#  49   API_Database_android.database.sqlite.SQLiteDatabase_deleteDatabase                  53439 non-null  int8
#  50   API_Database_android.database.sqlite.SQLiteDatabase_getPath                         53439 non-null  int16
#  51   API_Database_android.database.sqlite.SQLiteDatabase_insert                          53439 non-null  int16
#  52   API_Database_android.database.sqlite.SQLiteDatabase_insertOrThrow                   53439 non-null  int16
#  53   API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict            53439 non-null  int16
#  54   API_Database_android.database.sqlite.SQLiteDatabase_openDatabase                    53439 non-null  int16
#  55   API_Database_android.database.sqlite.SQLiteDatabase_openOrCreateDatabase            53439 non-null  int16
#  56   API_Database_android.database.sqlite.SQLiteDatabase_query                           53439 non-null  int16
#  57   API_Database_android.database.sqlite.SQLiteDatabase_queryWithFactory                53439 non-null  int16
#  58   API_Database_android.database.sqlite.SQLiteDatabase_rawQuery                        53439 non-null  int16
#  59   API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory             53439 non-null  int16
#  60   API_Database_android.database.sqlite.SQLiteDatabase_update                          53439 non-null  int16
#  61   API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict            53439 non-null  int16
#  62   API_Database_android.database.sqlite.SQLiteDatabase_compileStatement                53439 non-null  int16
#  63   API_Database_android.database.sqlite.SQLiteDatabase_create                          53439 non-null  int8
#  64   API_IPC_android.content.ContextWrapper_sendBroadcast                                53439 non-null  int16
#  65   API_IPC_android.content.ContextWrapper_sendStickyBroadcast                          53439 non-null  int8
#  66   API_IPC_android.content.ContextWrapper_startActivity                                53439 non-null  int16
#  67   API_IPC_android.content.ContextWrapper_startService                                 53439 non-null  int16
#  68   API_IPC_android.content.ContextWrapper_stopService                                  53439 non-null  int8
#  69   API_IPC_android.content.ContextWrapper_registerReceiver                             53439 non-null  int16
#  70   API_Binder_android.app.ContextImpl_registerReceiver                                 53439 non-null  int16
#  71   API_Binder_android.app.ActivityThread_handleReceiver                                53439 non-null  int16
#  72   API_Binder_android.app.Activity_startActivity                                       53439 non-null  int16
#  73   API_Crypto_javax.crypto.spec.SecretKeySpec_$init                                    53439 non-null  int32
#  74   API_Crypto_javax.crypto.Cipher_doFinal                                              53439 non-null  int16
#  75   API_Crypto-Hash_java.security.MessageDigest_digest                                  53439 non-null  int16
#  76   API_Crypto-Hash_java.security.MessageDigest_update                                  53439 non-null  int32
#  77   API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId                       53439 non-null  int16
#  78   API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId                   53439 non-null  int16
#  79   API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number                    53439 non-null  int16
#  80   API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperator                53439 non-null  int16
#  81   API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperatorName            53439 non-null  int16
#  82   API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName                53439 non-null  int16
#  83   API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress                              53439 non-null  int16
#  84   API_DeviceInfo_android.net.wifi.WifiInfo_getBSSID                                   53439 non-null  int16
#  85   API_DeviceInfo_android.net.wifi.WifiInfo_getIpAddress                               53439 non-null  int16
#  86   API_DeviceInfo_android.net.wifi.WifiInfo_getNetworkId                               53439 non-null  int16
#  87   API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso                  53439 non-null  int16
#  88   API_DeviceInfo_android.telephony.TelephonyManager_getSimSerialNumber                53439 non-null  int16
#  89   API_DeviceInfo_android.telephony.TelephonyManager_getNetworkCountryIso              53439 non-null  int16
#  90   API_DeviceInfo_android.telephony.TelephonyManager_getDeviceSoftwareVersion          53439 non-null  int8
#  91   API_DeviceInfo_android.os.Debug_isDebuggerConnected                                 53439 non-null  int16
#  92   API_DeviceInfo_android.content.pm.PackageManager_getInstallerPackageName            53439 non-null  int8
#  93   API_DeviceInfo_android.content.pm.PackageManager_getInstalledApplications           53439 non-null  int8
#  94   API_DeviceInfo_android.content.pm.PackageManager_getInstalledModules                53439 non-null  int8
#  95   API_DeviceInfo_android.content.pm.PackageManager_getInstalledPackages               53439 non-null  int8
#  96   API_Network_java.net.URL_openConnection                                             53439 non-null  int16
#  97   API_Network_org.apache.http.impl.client.AbstractHttpClient_execute                  53439 non-null  int8
#  98   API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream    53439 non-null  int16
#  99   API_Network_com.android.okhttp.internal.http.HttpURLConnectionImpl_getInputStream   53439 non-null  int8
#  100  API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResource                    53439 non-null  int16
#  101  API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResources                   53439 non-null  int8
#  102  API_DexClassLoader_dalvik.system.BaseDexClassLoader_findLibrary                     53439 non-null  int16
#  103  API_DexClassLoader_dalvik.system.DexFile_loadDex                                    53439 non-null  int8
#  104  API_DexClassLoader_dalvik.system.DexFile_loadClass                                  53439 non-null  int16
#  105  API_DexClassLoader_dalvik.system.DexClassLoader_$init                               53439 non-null  int16
#  106  API_Base64_android.util.Base64_decode                                               53439 non-null  int16
#  107  API_Base64_android.util.Base64_encode                                               53439 non-null  int16
#  108  API_Base64_android.util.Base64_encodeToString                                       53439 non-null  int16
#  109  API_SystemManager_android.app.ApplicationPackageManager_setComponentEnabledSetting  53439 non-null  int16
#  110  API_SystemManager_android.app.NotificationManager_notify                            53439 non-null  int16
#  111  API_SystemManager_android.telephony.TelephonyManager_listen                         53439 non-null  int8
#  112  API_SystemManager_android.content.BroadcastReceiver_abortBroadcast                  53439 non-null  int8
#  113  API_SMS_android.telephony.SmsManager_sendTextMessage                                53439 non-null  int16
#  114  API_SMS_android.telephony.SmsManager_sendMultipartTextMessage                       53439 non-null  int8
#  115  API_DeviceData_android.content.ContentResolver_query                                53439 non-null  int16
#  116  API_DeviceData_android.content.ContentResolver_registerContentObserver              53439 non-null  int16
#  117  API_DeviceData_android.content.ContentResolver_insert                               53439 non-null  int16
#  118  API_DeviceData_android.content.ContentResolver_delete                               53439 non-null  int16
#  119  API_DeviceData_android.accounts.AccountManager_getAccountsByType                    53439 non-null  int8
#  120  API_DeviceData_android.accounts.AccountManager_getAccounts                          53439 non-null  int16
#  121  API_DeviceData_android.location.Location_getLatitude                                53439 non-null  int16
#  122  API_DeviceData_android.location.Location_getLongitude                               53439 non-null  int16
#  123  API_DeviceData_android.media.AudioRecord_startRecording                             53439 non-null  int16
#  124  API_DeviceData_android.media.MediaRecorder_start                                    53439 non-null  int8
#  125  API_DeviceData_android.os.SystemProperties_get                                      53439 non-null  int16
#  126  API_DeviceData_android.app.ApplicationPackageManager_getInstalledPackages           53439 non-null  int16
#  127  API__sessions                                                                       53439 non-null  int8
#  128  Network_TotalReceivedBytes                                                          53439 non-null  int32
#  129  Network_TotalReceivedPackets                                                        53439 non-null  int32
#  130  Network_TotalTransmittedBytes                                                       53439 non-null  int32
#  131  Network_TotalTransmittedPackets                                                     53439 non-null  int32
#  132  Battery_wakelock                                                                    53439 non-null  int8
#  133  Battery_service                                                                     53439 non-null  int8
#  134  Logcat_debug                                                                        53439 non-null  int32
#  135  Logcat_warning                                                                      53439 non-null  int32
#  136  Logcat_info                                                                         53439 non-null  int32
#  137  Logcat_verbose                                                                      53439 non-null  int32
#  138  Logcat_error                                                                        53439 non-null  int32
#  139  Logcat_total                                                                        53439 non-null  int32
#  140  Process_total                                                                       53439 non-null  int16
#  141  Hash                                                                                53439 non-null  object
#  142  Category                                                                            53439 non-null  object
#  143  Family                                                                              53439 non-null  object
#  144  Label                                                                               53439 non-null  object
# dtypes: int16(81), int32(21), int8(39), object(4)
# memory usage: 16.2+ MB

# %%
# Menampilkan nilai unik pada kolom Category, Family, dan Label
unique_category = DM['Category'].unique()
unique_family = DM['Family'].unique()
unique_label = DM['Label'].unique()

print("Unique Categories:", unique_category)
print("Unique Families:", unique_family)
print("Unique Labels:", unique_label)
# Out:
# Unique Categories: ['Trojan_Spy' 'FileInfector' 'Zero_Day' 'Backdoor' 'Ransomware'
#  'No_Category' 'Trojan_SMS' 'Trojan_Dropper' 'Trojan_Banker' 'Scareware'
#  'PUA' 'Adware' 'Riskware' 'Trojan']
# Unique Families: ['smsthief' 'sandr' 'smforw' ... 'pesabti' 'mycompany' 'koomer']
# Unique Labels: ['Trojan_Spy_before_reboot_Cat' 'FileInfector_after_reboot_Cat'
#  'Zero_Day_after_reboot_Cat' 'Trojan_Spy_after_reboot_Cat'
#  'Backdoor_before_reboot_Cat' 'Ransomware_after_reboot_Cat'
#  'Ransomware_before_reboot_Cat' 'No_Category_before_reboot_Cat'
#  'Trojan_SMS_after_reboot_Cat' 'Zero_Day_before_reboot_Cat'
#  'Backdoor_after_reboot_Cat' 'Trojan_Dropper_after_reboot_Cat'
#  'Trojan_Banker_after_reboot_Cat' 'Scareware_before_reboot_Cat'
#  'PUA_after_reboot_Cat' 'Scareware_after_reboot_Cat'
#  'PUA_before_reboot_Cat' 'Adware_before_reboot_Cat'
#  'Riskware_before_reboot_Cat' 'Riskware_after_reboot_Cat'
#  'Trojan_Banker_before_reboot_Cat' 'Trojan_SMS_before_reboot_Cat'
#  'FileInfector_before_reboot_Cat' 'Trojan_before_reboot_Cat'
#  'Trojan_after_reboot_Cat' 'Adware_after_reboot_Cat'
#  'No_Category_after_reboot_Cat' 'Trojan_Dropper_before_reboot_Cat']

# %%
# Definisikan kategori benign dan malware
benign_categories = ['Adware', 'Riskware', 'PUA', 'No_Category']
malware_categories = ['Trojan_Spy', 'FileInfector', 'Zero_Day', 'Backdoor', 
                      'Ransomware', 'Trojan_SMS', 'Trojan_Dropper', 'Trojan_Banker', 
                      'Scareware', 'Trojan']

# Relabeling ke dalam kelas binari: 'Benign' dan 'Malware'
DM['Binary_Label'] = DM['Category'].apply(lambda x: 'Benign' if x in benign_categories else 'Malware')

# Cek hasil unique Binary_Label setelah relabeling
unique_binary_labels = DM['Binary_Label'].unique()
print("Unique Binary Labels after relabeling:", unique_binary_labels)
# Out:
# Unique Binary Labels after relabeling: ['Malware' 'Benign']

# %%
#Feature Selection
features_to_drop = ['Hash', 'Category', 'Family', 'Label', 'Network_TotalReceivedBytes', 'Binary_Label']

# Droping specified columns and target variable
X = DM.drop(features_to_drop, axis=1).values    
y = DM['Binary_Label'].values

# %%
#Remove Nan
X = pd.DataFrame(X).dropna()
y = y[X.index]

# %%
# Applying Min-Max scaling to make X non-negative
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Encode target variable 'Class' (y)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Ridge (L2 Regularization) for feature selection
ridge = Ridge(alpha=1.0)  # You can adjust alpha for regularization strength
ridge.fit(X_scaled, y_encoded)
# Out:
# Ridge()

# %%
# Selecting non-zero coefficients
ridge_support = np.where(ridge.coef_ != 0)[0]

# Retrieve column names for the selected features
filtered_columns = DM.drop(features_to_drop, axis=1).columns
features = filtered_columns[ridge_support]

# Print the selected features with their coefficients
print("Selected features using Ridge Regularization:")
for idx in ridge_support:
    print(f"Feature {filtered_columns[idx]} with Ridge coefficient {ridge.coef_[idx]}")
# Out:
# Selected features using Ridge Regularization:
# Feature Memory_PssTotal with Ridge coefficient -0.6258456021073353
# Feature Memory_PssClean with Ridge coefficient 0.35900675894230843
# Feature Memory_SharedDirty with Ridge coefficient -0.0808241316587655
# Feature Memory_PrivateDirty with Ridge coefficient 0.002077450290305998
# Feature Memory_SharedClean with Ridge coefficient -0.8445099342829279
# Feature Memory_PrivateClean with Ridge coefficient -0.43016939504991947
# Feature Memory_HeapSize with Ridge coefficient 0.6731292057523451
# Feature Memory_HeapAlloc with Ridge coefficient 0.9650666446841517
# Feature Memory_HeapFree with Ridge coefficient -0.7811370327251895
# Feature Memory_Views with Ridge coefficient -2.007513365123763
# Feature Memory_ViewRootImpl with Ridge coefficient -0.2844566576206199
# Feature Memory_AppContexts with Ridge coefficient 3.3003909262777307
# Feature Memory_Activities with Ridge coefficient -3.3238148343307863
# Feature Memory_Assets with Ridge coefficient 0.8255974072821012
# Feature Memory_LocalBinders with Ridge coefficient -1.646134011634416
# Feature Memory_ProxyBinders with Ridge coefficient 1.4712924488228736
# Feature Memory_ParcelMemory with Ridge coefficient 1.8855755284218338
# Feature Memory_ParcelCount with Ridge coefficient 2.4974222225050204
# Feature Memory_DeathRecipients with Ridge coefficient -0.15364348613340637
# Feature Memory_OpenSSLSockets with Ridge coefficient -1.2186394932091242
# Feature Memory_WebViews with Ridge coefficient -1.4521483431940312
# Feature API_Process_android.app.ActivityManager_killBackgroundProcesses with Ridge coefficient 0.6548966883451117
# Feature API_Process_android.os.Process_killProcess with Ridge coefficient -0.031616828511982255
# Feature API_Command_java.lang.Runtime_exec with Ridge coefficient -0.11539587444717653
# Feature API_Command_java.lang.ProcessBuilder_start with Ridge coefficient 0.9853466161967473
# Feature API_JavaNativeInterface_java.lang.Runtime_load with Ridge coefficient -0.10704057578096063
# Feature API_WebView_android.webkit.WebView_loadUrl with Ridge coefficient -0.19661877571125103
# Feature API_WebView_android.webkit.WebView_loadData with Ridge coefficient 0.1707073006769844
# Feature API_WebView_android.webkit.WebView_loadDataWithBaseURL with Ridge coefficient -0.09222187875322078
# Feature API_WebView_android.webkit.WebView_addJavascriptInterface with Ridge coefficient -0.46122504713309376
# Feature API_WebView_android.webkit.WebView_evaluateJavascript with Ridge coefficient -0.8428988668267977
# Feature API_WebView_android.webkit.WebView_postUrl with Ridge coefficient 0.3793838266694883
# Feature API_WebView_android.webkit.WebView_setWebContentsDebuggingEnabled with Ridge coefficient 0.04528984241689088
# Feature API_FileIO_libcore.io.IoBridge_open with Ridge coefficient 0.4846886309043926
# Feature API_FileIO_android.content.ContextWrapper_openFileInput with Ridge coefficient -1.967691878357119
# Feature API_FileIO_android.content.ContextWrapper_openFileOutput with Ridge coefficient 2.4449342217266397
# Feature API_FileIO_android.content.ContextWrapper_deleteFile with Ridge coefficient -1.9519278848700512
# Feature API_Database_android.content.ContextWrapper_openOrCreateDatabase with Ridge coefficient -0.08942781447450576
# Feature API_Database_android.content.ContextWrapper_databaseList with Ridge coefficient -2.5449355934024003
# Feature API_Database_android.content.ContextWrapper_deleteDatabase with Ridge coefficient 0.058520151591605056
# Feature API_Database_android.database.sqlite.SQLiteDatabase_execSQL with Ridge coefficient 0.003525071350236774
# Feature API_Database_android.database.sqlite.SQLiteDatabase_deleteDatabase with Ridge coefficient 0.058520151591604896
# Feature API_Database_android.database.sqlite.SQLiteDatabase_getPath with Ridge coefficient -0.02194340747063705
# Feature API_Database_android.database.sqlite.SQLiteDatabase_insert with Ridge coefficient -0.39580177914213327
# Feature API_Database_android.database.sqlite.SQLiteDatabase_insertOrThrow with Ridge coefficient -1.70565236121581
# Feature API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict with Ridge coefficient 0.21916509054006275
# Feature API_Database_android.database.sqlite.SQLiteDatabase_openDatabase with Ridge coefficient 0.12511608360772195
# Feature API_Database_android.database.sqlite.SQLiteDatabase_openOrCreateDatabase with Ridge coefficient -0.29121592826615067
# Feature API_Database_android.database.sqlite.SQLiteDatabase_query with Ridge coefficient -0.01809235680900999
# Feature API_Database_android.database.sqlite.SQLiteDatabase_queryWithFactory with Ridge coefficient 0.12058730319321945
# Feature API_Database_android.database.sqlite.SQLiteDatabase_rawQuery with Ridge coefficient -0.39135339526194124
# Feature API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory with Ridge coefficient 0.047627661182983935
# Feature API_Database_android.database.sqlite.SQLiteDatabase_update with Ridge coefficient 0.8767238721070483
# Feature API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict with Ridge coefficient -0.265335011936272
# Feature API_Database_android.database.sqlite.SQLiteDatabase_compileStatement with Ridge coefficient 0.1448776238984775
# Feature API_IPC_android.content.ContextWrapper_sendBroadcast with Ridge coefficient 0.36023926726444333
# Feature API_IPC_android.content.ContextWrapper_sendStickyBroadcast with Ridge coefficient -0.21887595736170193
# Feature API_IPC_android.content.ContextWrapper_startActivity with Ridge coefficient -1.4935479926437414
# Feature API_IPC_android.content.ContextWrapper_startService with Ridge coefficient 0.44748776182358946
# Feature API_IPC_android.content.ContextWrapper_stopService with Ridge coefficient 0.9269682907596126
# Feature API_IPC_android.content.ContextWrapper_registerReceiver with Ridge coefficient -0.6360836484303216
# Feature API_Binder_android.app.ContextImpl_registerReceiver with Ridge coefficient -0.9082832275605863
# Feature API_Binder_android.app.ActivityThread_handleReceiver with Ridge coefficient 0.4915901443628348
# Feature API_Binder_android.app.Activity_startActivity with Ridge coefficient 0.5054331432851544
# Feature API_Crypto_javax.crypto.spec.SecretKeySpec_$init with Ridge coefficient -0.5690436094274236
# Feature API_Crypto_javax.crypto.Cipher_doFinal with Ridge coefficient 0.7428328927800015
# Feature API_Crypto-Hash_java.security.MessageDigest_digest with Ridge coefficient -0.7417075233837613
# Feature API_Crypto-Hash_java.security.MessageDigest_update with Ridge coefficient 0.6104459784473667
# Feature API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId with Ridge coefficient 0.08120519103862368
# Feature API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId with Ridge coefficient -0.07015209603276554
# Feature API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number with Ridge coefficient 0.6634002462866182
# Feature API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperator with Ridge coefficient 0.2369376431978433
# Feature API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperatorName with Ridge coefficient -0.4073153101161124
# Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName with Ridge coefficient -0.9529043362529567
# Feature API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress with Ridge coefficient 0.0802077625541528
# Feature API_DeviceInfo_android.net.wifi.WifiInfo_getBSSID with Ridge coefficient -0.24705899761552932
# Feature API_DeviceInfo_android.net.wifi.WifiInfo_getIpAddress with Ridge coefficient -0.21469377354192265
# Feature API_DeviceInfo_android.net.wifi.WifiInfo_getNetworkId with Ridge coefficient 0.38368933632490293
# Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso with Ridge coefficient -0.30008913886985816
# Feature API_DeviceInfo_android.telephony.TelephonyManager_getSimSerialNumber with Ridge coefficient -1.6086289553826885
# Feature API_DeviceInfo_android.telephony.TelephonyManager_getNetworkCountryIso with Ridge coefficient -0.30077495008422367
# Feature API_DeviceInfo_android.telephony.TelephonyManager_getDeviceSoftwareVersion with Ridge coefficient 1.0510893038130442
# Feature API_DeviceInfo_android.os.Debug_isDebuggerConnected with Ridge coefficient -1.9666516551475508
# Feature API_Network_java.net.URL_openConnection with Ridge coefficient -0.9036161946667967
# Feature API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream with Ridge coefficient -0.607819065021667
# Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResource with Ridge coefficient 0.7812777405648973
# Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResources with Ridge coefficient 0.5893675970816914
# Feature API_DexClassLoader_dalvik.system.BaseDexClassLoader_findLibrary with Ridge coefficient -0.42510327120723856
# Feature API_DexClassLoader_dalvik.system.DexFile_loadDex with Ridge coefficient 0.20228002997788805
# Feature API_DexClassLoader_dalvik.system.DexFile_loadClass with Ridge coefficient 0.7731327893254683
# Feature API_DexClassLoader_dalvik.system.DexClassLoader_$init with Ridge coefficient -1.1489420821515641
# Feature API_Base64_android.util.Base64_decode with Ridge coefficient -0.5109112534129745
# Feature API_Base64_android.util.Base64_encode with Ridge coefficient 1.2663700417643586
# Feature API_Base64_android.util.Base64_encodeToString with Ridge coefficient -0.9306063312691303
# Feature API_SystemManager_android.app.ApplicationPackageManager_setComponentEnabledSetting with Ridge coefficient 2.5876141144766556
# Feature API_SystemManager_android.app.NotificationManager_notify with Ridge coefficient -0.6627719716934698
# Feature API_SystemManager_android.telephony.TelephonyManager_listen with Ridge coefficient 1.4751188390351646
# Feature API_SystemManager_android.content.BroadcastReceiver_abortBroadcast with Ridge coefficient 2.6888178116597445
# Feature API_SMS_android.telephony.SmsManager_sendTextMessage with Ridge coefficient 0.7441722170839972
# Feature API_SMS_android.telephony.SmsManager_sendMultipartTextMessage with Ridge coefficient 1.0666920959413133
# Feature API_DeviceData_android.content.ContentResolver_query with Ridge coefficient 0.12436469476425328
# Feature API_DeviceData_android.content.ContentResolver_registerContentObserver with Ridge coefficient 1.7458474944950166
# Feature API_DeviceData_android.content.ContentResolver_insert with Ridge coefficient 0.22161656797926257
# Feature API_DeviceData_android.content.ContentResolver_delete with Ridge coefficient 1.6447102846285402
# Feature API_DeviceData_android.accounts.AccountManager_getAccountsByType with Ridge coefficient 1.365446851227182
# Feature API_DeviceData_android.accounts.AccountManager_getAccounts with Ridge coefficient 0.20921938007119853
# Feature API_DeviceData_android.location.Location_getLatitude with Ridge coefficient 0.19067908620787727
# Feature API_DeviceData_android.location.Location_getLongitude with Ridge coefficient 0.004776807364166666
# Feature API_DeviceData_android.media.AudioRecord_startRecording with Ridge coefficient 0.23921096364677072
# Feature API_DeviceData_android.media.MediaRecorder_start with Ridge coefficient -0.3583096905891619
# Feature API_DeviceData_android.os.SystemProperties_get with Ridge coefficient 1.0312193089789845
# Feature API_DeviceData_android.app.ApplicationPackageManager_getInstalledPackages with Ridge coefficient -3.24558993366093
# Feature API__sessions with Ridge coefficient -0.27856557455413017
# Feature Network_TotalReceivedPackets with Ridge coefficient 0.22082273876056469
# Feature Network_TotalTransmittedBytes with Ridge coefficient -0.3259352222717465
# Feature Network_TotalTransmittedPackets with Ridge coefficient -0.6129728619731586
# Feature Battery_wakelock with Ridge coefficient 0.1382350644101359
# Feature Battery_service with Ridge coefficient -0.38906462857928115
# Feature Logcat_debug with Ridge coefficient -0.2866435750746864
# Feature Logcat_warning with Ridge coefficient 0.14600697750934097
# Feature Logcat_info with Ridge coefficient -0.8029171574002557
# Feature Logcat_verbose with Ridge coefficient -0.4522986009819451
# Feature Logcat_error with Ridge coefficient -0.039355240068170115
# Feature Logcat_total with Ridge coefficient -0.1495249042959848
# Feature Process_total with Ridge coefficient 0.21522326659333332

# %%
# Tentukan 1% dari total dataset
total_samples = int(len(DM) * 0.01)

# Ambil sampel secara acak dari kedua kelas dengan jumlah yang seimbang
sampled_data = DM.groupby('Binary_Label').apply(lambda x: x.sample(n=int(total_samples / 2), random_state=42)).reset_index(drop=True)

# Cek distribusi kelas setelah sampling
print(sampled_data['Binary_Label'].value_counts())
# Out:
# Binary_Label
# Benign     267
# Malware    267
# Name: count, dtype: int64
# C:\Users\Muhammad Raihan\AppData\Local\Temp\ipykernel_6820\2187110322.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_data = DM.groupby('Binary_Label').apply(lambda x: x.sample(n=int(total_samples / 2), random_state=42)).reset_index(drop=True)

# %%
# Pisahkan data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
# Inisialisasi variabel untuk menyimpan hasil evaluasi
hasil_ml_dl = []
hasil_ml_dl_xai = []

# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Fungsi untuk mengevaluasi model ML/DL
def EvaluateModel(model_name, model, X_train, y_train, X_test, y_test, use_xai=False, is_dl_model=False):
    start_time = time.time()

    # Melatih model
    model.fit(X_train, y_train, epochs=5, batch_size=32, verbose=0) if is_dl_model else model.fit(X_train, y_train)
    
    if is_dl_model:
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    elif hasattr(model, 'predict_proba'):
        # Model dengan metode predict_proba
        y_pred_proba = model.predict_proba(X_test)
        if y_pred_proba.shape[1] > 1:  # Model klasifikasi multi-kelas
            y_pred = np.argmax(y_pred_proba, axis=1)
        else:  # Model klasifikasi biner
            y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    else:
        # Model tanpa metode predict_proba
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()

    # Menghitung confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

    # Menghitung metrik
    Precision = tp / (tp + fp) if (tp + fp) != 0 else 0
    Recall = tp / (tp + fn) if (tp + fn) != 0 else 0
    F1Score = 2 * ((Precision * Recall) / (Precision + Recall)) if (Precision + Recall) != 0 else 0
    Accuracy = (tp + tn) / (tp + fp + tn + fn) if (tp + fp + tn + fn) != 0 else 0

    # Menghitung waktu running
    run_time = time.time() - start_time

    # Jika XAI diperlukan, tambahkan analisis dengan SHAP
    if use_xai:
        # Periksa apakah X_train adalah DataFrame
        if isinstance(X_train, pd.DataFrame):
            feature_names = X_train.columns
        else:
            feature_names = [f"Feature_{i}" for i in range(X_train.shape[1])]
        
        # Perbaiki format X_train untuk SHAP
        if is_dl_model:
            X_train_for_xai = X_train.reshape((X_train.shape[0], X_train.shape[1]))
            X_test_for_xai = X_test.reshape((X_test.shape[0], X_test.shape[1]))
        else:
            X_train_for_xai = X_train
            X_test_for_xai = X_test

        # Gunakan SHAP
        try:
            if is_dl_model:
                explainer = shap.DeepExplainer(model, X_train_for_xai)
                shap_values = explainer.shap_values(X_test_for_xai)
                shap_summary = np.mean(shap_values[0], axis=0)
            else:
                explainer = shap.Explainer(model.predict_proba, X_train_for_xai)
                shap_values = explainer(X_test_for_xai)
                shap_summary = shap_values.values.mean(axis=0)
        except Exception as e:
            print(f"Error using SHAP with {model_name}: {e}")
            shap_summary = None

        # Simpan hasil evaluasi dengan XAI
        hasil_ml_dl_xai.append([model_name, Precision, Recall, F1Score, Accuracy, run_time, {'SHAP': shap_summary}])
    else:
        # Simpan hasil evaluasi tanpa XAI
        hasil_ml_dl.append([model_name, Precision, Recall, F1Score, Accuracy, run_time])

# Model ML dan DL yang akan dievaluasi
model_ml_dl = {
    "DecisionTree": DecisionTreeClassifier(max_depth=10),
    "RandomForest": RandomForestClassifier(n_estimators=50),
    "Logistic Regression": LogisticRegression(random_state=0, max_iter=10000),
    "Naive Bayes": GaussianNB(),
    "MLP": MLPClassifier(solver='adam', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1, max_iter=1000),
    "Stochastic Gradient Descent": SGDClassifier(loss='log_loss', random_state=42),
    "ADA Boost": AdaBoostClassifier(n_estimators=100),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "XGBoost": XGBClassifier(n_estimators=100),
    "LightGBM": LGBMClassifier(n_estimators=100),
    "CatBoost": CatBoostClassifier(iterations=100, depth=6, learning_rate=0.1, loss_function='Logloss')
}

model_dl = {
    "DNN": Sequential([
        Dense(128, input_shape=(X_train.shape[1],), activation='relu'),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "CNN": Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "RNN": Sequential([
        LSTM(100, input_shape=(X_train.shape[1], 1)),
        Dense(1, activation='sigmoid')
    ]),
}

# Pastikan X_train dan X_test memiliki bentuk yang sesuai untuk DL
X_train_dl = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_dl = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Mengevaluasi model ML tanpa XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=False)

# Mengevaluasi model DL tanpa XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=False, is_dl_model=True)

# Mengevaluasi model ML dengan XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=True)

# Mengevaluasi model DL dengan XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=True, is_dl_model=True)

# Print hasil evaluasi tanpa XAI
print("\nHasil Evaluasi ML/DL tanpa XAI:")
print(hasil_ml_dl)

# Print hasil evaluasi dengan XAI
print("\nHasil Evaluasi ML/DL dengan XAI:")
print(hasil_ml_dl_xai)

# Convert results to DataFrame and save to CSV
df_ml_dl = pd.DataFrame(hasil_ml_dl, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime"])
df_ml_dl_xai = pd.DataFrame(hasil_ml_dl_xai, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime", "XAI"])

df_ml_dl.to_csv("hasil_evaluasi_ml_dl_RFC.csv", index=False)
df_ml_dl_xai.to_csv("hasil_evaluasi_ml_dl_xai_RFC.csv", index=False)
# Out:
# [LightGBM] [Info] Number of positive: 17620, number of negative: 19787
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026981 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 14604
# [LightGBM] [Info] Number of data points in the train set: 37407, number of used features: 120
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.471035 -> initscore=-0.115991
# [LightGBM] [Info] Start training from score -0.115991
# 0:	learn: 0.6420239	total: 174ms	remaining: 17.2s
# 1:	learn: 0.5995319	total: 215ms	remaining: 10.5s
# 2:	learn: 0.5669839	total: 239ms	remaining: 7.74s
# 3:	learn: 0.5398208	total: 271ms	remaining: 6.5s
# 4:	learn: 0.5198500	total: 306ms	remaining: 5.81s
# 5:	learn: 0.5038048	total: 342ms	remaining: 5.36s
# 6:	learn: 0.4879654	total: 381ms	remaining: 5.06s
# 7:	learn: 0.4774026	total: 419ms	remaining: 4.82s
# 8:	learn: 0.4653487	total: 459ms	remaining: 4.64s
# 9:	learn: 0.4549761	total: 490ms	remaining: 4.41s
# 10:	learn: 0.4432840	total: 520ms	remaining: 4.2s
# 11:	learn: 0.4322878	total: 546ms	remaining: 4s
# 12:	learn: 0.4249601	total: 576ms	remaining: 3.86s
# 13:	learn: 0.4183419	total: 601ms	remaining: 3.69s
# 14:	learn: 0.4113348	total: 630ms	remaining: 3.57s
# 15:	learn: 0.4045004	total: 657ms	remaining: 3.45s
# 16:	learn: 0.3995319	total: 686ms	remaining: 3.35s
# 17:	learn: 0.3958343	total: 718ms	remaining: 3.27s
# 18:	learn: 0.3912057	total: 740ms	remaining: 3.15s
# 19:	learn: 0.3864993	total: 773ms	remaining: 3.09s
# 20:	learn: 0.3834897	total: 807ms	remaining: 3.04s
# 21:	learn: 0.3800269	total: 842ms	remaining: 2.99s
# 22:	learn: 0.3768345	total: 880ms	remaining: 2.95s
# 23:	learn: 0.3738125	total: 913ms	remaining: 2.89s
# 24:	learn: 0.3712601	total: 939ms	remaining: 2.82s
# 25:	learn: 0.3676301	total: 971ms	remaining: 2.76s
# 26:	learn: 0.3658416	total: 995ms	remaining: 2.69s
# 27:	learn: 0.3622808	total: 1.02s	remaining: 2.63s
# 28:	learn: 0.3602983	total: 1.04s	remaining: 2.56s
# 29:	learn: 0.3575570	total: 1.07s	remaining: 2.5s
# 30:	learn: 0.3549943	total: 1.1s	remaining: 2.45s
# 31:	learn: 0.3528909	total: 1.13s	remaining: 2.4s
# 32:	learn: 0.3499096	total: 1.16s	remaining: 2.35s
# 33:	learn: 0.3485976	total: 1.19s	remaining: 2.3s
# 34:	learn: 0.3468720	total: 1.21s	remaining: 2.25s
# 35:	learn: 0.3450585	total: 1.24s	remaining: 2.2s
# 36:	learn: 0.3437813	total: 1.27s	remaining: 2.16s
# 37:	learn: 0.3424471	total: 1.29s	remaining: 2.11s
# 38:	learn: 0.3412242	total: 1.32s	remaining: 2.06s
# 39:	learn: 0.3392428	total: 1.35s	remaining: 2.02s
# 40:	learn: 0.3377711	total: 1.37s	remaining: 1.97s
# 41:	learn: 0.3370078	total: 1.4s	remaining: 1.93s
# 42:	learn: 0.3352098	total: 1.42s	remaining: 1.89s
# 43:	learn: 0.3328733	total: 1.45s	remaining: 1.85s
# 44:	learn: 0.3315480	total: 1.48s	remaining: 1.81s
# 45:	learn: 0.3301096	total: 1.51s	remaining: 1.77s
# 46:	learn: 0.3286177	total: 1.54s	remaining: 1.74s
# 47:	learn: 0.3274465	total: 1.57s	remaining: 1.7s
# 48:	learn: 0.3263665	total: 1.6s	remaining: 1.66s
# 49:	learn: 0.3255748	total: 1.62s	remaining: 1.62s
# 50:	learn: 0.3240634	total: 1.65s	remaining: 1.58s
# 51:	learn: 0.3226468	total: 1.67s	remaining: 1.54s
# 52:	learn: 0.3213654	total: 1.7s	remaining: 1.51s
# 53:	learn: 0.3207548	total: 1.73s	remaining: 1.47s
# 54:	learn: 0.3189366	total: 1.75s	remaining: 1.44s
# 55:	learn: 0.3177566	total: 1.79s	remaining: 1.4s
# 56:	learn: 0.3158873	total: 1.82s	remaining: 1.37s
# 57:	learn: 0.3152898	total: 1.84s	remaining: 1.34s
# 58:	learn: 0.3142664	total: 1.88s	remaining: 1.3s
# 59:	learn: 0.3138721	total: 1.9s	remaining: 1.27s
# 60:	learn: 0.3125692	total: 1.93s	remaining: 1.24s
# 61:	learn: 0.3119088	total: 1.96s	remaining: 1.2s
# 62:	learn: 0.3105525	total: 1.99s	remaining: 1.17s
# 63:	learn: 0.3101485	total: 2.02s	remaining: 1.14s
# 64:	learn: 0.3092612	total: 2.05s	remaining: 1.1s
# 65:	learn: 0.3086655	total: 2.08s	remaining: 1.07s
# 66:	learn: 0.3081894	total: 2.1s	remaining: 1.03s
# 67:	learn: 0.3074578	total: 2.13s	remaining: 1s
# 68:	learn: 0.3064549	total: 2.17s	remaining: 973ms
# 69:	learn: 0.3060930	total: 2.19s	remaining: 940ms
# 70:	learn: 0.3051193	total: 2.22s	remaining: 907ms
# 71:	learn: 0.3049221	total: 2.25s	remaining: 876ms
# 72:	learn: 0.3046614	total: 2.28s	remaining: 842ms
# 73:	learn: 0.3040235	total: 2.31s	remaining: 810ms
# 74:	learn: 0.3032699	total: 2.33s	remaining: 778ms
# 75:	learn: 0.3025177	total: 2.37s	remaining: 747ms
# 76:	learn: 0.3020876	total: 2.39s	remaining: 714ms
# 77:	learn: 0.3012235	total: 2.42s	remaining: 682ms
# 78:	learn: 0.3006919	total: 2.45s	remaining: 652ms
# 79:	learn: 0.3000132	total: 2.48s	remaining: 620ms
# 80:	learn: 0.2996595	total: 2.51s	remaining: 589ms
# 81:	learn: 0.2987384	total: 2.54s	remaining: 558ms
# 82:	learn: 0.2982053	total: 2.57s	remaining: 527ms
# 83:	learn: 0.2969678	total: 2.6s	remaining: 495ms
# 84:	learn: 0.2958211	total: 2.63s	remaining: 464ms
# 85:	learn: 0.2949341	total: 2.66s	remaining: 433ms
# 86:	learn: 0.2944686	total: 2.69s	remaining: 402ms
# 87:	learn: 0.2938587	total: 2.72s	remaining: 371ms
# 88:	learn: 0.2936202	total: 2.75s	remaining: 340ms
# 89:	learn: 0.2927786	total: 2.78s	remaining: 309ms
# 90:	learn: 0.2921100	total: 2.81s	remaining: 277ms
# 91:	learn: 0.2916742	total: 2.88s	remaining: 251ms
# 92:	learn: 0.2913854	total: 2.92s	remaining: 220ms
# 93:	learn: 0.2908174	total: 2.96s	remaining: 189ms
# 94:	learn: 0.2899043	total: 2.98s	remaining: 157ms
# 95:	learn: 0.2894606	total: 3.01s	remaining: 125ms
# 96:	learn: 0.2891338	total: 3.04s	remaining: 93.9ms
# 97:	learn: 0.2877358	total: 3.06s	remaining: 62.5ms
# 98:	learn: 0.2872734	total: 3.09s	remaining: 31.2ms
# 99:	learn: 0.2869848	total: 3.12s	remaining: 0us
# 501/501 [==============================] - 1s 845us/step
# 501/501 [==============================] - 1s 2ms/step
# 501/501 [==============================] - 11s 19ms/step
# PermutationExplainer explainer: 16033it [32:33,  8.21it/s]
# PermutationExplainer explainer: 16033it [2:12:05,  2.02it/s]
# PermutationExplainer explainer: 16033it [23:43, 11.19it/s]
# PermutationExplainer explainer: 16033it [1:21:34,  3.27it/s]
# PermutationExplainer explainer: 16033it [6:14:07,  1.41s/it]
# PermutationExplainer explainer: 16033it [18:23:17,  4.13s/it]
# PermutationExplainer explainer: 16033it [1:37:28,  2.74it/s]
# PermutationExplainer explainer: 16033it [1:25:10,  3.13it/s]
# [LightGBM] [Info] Number of positive: 17620, number of negative: 19787
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 2.326357 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 14604
# [LightGBM] [Info] Number of data points in the train set: 37407, number of used features: 120
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.471035 -> initscore=-0.115991
# [LightGBM] [Info] Start training from score -0.115991
# PermutationExplainer explainer: 16033it [1:16:15,  3.49it/s]
# 0:	learn: 0.6420239	total: 1.01s	remaining: 1m 39s
# 1:	learn: 0.5995319	total: 1.85s	remaining: 1m 30s
# 2:	learn: 0.5669839	total: 2.86s	remaining: 1m 32s
# 3:	learn: 0.5398208	total: 3.88s	remaining: 1m 33s
# 4:	learn: 0.5198500	total: 4.75s	remaining: 1m 30s
# 5:	learn: 0.5038048	total: 5.84s	remaining: 1m 31s
# 6:	learn: 0.4879654	total: 6.74s	remaining: 1m 29s
# 7:	learn: 0.4774026	total: 7.99s	remaining: 1m 31s
# 8:	learn: 0.4653487	total: 8.73s	remaining: 1m 28s
# 9:	learn: 0.4549761	total: 10.1s	remaining: 1m 30s
# 10:	learn: 0.4432840	total: 11.2s	remaining: 1m 30s
# 11:	learn: 0.4322878	total: 12.1s	remaining: 1m 28s
# 12:	learn: 0.4249601	total: 13.1s	remaining: 1m 27s
# 13:	learn: 0.4183419	total: 14.1s	remaining: 1m 26s
# 14:	learn: 0.4113348	total: 15.1s	remaining: 1m 25s
# 15:	learn: 0.4045004	total: 15.9s	remaining: 1m 23s
# 16:	learn: 0.3995319	total: 16.9s	remaining: 1m 22s
# 17:	learn: 0.3958343	total: 17.8s	remaining: 1m 21s
# 18:	learn: 0.3912057	total: 18.5s	remaining: 1m 18s
# 19:	learn: 0.3864993	total: 19.4s	remaining: 1m 17s
# 20:	learn: 0.3834897	total: 20.2s	remaining: 1m 16s
# 21:	learn: 0.3800269	total: 21.4s	remaining: 1m 15s
# 22:	learn: 0.3768345	total: 22.3s	remaining: 1m 14s
# 23:	learn: 0.3738125	total: 23.1s	remaining: 1m 13s
# 24:	learn: 0.3712601	total: 24.5s	remaining: 1m 13s
# 25:	learn: 0.3676301	total: 25.8s	remaining: 1m 13s
# 26:	learn: 0.3658416	total: 26.8s	remaining: 1m 12s
# 27:	learn: 0.3622808	total: 27.6s	remaining: 1m 10s
# 28:	learn: 0.3602983	total: 28.6s	remaining: 1m 10s
# 29:	learn: 0.3575570	total: 29.9s	remaining: 1m 9s
# 30:	learn: 0.3549943	total: 30.7s	remaining: 1m 8s
# 31:	learn: 0.3528909	total: 31.7s	remaining: 1m 7s
# 32:	learn: 0.3499096	total: 32.9s	remaining: 1m 6s
# 33:	learn: 0.3485976	total: 33.9s	remaining: 1m 5s
# 34:	learn: 0.3468720	total: 34.8s	remaining: 1m 4s
# 35:	learn: 0.3450585	total: 35.8s	remaining: 1m 3s
# 36:	learn: 0.3437813	total: 36.5s	remaining: 1m 2s
# 37:	learn: 0.3424471	total: 37.5s	remaining: 1m 1s
# 38:	learn: 0.3412242	total: 38.2s	remaining: 59.7s
# 39:	learn: 0.3392428	total: 38.7s	remaining: 58.1s
# 40:	learn: 0.3377711	total: 39.5s	remaining: 56.9s
# 41:	learn: 0.3370078	total: 40.5s	remaining: 56s
# 42:	learn: 0.3352098	total: 41.3s	remaining: 54.7s
# 43:	learn: 0.3328733	total: 42.1s	remaining: 53.6s
# 44:	learn: 0.3315480	total: 43.4s	remaining: 53.1s
# 45:	learn: 0.3301096	total: 44.3s	remaining: 52s
# 46:	learn: 0.3286177	total: 45.3s	remaining: 51.1s
# 47:	learn: 0.3274465	total: 46.2s	remaining: 50s
# 48:	learn: 0.3263665	total: 47.1s	remaining: 49.1s
# 49:	learn: 0.3255748	total: 48.2s	remaining: 48.2s
# 50:	learn: 0.3240634	total: 49.1s	remaining: 47.2s
# 51:	learn: 0.3226468	total: 50s	remaining: 46.1s
# 52:	learn: 0.3213654	total: 50.7s	remaining: 45s
# 53:	learn: 0.3207548	total: 51.5s	remaining: 43.9s
# 54:	learn: 0.3189366	total: 52.4s	remaining: 42.9s
# 55:	learn: 0.3177566	total: 53.1s	remaining: 41.7s
# 56:	learn: 0.3158873	total: 54s	remaining: 40.8s
# 57:	learn: 0.3152898	total: 55s	remaining: 39.9s
# 58:	learn: 0.3142664	total: 56.2s	remaining: 39.1s
# 59:	learn: 0.3138721	total: 57.4s	remaining: 38.3s
# 60:	learn: 0.3125692	total: 58.4s	remaining: 37.4s
# 61:	learn: 0.3119088	total: 59.4s	remaining: 36.4s
# 62:	learn: 0.3105525	total: 1m	remaining: 35.4s
# 63:	learn: 0.3101485	total: 1m 1s	remaining: 34.4s
# 64:	learn: 0.3092612	total: 1m 1s	remaining: 33.4s
# 65:	learn: 0.3086655	total: 1m 3s	remaining: 32.5s
# 66:	learn: 0.3081894	total: 1m 4s	remaining: 31.5s
# 67:	learn: 0.3074578	total: 1m 4s	remaining: 30.6s
# 68:	learn: 0.3064549	total: 1m 6s	remaining: 29.7s
# 69:	learn: 0.3060930	total: 1m 6s	remaining: 28.6s
# 70:	learn: 0.3051193	total: 1m 7s	remaining: 27.7s
# 71:	learn: 0.3049221	total: 1m 8s	remaining: 26.6s
# 72:	learn: 0.3046614	total: 1m 8s	remaining: 25.5s
# 73:	learn: 0.3040235	total: 1m 9s	remaining: 24.5s
# 74:	learn: 0.3032699	total: 1m 10s	remaining: 23.6s
# 75:	learn: 0.3025177	total: 1m 11s	remaining: 22.7s
# 76:	learn: 0.3020876	total: 1m 12s	remaining: 21.7s
# 77:	learn: 0.3012235	total: 1m 13s	remaining: 20.9s
# 78:	learn: 0.3006919	total: 1m 14s	remaining: 19.9s
# 79:	learn: 0.3000132	total: 1m 15s	remaining: 19s
# 80:	learn: 0.2996595	total: 1m 16s	remaining: 18s
# 81:	learn: 0.2987384	total: 1m 17s	remaining: 17.1s
# 82:	learn: 0.2982053	total: 1m 18s	remaining: 16.1s
# 83:	learn: 0.2969678	total: 1m 19s	remaining: 15.1s
# 84:	learn: 0.2958211	total: 1m 19s	remaining: 14.1s
# 85:	learn: 0.2949341	total: 1m 20s	remaining: 13.1s
# 86:	learn: 0.2944686	total: 1m 21s	remaining: 12.2s
# 87:	learn: 0.2938587	total: 1m 22s	remaining: 11.2s
# 88:	learn: 0.2936202	total: 1m 23s	remaining: 10.3s
# 89:	learn: 0.2927786	total: 1m 23s	remaining: 9.33s
# 90:	learn: 0.2921100	total: 1m 24s	remaining: 8.37s
# 91:	learn: 0.2916742	total: 1m 25s	remaining: 7.43s
# 92:	learn: 0.2913854	total: 1m 26s	remaining: 6.51s
# 93:	learn: 0.2908174	total: 1m 27s	remaining: 5.59s
# 94:	learn: 0.2899043	total: 1m 28s	remaining: 4.66s
# 95:	learn: 0.2894606	total: 1m 29s	remaining: 3.72s
# 96:	learn: 0.2891338	total: 1m 30s	remaining: 2.79s
# 97:	learn: 0.2877358	total: 1m 31s	remaining: 1.86s
# 98:	learn: 0.2872734	total: 1m 31s	remaining: 929ms
# 99:	learn: 0.2869848	total: 1m 32s	remaining: 0us
# PermutationExplainer explainer: 16033it [6:30:02,  1.46s/it]
# 501/501 [==============================] - 1s 2ms/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# 501/501 [==============================] - 3s 7ms/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Error using SHAP with CNN: operands could not be broadcast together with shapes (37407,140,1) (37407,140)
# 501/501 [==============================] - 39s 72ms/step
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
