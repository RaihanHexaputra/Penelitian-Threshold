# %%
# Library
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import sklearn.metrics as metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from lime.lime_tabular import LimeTabularExplainer
import shap
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, LSTM, Dropout
from tensorflow.keras.losses import BinaryCrossentropy
from keras.optimizers import Adam

# %%
# Input Dataset 

DM = pd.read_parquet("C:\\Data Raihan\\Penelitian Threshold\\Dataset\\CCCS-CIC-AndMal-2020\\cicandmal2020-dynamic.parquet")#DM--> Dataset Malware

# %%
DM.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53439 entries, 0 to 53438
# Data columns (total 145 columns):
#  #    Column                                                                              Non-Null Count  Dtype
# ---   ------                                                                              --------------  -----
#  0    Memory_PssTotal                                                                     53439 non-null  int32
#  1    Memory_PssClean                                                                     53439 non-null  int32
#  2    Memory_SharedDirty                                                                  53439 non-null  int32
#  3    Memory_PrivateDirty                                                                 53439 non-null  int32
#  4    Memory_SharedClean                                                                  53439 non-null  int32
#  5    Memory_PrivateClean                                                                 53439 non-null  int32
#  6    Memory_SwapPssDirty                                                                 53439 non-null  int8
#  7    Memory_HeapSize                                                                     53439 non-null  int32
#  8    Memory_HeapAlloc                                                                    53439 non-null  int32
#  9    Memory_HeapFree                                                                     53439 non-null  int32
#  10   Memory_Views                                                                        53439 non-null  int16
#  11   Memory_ViewRootImpl                                                                 53439 non-null  int16
#  12   Memory_AppContexts                                                                  53439 non-null  int16
#  13   Memory_Activities                                                                   53439 non-null  int16
#  14   Memory_Assets                                                                       53439 non-null  int8
#  15   Memory_AssetManagers                                                                53439 non-null  int8
#  16   Memory_LocalBinders                                                                 53439 non-null  int16
#  17   Memory_ProxyBinders                                                                 53439 non-null  int16
#  18   Memory_ParcelMemory                                                                 53439 non-null  int16
#  19   Memory_ParcelCount                                                                  53439 non-null  int16
#  20   Memory_DeathRecipients                                                              53439 non-null  int8
#  21   Memory_OpenSSLSockets                                                               53439 non-null  int8
#  22   Memory_WebViews                                                                     53439 non-null  int8
#  23   API_Process_android.os.Process_start                                                53439 non-null  int8
#  24   API_Process_android.app.ActivityManager_killBackgroundProcesses                     53439 non-null  int16
#  25   API_Process_android.os.Process_killProcess                                          53439 non-null  int16
#  26   API_Command_java.lang.Runtime_exec                                                  53439 non-null  int16
#  27   API_Command_java.lang.ProcessBuilder_start                                          53439 non-null  int16
#  28   API_JavaNativeInterface_java.lang.Runtime_loadLibrary                               53439 non-null  int8
#  29   API_JavaNativeInterface_java.lang.Runtime_load                                      53439 non-null  int8
#  30   API_WebView_android.webkit.WebView_loadUrl                                          53439 non-null  int16
#  31   API_WebView_android.webkit.WebView_loadData                                         53439 non-null  int8
#  32   API_WebView_android.webkit.WebView_loadDataWithBaseURL                              53439 non-null  int16
#  33   API_WebView_android.webkit.WebView_addJavascriptInterface                           53439 non-null  int16
#  34   API_WebView_android.webkit.WebView_evaluateJavascript                               53439 non-null  int16
#  35   API_WebView_android.webkit.WebView_postUrl                                          53439 non-null  int8
#  36   API_WebView_android.webkit.WebView_postWebMessage                                   53439 non-null  int8
#  37   API_WebView_android.webkit.WebView_savePassword                                     53439 non-null  int8
#  38   API_WebView_android.webkit.WebView_setHttpAuthUsernamePassword                      53439 non-null  int8
#  39   API_WebView_android.webkit.WebView_getHttpAuthUsernamePassword                      53439 non-null  int8
#  40   API_WebView_android.webkit.WebView_setWebContentsDebuggingEnabled                   53439 non-null  int16
#  41   API_FileIO_libcore.io.IoBridge_open                                                 53439 non-null  int16
#  42   API_FileIO_android.content.ContextWrapper_openFileInput                             53439 non-null  int16
#  43   API_FileIO_android.content.ContextWrapper_openFileOutput                            53439 non-null  int16
#  44   API_FileIO_android.content.ContextWrapper_deleteFile                                53439 non-null  int8
#  45   API_Database_android.content.ContextWrapper_openOrCreateDatabase                    53439 non-null  int16
#  46   API_Database_android.content.ContextWrapper_databaseList                            53439 non-null  int8
#  47   API_Database_android.content.ContextWrapper_deleteDatabase                          53439 non-null  int8
#  48   API_Database_android.database.sqlite.SQLiteDatabase_execSQL                         53439 non-null  int16
#  49   API_Database_android.database.sqlite.SQLiteDatabase_deleteDatabase                  53439 non-null  int8
#  50   API_Database_android.database.sqlite.SQLiteDatabase_getPath                         53439 non-null  int16
#  51   API_Database_android.database.sqlite.SQLiteDatabase_insert                          53439 non-null  int16
#  52   API_Database_android.database.sqlite.SQLiteDatabase_insertOrThrow                   53439 non-null  int16
#  53   API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict            53439 non-null  int16
#  54   API_Database_android.database.sqlite.SQLiteDatabase_openDatabase                    53439 non-null  int16
#  55   API_Database_android.database.sqlite.SQLiteDatabase_openOrCreateDatabase            53439 non-null  int16
#  56   API_Database_android.database.sqlite.SQLiteDatabase_query                           53439 non-null  int16
#  57   API_Database_android.database.sqlite.SQLiteDatabase_queryWithFactory                53439 non-null  int16
#  58   API_Database_android.database.sqlite.SQLiteDatabase_rawQuery                        53439 non-null  int16
#  59   API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory             53439 non-null  int16
#  60   API_Database_android.database.sqlite.SQLiteDatabase_update                          53439 non-null  int16
#  61   API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict            53439 non-null  int16
#  62   API_Database_android.database.sqlite.SQLiteDatabase_compileStatement                53439 non-null  int16
#  63   API_Database_android.database.sqlite.SQLiteDatabase_create                          53439 non-null  int8
#  64   API_IPC_android.content.ContextWrapper_sendBroadcast                                53439 non-null  int16
#  65   API_IPC_android.content.ContextWrapper_sendStickyBroadcast                          53439 non-null  int8
#  66   API_IPC_android.content.ContextWrapper_startActivity                                53439 non-null  int16
#  67   API_IPC_android.content.ContextWrapper_startService                                 53439 non-null  int16
#  68   API_IPC_android.content.ContextWrapper_stopService                                  53439 non-null  int8
#  69   API_IPC_android.content.ContextWrapper_registerReceiver                             53439 non-null  int16
#  70   API_Binder_android.app.ContextImpl_registerReceiver                                 53439 non-null  int16
#  71   API_Binder_android.app.ActivityThread_handleReceiver                                53439 non-null  int16
#  72   API_Binder_android.app.Activity_startActivity                                       53439 non-null  int16
#  73   API_Crypto_javax.crypto.spec.SecretKeySpec_$init                                    53439 non-null  int32
#  74   API_Crypto_javax.crypto.Cipher_doFinal                                              53439 non-null  int16
#  75   API_Crypto-Hash_java.security.MessageDigest_digest                                  53439 non-null  int16
#  76   API_Crypto-Hash_java.security.MessageDigest_update                                  53439 non-null  int32
#  77   API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId                       53439 non-null  int16
#  78   API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId                   53439 non-null  int16
#  79   API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number                    53439 non-null  int16
#  80   API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperator                53439 non-null  int16
#  81   API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperatorName            53439 non-null  int16
#  82   API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName                53439 non-null  int16
#  83   API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress                              53439 non-null  int16
#  84   API_DeviceInfo_android.net.wifi.WifiInfo_getBSSID                                   53439 non-null  int16
#  85   API_DeviceInfo_android.net.wifi.WifiInfo_getIpAddress                               53439 non-null  int16
#  86   API_DeviceInfo_android.net.wifi.WifiInfo_getNetworkId                               53439 non-null  int16
#  87   API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso                  53439 non-null  int16
#  88   API_DeviceInfo_android.telephony.TelephonyManager_getSimSerialNumber                53439 non-null  int16
#  89   API_DeviceInfo_android.telephony.TelephonyManager_getNetworkCountryIso              53439 non-null  int16
#  90   API_DeviceInfo_android.telephony.TelephonyManager_getDeviceSoftwareVersion          53439 non-null  int8
#  91   API_DeviceInfo_android.os.Debug_isDebuggerConnected                                 53439 non-null  int16
#  92   API_DeviceInfo_android.content.pm.PackageManager_getInstallerPackageName            53439 non-null  int8
#  93   API_DeviceInfo_android.content.pm.PackageManager_getInstalledApplications           53439 non-null  int8
#  94   API_DeviceInfo_android.content.pm.PackageManager_getInstalledModules                53439 non-null  int8
#  95   API_DeviceInfo_android.content.pm.PackageManager_getInstalledPackages               53439 non-null  int8
#  96   API_Network_java.net.URL_openConnection                                             53439 non-null  int16
#  97   API_Network_org.apache.http.impl.client.AbstractHttpClient_execute                  53439 non-null  int8
#  98   API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream    53439 non-null  int16
#  99   API_Network_com.android.okhttp.internal.http.HttpURLConnectionImpl_getInputStream   53439 non-null  int8
#  100  API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResource                    53439 non-null  int16
#  101  API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResources                   53439 non-null  int8
#  102  API_DexClassLoader_dalvik.system.BaseDexClassLoader_findLibrary                     53439 non-null  int16
#  103  API_DexClassLoader_dalvik.system.DexFile_loadDex                                    53439 non-null  int8
#  104  API_DexClassLoader_dalvik.system.DexFile_loadClass                                  53439 non-null  int16
#  105  API_DexClassLoader_dalvik.system.DexClassLoader_$init                               53439 non-null  int16
#  106  API_Base64_android.util.Base64_decode                                               53439 non-null  int16
#  107  API_Base64_android.util.Base64_encode                                               53439 non-null  int16
#  108  API_Base64_android.util.Base64_encodeToString                                       53439 non-null  int16
#  109  API_SystemManager_android.app.ApplicationPackageManager_setComponentEnabledSetting  53439 non-null  int16
#  110  API_SystemManager_android.app.NotificationManager_notify                            53439 non-null  int16
#  111  API_SystemManager_android.telephony.TelephonyManager_listen                         53439 non-null  int8
#  112  API_SystemManager_android.content.BroadcastReceiver_abortBroadcast                  53439 non-null  int8
#  113  API_SMS_android.telephony.SmsManager_sendTextMessage                                53439 non-null  int16
#  114  API_SMS_android.telephony.SmsManager_sendMultipartTextMessage                       53439 non-null  int8
#  115  API_DeviceData_android.content.ContentResolver_query                                53439 non-null  int16
#  116  API_DeviceData_android.content.ContentResolver_registerContentObserver              53439 non-null  int16
#  117  API_DeviceData_android.content.ContentResolver_insert                               53439 non-null  int16
#  118  API_DeviceData_android.content.ContentResolver_delete                               53439 non-null  int16
#  119  API_DeviceData_android.accounts.AccountManager_getAccountsByType                    53439 non-null  int8
#  120  API_DeviceData_android.accounts.AccountManager_getAccounts                          53439 non-null  int16
#  121  API_DeviceData_android.location.Location_getLatitude                                53439 non-null  int16
#  122  API_DeviceData_android.location.Location_getLongitude                               53439 non-null  int16
#  123  API_DeviceData_android.media.AudioRecord_startRecording                             53439 non-null  int16
#  124  API_DeviceData_android.media.MediaRecorder_start                                    53439 non-null  int8
#  125  API_DeviceData_android.os.SystemProperties_get                                      53439 non-null  int16
#  126  API_DeviceData_android.app.ApplicationPackageManager_getInstalledPackages           53439 non-null  int16
#  127  API__sessions                                                                       53439 non-null  int8
#  128  Network_TotalReceivedBytes                                                          53439 non-null  int32
#  129  Network_TotalReceivedPackets                                                        53439 non-null  int32
#  130  Network_TotalTransmittedBytes                                                       53439 non-null  int32
#  131  Network_TotalTransmittedPackets                                                     53439 non-null  int32
#  132  Battery_wakelock                                                                    53439 non-null  int8
#  133  Battery_service                                                                     53439 non-null  int8
#  134  Logcat_debug                                                                        53439 non-null  int32
#  135  Logcat_warning                                                                      53439 non-null  int32
#  136  Logcat_info                                                                         53439 non-null  int32
#  137  Logcat_verbose                                                                      53439 non-null  int32
#  138  Logcat_error                                                                        53439 non-null  int32
#  139  Logcat_total                                                                        53439 non-null  int32
#  140  Process_total                                                                       53439 non-null  int16
#  141  Hash                                                                                53439 non-null  object
#  142  Category                                                                            53439 non-null  object
#  143  Family                                                                              53439 non-null  object
#  144  Label                                                                               53439 non-null  object
# dtypes: int16(81), int32(21), int8(39), object(4)
# memory usage: 16.2+ MB

# %%
# Menampilkan nilai unik pada kolom Category, Family, dan Label
unique_category = DM['Category'].unique()
unique_family = DM['Family'].unique()
unique_label = DM['Label'].unique()

print("Unique Categories:", unique_category)
print("Unique Families:", unique_family)
print("Unique Labels:", unique_label)
# Out:
# Unique Categories: ['Trojan_Spy' 'FileInfector' 'Zero_Day' 'Backdoor' 'Ransomware'
#  'No_Category' 'Trojan_SMS' 'Trojan_Dropper' 'Trojan_Banker' 'Scareware'
#  'PUA' 'Adware' 'Riskware' 'Trojan']
# Unique Families: ['smsthief' 'sandr' 'smforw' ... 'pesabti' 'mycompany' 'koomer']
# Unique Labels: ['Trojan_Spy_before_reboot_Cat' 'FileInfector_after_reboot_Cat'
#  'Zero_Day_after_reboot_Cat' 'Trojan_Spy_after_reboot_Cat'
#  'Backdoor_before_reboot_Cat' 'Ransomware_after_reboot_Cat'
#  'Ransomware_before_reboot_Cat' 'No_Category_before_reboot_Cat'
#  'Trojan_SMS_after_reboot_Cat' 'Zero_Day_before_reboot_Cat'
#  'Backdoor_after_reboot_Cat' 'Trojan_Dropper_after_reboot_Cat'
#  'Trojan_Banker_after_reboot_Cat' 'Scareware_before_reboot_Cat'
#  'PUA_after_reboot_Cat' 'Scareware_after_reboot_Cat'
#  'PUA_before_reboot_Cat' 'Adware_before_reboot_Cat'
#  'Riskware_before_reboot_Cat' 'Riskware_after_reboot_Cat'
#  'Trojan_Banker_before_reboot_Cat' 'Trojan_SMS_before_reboot_Cat'
#  'FileInfector_before_reboot_Cat' 'Trojan_before_reboot_Cat'
#  'Trojan_after_reboot_Cat' 'Adware_after_reboot_Cat'
#  'No_Category_after_reboot_Cat' 'Trojan_Dropper_before_reboot_Cat']

# %%
# Definisikan kategori benign dan malware
benign_categories = ['Adware', 'Riskware', 'PUA', 'No_Category']
malware_categories = ['Trojan_Spy', 'FileInfector', 'Zero_Day', 'Backdoor', 
                      'Ransomware', 'Trojan_SMS', 'Trojan_Dropper', 'Trojan_Banker', 
                      'Scareware', 'Trojan']

# Relabeling ke dalam kelas binari: 'Benign' dan 'Malware'
DM['Binary_Label'] = DM['Category'].apply(lambda x: 'Benign' if x in benign_categories else 'Malware')

# Cek hasil unique Binary_Label setelah relabeling
unique_binary_labels = DM['Binary_Label'].unique()
print("Unique Binary Labels after relabeling:", unique_binary_labels)
# Out:
# Unique Binary Labels after relabeling: ['Malware' 'Benign']

# %%
#Feature Selection
features = DM.drop(['Hash', 'Category', 'Family', 'Label', 'Network_TotalReceivedBytes', 'Network_TotalReceivedPackets', 'Binary_Label'],axis=1).columns.tolist()
# Target variable
y = DM['Binary_Label'].values

# %%
# Tentukan 1% dari total dataset
total_samples = int(len(DM) * 0.01)

# Ambil sampel secara acak dari kedua kelas dengan jumlah yang seimbang
sampled_data = DM.groupby('Binary_Label').apply(lambda x: x.sample(n=int(total_samples / 2), random_state=42)).reset_index(drop=True)

# Cek distribusi kelas setelah sampling
print(sampled_data['Binary_Label'].value_counts())
# Out:
# Binary_Label
# Benign     267
# Malware    267
# Name: count, dtype: int64
# C:\Users\Muhammad Raihan\AppData\Local\Temp\ipykernel_17292\2187110322.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_data = DM.groupby('Binary_Label').apply(lambda x: x.sample(n=int(total_samples / 2), random_state=42)).reset_index(drop=True)

# %%
for i, column_name in enumerate(features):
    print(f"{i+1:3} {column_name:40} {sampled_data[column_name].count():<15} {sampled_data[column_name].dtype}")
# Out:
#   1 Memory_PssTotal                          534             int32
#   2 Memory_PssClean                          534             int32
#   3 Memory_SharedDirty                       534             int32
#   4 Memory_PrivateDirty                      534             int32
#   5 Memory_SharedClean                       534             int32
#   6 Memory_PrivateClean                      534             int32
#   7 Memory_SwapPssDirty                      534             int8
#   8 Memory_HeapSize                          534             int32
#   9 Memory_HeapAlloc                         534             int32
#  10 Memory_HeapFree                          534             int32
#  11 Memory_Views                             534             int16
#  12 Memory_ViewRootImpl                      534             int16
#  13 Memory_AppContexts                       534             int16
#  14 Memory_Activities                        534             int16
#  15 Memory_Assets                            534             int8
#  16 Memory_AssetManagers                     534             int8
#  17 Memory_LocalBinders                      534             int16
#  18 Memory_ProxyBinders                      534             int16
#  19 Memory_ParcelMemory                      534             int16
#  20 Memory_ParcelCount                       534             int16
#  21 Memory_DeathRecipients                   534             int8
#  22 Memory_OpenSSLSockets                    534             int8
#  23 Memory_WebViews                          534             int8
#  24 API_Process_android.os.Process_start     534             int8
#  25 API_Process_android.app.ActivityManager_killBackgroundProcesses 534             int16
#  26 API_Process_android.os.Process_killProcess 534             int16
#  27 API_Command_java.lang.Runtime_exec       534             int16
#  28 API_Command_java.lang.ProcessBuilder_start 534             int16
#  29 API_JavaNativeInterface_java.lang.Runtime_loadLibrary 534             int8
#  30 API_JavaNativeInterface_java.lang.Runtime_load 534             int8
#  31 API_WebView_android.webkit.WebView_loadUrl 534             int16
#  32 API_WebView_android.webkit.WebView_loadData 534             int8
#  33 API_WebView_android.webkit.WebView_loadDataWithBaseURL 534             int16
#  34 API_WebView_android.webkit.WebView_addJavascriptInterface 534             int16
#  35 API_WebView_android.webkit.WebView_evaluateJavascript 534             int16
#  36 API_WebView_android.webkit.WebView_postUrl 534             int8
#  37 API_WebView_android.webkit.WebView_postWebMessage 534             int8
#  38 API_WebView_android.webkit.WebView_savePassword 534             int8
#  39 API_WebView_android.webkit.WebView_setHttpAuthUsernamePassword 534             int8
#  40 API_WebView_android.webkit.WebView_getHttpAuthUsernamePassword 534             int8
#  41 API_WebView_android.webkit.WebView_setWebContentsDebuggingEnabled 534             int16
#  42 API_FileIO_libcore.io.IoBridge_open      534             int16
#  43 API_FileIO_android.content.ContextWrapper_openFileInput 534             int16
#  44 API_FileIO_android.content.ContextWrapper_openFileOutput 534             int16
#  45 API_FileIO_android.content.ContextWrapper_deleteFile 534             int8
#  46 API_Database_android.content.ContextWrapper_openOrCreateDatabase 534             int16
#  47 API_Database_android.content.ContextWrapper_databaseList 534             int8
#  48 API_Database_android.content.ContextWrapper_deleteDatabase 534             int8
#  49 API_Database_android.database.sqlite.SQLiteDatabase_execSQL 534             int16
#  50 API_Database_android.database.sqlite.SQLiteDatabase_deleteDatabase 534             int8
#  51 API_Database_android.database.sqlite.SQLiteDatabase_getPath 534             int16
#  52 API_Database_android.database.sqlite.SQLiteDatabase_insert 534             int16
#  53 API_Database_android.database.sqlite.SQLiteDatabase_insertOrThrow 534             int16
#  54 API_Database_android.database.sqlite.SQLiteDatabase_insertWithOnConflict 534             int16
#  55 API_Database_android.database.sqlite.SQLiteDatabase_openDatabase 534             int16
#  56 API_Database_android.database.sqlite.SQLiteDatabase_openOrCreateDatabase 534             int16
#  57 API_Database_android.database.sqlite.SQLiteDatabase_query 534             int16
#  58 API_Database_android.database.sqlite.SQLiteDatabase_queryWithFactory 534             int16
#  59 API_Database_android.database.sqlite.SQLiteDatabase_rawQuery 534             int16
#  60 API_Database_android.database.sqlite.SQLiteDatabase_rawQueryWithFactory 534             int16
#  61 API_Database_android.database.sqlite.SQLiteDatabase_update 534             int16
#  62 API_Database_android.database.sqlite.SQLiteDatabase_updateWithOnConflict 534             int16
#  63 API_Database_android.database.sqlite.SQLiteDatabase_compileStatement 534             int16
#  64 API_Database_android.database.sqlite.SQLiteDatabase_create 534             int8
#  65 API_IPC_android.content.ContextWrapper_sendBroadcast 534             int16
#  66 API_IPC_android.content.ContextWrapper_sendStickyBroadcast 534             int8
#  67 API_IPC_android.content.ContextWrapper_startActivity 534             int16
#  68 API_IPC_android.content.ContextWrapper_startService 534             int16
#  69 API_IPC_android.content.ContextWrapper_stopService 534             int8
#  70 API_IPC_android.content.ContextWrapper_registerReceiver 534             int16
#  71 API_Binder_android.app.ContextImpl_registerReceiver 534             int16
#  72 API_Binder_android.app.ActivityThread_handleReceiver 534             int16
#  73 API_Binder_android.app.Activity_startActivity 534             int16
#  74 API_Crypto_javax.crypto.spec.SecretKeySpec_$init 534             int32
#  75 API_Crypto_javax.crypto.Cipher_doFinal   534             int16
#  76 API_Crypto-Hash_java.security.MessageDigest_digest 534             int16
#  77 API_Crypto-Hash_java.security.MessageDigest_update 534             int32
#  78 API_DeviceInfo_android.telephony.TelephonyManager_getDeviceId 534             int16
#  79 API_DeviceInfo_android.telephony.TelephonyManager_getSubscriberId 534             int16
#  80 API_DeviceInfo_android.telephony.TelephonyManager_getLine1Number 534             int16
#  81 API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperator 534             int16
#  82 API_DeviceInfo_android.telephony.TelephonyManager_getNetworkOperatorName 534             int16
#  83 API_DeviceInfo_android.telephony.TelephonyManager_getSimOperatorName 534             int16
#  84 API_DeviceInfo_android.net.wifi.WifiInfo_getMacAddress 534             int16
#  85 API_DeviceInfo_android.net.wifi.WifiInfo_getBSSID 534             int16
#  86 API_DeviceInfo_android.net.wifi.WifiInfo_getIpAddress 534             int16
#  87 API_DeviceInfo_android.net.wifi.WifiInfo_getNetworkId 534             int16
#  88 API_DeviceInfo_android.telephony.TelephonyManager_getSimCountryIso 534             int16
#  89 API_DeviceInfo_android.telephony.TelephonyManager_getSimSerialNumber 534             int16
#  90 API_DeviceInfo_android.telephony.TelephonyManager_getNetworkCountryIso 534             int16
#  91 API_DeviceInfo_android.telephony.TelephonyManager_getDeviceSoftwareVersion 534             int8
#  92 API_DeviceInfo_android.os.Debug_isDebuggerConnected 534             int16
#  93 API_DeviceInfo_android.content.pm.PackageManager_getInstallerPackageName 534             int8
#  94 API_DeviceInfo_android.content.pm.PackageManager_getInstalledApplications 534             int8
#  95 API_DeviceInfo_android.content.pm.PackageManager_getInstalledModules 534             int8
#  96 API_DeviceInfo_android.content.pm.PackageManager_getInstalledPackages 534             int8
#  97 API_Network_java.net.URL_openConnection  534             int16
#  98 API_Network_org.apache.http.impl.client.AbstractHttpClient_execute 534             int8
#  99 API_Network_com.android.okhttp.internal.huc.HttpURLConnectionImpl_getInputStream 534             int16
# 100 API_Network_com.android.okhttp.internal.http.HttpURLConnectionImpl_getInputStream 534             int8
# 101 API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResource 534             int16
# 102 API_DexClassLoader_dalvik.system.BaseDexClassLoader_findResources 534             int8
# 103 API_DexClassLoader_dalvik.system.BaseDexClassLoader_findLibrary 534             int16
# 104 API_DexClassLoader_dalvik.system.DexFile_loadDex 534             int8
# 105 API_DexClassLoader_dalvik.system.DexFile_loadClass 534             int16
# 106 API_DexClassLoader_dalvik.system.DexClassLoader_$init 534             int16
# 107 API_Base64_android.util.Base64_decode    534             int16
# 108 API_Base64_android.util.Base64_encode    534             int16
# 109 API_Base64_android.util.Base64_encodeToString 534             int16
# 110 API_SystemManager_android.app.ApplicationPackageManager_setComponentEnabledSetting 534             int16
# 111 API_SystemManager_android.app.NotificationManager_notify 534             int16
# 112 API_SystemManager_android.telephony.TelephonyManager_listen 534             int8
# 113 API_SystemManager_android.content.BroadcastReceiver_abortBroadcast 534             int8
# 114 API_SMS_android.telephony.SmsManager_sendTextMessage 534             int16
# 115 API_SMS_android.telephony.SmsManager_sendMultipartTextMessage 534             int8
# 116 API_DeviceData_android.content.ContentResolver_query 534             int16
# 117 API_DeviceData_android.content.ContentResolver_registerContentObserver 534             int16
# 118 API_DeviceData_android.content.ContentResolver_insert 534             int16
# 119 API_DeviceData_android.content.ContentResolver_delete 534             int16
# 120 API_DeviceData_android.accounts.AccountManager_getAccountsByType 534             int8
# 121 API_DeviceData_android.accounts.AccountManager_getAccounts 534             int16
# 122 API_DeviceData_android.location.Location_getLatitude 534             int16
# 123 API_DeviceData_android.location.Location_getLongitude 534             int16
# 124 API_DeviceData_android.media.AudioRecord_startRecording 534             int16
# 125 API_DeviceData_android.media.MediaRecorder_start 534             int8
# 126 API_DeviceData_android.os.SystemProperties_get 534             int16
# 127 API_DeviceData_android.app.ApplicationPackageManager_getInstalledPackages 534             int16
# 128 API__sessions                            534             int8
# 129 Network_TotalTransmittedBytes            534             int32
# 130 Network_TotalTransmittedPackets          534             int32
# 131 Battery_wakelock                         534             int8
# 132 Battery_service                          534             int8
# 133 Logcat_debug                             534             int32
# 134 Logcat_warning                           534             int32
# 135 Logcat_info                              534             int32
# 136 Logcat_verbose                           534             int32
# 137 Logcat_error                             534             int32
# 138 Logcat_total                             534             int32
# 139 Process_total                            534             int16

# %%
# Pisahkan data menjadi fitur (X) dan target (y)
X = sampled_data[features]
y = sampled_data['Binary_Label']

# Split data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Membuat imputer untuk menggantikan NaN dengan rata-rata
imputer = SimpleImputer(strategy='mean')

# Menangani missing values pada X_train dan X_test
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

# %%
# Gabungkan semua label
all_labels = np.concatenate([y_train, y_test])

# Inisialisasi LabelEncoder
label_encoder = LabelEncoder()

# Fit encoder pada gabungan label
label_encoder.fit(all_labels)

# Transform data
y_train_encoded = label_encoder.transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Cek label yang ada di y_train dan y_test
train_labels = set(label_encoder.classes_)
test_labels = set(y_test)

# Menampilkan label yang tidak ada di y_train
missing_labels = test_labels - train_labels
if missing_labels:
    print(f"Labels in y_test that are not in y_train: {missing_labels}")
else:
    print("All labels in y_test are present in y_train.")
# Out:
# All labels in y_test are present in y_train.

# %%
# Inisialisasi variabel untuk menyimpan hasil evaluasi
hasil_ml_dl = []
hasil_ml_dl_xai = []

# Encode labels ke bentuk numerik jika diperlukan
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Fungsi untuk mengevaluasi model ML/DL
def EvaluateModel(model_name, model, X_train, y_train, X_test, y_test, use_xai=False, is_dl_model=False):
    start_time = time.time()

    # Melatih model
    model.fit(X_train, y_train, epochs=5, batch_size=32, verbose=0) if is_dl_model else model.fit(X_train, y_train)
    
    if is_dl_model:
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    elif hasattr(model, 'predict_proba'):
        # Model dengan metode predict_proba
        y_pred_proba = model.predict_proba(X_test)
        if y_pred_proba.shape[1] > 1:  # Model klasifikasi multi-kelas
            y_pred = np.argmax(y_pred_proba, axis=1)
        else:  # Model klasifikasi biner
            y_pred = (y_pred_proba > 0.5).astype(int).ravel()
    else:
        # Model tanpa metode predict_proba
        y_pred_proba = model.predict(X_test)
        y_pred = (y_pred_proba > 0.5).astype(int).ravel()

    # Menghitung confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

    # Menghitung metrik
    Precision = tp / (tp + fp) if (tp + fp) != 0 else 0
    Recall = tp / (tp + fn) if (tp + fn) != 0 else 0
    F1Score = 2 * ((Precision * Recall) / (Precision + Recall)) if (Precision + Recall) != 0 else 0
    Accuracy = (tp + tn) / (tp + fp + tn + fn) if (tp + fp + tn + fn) != 0 else 0

    # Menghitung waktu running
    run_time = time.time() - start_time

    # Jika XAI diperlukan, tambahkan analisis dengan SHAP
    if use_xai:
        # Periksa apakah X_train adalah DataFrame
        if isinstance(X_train, pd.DataFrame):
            feature_names = X_train.columns
        else:
            feature_names = [f"Feature_{i}" for i in range(X_train.shape[1])]
        
        # Perbaiki format X_train untuk SHAP
        if is_dl_model:
            X_train_for_xai = X_train.reshape((X_train.shape[0], X_train.shape[1]))
            X_test_for_xai = X_test.reshape((X_test.shape[0], X_test.shape[1]))
        else:
            X_train_for_xai = X_train
            X_test_for_xai = X_test

        # Gunakan SHAP
        try:
            if is_dl_model:
                explainer = shap.DeepExplainer(model, X_train_for_xai)
                shap_values = explainer.shap_values(X_test_for_xai)
                shap_summary = np.mean(shap_values[0], axis=0)
            else:
                explainer = shap.Explainer(model.predict_proba, X_train_for_xai)
                shap_values = explainer(X_test_for_xai)
                shap_summary = shap_values.values.mean(axis=0)
        except Exception as e:
            print(f"Error using SHAP with {model_name}: {e}")
            shap_summary = None

        # Simpan hasil evaluasi dengan XAI
        hasil_ml_dl_xai.append([model_name, Precision, Recall, F1Score, Accuracy, run_time, {'SHAP': shap_summary}])
    else:
        # Simpan hasil evaluasi tanpa XAI
        hasil_ml_dl.append([model_name, Precision, Recall, F1Score, Accuracy, run_time])

# Model ML dan DL yang akan dievaluasi
model_ml_dl = {
    "DecisionTree": DecisionTreeClassifier(max_depth=10),
    "RandomForest": RandomForestClassifier(n_estimators=50),
    "Logistic Regression": LogisticRegression(random_state=0, max_iter=10000),
    "Naive Bayes": GaussianNB(),
    "MLP": MLPClassifier(solver='adam', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1, max_iter=1000),
    "Stochastic Gradient Descent": SGDClassifier(loss='log_loss', random_state=42),
    "ADA Boost": AdaBoostClassifier(n_estimators=100),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "XGBoost": XGBClassifier(n_estimators=100),
    "LightGBM": LGBMClassifier(n_estimators=100),
    "CatBoost": CatBoostClassifier(iterations=100, depth=6, learning_rate=0.1, loss_function='Logloss')
}

model_dl = {
    "DNN": Sequential([
        Dense(128, input_shape=(X_train.shape[1],), activation='relu'),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "CNN": Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "RNN": Sequential([
        LSTM(100, input_shape=(X_train.shape[1], 1)),
        Dense(1, activation='sigmoid')
    ]),
}

# Pastikan X_train dan X_test memiliki bentuk yang sesuai untuk DL
X_train_dl = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_dl = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Mengevaluasi model ML tanpa XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=False)

# Mengevaluasi model DL tanpa XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=False, is_dl_model=True)

# Mengevaluasi model ML dengan XAI
for model_name, model in model_ml_dl.items():
    EvaluateModel(model_name, model, X_train, y_train_encoded, X_test, y_test_encoded, use_xai=True)

# Mengevaluasi model DL dengan XAI
for model_name, model in model_dl.items():
    model.compile(optimizer='adam', loss=BinaryCrossentropy(), metrics=['accuracy'])
    EvaluateModel(model_name, model, X_train_dl, y_train_encoded, X_test_dl, y_test_encoded, use_xai=True, is_dl_model=True)

# Print hasil evaluasi tanpa XAI
print("\nHasil Evaluasi ML/DL tanpa XAI:")
print(hasil_ml_dl)

# Print hasil evaluasi dengan XAI
print("\nHasil Evaluasi ML/DL dengan XAI:")
print(hasil_ml_dl_xai)

# Convert results to DataFrame and save to CSV
df_ml_dl = pd.DataFrame(hasil_ml_dl, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime"])
df_ml_dl_xai = pd.DataFrame(hasil_ml_dl_xai, columns=["Model", "Precision", "Recall", "F1Score", "Accuracy", "RunTime", "XAI"])

df_ml_dl.to_csv("hasil_evaluasi_ml_dl_BF.csv", index=False)
df_ml_dl_xai.to_csv("hasil_evaluasi_ml_dl_xai_BF.csv", index=False)
# Out:
# C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [LightGBM] [Info] Number of positive: 185, number of negative: 188
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000328 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3541
# [LightGBM] [Info] Number of data points in the train set: 373, number of used features: 86
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.495979 -> initscore=-0.016086
# [LightGBM] [Info] Start training from score -0.016086
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 0:	learn: 0.6564064	total: 137ms	remaining: 13.6s
# 1:	learn: 0.6222528	total: 140ms	remaining: 6.84s
# 2:	learn: 0.5987228	total: 142ms	remaining: 4.6s
# 3:	learn: 0.5758995	total: 145ms	remaining: 3.48s
# 4:	learn: 0.5524841	total: 148ms	remaining: 2.81s
# 5:	learn: 0.5334939	total: 151ms	remaining: 2.36s
# 6:	learn: 0.5035752	total: 154ms	remaining: 2.04s
# 7:	learn: 0.4904400	total: 157ms	remaining: 1.81s
# 8:	learn: 0.4793135	total: 161ms	remaining: 1.63s
# 9:	learn: 0.4627931	total: 164ms	remaining: 1.48s
# 10:	learn: 0.4476481	total: 167ms	remaining: 1.35s
# 11:	learn: 0.4348368	total: 170ms	remaining: 1.25s
# 12:	learn: 0.4226281	total: 173ms	remaining: 1.16s
# 13:	learn: 0.4117943	total: 176ms	remaining: 1.08s
# 14:	learn: 0.3995265	total: 179ms	remaining: 1.01s
# 15:	learn: 0.3903862	total: 182ms	remaining: 958ms
# 16:	learn: 0.3809009	total: 185ms	remaining: 905ms
# 17:	learn: 0.3731086	total: 188ms	remaining: 858ms
# 18:	learn: 0.3658266	total: 192ms	remaining: 819ms
# 19:	learn: 0.3574337	total: 196ms	remaining: 782ms
# 20:	learn: 0.3525771	total: 199ms	remaining: 749ms
# 21:	learn: 0.3441234	total: 202ms	remaining: 718ms
# 22:	learn: 0.3368693	total: 206ms	remaining: 690ms
# 23:	learn: 0.3315955	total: 209ms	remaining: 663ms
# 24:	learn: 0.3239740	total: 212ms	remaining: 636ms
# 25:	learn: 0.3173607	total: 215ms	remaining: 613ms
# 26:	learn: 0.3101963	total: 219ms	remaining: 591ms
# 27:	learn: 0.3027234	total: 222ms	remaining: 570ms
# 28:	learn: 0.2992337	total: 225ms	remaining: 550ms
# 29:	learn: 0.2979721	total: 228ms	remaining: 532ms
# 30:	learn: 0.2931142	total: 231ms	remaining: 513ms

#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler  **
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 371, in custom_grad
#         out = op_handlers[type_name](self, op, *grads) # we cut off the shap_ prefix before the lookup
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 663, in handler
#         return linearity_with_excluded_handler(input_inds, explainer, op, *grads)
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 670, in linearity_with_excluded_handler
#         assert not explainer._variable_inputs(op)[i], str(i) + "th input to " + op.name + " cannot vary!"
#     File "C:\Users\Muhammad Raihan\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 222, in _variable_inputs
#         out[i] = t.name in self.between_tensors
#
#     AttributeError: Exception encountered when calling layer 'lstm' (type LSTM).
#
#     'TFDeep' object has no attribute 'between_tensors'
#
#     Call arguments received by layer 'lstm' (type LSTM):
#       • inputs=tf.Tensor(shape=(746, 139, 1), dtype=float32)
#       • mask=None
#       • training=False
#       • initial_state=None
#
#
# Hasil Evaluasi ML/DL tanpa XAI:
# [['DecisionTree', 0.7285714285714285, 0.6219512195121951, 0.6710526315789473, 0.6894409937888198, 0.01259613037109375], ['RandomForest', 0.8395061728395061, 0.8292682926829268, 0.8343558282208587, 0.8322981366459627, 0.08316755294799805], ['Logistic Regression', 0.7375, 0.7195121951219512, 0.7283950617283951, 0.7267080745341615, 2.672823905944824], ['Naive Bayes', 0.6533333333333333, 0.5975609756097561, 0.6242038216560509, 0.6335403726708074, 0.002009868621826172], ['MLP', 0.5093167701863354, 1.0, 0.6748971193415638, 0.5093167701863354, 0.43357205390930176], ['Stochastic Gradient Descent', 0.5359477124183006, 1.0, 0.6978723404255319, 0.5590062111801242, 0.004001140594482422], ['ADA Boost', 0.7888888888888889, 0.8658536585365854, 0.8255813953488372, 0.8136645962732919, 0.2930142879486084], ['Gradient Boosting', 0.7926829268292683, 0.7926829268292683, 0.7926829268292683, 0.7888198757763976, 0.8018262386322021], ['XGBoost', 0.7777777777777778, 0.7682926829268293, 0.773006134969325, 0.7701863354037267, 1.3386802673339844], ['LightGBM', 0.8271604938271605, 0.8170731707317073, 0.8220858895705522, 0.8198757763975155, 0.14994215965270996], ['CatBoost', 0.8117647058823529, 0.8414634146341463, 0.8263473053892215, 0.8198757763975155, 0.5027647018432617], ['DNN', 0.48717948717948717, 0.4634146341463415, 0.47500000000000003, 0.4782608695652174, 0.9588446617126465], ['CNN', 0.6385542168674698, 0.6463414634146342, 0.6424242424242423, 0.6335403726708074, 0.957688570022583], ['RNN', 0.7931034482758621, 0.5609756097560976, 0.6571428571428573, 0.7018633540372671, 4.662092924118042]]
#
# Hasil Evaluasi ML/DL dengan XAI:
# [['DecisionTree', 0.7428571428571429, 0.6341463414634146, 0.6842105263157895, 0.7018633540372671, 0.013004302978515625, {'SHAP': array([[ 0.        ,  0.        ],
#        [ 0.00406832, -0.00406832],
#        [ 0.00042702, -0.00042702],
#        [-0.01700311,  0.01700311],
#        [ 0.00423913, -0.00423913],
#        [ 0.01194099, -0.01194099],
#        [ 0.        ,  0.        ],
#        [ 0.        ,  0.        ],
#        [ 0.        ,  0.        ],
#        [ 0.